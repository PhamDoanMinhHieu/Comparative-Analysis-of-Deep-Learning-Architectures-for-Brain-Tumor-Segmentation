# %% [markdown]
# ## **1. Importing required libraries**

# %%
import os
import cv2
import time
import numpy as np
import pandas as pd
from glob import glob
from tqdm import tqdm
import numpy as np 
import cv2 as cv
import zipfile
import io
import requests
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW, lr_scheduler
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
from sklearn.impute import SimpleImputer
# import albumentations
from sklearn.model_selection import train_test_split
from scipy.ndimage.morphology import binary_dilation
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, models, transforms
import torchvision.transforms.functional as TF
from torchvision.utils import make_grid
from datetime import datetime
from enum import Enum
import math
# import hdf5storage
import h5py
from typing import Dict, List, Tuple, Optional, Union

from PIL import Image

# You can use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass

warnings.warn = warn
warnings.filterwarnings('ignore')
# Out:
# /tmp/ipykernel_19/368343941.py:23: DeprecationWarning: Please import `binary_dilation` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.morphology import binary_dilation

# %%
class Config:
    def __init__(self):
        # Dataset and DataLoader Parameters
        self.IMG_SIZE = (256, 256)
        self.BATCH_SIZE = 16
        self.TRAIN_RATIO = 0.8
        self.TEST_RATIO = 0.2

        # Training Parameters
        self.EPOCHS = 150
        self.LEARNING_RATE = 1e-3
        self.WEIGHT_DECAY = 1e-4
        self.LEARNING_RATE_MIN = 1e-6
        self.ACCUMALATION_STEPS = 1
        self.DICE_LOSS = True
        self.PATIENCE = 150

        # Model Parameters
        self.IN_CHANNELS = 1
        self.OUT_CLASSES = 1

        # Other Parameters
        self.DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.SEED = 42
        self.ROOT = "/kaggle/input/brain-tumor-dataset/data/"
        self.SAVE_DIR = '/kaggle/working/checkpoint'

config = Config()
# config.display()

# %%
def set_all_seeds(seed):
    # NumPy
    np.random.seed(seed)
    # PyTorch
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # For multi-GPU setups
    # Ensures that the CUDA convolutions are deterministic, but might slow down training
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False # Set to False for reproducibility

set_all_seeds(config.SEED)

# %%
class ClassesLabels(Enum):
    """Brain tumor classification labels"""
    Meningioma = 1  # U màng não
    Glioma = 2      # U thần kinh đệm  
    Pituitary = 3   # Tuyến uyên
    
    def __len__(self):
        return 3


class BrainTumorDataset(Dataset):
    """
    Brain tumor dataset with balanced class distribution
    
    Args:
        root: Root directory containing class folders
        train: If True, creates training set; if False, creates test set 
        classes: Tuple of classes to include
        test_freq: Fraction of data to use for testing
        random_seed: Random seed for reproducible splits
        normalize_image: Whether to normalize images to 0-255 range
        verbose: Whether to print dataset statistics
    """
    
    CLASS_FOLDERS = {
        ClassesLabels.Meningioma: 'meningioma',
        ClassesLabels.Glioma: 'glioma',
        ClassesLabels.Pituitary: 'pituitary'
    }
    
    def __init__(
        self,
        root: str,
        train: bool = True,
        classes: Tuple[ClassesLabels, ...] = (ClassesLabels.Meningioma, ClassesLabels.Glioma, ClassesLabels.Pituitary),
        test_freq: float = 0.15,
        random_seed: int = 42,
        normalize_image: bool = True,
        verbose: bool = True
    ):
        super().__init__()
        self.root = self._validate_path(root)
        self.train = train
        self.classes = classes
        self.test_freq = test_freq
        self.normalize_image = normalize_image
        
        # Set random seed for reproducible splits
        np.random.seed(random_seed)
        
        # Load and split data
        self.items, self.class_info = self._load_and_split_data()
        
        if verbose:
            self._print_stats()
    
    def _validate_path(self, path: str) -> str:
        """Validate and normalize root path"""
        if not os.path.exists(path):
            raise ValueError(f"Root path does not exist: {path}")
        return os.path.normpath(path)
    
    def _load_and_split_data(self) -> Tuple[List[str], Dict]:
        """Load files and split into train/test per class"""
        items = []
        class_info = {}
        
        for class_label in self.classes:
            folder_name = self.CLASS_FOLDERS[class_label]
            folder_path = os.path.join(self.root, folder_name)
            
            if not os.path.exists(folder_path):
                print(f"Warning: Folder {folder_path} does not exist!")
                continue
            
            # Get all valid files for this class
            all_files = self._get_valid_files(folder_path)
            if not all_files:
                print(f"Warning: No valid files found in {folder_path}")
                continue
            
            # Split files for this class
            train_files, test_files = self._split_files(all_files)
            selected_files = train_files if self.train else test_files
            
            # Add to items with folder prefix
            items.extend([f'{folder_name}/{f}' for f in selected_files])
            
            # Store class statistics
            class_info[class_label.name] = {
                'total': len(all_files),
                'train': len(train_files),
                'test': len(test_files),
                'selected': len(selected_files)
            }
        
        return items, class_info
    
    def _get_valid_files(self, folder_path: str) -> List[str]:
        """Get all valid data files from folder"""
        valid_extensions = ('.mat', '.h5', '.hdf5')
        files = [f for f in os.listdir(folder_path) 
                if f.lower().endswith(valid_extensions)]
        return sorted(files)  # Sort for consistent ordering
    
    def _split_files(self, files: List[str]) -> Tuple[List[str], List[str]]:
        """Split files into train and test sets"""
        files_shuffled = files.copy()
        np.random.shuffle(files_shuffled)
        
        split_point = math.floor((1 - self.test_freq) * len(files_shuffled))
        train_files = files_shuffled[:split_point]
        test_files = files_shuffled[split_point:]
        
        return train_files, test_files
    
    def _normalize_image(self, image: np.ndarray) -> np.ndarray:
        """Normalize image to 0-255 range using MATLAB formula"""
        im1 = image.astype(np.float64)
        min_val, max_val = np.min(im1), np.max(im1)
        
        if max_val == min_val:
            return np.zeros_like(im1, dtype=np.uint8)
        
        im_normalized = 255.0 * (im1 - min_val) / (max_val - min_val)
        return im_normalized.astype(np.uint8)
    
    def _print_stats(self):
        """Print dataset statistics"""
        mode = "Training" if self.train else "Testing"
        print(f"\n=== {mode} Dataset Statistics ===")
        print(f"Total samples: {len(self.items)}")
        print(f"Test frequency: {self.test_freq}")
        
        if self.class_info:
            print("\nClass breakdown:")
            total_selected = sum(info['selected'] for info in self.class_info.values())
            
            for class_name, info in self.class_info.items():
                percentage = (info['selected'] / total_selected * 100) if total_selected > 0 else 0
                print(f"  {class_name}: {info['selected']} ({percentage:.1f}%) "
                      f"[Total: {info['total']}, Train: {info['train']}, Test: {info['test']}]")
        print("=" * 50)
    
    def get_class_distribution(self) -> Dict[str, int]:
        """Get class distribution in current dataset"""
        return {name: info['selected'] for name, info in self.class_info.items()}
    
    def __len__(self) -> int:
        return len(self.items)
    
    def __getitem__(self, idx: int) -> Dict:
        if not (0 <= idx < len(self.items)):
            raise IndexError(f"Index {idx} out of range [0, {len(self.items)})")
        
        file_path = os.path.join(self.root, self.items[idx])
        
        try:
            with h5py.File(file_path, 'r') as f:
                data = f['cjdata']
                
                raw_image = data['image'][:]
                mask = data['tumorMask'][:]
                label = int(data['label'][0][0])
                
                # Apply normalization if requested
                image = self._normalize_image(raw_image) if self.normalize_image else raw_image
                
                return {
                    "label": label,
                    "image": image,
                    "mask": mask,
                    "file_path": self.items[idx]
                }
        
        except Exception as e:
            raise RuntimeError(f"Error loading {file_path}: {str(e)}")


class BrainTumorDatasetMask(BrainTumorDataset):
    """Dataset that returns (image, mask) tuples for backward compatibility"""
    
    def __init__(self, root: str, train: bool = True, transform=None, **kwargs):
        super().__init__(root=root, train=train, **kwargs)
        self.transform = transform
    
    def __getitem__(self, idx: int) -> Union[Tuple[np.ndarray, np.ndarray], any]:
        metadata = super().__getitem__(idx)
        sample = (metadata["image"], metadata["mask"])
        
        return self.transform(*sample) if self.transform else sample

# %%
def inspect_sample(dataset: BrainTumorDataset, idx: int = 0):
    """Inspect a dataset sample"""
    if len(dataset) == 0:
        print("Dataset is empty!")
        return
    
    sample = dataset[idx]
    print(f"\n=== Sample {idx} Inspection ===")
    
    if isinstance(sample, dict):
        print(f"Label: {sample['label']}")
        print(f"Image shape: {sample['image'].shape}, dtype: {sample['image'].dtype}")
        print(f"Image range: [{sample['image'].min()}, {sample['image'].max()}]")
        print(f"Mask shape: {sample['mask'].shape}, dtype: {sample['mask'].dtype}")
        print(f"File: {sample['file_path']}")
    else:
        print(f"Sample type: {type(sample)}")
        if isinstance(sample, tuple) and len(sample) == 2:
            image, mask = sample
            print(f"Image shape: {image.shape}, dtype: {image.dtype}")
            print(f"Mask shape: {mask.shape}, dtype: {mask.dtype}")
    
    print("=" * 35)

# %%
dataset_mask = BrainTumorDatasetMask(root=config.ROOT, train=True, test_freq=0.2)
sample_mask = dataset_mask[0]  # Trả về (image, mask)
print(f"Mask dataset sample type: {type(sample_mask)}")

inspect_sample(dataset_mask, 0)
# Out:
# === Training Dataset Statistics ===
# Total samples: 2438
# Test frequency: 0.2
#
# Class breakdown:
#   Meningioma: 566 (23.2%) [Total: 708, Train: 566, Test: 142]
#   Glioma: 1140 (46.8%) [Total: 1426, Train: 1140, Test: 286]
#   Pituitary: 732 (30.0%) [Total: 915, Train: 732, Test: 183]
# ==================================================
# Mask dataset sample type: <class 'tuple'>
#
# === Sample 0 Inspection ===
# Sample type: <class 'tuple'>
# Image shape: (512, 512), dtype: uint8
# Mask shape: (512, 512), dtype: uint8
# ===================================

# %%
# Visualize function
def visualize(images, masks, original_images=None, original_masks=None):
    fontsize=18
    
    # Xử lý trường hợp input là single sample
    if not isinstance(images, (list, tuple)):
        images = [images]
        masks = [masks]
        if original_images is not None:
            original_images = [original_images]
        if original_masks is not None:
            original_masks = [original_masks]
    
    num_samples = len(images)
    
    if original_images is None and original_masks is None:
        # Hiển thị 2 hàng: hàng 1 là images, hàng 2 là masks
        f, ax = plt.subplots(2, num_samples, figsize=(4*num_samples, 8))
        
        # Nếu chỉ có 1 sample, ax sẽ là 1D array
        if num_samples == 1:
            ax = ax.reshape(2, 1)
        
        for i in range(num_samples):
            ax[0, i].imshow(images[i], cmap='gray')
            ax[0, i].set_title(f'Image {i+1}', fontsize=fontsize)
            ax[0, i].axis('off')
            
            ax[1, i].imshow(masks[i], cmap='gray')
            ax[1, i].set_title(f'Mask {i+1}', fontsize=fontsize)
            ax[1, i].axis('off')
    else:
        # Hiển thị 4 hàng: original images, original masks, transformed images, transformed masks
        f, ax = plt.subplots(4, num_samples, figsize=(4*num_samples, 16))
        
        # Nếu chỉ có 1 sample, ax sẽ là 1D array
        if num_samples == 1:
            ax = ax.reshape(4, 1)
        
        for i in range(num_samples):
            ax[0, i].imshow(original_images[i], cmap='gray')
            ax[0, i].set_title(f'Original Image {i+1}', fontsize=fontsize)
            ax[0, i].axis('off')
            
            ax[1, i].imshow(original_masks[i], cmap='gray')
            ax[1, i].set_title(f'Original Mask {i+1}', fontsize=fontsize)
            ax[1, i].axis('off')
            
            ax[2, i].imshow(images[i], cmap='gray')
            ax[2, i].set_title(f'Transformed Image {i+1}', fontsize=fontsize)
            ax[2, i].axis('off')
            
            ax[3, i].imshow(masks[i], cmap='gray')
            ax[3, i].set_title(f'Transformed Mask {i+1}', fontsize=fontsize)
            ax[3, i].axis('off')
    
    plt.tight_layout()
    plt.show()

# Ví dụ sử dụng với multiple samples
def visualize_multiple_samples(dataset, indices, with_preprocessing=True):
    """
    Hiển thị nhiều samples từ dataset
    
    Args:
        dataset: Dataset object
        indices: List các index muốn hiển thị
        with_preprocessing: Có hiển thị ảnh trước và sau preprocessing không
    """
    images = []
    masks = []
    original_images = []
    original_masks = []
    
    for idx in indices:
        if with_preprocessing and hasattr(dataset, 'transform') and dataset.transform is not None:
            # Lấy dữ liệu gốc (không preprocessing)
            dataset_temp = dataset.__class__(dataset.root, dataset.train, transform=None, classes=dataset.classes)
            orig_img, orig_mask = dataset_temp[idx]
            original_images.append(orig_img)
            original_masks.append(orig_mask)
            
            # Lấy dữ liệu đã preprocessing
            proc_img, proc_mask = dataset[idx]
            images.append(proc_img.squeeze() if hasattr(proc_img, 'squeeze') else proc_img)
            masks.append(proc_mask.squeeze() if hasattr(proc_mask, 'squeeze') else proc_mask)
        else:
            # Chỉ lấy dữ liệu hiện tại
            img, mask = dataset[idx]
            images.append(img.squeeze() if hasattr(img, 'squeeze') else img)
            masks.append(mask.squeeze() if hasattr(mask, 'squeeze') else mask)
    
    if with_preprocessing and original_images:
        visualize(images, masks, original_images, original_masks)
    else:
        visualize(images, masks)

# Hàm tiền xử lí dữ liệu
def preprocessing(image, mask):
    image_transformer = transforms.Compose([
        transforms.ToTensor(),
        transforms.Resize(config.IMG_SIZE, interpolation=0),
        # transforms.Normalize(mean=(0.5,), std=(0.5,))  # Normalize image
        ])
    mask_transformer = transforms.Compose([
        transforms.Lambda(lambda x: transforms.ToPILImage()(transforms.ToTensor()(x).float().squeeze())),
        transforms.ToTensor(),
        transforms.Resize(config.IMG_SIZE, interpolation=0),
    ])
    # image = np.transpose(np.array(image)) / 65535.0
    # image = image * 2 - 1
    image = np.transpose(np.array(image))
    mask = np.transpose(np.array(mask))
    mask = mask_transformer(mask)
    mask = mask / mask.max()
    mask = torch.where(mask > 0.5, 1, 0).float()
    return image_transformer(image).float(), mask

# %%
# Khởi tạo dataset
dataset = BrainTumorDatasetMask(root=config.ROOT, train=True, transform=preprocessing)
original_image, original_mask = dataset[3]
print(f'#=>Original image: {type(original_image)}')
print(f'#=>Original mask: {type(original_mask)}')
# Out:
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
# #=>Original image: <class 'torch.Tensor'>
# #=>Original mask: <class 'torch.Tensor'>

# %%
visualize(original_image.squeeze(), original_mask.squeeze())

# %%
visualize_multiple_samples(dataset, [0, 1, 2, 3])
# Out:
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
#
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
#
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
#
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DoubleConv, self).__init__()
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.GroupNorm(min(8, out_channels), out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.GroupNorm(min(8, out_channels), out_channels),
            nn.ReLU(inplace=True),
        )
    
    def forward(self, x):
        return self.double_conv(x)
    
class DownBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DownBlock, self).__init__()
        self.double_conv = DoubleConv(in_channels, out_channels)
        self.down_sample = nn.MaxPool2d(2)
        
    def forward(self, x):
        skip_out = self.double_conv(x)
        down_out = self.down_sample(skip_out)
        return down_out, skip_out
    
class UpBlock(nn.Module):
    def __init__(self, in_channels, out_channels, up_sample_mode):
        super(UpBlock, self).__init__()
        if up_sample_mode == 'conv_transpose':
            self.up_sample = nn.ConvTranspose2d(in_channels-out_channels, in_channels-out_channels, kernel_size=2, stride=2)        
        elif up_sample_mode == 'bilinear':
            self.up_sample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        else:
            raise ValueError("Unsupported `up_sample_mode` (can take one of `conv_transpose` or `bilinear`)")
        self.double_conv = DoubleConv(in_channels, out_channels)

    def forward(self, down_input, skip_input):
        x = self.up_sample(down_input)
        x = torch.cat([x, skip_input], dim=1)
        return self.double_conv(x)

class ConvSRU(nn.Module):
    def __init__(self,
                 input_size,
                 hidden_size,
                 ):
        super(ConvSRU, self).__init__()

        self.update_gate = DoubleConv(input_size, hidden_size)
        self.out_gate = DoubleConv(input_size, hidden_size)

    def forward(self, input_, h=None):
        update = torch.sigmoid(self.update_gate(input_))

        out_inputs = torch.tanh(self.out_gate(input_))
        h_new = h * (1 - update) + out_inputs * update

        return h_new

# Single-gated Reccurent Unit
class SRU(nn.Module):
    def __init__(self, in_channels=3, out_classes=2, steps=3, up_sample_mode='conv_transpose'):
        super(SRU, self).__init__()
        self.up_sample_mode = up_sample_mode
        self.steps = steps
        filters = [32, 64, 128, 256, 512]
        # filters = [64, 128, 256, 512, 1024]
        # Downsampling Path
        self.down_conv1 = DownBlock(in_channels + out_classes, filters[0])
        self.down_conv2 = DownBlock(filters[0], filters[1])
        self.down_conv3 = DownBlock(filters[1], filters[2])
        self.down_conv4 = DownBlock(filters[2], filters[3])
        # Bottleneck
        self.gru = ConvSRU(filters[3], filters[4])
        # upsampling Path
        self.up_conv4 = UpBlock(filters[3] + filters[4], filters[3], self.up_sample_mode)
        self.up_conv3 = UpBlock(filters[2] + filters[3], filters[2], self.up_sample_mode)
        self.up_conv2 = UpBlock(filters[1] + filters[2], filters[1], self.up_sample_mode)
        self.up_conv1 = UpBlock(filters[1] + filters[0], filters[0], self.up_sample_mode)
        # Final Convolution
        self.conv_last = nn.Conv2d(filters[0], out_classes, kernel_size=1)
        self.softmax = nn.Softmax2d()
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x, h, s):
        list_st = []
        for i in range(self.steps):
            stacked_inputs = torch.cat([x, s], dim=1)
            x, skip1_out = self.down_conv1(stacked_inputs)
            x, skip2_out = self.down_conv2(x)
            x, skip3_out = self.down_conv3(x)
            x, skip4_out = self.down_conv4(x)
            h = self.gru(x, h)
            x = self.up_conv4(h, skip4_out)
            x = self.up_conv3(x, skip3_out)
            x = self.up_conv2(x, skip2_out)
            x = self.up_conv1(x, skip1_out)
            x = self.conv_last(x)
            x = self.sigmoid(x)

            list_st += [x]
        return list_st

# %%
class Trainer():
    def __init__(self,
                 model,
                 train_dataloader,
                 valid_dataloader,
                 epochs=10,
                 save_dir=None,
                 device='cpu',
                 accumalation_steps=4,
                 patience=5):  # Add patience for early stopping
        self.device = device
        self.accumalation_steps = accumalation_steps

        self.model = model.to(self.device)

        self.train_losses = []
        self.train_dice_coeff_values = []
        self.train_iou_values = []
        self.val_losses = []
        self.val_dice_coeff_values = []
        self.val_iou_values = []
        
        self.patience = patience  # Early stopping patience
        self.early_stop = False  # Flag for early stopping
        self.best_valid_loss = float('inf')  # Initialize best loss

        if save_dir != None and os.path.exists(save_dir):
            print("Load weight from file:{}".format(save_dir))
            self.save_dir = save_dir
            epcho_checkpoint_path = glob.glob("{}/model_epoch*".format(self.save_dir))
            if len(epcho_checkpoint_path) == 0:
                print("No checkpoint found in: {}\nCheck save_dir...".format(self.save_dir))
            else:
                self.load_checkpoint(epcho_checkpoint_path[0])
                print("Restore weight successful from: {}".format(epcho_checkpoint_path))
        else:
            self.save_dir = datetime.now().strftime("%d-%m-%Y_%H-%M-%S")
            os.makedirs(self.save_dir)
            print("Training new model, save to: {}".format(self.save_dir))

        self.train_dataloader = train_dataloader
        self.valid_dataloader = valid_dataloader
        self.epochs = epochs

    def save_checkpoint(self, save_path):
        state_dict = {'model_state_dict': self.model.state_dict(),
                      'train_losses': self.train_losses,
                      'train_dice_coeff_values': self.train_dice_coeff_values,
                      'train_iou_values': self.train_iou_values,
                      'val_losses': self.val_losses,
                      'val_dice_coeff_values': self.val_dice_coeff_values,
                      'val_iou_values': self.val_iou_values
                     }
        torch.save(state_dict, save_path)
        print(f"Model saved to ==> {save_path}")

    def load_checkpoint(self, load_path):
        state_dict = torch.load(load_path, map_location=self.device)
        print(f"Model restored from <== {load_path}")
        self.model.load_state_dict(state_dict["model_state_dict"])
        self.train_losses = state_dict["train_losses"]
        self.train_dice_coeff_values = state_dict["train_dice_coeff_values"]
        self.train_iou_values = state_dict['train_iou_values']
        self.val_losses = state_dict["val_losses"]
        self.val_dice_coeff_values = state_dict["val_dice_coeff_values"]
        self.val_iou_values = state_dict['val_iou_values']

    @staticmethod
    def iou(pred_mask, true_mask):
        # Làm phẳng các tensor
        pred_mask = pred_mask.view(-1)
        true_mask = true_mask.view(-1)
    
        # Tính toán phần giao nhau và hợp nhất
        intersection = torch.sum(pred_mask * true_mask)
        union = torch.sum(pred_mask) + torch.sum(true_mask) - intersection
    
        # Tính IoU
        iou = intersection / union
    
        return iou

    @staticmethod
    def dice_loss(pred, target, smooth=1e-6):
        pred = pred.view(-1)
        target = target.view(-1)
        
        # Flatten the tensors to calculate the intersection and union of predicted and true masks
        intersection = torch.sum(pred * target)
        union = torch.sum(pred) + torch.sum(target)
        
        # Compute Dice coefficient
        dice = (2. * intersection + smooth) / (union + smooth)
        
        return 1 - dice

    @staticmethod
    def dice_coeff(pred, target, smooth=1e-6, threshold=0.5):
        pred = pred.view(-1)
        target = target.view(-1)
        # pred = (pred > threshold).float()
        
        intersection = torch.sum(pred * target)
        union = torch.sum(pred) + torch.sum(target)
        return (2. * intersection + smooth) / (union + smooth)
    
    def train(self):
        if config.DICE_LOSS:
            criterions= [self.dice_loss for _ in range(3)]
        else:
            criterions= [nn.BCELoss() for _ in range(3)]
            
        # print(len(criterions))
        # criterion = self.dice_loss
        optimizer = torch.optim.AdamW(self.model.parameters(), lr=config.LEARNING_RATE, weight_decay=config.WEIGHT_DECAY)

        scheduler = lr_scheduler.CosineAnnealingLR(optimizer, T_max=config.EPOCHS, eta_min=config.LEARNING_RATE_MIN)
        
        patience_counter = 0  # Track epochs without improvement

        for epoch_i in range(0, self.epochs):
            if self.early_stop:  # Check if early stopping is triggered
                print("Early stopping triggered. Training stopped.")
                break

            print('========== Epoch {:} / {:} =========='.format(epoch_i + 1, self.epochs))
            print('Training...')

            total_loss = 0
            total_com_losses = [0]*3
            self.model.train()
            nb_train_steps = 0
            train_iou = 0
            train_dice_coeff = 0

            for step, batch in enumerate(self.train_dataloader):
                img, mask = batch
                img, mask = img.to(self.device), mask.to(self.device)
                
                s = torch.zeros_like(mask).to(self.device)
                h = torch.zeros(mask.size(0), 512, 16, 16).to(self.device)
                outputs = self.model(img, h, s)

               # compute loss
                alpha = 0.4 # 0.4 # 1
                steps = 3
                loss = 0
                losses = []
                # for i in range(steps-1, -1, -1):
                for i in range(steps):
                    _loss = criterions[i](outputs[i], mask)
                    # print(_loss)
                    # print(_loss.requires_grad)     # Phải trả về True
                    loss = loss + _loss*(alpha**(steps-i-1))
                    losses.append(_loss)
                    # losses = [_loss] + losses

                
                dice = self.dice_coeff(outputs[-1].detach(), mask).item()
                train_dice_coeff += dice
                iou = self.iou(outputs[-1].detach(), mask).item()
                train_iou += iou
                # print(loss)
                loss = loss / self.accumalation_steps
                total_loss += loss.item() * self.accumalation_steps
                for i in range(steps):
                    total_com_losses[i] += losses[i].item()
                
                nb_train_steps += 1

                loss.backward()
                if (step + 1) % self.accumalation_steps == 0:
                    optimizer.step()
                    # scheduler.step()
                    optimizer.zero_grad()

                if (step + 1) % 10 == 0:
                    print("[TRAIN] Epoch {}/{} | Batch {}/{} | Loss_1={:.4f} | Loss_2={:.4f} | Loss_3={:.4f} | Totol_Loss={:.4f} | Dice_coeff={:.4f} | IoU={:.4f}".format(epoch_i + 1, self.epochs, step + 1, len(self.train_dataloader), losses[0].item(), losses[1].item(), losses[2].item(), loss.item(), dice, iou))
                            
            scheduler.step()
            avg_train_loss = total_loss / len(self.train_dataloader)
            avg_train_dice_coeff = train_dice_coeff / nb_train_steps
            avg_train_iou = train_iou / nb_train_steps
            print(" Train Loss_1: {:.4f} | Loss_2: {:.4f} | Loss_3: {:.4f} | Total_Loss: {:.4f} | Avg_dice_coeff: {:.4f} | Avg_IoU: {:.4f}".format(total_com_losses[0]/nb_train_steps, total_com_losses[1]/nb_train_steps, total_com_losses[2]/nb_train_steps, avg_train_loss, avg_train_dice_coeff, avg_train_iou))

            self.train_losses.append(avg_train_loss)
            self.train_dice_coeff_values.append(avg_train_dice_coeff)
            self.train_iou_values.append(avg_train_iou)

            print("Running Validation...")
            self.model.eval()
            eval_loss = 0
            eval_com_losses = [0]*3
            eval_iou = 0
            eval_dice_coeff = 0
            nb_eval_steps = 0

            for batch in self.valid_dataloader:
                img, mask = batch
                img, mask = img.to(self.device), mask.to(self.device)

                with torch.no_grad():
                    s = torch.zeros_like(mask).to(self.device)
                    h = torch.zeros(mask.size(0), 512, 16, 16).to(self.device)
                    outputs = self.model(img, h, s)
            
                    # compute loss
                    alpha = 0.4 # 0.4 # 1
                    steps = 3
                    loss = 0
                    losses = []
                    # for i in range(steps-1, -1, -1):
                    for i in range(steps):
                        _loss = criterions[i](outputs[i], mask)
                        loss = loss + _loss*(alpha**(steps-i-1))
                        losses.append(_loss)

                    for i in range(steps):
                        eval_com_losses[i] += losses[i].item()
                        
                    eval_dice_coeff += self.dice_coeff(outputs[-1].detach(), mask).item()
                    eval_iou += self.iou(outputs[-1].detach(), mask).item()
                    eval_loss += loss.item()
                    nb_eval_steps += 1

            avg_val_loss = eval_loss / nb_eval_steps
            avg_val_dice_coeff = eval_dice_coeff / nb_eval_steps
            avg_val_iou = eval_iou / nb_eval_steps
            
            print(f" Valid Loss_1: {eval_com_losses[0]/nb_eval_steps:.4f} | Loss_2: {eval_com_losses[1]/nb_eval_steps:.4f} | Loss_3: {eval_com_losses[2]/nb_eval_steps:.4f} \n Total_Loss: {avg_val_loss:.4f} | Dice_coeff: {avg_val_dice_coeff:.4f} | IoU: {avg_val_iou:.4f}")

            self.val_losses.append(avg_val_loss)
            self.val_dice_coeff_values.append(avg_val_dice_coeff)
            self.val_iou_values.append(avg_val_iou)

            # Early stopping logic
            if (eval_com_losses[2]/nb_eval_steps) < self.best_valid_loss:
                print(f"Validation loss improved from {self.best_valid_loss:.4f} to {eval_com_losses[2]/nb_eval_steps:.4f}. Saving model...")
                self.best_valid_loss = eval_com_losses[2]/nb_eval_steps
                patience_counter = 0  # Reset patience counter
                best_valid_loss_path = "{}/model_best_valloss.pt".format(self.save_dir)
                self.save_checkpoint(best_valid_loss_path)
            else:
                patience_counter += 1
                print(f"No improvement in validation loss for {patience_counter} epochs.")
                if patience_counter >= self.patience:
                    print(f"Stopping early after {patience_counter} epochs without improvement.")
                    self.early_stop = True

            # Save checkpoint for current epoch
            epoch_i_path = "{}/model_epoch{}.pt".format(self.save_dir, epoch_i)
            self.save_checkpoint(epoch_i_path)

            # Remove the previous epoch's checkpoint
            if os.path.exists("{}/model_epoch{}.pt".format(self.save_dir, epoch_i-1)):
                os.remove("{}/model_epoch{}.pt".format(self.save_dir, epoch_i-1))

        print("Training complete!")
        

    def eval(self, dataloader):
        self.model.eval()
        if config.DICE_LOSS:
            criterions= [self.dice_loss for _ in range(3)]
        else:
            criterions= [nn.BCELoss() for _ in range(3)]
        nb_eval_steps = 0
        eval_loss = 0
        eval_com_losses = [0]*3
        eval_iou = 0
        eval_dice_coeff = 0
        for step, batch in enumerate(dataloader):
            img, mask = batch
            img, mask = img.to(self.device), mask.to(self.device)

            with torch.no_grad():
                s = torch.zeros_like(mask).to(self.device)
                h = torch.zeros(mask.size(0), 512, 16, 16).to(self.device)
                outputs = self.model(img.to(self.device), h, s)

                # compute loss
                alpha = 0.4 # 0.4 # 1
                steps = 3
                loss = 0
                losses = []
                # for i in range(steps-1, -1, -1):
                for i in range(steps):
                    _loss = criterions[i](outputs[i], mask)
                    # print(_loss)
                    # print(_loss.requires_grad)     # Phải trả về True
                    loss = loss + _loss*(alpha**(steps-i-1))
                    losses.append(_loss)
                    # losses = [_loss] + losses

                for i in range(steps):
                    eval_com_losses[i] += losses[i].item()
                    
                eval_dice_coeff += self.dice_coeff(outputs[-1], mask).item()
                eval_iou += self.iou(outputs[-1], mask).item()
                eval_loss += loss.item()
                nb_eval_steps += 1
                
            if (step + 1) % 100 == 0:
                    print("[Test] Batch {}/{} | Test Loss_1={:.4f} | Loss_2={:.4f} | Loss_3={:.4f} | Total_Loss={:.4f}".format(step + 1, len(dataloader), losses[0], losses[1], losses[2], loss))
        avg_val_loss = eval_loss / nb_eval_steps
        avg_dice_coeff = eval_dice_coeff / nb_eval_steps
        avg_iou = eval_iou / nb_eval_steps
        
        print(f" Test Loss_1: {eval_com_losses[0]/nb_eval_steps:.4f} | Loss_2: {eval_com_losses[1]/nb_eval_steps:.4f} | Loss_2: {eval_com_losses[2]/nb_eval_steps:.4f} \n Total_Loss: {avg_val_loss:.4f} | Dice_coeff: {avg_dice_coeff:.4f} | IoU: {avg_iou:.4f}")
        return

    def visualize_scores(self):
        num_epoches = range(1, len(self.train_losses) + 1)
        # Vẽ Loss
        plt.figure(figsize=(12, 6))
        plt.plot(num_epoches, self.train_losses, label='Train Loss', marker='o', color='blue')
        plt.plot(num_epoches, self.val_losses, label='Test Loss', marker='o', color='orange')
        plt.title('Training and Testing Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        plt.grid(True)
        plt.show()
        
        # Vẽ Dice Coeff
        plt.figure(figsize=(12, 6))
        plt.plot(num_epoches, self.train_dice_coeff_values, label='Train Dice Coeff', marker='o', color='green')
        plt.plot(num_epoches, self.val_dice_coeff_values, label='Test Dice Coeff', marker='o', color='red')
        plt.title('Training and Testing Dice Coeff')
        plt.xlabel('Epochs')
        plt.ylabel('Dice Coeff')
        plt.legend()
        plt.grid(True)
        plt.show()

        # Vẽ IoU
        plt.figure(figsize=(12, 6))
        plt.plot(num_epoches, self.train_iou_values, label='Train IoU', marker='o', color='green')
        plt.plot(num_epoches, self.val_iou_values, label='Test IoU', marker='o', color='red')
        plt.title('Training and Testing IoU')
        plt.xlabel('Epochs')
        plt.ylabel('IoU')
        plt.legend()
        plt.grid(True)
        plt.show()

# %%
train_dataset = BrainTumorDatasetMask(root=config.ROOT, train=True, 
                                      test_freq=config.TEST_RATIO, transform=preprocessing)
valid_dataset = BrainTumorDatasetMask(root=config.ROOT, train=False, 
                                      test_freq=config.TEST_RATIO, transform=preprocessing)
print(f'Length of train dataset: {len(train_dataset)}')
print(f'Length of test dataset: {len(valid_dataset)}')

train_loader = DataLoader(dataset=train_dataset, batch_size=config.BATCH_SIZE, shuffle=True)
valid_loader = DataLoader(dataset=valid_dataset, batch_size=config.BATCH_SIZE, shuffle=False)
print(f'Length of train loader: {len(train_loader)}')
print(f'Length of test loader: {len(valid_loader)}')
# Out:
# === Training Dataset Statistics ===
# Total samples: 2438
# Test frequency: 0.2
#
# Class breakdown:
#   Meningioma: 566 (23.2%) [Total: 708, Train: 566, Test: 142]
#   Glioma: 1140 (46.8%) [Total: 1426, Train: 1140, Test: 286]
#   Pituitary: 732 (30.0%) [Total: 915, Train: 732, Test: 183]
# ==================================================
#
# === Testing Dataset Statistics ===
# Total samples: 611
# Test frequency: 0.2
#
# Class breakdown:
#   Meningioma: 142 (23.2%) [Total: 708, Train: 566, Test: 142]
#   Glioma: 286 (46.8%) [Total: 1426, Train: 1140, Test: 286]
#   Pituitary: 183 (30.0%) [Total: 915, Train: 732, Test: 183]
# ==================================================
# Length of train dataset: 2438
# Length of test dataset: 611
# Length of train loader: 153
# Length of test loader: 39

# %%
model = SRU(in_channels=config.IN_CHANNELS, out_classes=config.OUT_CLASSES).to(config.DEVICE)

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
    
print("Number parameters:", count_parameters(model))
# Out:
# Number parameters: 12787873

# %%
trainer = Trainer(
    model=model,
    train_dataloader=train_loader,
    valid_dataloader=valid_loader,
    epochs=config.EPOCHS,
    save_dir=config.SAVE_DIR,
    device=config.DEVICE,
    accumalation_steps=config.ACCUMALATION_STEPS,
    patience = config.PATIENCE
)
# Out:
# Training new model, save to: 20-06-2025_08-42-41

# %%
# trainer.load_checkpoint('/kaggle/input/sru_brain_tumor/pytorch/default/3/model_sru_brain_tumor_v3.pt')

# %%
trainer.train()
# Out:
# ========== Epoch 1 / 150 ==========
# Training...
# [TRAIN] Epoch 1/150 | Batch 10/153 | Loss_1=0.9366 | Loss_2=0.9358 | Loss_3=0.9363 | Totol_Loss=1.4605 | Dice_coeff=0.0637 | IoU=0.0329
# [TRAIN] Epoch 1/150 | Batch 20/153 | Loss_1=0.9219 | Loss_2=0.9287 | Loss_3=0.9357 | Totol_Loss=1.4546 | Dice_coeff=0.0643 | IoU=0.0332
# [TRAIN] Epoch 1/150 | Batch 30/153 | Loss_1=0.9040 | Loss_2=0.9019 | Loss_3=0.9025 | Totol_Loss=1.4078 | Dice_coeff=0.0975 | IoU=0.0513
# [TRAIN] Epoch 1/150 | Batch 40/153 | Loss_1=0.9047 | Loss_2=0.9007 | Loss_3=0.9011 | Totol_Loss=1.4061 | Dice_coeff=0.0989 | IoU=0.0520
# [TRAIN] Epoch 1/150 | Batch 50/153 | Loss_1=0.9129 | Loss_2=0.9142 | Loss_3=0.9153 | Totol_Loss=1.4271 | Dice_coeff=0.0847 | IoU=0.0442
# [TRAIN] Epoch 1/150 | Batch 60/153 | Loss_1=0.8829 | Loss_2=0.8750 | Loss_3=0.8749 | Totol_Loss=1.3662 | Dice_coeff=0.1251 | IoU=0.0667
# [TRAIN] Epoch 1/150 | Batch 70/153 | Loss_1=0.8913 | Loss_2=0.8850 | Loss_3=0.8823 | Totol_Loss=1.3788 | Dice_coeff=0.1177 | IoU=0.0626
# [TRAIN] Epoch 1/150 | Batch 80/153 | Loss_1=0.8634 | Loss_2=0.8469 | Loss_3=0.8434 | Totol_Loss=1.3202 | Dice_coeff=0.1566 | IoU=0.0850
# [TRAIN] Epoch 1/150 | Batch 90/153 | Loss_1=0.8834 | Loss_2=0.8679 | Loss_3=0.8687 | Totol_Loss=1.3572 | Dice_coeff=0.1313 | IoU=0.0703
# [TRAIN] Epoch 1/150 | Batch 100/153 | Loss_1=0.9081 | Loss_2=0.8697 | Loss_3=0.8611 | Totol_Loss=1.3542 | Dice_coeff=0.1389 | IoU=0.0747
# [TRAIN] Epoch 1/150 | Batch 110/153 | Loss_1=0.8091 | Loss_2=0.7772 | Loss_3=0.7787 | Totol_Loss=1.2191 | Dice_coeff=0.2213 | IoU=0.1244
# [TRAIN] Epoch 1/150 | Batch 120/153 | Loss_1=0.7946 | Loss_2=0.7442 | Loss_3=0.7354 | Totol_Loss=1.1602 | Dice_coeff=0.2646 | IoU=0.1525
# [TRAIN] Epoch 1/150 | Batch 130/153 | Loss_1=0.8333 | Loss_2=0.7598 | Loss_3=0.7358 | Totol_Loss=1.1731 | Dice_coeff=0.2642 | IoU=0.1522
# [TRAIN] Epoch 1/150 | Batch 140/153 | Loss_1=0.7720 | Loss_2=0.6944 | Loss_3=0.6752 | Totol_Loss=1.0765 | Dice_coeff=0.3248 | IoU=0.1939
# [TRAIN] Epoch 1/150 | Batch 150/153 | Loss_1=0.6348 | Loss_2=0.5955 | Loss_3=0.6085 | Totol_Loss=0.9483 | Dice_coeff=0.3915 | IoU=0.2434
#  Train Loss_1: 0.8730 | Loss_2: 0.8505 | Loss_3: 0.8487 | Total_Loss: 1.3286 | Avg_dice_coeff: 0.1513 | Avg_IoU: 0.0845
# Running Validation...
#  Valid Loss_1: 0.7356 | Loss_2: 0.6886 | Loss_3: 0.6848
#  Total_Loss: 1.0780 | Dice_coeff: 0.3152 | IoU: 0.1963
# Validation loss improved from inf to 0.6848. Saving model...
# Model saved to ==> 20-06-2025_08-42-41/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-42-41/model_epoch0.pt
# ========== Epoch 2 / 150 ==========
# Training...
# [TRAIN] Epoch 2/150 | Batch 10/153 | Loss_1=0.6833 | Loss_2=0.6452 | Loss_3=0.6685 | Totol_Loss=1.0359 | Dice_coeff=0.3315 | IoU=0.1987
# [TRAIN] Epoch 2/150 | Batch 20/153 | Loss_1=0.7420 | Loss_2=0.7008 | Loss_3=0.7090 | Totol_Loss=1.1081 | Dice_coeff=0.2910 | IoU=0.1703
# [TRAIN] Epoch 2/150 | Batch 30/153 | Loss_1=0.7209 | Loss_2=0.6326 | Loss_3=0.6101 | Totol_Loss=0.9785 | Dice_coeff=0.3899 | IoU=0.2421
# [TRAIN] Epoch 2/150 | Batch 40/153 | Loss_1=0.7857 | Loss_2=0.7310 | Loss_3=0.7204 | Totol_Loss=1.1385 | Dice_coeff=0.2796 | IoU=0.1625
# [TRAIN] Epoch 2/150 | Batch 50/153 | Loss_1=0.8202 | Loss_2=0.7389 | Loss_3=0.7009 | Totol_Loss=1.1277 | Dice_coeff=0.2991 | IoU=0.1758
# [TRAIN] Epoch 2/150 | Batch 60/153 | Loss_1=0.9956 | Loss_2=0.9986 | Loss_3=0.9987 | Totol_Loss=1.5574 | Dice_coeff=0.0013 | IoU=0.0007
# [TRAIN] Epoch 2/150 | Batch 70/153 | Loss_1=0.5789 | Loss_2=0.5058 | Loss_3=0.5021 | Totol_Loss=0.7971 | Dice_coeff=0.4979 | IoU=0.3315
# [TRAIN] Epoch 2/150 | Batch 80/153 | Loss_1=0.7688 | Loss_2=0.6785 | Loss_3=0.6655 | Totol_Loss=1.0599 | Dice_coeff=0.3345 | IoU=0.2009
# [TRAIN] Epoch 2/150 | Batch 90/153 | Loss_1=0.5612 | Loss_2=0.5488 | Loss_3=0.5564 | Totol_Loss=0.8657 | Dice_coeff=0.4436 | IoU=0.2850
# [TRAIN] Epoch 2/150 | Batch 100/153 | Loss_1=0.6721 | Loss_2=0.5817 | Loss_3=0.5587 | Totol_Loss=0.8989 | Dice_coeff=0.4413 | IoU=0.2831
# [TRAIN] Epoch 2/150 | Batch 110/153 | Loss_1=0.7477 | Loss_2=0.7897 | Loss_3=0.8086 | Totol_Loss=1.2441 | Dice_coeff=0.1914 | IoU=0.1058
# [TRAIN] Epoch 2/150 | Batch 120/153 | Loss_1=0.7436 | Loss_2=0.7479 | Loss_3=0.7747 | Totol_Loss=1.1929 | Dice_coeff=0.2253 | IoU=0.1269
# [TRAIN] Epoch 2/150 | Batch 130/153 | Loss_1=0.7176 | Loss_2=0.6495 | Loss_3=0.6364 | Totol_Loss=1.0110 | Dice_coeff=0.3636 | IoU=0.2222
# [TRAIN] Epoch 2/150 | Batch 140/153 | Loss_1=0.5906 | Loss_2=0.5485 | Loss_3=0.5624 | Totol_Loss=0.8762 | Dice_coeff=0.4376 | IoU=0.2801
# [TRAIN] Epoch 2/150 | Batch 150/153 | Loss_1=0.6305 | Loss_2=0.5660 | Loss_3=0.5889 | Totol_Loss=0.9162 | Dice_coeff=0.4111 | IoU=0.2587
#  Train Loss_1: 0.7088 | Loss_2: 0.6535 | Loss_3: 0.6471 | Total_Loss: 1.0219 | Avg_dice_coeff: 0.3529 | Avg_IoU: 0.2200
# Running Validation...
#  Valid Loss_1: 0.8887 | Loss_2: 0.8025 | Loss_3: 0.7545
#  Total_Loss: 1.2178 | Dice_coeff: 0.2455 | IoU: 0.1466
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch1.pt
# ========== Epoch 3 / 150 ==========
# Training...
# [TRAIN] Epoch 3/150 | Batch 10/153 | Loss_1=0.7178 | Loss_2=0.6117 | Loss_3=0.6094 | Totol_Loss=0.9689 | Dice_coeff=0.3906 | IoU=0.2427
# [TRAIN] Epoch 3/150 | Batch 20/153 | Loss_1=0.7375 | Loss_2=0.7214 | Loss_3=0.7298 | Totol_Loss=1.1364 | Dice_coeff=0.2702 | IoU=0.1562
# [TRAIN] Epoch 3/150 | Batch 30/153 | Loss_1=0.7422 | Loss_2=0.7083 | Loss_3=0.7047 | Totol_Loss=1.1067 | Dice_coeff=0.2953 | IoU=0.1732
# [TRAIN] Epoch 3/150 | Batch 40/153 | Loss_1=0.7666 | Loss_2=0.7342 | Loss_3=0.7272 | Totol_Loss=1.1436 | Dice_coeff=0.2728 | IoU=0.1579
# [TRAIN] Epoch 3/150 | Batch 50/153 | Loss_1=0.7248 | Loss_2=0.6866 | Loss_3=0.6761 | Totol_Loss=1.0667 | Dice_coeff=0.3239 | IoU=0.1933
# [TRAIN] Epoch 3/150 | Batch 60/153 | Loss_1=0.6788 | Loss_2=0.6051 | Loss_3=0.5857 | Totol_Loss=0.9363 | Dice_coeff=0.4143 | IoU=0.2613
# [TRAIN] Epoch 3/150 | Batch 70/153 | Loss_1=0.7708 | Loss_2=0.7206 | Loss_3=0.7020 | Totol_Loss=1.1136 | Dice_coeff=0.2980 | IoU=0.1751
# [TRAIN] Epoch 3/150 | Batch 80/153 | Loss_1=0.6356 | Loss_2=0.5519 | Loss_3=0.5234 | Totol_Loss=0.8459 | Dice_coeff=0.4766 | IoU=0.3129
# [TRAIN] Epoch 3/150 | Batch 90/153 | Loss_1=0.6545 | Loss_2=0.5962 | Loss_3=0.5847 | Totol_Loss=0.9279 | Dice_coeff=0.4153 | IoU=0.2621
# [TRAIN] Epoch 3/150 | Batch 100/153 | Loss_1=0.7304 | Loss_2=0.6723 | Loss_3=0.6557 | Totol_Loss=1.0415 | Dice_coeff=0.3443 | IoU=0.2080
# [TRAIN] Epoch 3/150 | Batch 110/153 | Loss_1=0.8294 | Loss_2=0.7864 | Loss_3=0.7736 | Totol_Loss=1.2209 | Dice_coeff=0.2264 | IoU=0.1276
# [TRAIN] Epoch 3/150 | Batch 120/153 | Loss_1=0.5463 | Loss_2=0.4916 | Loss_3=0.5138 | Totol_Loss=0.7979 | Dice_coeff=0.4862 | IoU=0.3212
# [TRAIN] Epoch 3/150 | Batch 130/153 | Loss_1=0.6975 | Loss_2=0.6430 | Loss_3=0.6464 | Totol_Loss=1.0152 | Dice_coeff=0.3536 | IoU=0.2148
# [TRAIN] Epoch 3/150 | Batch 140/153 | Loss_1=0.6445 | Loss_2=0.5624 | Loss_3=0.5583 | Totol_Loss=0.8864 | Dice_coeff=0.4417 | IoU=0.2834
# [TRAIN] Epoch 3/150 | Batch 150/153 | Loss_1=0.4538 | Loss_2=0.4016 | Loss_3=0.4396 | Totol_Loss=0.6728 | Dice_coeff=0.5604 | IoU=0.3893
#  Train Loss_1: 0.6710 | Loss_2: 0.6115 | Loss_3: 0.6050 | Total_Loss: 0.9570 | Avg_dice_coeff: 0.3950 | Avg_IoU: 0.2508
# Running Validation...
#  Valid Loss_1: 0.6523 | Loss_2: 0.5637 | Loss_3: 0.5535
#  Total_Loss: 0.8834 | Dice_coeff: 0.4465 | IoU: 0.3068
# Validation loss improved from 0.6848 to 0.5535. Saving model...
# Model saved to ==> 20-06-2025_08-42-41/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-42-41/model_epoch2.pt
# ========== Epoch 4 / 150 ==========
# Training...
# [TRAIN] Epoch 4/150 | Batch 10/153 | Loss_1=0.5384 | Loss_2=0.4481 | Loss_3=0.4453 | Totol_Loss=0.7107 | Dice_coeff=0.5547 | IoU=0.3838
# [TRAIN] Epoch 4/150 | Batch 20/153 | Loss_1=0.6886 | Loss_2=0.6634 | Loss_3=0.6710 | Totol_Loss=1.0465 | Dice_coeff=0.3290 | IoU=0.1969
# [TRAIN] Epoch 4/150 | Batch 30/153 | Loss_1=0.6803 | Loss_2=0.6008 | Loss_3=0.5965 | Totol_Loss=0.9456 | Dice_coeff=0.4035 | IoU=0.2528
# [TRAIN] Epoch 4/150 | Batch 40/153 | Loss_1=0.7178 | Loss_2=0.6051 | Loss_3=0.5959 | Totol_Loss=0.9527 | Dice_coeff=0.4041 | IoU=0.2532
# [TRAIN] Epoch 4/150 | Batch 50/153 | Loss_1=0.8665 | Loss_2=0.7958 | Loss_3=0.7424 | Totol_Loss=1.1994 | Dice_coeff=0.2576 | IoU=0.1478
# [TRAIN] Epoch 4/150 | Batch 60/153 | Loss_1=0.6377 | Loss_2=0.5803 | Loss_3=0.5784 | Totol_Loss=0.9125 | Dice_coeff=0.4216 | IoU=0.2671
# [TRAIN] Epoch 4/150 | Batch 70/153 | Loss_1=0.4330 | Loss_2=0.3652 | Loss_3=0.3675 | Totol_Loss=0.5829 | Dice_coeff=0.6325 | IoU=0.4625
# [TRAIN] Epoch 4/150 | Batch 80/153 | Loss_1=0.5507 | Loss_2=0.4583 | Loss_3=0.4567 | Totol_Loss=0.7281 | Dice_coeff=0.5433 | IoU=0.3730
# [TRAIN] Epoch 4/150 | Batch 90/153 | Loss_1=0.5353 | Loss_2=0.4038 | Loss_3=0.3849 | Totol_Loss=0.6321 | Dice_coeff=0.6151 | IoU=0.4442
# [TRAIN] Epoch 4/150 | Batch 100/153 | Loss_1=0.6208 | Loss_2=0.5360 | Loss_3=0.5353 | Totol_Loss=0.8490 | Dice_coeff=0.4647 | IoU=0.3027
# [TRAIN] Epoch 4/150 | Batch 110/153 | Loss_1=0.7405 | Loss_2=0.6117 | Loss_3=0.5590 | Totol_Loss=0.9221 | Dice_coeff=0.4410 | IoU=0.2829
# [TRAIN] Epoch 4/150 | Batch 120/153 | Loss_1=0.6723 | Loss_2=0.5734 | Loss_3=0.5393 | Totol_Loss=0.8763 | Dice_coeff=0.4607 | IoU=0.2993
# [TRAIN] Epoch 4/150 | Batch 130/153 | Loss_1=0.6889 | Loss_2=0.5520 | Loss_3=0.5191 | Totol_Loss=0.8501 | Dice_coeff=0.4809 | IoU=0.3166
# [TRAIN] Epoch 4/150 | Batch 140/153 | Loss_1=0.5988 | Loss_2=0.5255 | Loss_3=0.5414 | Totol_Loss=0.8474 | Dice_coeff=0.4586 | IoU=0.2975
# [TRAIN] Epoch 4/150 | Batch 150/153 | Loss_1=0.5134 | Loss_2=0.4402 | Loss_3=0.4350 | Totol_Loss=0.6932 | Dice_coeff=0.5650 | IoU=0.3938
#  Train Loss_1: 0.6462 | Loss_2: 0.5707 | Loss_3: 0.5615 | Total_Loss: 0.8931 | Avg_dice_coeff: 0.4385 | Avg_IoU: 0.2859
# Running Validation...
#  Valid Loss_1: 0.6177 | Loss_2: 0.5406 | Loss_3: 0.5336
#  Total_Loss: 0.8487 | Dice_coeff: 0.4664 | IoU: 0.3272
# Validation loss improved from 0.5535 to 0.5336. Saving model...
# Model saved to ==> 20-06-2025_08-42-41/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-42-41/model_epoch3.pt
# ========== Epoch 5 / 150 ==========
# Training...
# [TRAIN] Epoch 5/150 | Batch 10/153 | Loss_1=0.6630 | Loss_2=0.5805 | Loss_3=0.5657 | Totol_Loss=0.9040 | Dice_coeff=0.4343 | IoU=0.2774
# [TRAIN] Epoch 5/150 | Batch 20/153 | Loss_1=0.7568 | Loss_2=0.7017 | Loss_3=0.7053 | Totol_Loss=1.1070 | Dice_coeff=0.2947 | IoU=0.1728
# [TRAIN] Epoch 5/150 | Batch 30/153 | Loss_1=0.5697 | Loss_2=0.5028 | Loss_3=0.5021 | Totol_Loss=0.7944 | Dice_coeff=0.4979 | IoU=0.3314
# [TRAIN] Epoch 5/150 | Batch 40/153 | Loss_1=0.5746 | Loss_2=0.4702 | Loss_3=0.4471 | Totol_Loss=0.7271 | Dice_coeff=0.5529 | IoU=0.3821
# [TRAIN] Epoch 5/150 | Batch 50/153 | Loss_1=0.6836 | Loss_2=0.6044 | Loss_3=0.5815 | Totol_Loss=0.9326 | Dice_coeff=0.4185 | IoU=0.2646
# [TRAIN] Epoch 5/150 | Batch 60/153 | Loss_1=0.6745 | Loss_2=0.5947 | Loss_3=0.5830 | Totol_Loss=0.9288 | Dice_coeff=0.4170 | IoU=0.2634
# [TRAIN] Epoch 5/150 | Batch 70/153 | Loss_1=0.6677 | Loss_2=0.5745 | Loss_3=0.5506 | Totol_Loss=0.8872 | Dice_coeff=0.4494 | IoU=0.2899
# [TRAIN] Epoch 5/150 | Batch 80/153 | Loss_1=0.4634 | Loss_2=0.3103 | Loss_3=0.3046 | Totol_Loss=0.5028 | Dice_coeff=0.6954 | IoU=0.5331
# [TRAIN] Epoch 5/150 | Batch 90/153 | Loss_1=0.5994 | Loss_2=0.5352 | Loss_3=0.5391 | Totol_Loss=0.8490 | Dice_coeff=0.4609 | IoU=0.2995
# [TRAIN] Epoch 5/150 | Batch 100/153 | Loss_1=0.8359 | Loss_2=0.7459 | Loss_3=0.7053 | Totol_Loss=1.1374 | Dice_coeff=0.2947 | IoU=0.1728
# [TRAIN] Epoch 5/150 | Batch 110/153 | Loss_1=0.5991 | Loss_2=0.5325 | Loss_3=0.5341 | Totol_Loss=0.8430 | Dice_coeff=0.4659 | IoU=0.3037
# [TRAIN] Epoch 5/150 | Batch 120/153 | Loss_1=0.5909 | Loss_2=0.5116 | Loss_3=0.4745 | Totol_Loss=0.7737 | Dice_coeff=0.5255 | IoU=0.3564
# [TRAIN] Epoch 5/150 | Batch 130/153 | Loss_1=0.6006 | Loss_2=0.5280 | Loss_3=0.5459 | Totol_Loss=0.8532 | Dice_coeff=0.4541 | IoU=0.2937
# [TRAIN] Epoch 5/150 | Batch 140/153 | Loss_1=0.7303 | Loss_2=0.6497 | Loss_3=0.6186 | Totol_Loss=0.9953 | Dice_coeff=0.3814 | IoU=0.2356
# [TRAIN] Epoch 5/150 | Batch 150/153 | Loss_1=0.6603 | Loss_2=0.5814 | Loss_3=0.5604 | Totol_Loss=0.8986 | Dice_coeff=0.4396 | IoU=0.2817
#  Train Loss_1: 0.6310 | Loss_2: 0.5525 | Loss_3: 0.5437 | Total_Loss: 0.8656 | Avg_dice_coeff: 0.4563 | Avg_IoU: 0.3008
# Running Validation...
#  Valid Loss_1: 0.6463 | Loss_2: 0.5598 | Loss_3: 0.5402
#  Total_Loss: 0.8675 | Dice_coeff: 0.4598 | IoU: 0.3228
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch4.pt
# ========== Epoch 6 / 150 ==========
# Training...
# [TRAIN] Epoch 6/150 | Batch 10/153 | Loss_1=0.6752 | Loss_2=0.6464 | Loss_3=0.6630 | Totol_Loss=1.0296 | Dice_coeff=0.3370 | IoU=0.2027
# [TRAIN] Epoch 6/150 | Batch 20/153 | Loss_1=0.6052 | Loss_2=0.4999 | Loss_3=0.4488 | Totol_Loss=0.7455 | Dice_coeff=0.5512 | IoU=0.3805
# [TRAIN] Epoch 6/150 | Batch 30/153 | Loss_1=0.5691 | Loss_2=0.5170 | Loss_3=0.5239 | Totol_Loss=0.8218 | Dice_coeff=0.4761 | IoU=0.3124
# [TRAIN] Epoch 6/150 | Batch 40/153 | Loss_1=0.4742 | Loss_2=0.4159 | Loss_3=0.4435 | Totol_Loss=0.6857 | Dice_coeff=0.5565 | IoU=0.3855
# [TRAIN] Epoch 6/150 | Batch 50/153 | Loss_1=0.4957 | Loss_2=0.3942 | Loss_3=0.3913 | Totol_Loss=0.6282 | Dice_coeff=0.6087 | IoU=0.4376
# [TRAIN] Epoch 6/150 | Batch 60/153 | Loss_1=0.5738 | Loss_2=0.4928 | Loss_3=0.4779 | Totol_Loss=0.7668 | Dice_coeff=0.5221 | IoU=0.3533
# [TRAIN] Epoch 6/150 | Batch 70/153 | Loss_1=0.6011 | Loss_2=0.4819 | Loss_3=0.4767 | Totol_Loss=0.7656 | Dice_coeff=0.5233 | IoU=0.3544
# [TRAIN] Epoch 6/150 | Batch 80/153 | Loss_1=0.6927 | Loss_2=0.6115 | Loss_3=0.6004 | Totol_Loss=0.9558 | Dice_coeff=0.3996 | IoU=0.2497
# [TRAIN] Epoch 6/150 | Batch 90/153 | Loss_1=0.5481 | Loss_2=0.5144 | Loss_3=0.5119 | Totol_Loss=0.8054 | Dice_coeff=0.4881 | IoU=0.3228
# [TRAIN] Epoch 6/150 | Batch 100/153 | Loss_1=0.4989 | Loss_2=0.4074 | Loss_3=0.4380 | Totol_Loss=0.6808 | Dice_coeff=0.5620 | IoU=0.3908
# [TRAIN] Epoch 6/150 | Batch 110/153 | Loss_1=0.5566 | Loss_2=0.4519 | Loss_3=0.4373 | Totol_Loss=0.7071 | Dice_coeff=0.5627 | IoU=0.3915
# [TRAIN] Epoch 6/150 | Batch 120/153 | Loss_1=0.5049 | Loss_2=0.4062 | Loss_3=0.4005 | Totol_Loss=0.6437 | Dice_coeff=0.5995 | IoU=0.4281
# [TRAIN] Epoch 6/150 | Batch 130/153 | Loss_1=0.7525 | Loss_2=0.6671 | Loss_3=0.6277 | Totol_Loss=1.0149 | Dice_coeff=0.3723 | IoU=0.2287
# [TRAIN] Epoch 6/150 | Batch 140/153 | Loss_1=0.7390 | Loss_2=0.6714 | Loss_3=0.6329 | Totol_Loss=1.0197 | Dice_coeff=0.3671 | IoU=0.2248
# [TRAIN] Epoch 6/150 | Batch 150/153 | Loss_1=0.5962 | Loss_2=0.5460 | Loss_3=0.5621 | Totol_Loss=0.8759 | Dice_coeff=0.4379 | IoU=0.2803
#  Train Loss_1: 0.6243 | Loss_2: 0.5467 | Loss_3: 0.5378 | Total_Loss: 0.8564 | Avg_dice_coeff: 0.4622 | Avg_IoU: 0.3053
# Running Validation...
#  Valid Loss_1: 0.6038 | Loss_2: 0.5077 | Loss_3: 0.4921
#  Total_Loss: 0.7918 | Dice_coeff: 0.5079 | IoU: 0.3677
# Validation loss improved from 0.5336 to 0.4921. Saving model...
# Model saved to ==> 20-06-2025_08-42-41/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-42-41/model_epoch5.pt
# ========== Epoch 7 / 150 ==========
# Training...
# [TRAIN] Epoch 7/150 | Batch 10/153 | Loss_1=0.7547 | Loss_2=0.6896 | Loss_3=0.6788 | Totol_Loss=1.0754 | Dice_coeff=0.3212 | IoU=0.1913
# [TRAIN] Epoch 7/150 | Batch 20/153 | Loss_1=0.5843 | Loss_2=0.5228 | Loss_3=0.5428 | Totol_Loss=0.8454 | Dice_coeff=0.4572 | IoU=0.2964
# [TRAIN] Epoch 7/150 | Batch 30/153 | Loss_1=0.4858 | Loss_2=0.4105 | Loss_3=0.4140 | Totol_Loss=0.6559 | Dice_coeff=0.5860 | IoU=0.4144
# [TRAIN] Epoch 7/150 | Batch 40/153 | Loss_1=0.7085 | Loss_2=0.6223 | Loss_3=0.5890 | Totol_Loss=0.9512 | Dice_coeff=0.4110 | IoU=0.2587
# [TRAIN] Epoch 7/150 | Batch 50/153 | Loss_1=0.6092 | Loss_2=0.5446 | Loss_3=0.5541 | Totol_Loss=0.8695 | Dice_coeff=0.4459 | IoU=0.2869
# [TRAIN] Epoch 7/150 | Batch 60/153 | Loss_1=0.5454 | Loss_2=0.4398 | Loss_3=0.4171 | Totol_Loss=0.6803 | Dice_coeff=0.5829 | IoU=0.4113
# [TRAIN] Epoch 7/150 | Batch 70/153 | Loss_1=0.5457 | Loss_2=0.4741 | Loss_3=0.5089 | Totol_Loss=0.7859 | Dice_coeff=0.4911 | IoU=0.3254
# [TRAIN] Epoch 7/150 | Batch 80/153 | Loss_1=0.5155 | Loss_2=0.4168 | Loss_3=0.4340 | Totol_Loss=0.6832 | Dice_coeff=0.5660 | IoU=0.3947
# [TRAIN] Epoch 7/150 | Batch 90/153 | Loss_1=0.5782 | Loss_2=0.5017 | Loss_3=0.5206 | Totol_Loss=0.8138 | Dice_coeff=0.4794 | IoU=0.3153
# [TRAIN] Epoch 7/150 | Batch 100/153 | Loss_1=0.5798 | Loss_2=0.5041 | Loss_3=0.4971 | Totol_Loss=0.7915 | Dice_coeff=0.5029 | IoU=0.3359
# [TRAIN] Epoch 7/150 | Batch 110/153 | Loss_1=0.6577 | Loss_2=0.5666 | Loss_3=0.5597 | Totol_Loss=0.8916 | Dice_coeff=0.4403 | IoU=0.2823
# [TRAIN] Epoch 7/150 | Batch 120/153 | Loss_1=0.3838 | Loss_2=0.2966 | Loss_3=0.3125 | Totol_Loss=0.4926 | Dice_coeff=0.6875 | IoU=0.5238
# [TRAIN] Epoch 7/150 | Batch 130/153 | Loss_1=0.7644 | Loss_2=0.7325 | Loss_3=0.7342 | Totol_Loss=1.1496 | Dice_coeff=0.2658 | IoU=0.1532
# [TRAIN] Epoch 7/150 | Batch 140/153 | Loss_1=0.7424 | Loss_2=0.6467 | Loss_3=0.6047 | Totol_Loss=0.9822 | Dice_coeff=0.3953 | IoU=0.2463
# [TRAIN] Epoch 7/150 | Batch 150/153 | Loss_1=0.5905 | Loss_2=0.5218 | Loss_3=0.5337 | Totol_Loss=0.8369 | Dice_coeff=0.4663 | IoU=0.3041
#  Train Loss_1: 0.6138 | Loss_2: 0.5341 | Loss_3: 0.5270 | Total_Loss: 0.8388 | Avg_dice_coeff: 0.4730 | Avg_IoU: 0.3154
# Running Validation...
#  Valid Loss_1: 0.6427 | Loss_2: 0.5677 | Loss_3: 0.5653
#  Total_Loss: 0.8952 | Dice_coeff: 0.4347 | IoU: 0.2954
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch6.pt
# ========== Epoch 8 / 150 ==========
# Training...
# [TRAIN] Epoch 8/150 | Batch 10/153 | Loss_1=0.7717 | Loss_2=0.6479 | Loss_3=0.6132 | Totol_Loss=0.9958 | Dice_coeff=0.3868 | IoU=0.2398
# [TRAIN] Epoch 8/150 | Batch 20/153 | Loss_1=0.5706 | Loss_2=0.4307 | Loss_3=0.4010 | Totol_Loss=0.6645 | Dice_coeff=0.5990 | IoU=0.4276
# [TRAIN] Epoch 8/150 | Batch 30/153 | Loss_1=0.5342 | Loss_2=0.4629 | Loss_3=0.4823 | Totol_Loss=0.7530 | Dice_coeff=0.5177 | IoU=0.3492
# [TRAIN] Epoch 8/150 | Batch 40/153 | Loss_1=0.5438 | Loss_2=0.4708 | Loss_3=0.4938 | Totol_Loss=0.7692 | Dice_coeff=0.5062 | IoU=0.3388
# [TRAIN] Epoch 8/150 | Batch 50/153 | Loss_1=0.5565 | Loss_2=0.4448 | Loss_3=0.4554 | Totol_Loss=0.7223 | Dice_coeff=0.5446 | IoU=0.3742
# [TRAIN] Epoch 8/150 | Batch 60/153 | Loss_1=0.6603 | Loss_2=0.5472 | Loss_3=0.5107 | Totol_Loss=0.8352 | Dice_coeff=0.4893 | IoU=0.3239
# [TRAIN] Epoch 8/150 | Batch 70/153 | Loss_1=0.6272 | Loss_2=0.5205 | Loss_3=0.4948 | Totol_Loss=0.8033 | Dice_coeff=0.5052 | IoU=0.3380
# [TRAIN] Epoch 8/150 | Batch 80/153 | Loss_1=0.7835 | Loss_2=0.6917 | Loss_3=0.6394 | Totol_Loss=1.0414 | Dice_coeff=0.3606 | IoU=0.2200
# [TRAIN] Epoch 8/150 | Batch 90/153 | Loss_1=0.6556 | Loss_2=0.5859 | Loss_3=0.5903 | Totol_Loss=0.9295 | Dice_coeff=0.4097 | IoU=0.2576
# [TRAIN] Epoch 8/150 | Batch 100/153 | Loss_1=0.5561 | Loss_2=0.4552 | Loss_3=0.4264 | Totol_Loss=0.6975 | Dice_coeff=0.5736 | IoU=0.4021
# [TRAIN] Epoch 8/150 | Batch 110/153 | Loss_1=0.4850 | Loss_2=0.3819 | Loss_3=0.3365 | Totol_Loss=0.5669 | Dice_coeff=0.6635 | IoU=0.4964
# [TRAIN] Epoch 8/150 | Batch 120/153 | Loss_1=0.6219 | Loss_2=0.5533 | Loss_3=0.5453 | Totol_Loss=0.8662 | Dice_coeff=0.4547 | IoU=0.2942
# [TRAIN] Epoch 8/150 | Batch 130/153 | Loss_1=0.4973 | Loss_2=0.4313 | Loss_3=0.4821 | Totol_Loss=0.7342 | Dice_coeff=0.5179 | IoU=0.3494
# [TRAIN] Epoch 8/150 | Batch 140/153 | Loss_1=0.6289 | Loss_2=0.5487 | Loss_3=0.5615 | Totol_Loss=0.8817 | Dice_coeff=0.4385 | IoU=0.2808
# [TRAIN] Epoch 8/150 | Batch 150/153 | Loss_1=0.7535 | Loss_2=0.6455 | Loss_3=0.6021 | Totol_Loss=0.9808 | Dice_coeff=0.3979 | IoU=0.2484
#  Train Loss_1: 0.6215 | Loss_2: 0.5311 | Loss_3: 0.5220 | Total_Loss: 0.8339 | Avg_dice_coeff: 0.4780 | Avg_IoU: 0.3190
# Running Validation...
#  Valid Loss_1: 0.6221 | Loss_2: 0.4954 | Loss_3: 0.4960
#  Total_Loss: 0.7937 | Dice_coeff: 0.5040 | IoU: 0.3633
# No improvement in validation loss for 2 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch7.pt
# ========== Epoch 9 / 150 ==========
# Training...
# [TRAIN] Epoch 9/150 | Batch 10/153 | Loss_1=0.6625 | Loss_2=0.5805 | Loss_3=0.5691 | Totol_Loss=0.9073 | Dice_coeff=0.4309 | IoU=0.2746
# [TRAIN] Epoch 9/150 | Batch 20/153 | Loss_1=0.6846 | Loss_2=0.6199 | Loss_3=0.6343 | Totol_Loss=0.9918 | Dice_coeff=0.3657 | IoU=0.2238
# [TRAIN] Epoch 9/150 | Batch 30/153 | Loss_1=0.5321 | Loss_2=0.4345 | Loss_3=0.4462 | Totol_Loss=0.7052 | Dice_coeff=0.5538 | IoU=0.3829
# [TRAIN] Epoch 9/150 | Batch 40/153 | Loss_1=0.5925 | Loss_2=0.5003 | Loss_3=0.5041 | Totol_Loss=0.7991 | Dice_coeff=0.4959 | IoU=0.3297
# [TRAIN] Epoch 9/150 | Batch 50/153 | Loss_1=0.6019 | Loss_2=0.5569 | Loss_3=0.5597 | Totol_Loss=0.8787 | Dice_coeff=0.4403 | IoU=0.2823
# [TRAIN] Epoch 9/150 | Batch 60/153 | Loss_1=0.6185 | Loss_2=0.5966 | Loss_3=0.6145 | Totol_Loss=0.9521 | Dice_coeff=0.3855 | IoU=0.2388
# [TRAIN] Epoch 9/150 | Batch 70/153 | Loss_1=0.5798 | Loss_2=0.4974 | Loss_3=0.4698 | Totol_Loss=0.7615 | Dice_coeff=0.5302 | IoU=0.3608
# [TRAIN] Epoch 9/150 | Batch 80/153 | Loss_1=0.6358 | Loss_2=0.5787 | Loss_3=0.5772 | Totol_Loss=0.9105 | Dice_coeff=0.4228 | IoU=0.2680
# [TRAIN] Epoch 9/150 | Batch 90/153 | Loss_1=0.6250 | Loss_2=0.5151 | Loss_3=0.4913 | Totol_Loss=0.7974 | Dice_coeff=0.5087 | IoU=0.3411
# [TRAIN] Epoch 9/150 | Batch 100/153 | Loss_1=0.6239 | Loss_2=0.5407 | Loss_3=0.5127 | Totol_Loss=0.8288 | Dice_coeff=0.4873 | IoU=0.3221
# [TRAIN] Epoch 9/150 | Batch 110/153 | Loss_1=0.6951 | Loss_2=0.5288 | Loss_3=0.4708 | Totol_Loss=0.7935 | Dice_coeff=0.5292 | IoU=0.3598
# [TRAIN] Epoch 9/150 | Batch 120/153 | Loss_1=0.6956 | Loss_2=0.5829 | Loss_3=0.5544 | Totol_Loss=0.8988 | Dice_coeff=0.4456 | IoU=0.2867
# [TRAIN] Epoch 9/150 | Batch 130/153 | Loss_1=0.7773 | Loss_2=0.7296 | Loss_3=0.7161 | Totol_Loss=1.1323 | Dice_coeff=0.2839 | IoU=0.1654
# [TRAIN] Epoch 9/150 | Batch 140/153 | Loss_1=0.5508 | Loss_2=0.4326 | Loss_3=0.4174 | Totol_Loss=0.6786 | Dice_coeff=0.5826 | IoU=0.4111
# [TRAIN] Epoch 9/150 | Batch 150/153 | Loss_1=0.5685 | Loss_2=0.4128 | Loss_3=0.4448 | Totol_Loss=0.7009 | Dice_coeff=0.5552 | IoU=0.3843
#  Train Loss_1: 0.6134 | Loss_2: 0.5271 | Loss_3: 0.5207 | Total_Loss: 0.8297 | Avg_dice_coeff: 0.4793 | Avg_IoU: 0.3204
# Running Validation...
#  Valid Loss_1: 0.5879 | Loss_2: 0.4766 | Loss_3: 0.4785
#  Total_Loss: 0.7632 | Dice_coeff: 0.5215 | IoU: 0.3775
# Validation loss improved from 0.4921 to 0.4785. Saving model...
# Model saved to ==> 20-06-2025_08-42-41/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-42-41/model_epoch8.pt
# ========== Epoch 10 / 150 ==========
# Training...
# [TRAIN] Epoch 10/150 | Batch 10/153 | Loss_1=0.5989 | Loss_2=0.5068 | Loss_3=0.5166 | Totol_Loss=0.8151 | Dice_coeff=0.4834 | IoU=0.3188
# [TRAIN] Epoch 10/150 | Batch 20/153 | Loss_1=0.4933 | Loss_2=0.4160 | Loss_3=0.4522 | Totol_Loss=0.6976 | Dice_coeff=0.5478 | IoU=0.3772
# [TRAIN] Epoch 10/150 | Batch 30/153 | Loss_1=0.5646 | Loss_2=0.4700 | Loss_3=0.4536 | Totol_Loss=0.7320 | Dice_coeff=0.5464 | IoU=0.3759
# [TRAIN] Epoch 10/150 | Batch 40/153 | Loss_1=0.4768 | Loss_2=0.3523 | Loss_3=0.3450 | Totol_Loss=0.5622 | Dice_coeff=0.6550 | IoU=0.4870
# [TRAIN] Epoch 10/150 | Batch 50/153 | Loss_1=0.6669 | Loss_2=0.5695 | Loss_3=0.5310 | Totol_Loss=0.8655 | Dice_coeff=0.4690 | IoU=0.3063
# [TRAIN] Epoch 10/150 | Batch 60/153 | Loss_1=0.5552 | Loss_2=0.3777 | Loss_3=0.3929 | Totol_Loss=0.6328 | Dice_coeff=0.6071 | IoU=0.4359
# [TRAIN] Epoch 10/150 | Batch 70/153 | Loss_1=0.4747 | Loss_2=0.4500 | Loss_3=0.4876 | Totol_Loss=0.7436 | Dice_coeff=0.5124 | IoU=0.3444
# [TRAIN] Epoch 10/150 | Batch 80/153 | Loss_1=0.4622 | Loss_2=0.3326 | Loss_3=0.3720 | Totol_Loss=0.5790 | Dice_coeff=0.6280 | IoU=0.4577
# [TRAIN] Epoch 10/150 | Batch 90/153 | Loss_1=0.6930 | Loss_2=0.5758 | Loss_3=0.5918 | Totol_Loss=0.9330 | Dice_coeff=0.4082 | IoU=0.2565
# [TRAIN] Epoch 10/150 | Batch 100/153 | Loss_1=0.6694 | Loss_2=0.5516 | Loss_3=0.5461 | Totol_Loss=0.8738 | Dice_coeff=0.4539 | IoU=0.2936
# [TRAIN] Epoch 10/150 | Batch 110/153 | Loss_1=0.5926 | Loss_2=0.5080 | Loss_3=0.5336 | Totol_Loss=0.8316 | Dice_coeff=0.4664 | IoU=0.3041
# [TRAIN] Epoch 10/150 | Batch 120/153 | Loss_1=0.6781 | Loss_2=0.5640 | Loss_3=0.5402 | Totol_Loss=0.8742 | Dice_coeff=0.4598 | IoU=0.2986
# [TRAIN] Epoch 10/150 | Batch 130/153 | Loss_1=0.7184 | Loss_2=0.6208 | Loss_3=0.6184 | Totol_Loss=0.9817 | Dice_coeff=0.3816 | IoU=0.2358
# [TRAIN] Epoch 10/150 | Batch 140/153 | Loss_1=0.6116 | Loss_2=0.4376 | Loss_3=0.4552 | Totol_Loss=0.7281 | Dice_coeff=0.5448 | IoU=0.3744
# [TRAIN] Epoch 10/150 | Batch 150/153 | Loss_1=0.5468 | Loss_2=0.4197 | Loss_3=0.4130 | Totol_Loss=0.6683 | Dice_coeff=0.5870 | IoU=0.4155
#  Train Loss_1: 0.6123 | Loss_2: 0.5102 | Loss_3: 0.5059 | Total_Loss: 0.8080 | Avg_dice_coeff: 0.4941 | Avg_IoU: 0.3334
# Running Validation...
#  Valid Loss_1: 0.5900 | Loss_2: 0.4674 | Loss_3: 0.4642
#  Total_Loss: 0.7456 | Dice_coeff: 0.5358 | IoU: 0.3910
# Validation loss improved from 0.4785 to 0.4642. Saving model...
# Model saved to ==> 20-06-2025_08-42-41/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-42-41/model_epoch9.pt
# ========== Epoch 11 / 150 ==========
# Training...
# [TRAIN] Epoch 11/150 | Batch 10/153 | Loss_1=0.7076 | Loss_2=0.6148 | Loss_3=0.5901 | Totol_Loss=0.9492 | Dice_coeff=0.4099 | IoU=0.2578
# [TRAIN] Epoch 11/150 | Batch 20/153 | Loss_1=0.8251 | Loss_2=0.7513 | Loss_3=0.7249 | Totol_Loss=1.1574 | Dice_coeff=0.2751 | IoU=0.1595
# [TRAIN] Epoch 11/150 | Batch 30/153 | Loss_1=0.7414 | Loss_2=0.6757 | Loss_3=0.6680 | Totol_Loss=1.0569 | Dice_coeff=0.3320 | IoU=0.1990
# [TRAIN] Epoch 11/150 | Batch 40/153 | Loss_1=0.4385 | Loss_2=0.3189 | Loss_3=0.3242 | Totol_Loss=0.5219 | Dice_coeff=0.6758 | IoU=0.5103
# [TRAIN] Epoch 11/150 | Batch 50/153 | Loss_1=0.6408 | Loss_2=0.4935 | Loss_3=0.4701 | Totol_Loss=0.7701 | Dice_coeff=0.5299 | IoU=0.3604
# [TRAIN] Epoch 11/150 | Batch 60/153 | Loss_1=0.6084 | Loss_2=0.4975 | Loss_3=0.4733 | Totol_Loss=0.7696 | Dice_coeff=0.5267 | IoU=0.3575
# [TRAIN] Epoch 11/150 | Batch 70/153 | Loss_1=0.5961 | Loss_2=0.5164 | Loss_3=0.5177 | Totol_Loss=0.8197 | Dice_coeff=0.4823 | IoU=0.3178
# [TRAIN] Epoch 11/150 | Batch 80/153 | Loss_1=0.5821 | Loss_2=0.4377 | Loss_3=0.4278 | Totol_Loss=0.6960 | Dice_coeff=0.5722 | IoU=0.4007
# [TRAIN] Epoch 11/150 | Batch 90/153 | Loss_1=0.7020 | Loss_2=0.6142 | Loss_3=0.5939 | Totol_Loss=0.9519 | Dice_coeff=0.4061 | IoU=0.2548
# [TRAIN] Epoch 11/150 | Batch 100/153 | Loss_1=0.5720 | Loss_2=0.3727 | Loss_3=0.4021 | Totol_Loss=0.6427 | Dice_coeff=0.5979 | IoU=0.4264
# [TRAIN] Epoch 11/150 | Batch 110/153 | Loss_1=0.5407 | Loss_2=0.4285 | Loss_3=0.4023 | Totol_Loss=0.6602 | Dice_coeff=0.5977 | IoU=0.4263
# [TRAIN] Epoch 11/150 | Batch 120/153 | Loss_1=0.6562 | Loss_2=0.5497 | Loss_3=0.5295 | Totol_Loss=0.8544 | Dice_coeff=0.4705 | IoU=0.3076
# [TRAIN] Epoch 11/150 | Batch 130/153 | Loss_1=0.5662 | Loss_2=0.4446 | Loss_3=0.4342 | Totol_Loss=0.7027 | Dice_coeff=0.5658 | IoU=0.3945
# [TRAIN] Epoch 11/150 | Batch 140/153 | Loss_1=0.6474 | Loss_2=0.5529 | Loss_3=0.5293 | Totol_Loss=0.8541 | Dice_coeff=0.4707 | IoU=0.3078
# [TRAIN] Epoch 11/150 | Batch 150/153 | Loss_1=0.7206 | Loss_2=0.6481 | Loss_3=0.6548 | Totol_Loss=1.0293 | Dice_coeff=0.3452 | IoU=0.2086
#  Train Loss_1: 0.6211 | Loss_2: 0.5121 | Loss_3: 0.5058 | Total_Loss: 0.8100 | Avg_dice_coeff: 0.4942 | Avg_IoU: 0.3342
# Running Validation...
#  Valid Loss_1: 0.5902 | Loss_2: 0.5219 | Loss_3: 0.5278
#  Total_Loss: 0.8310 | Dice_coeff: 0.4722 | IoU: 0.3277
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch10.pt
# ========== Epoch 12 / 150 ==========
# Training...
# [TRAIN] Epoch 12/150 | Batch 10/153 | Loss_1=0.5571 | Loss_2=0.4879 | Loss_3=0.4944 | Totol_Loss=0.7787 | Dice_coeff=0.5056 | IoU=0.3383
# [TRAIN] Epoch 12/150 | Batch 20/153 | Loss_1=0.5677 | Loss_2=0.4720 | Loss_3=0.4761 | Totol_Loss=0.7557 | Dice_coeff=0.5239 | IoU=0.3549
# [TRAIN] Epoch 12/150 | Batch 30/153 | Loss_1=0.6670 | Loss_2=0.5610 | Loss_3=0.5605 | Totol_Loss=0.8916 | Dice_coeff=0.4395 | IoU=0.2816
# [TRAIN] Epoch 12/150 | Batch 40/153 | Loss_1=0.5957 | Loss_2=0.3844 | Loss_3=0.3757 | Totol_Loss=0.6247 | Dice_coeff=0.6243 | IoU=0.4539
# [TRAIN] Epoch 12/150 | Batch 50/153 | Loss_1=0.6503 | Loss_2=0.5720 | Loss_3=0.5688 | Totol_Loss=0.9016 | Dice_coeff=0.4312 | IoU=0.2749
# [TRAIN] Epoch 12/150 | Batch 60/153 | Loss_1=0.4418 | Loss_2=0.3441 | Loss_3=0.3515 | Totol_Loss=0.5598 | Dice_coeff=0.6485 | IoU=0.4798
# [TRAIN] Epoch 12/150 | Batch 70/153 | Loss_1=0.7046 | Loss_2=0.6756 | Loss_3=0.6620 | Totol_Loss=1.0450 | Dice_coeff=0.3380 | IoU=0.2034
# [TRAIN] Epoch 12/150 | Batch 80/153 | Loss_1=0.7081 | Loss_2=0.6263 | Loss_3=0.6193 | Totol_Loss=0.9831 | Dice_coeff=0.3807 | IoU=0.2351
# [TRAIN] Epoch 12/150 | Batch 90/153 | Loss_1=0.7177 | Loss_2=0.5634 | Loss_3=0.5325 | Totol_Loss=0.8727 | Dice_coeff=0.4675 | IoU=0.3050
# [TRAIN] Epoch 12/150 | Batch 100/153 | Loss_1=0.4839 | Loss_2=0.3165 | Loss_3=0.3430 | Totol_Loss=0.5470 | Dice_coeff=0.6570 | IoU=0.4893
# [TRAIN] Epoch 12/150 | Batch 110/153 | Loss_1=0.4692 | Loss_2=0.3570 | Loss_3=0.3685 | Totol_Loss=0.5864 | Dice_coeff=0.6315 | IoU=0.4614
# [TRAIN] Epoch 12/150 | Batch 120/153 | Loss_1=0.4875 | Loss_2=0.3297 | Loss_3=0.3537 | Totol_Loss=0.5636 | Dice_coeff=0.6463 | IoU=0.4774
# [TRAIN] Epoch 12/150 | Batch 130/153 | Loss_1=0.6032 | Loss_2=0.5354 | Loss_3=0.5064 | Totol_Loss=0.8171 | Dice_coeff=0.4936 | IoU=0.3277
# [TRAIN] Epoch 12/150 | Batch 140/153 | Loss_1=0.7225 | Loss_2=0.6370 | Loss_3=0.6072 | Totol_Loss=0.9777 | Dice_coeff=0.3928 | IoU=0.2444
# [TRAIN] Epoch 12/150 | Batch 150/153 | Loss_1=0.6134 | Loss_2=0.4869 | Loss_3=0.4890 | Totol_Loss=0.7819 | Dice_coeff=0.5110 | IoU=0.3432
#  Train Loss_1: 0.6160 | Loss_2: 0.5008 | Loss_3: 0.4931 | Total_Loss: 0.7919 | Avg_dice_coeff: 0.5069 | Avg_IoU: 0.3451
# Running Validation...
#  Valid Loss_1: 0.5926 | Loss_2: 0.4592 | Loss_3: 0.4727
#  Total_Loss: 0.7512 | Dice_coeff: 0.5273 | IoU: 0.3815
# No improvement in validation loss for 2 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch11.pt
# ========== Epoch 13 / 150 ==========
# Training...
# [TRAIN] Epoch 13/150 | Batch 10/153 | Loss_1=0.5226 | Loss_2=0.3965 | Loss_3=0.4109 | Totol_Loss=0.6531 | Dice_coeff=0.5891 | IoU=0.4175
# [TRAIN] Epoch 13/150 | Batch 20/153 | Loss_1=0.5214 | Loss_2=0.3724 | Loss_3=0.3701 | Totol_Loss=0.6025 | Dice_coeff=0.6299 | IoU=0.4598
# [TRAIN] Epoch 13/150 | Batch 30/153 | Loss_1=0.6234 | Loss_2=0.4890 | Loss_3=0.4889 | Totol_Loss=0.7843 | Dice_coeff=0.5111 | IoU=0.3433
# [TRAIN] Epoch 13/150 | Batch 40/153 | Loss_1=0.4170 | Loss_2=0.2666 | Loss_3=0.2581 | Totol_Loss=0.4315 | Dice_coeff=0.7419 | IoU=0.5897
# [TRAIN] Epoch 13/150 | Batch 50/153 | Loss_1=0.6753 | Loss_2=0.5917 | Loss_3=0.5893 | Totol_Loss=0.9340 | Dice_coeff=0.4107 | IoU=0.2584
# [TRAIN] Epoch 13/150 | Batch 60/153 | Loss_1=0.6429 | Loss_2=0.5292 | Loss_3=0.4856 | Totol_Loss=0.8001 | Dice_coeff=0.5144 | IoU=0.3463
# [TRAIN] Epoch 13/150 | Batch 70/153 | Loss_1=0.6651 | Loss_2=0.5498 | Loss_3=0.5410 | Totol_Loss=0.8674 | Dice_coeff=0.4590 | IoU=0.2978
# [TRAIN] Epoch 13/150 | Batch 80/153 | Loss_1=0.3771 | Loss_2=0.2865 | Loss_3=0.3228 | Totol_Loss=0.4978 | Dice_coeff=0.6772 | IoU=0.5119
# [TRAIN] Epoch 13/150 | Batch 90/153 | Loss_1=0.5803 | Loss_2=0.4929 | Loss_3=0.5153 | Totol_Loss=0.8053 | Dice_coeff=0.4847 | IoU=0.3199
# [TRAIN] Epoch 13/150 | Batch 100/153 | Loss_1=0.7322 | Loss_2=0.6623 | Loss_3=0.6431 | Totol_Loss=1.0252 | Dice_coeff=0.3569 | IoU=0.2172
# [TRAIN] Epoch 13/150 | Batch 110/153 | Loss_1=0.6629 | Loss_2=0.5389 | Loss_3=0.5136 | Totol_Loss=0.8352 | Dice_coeff=0.4864 | IoU=0.3213
# [TRAIN] Epoch 13/150 | Batch 120/153 | Loss_1=0.4742 | Loss_2=0.4276 | Loss_3=0.4185 | Totol_Loss=0.6654 | Dice_coeff=0.5815 | IoU=0.4100
# [TRAIN] Epoch 13/150 | Batch 130/153 | Loss_1=0.7209 | Loss_2=0.6517 | Loss_3=0.6322 | Totol_Loss=1.0083 | Dice_coeff=0.3678 | IoU=0.2253
# [TRAIN] Epoch 13/150 | Batch 140/153 | Loss_1=0.6303 | Loss_2=0.5234 | Loss_3=0.4923 | Totol_Loss=0.8025 | Dice_coeff=0.5077 | IoU=0.3402
# [TRAIN] Epoch 13/150 | Batch 150/153 | Loss_1=0.5747 | Loss_2=0.4780 | Loss_3=0.4617 | Totol_Loss=0.7449 | Dice_coeff=0.5383 | IoU=0.3683
#  Train Loss_1: 0.6034 | Loss_2: 0.4862 | Loss_3: 0.4791 | Total_Loss: 0.7701 | Avg_dice_coeff: 0.5209 | Avg_IoU: 0.3590
# Running Validation...
#  Valid Loss_1: 0.5780 | Loss_2: 0.4548 | Loss_3: 0.4500
#  Total_Loss: 0.7244 | Dice_coeff: 0.5500 | IoU: 0.4122
# Validation loss improved from 0.4642 to 0.4500. Saving model...
# Model saved to ==> 20-06-2025_08-42-41/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-42-41/model_epoch12.pt
# ========== Epoch 14 / 150 ==========
# Training...
# [TRAIN] Epoch 14/150 | Batch 10/153 | Loss_1=0.7419 | Loss_2=0.6584 | Loss_3=0.6331 | Totol_Loss=1.0152 | Dice_coeff=0.3669 | IoU=0.2247
# [TRAIN] Epoch 14/150 | Batch 20/153 | Loss_1=0.7350 | Loss_2=0.6209 | Loss_3=0.5759 | Totol_Loss=0.9418 | Dice_coeff=0.4241 | IoU=0.2691
# [TRAIN] Epoch 14/150 | Batch 30/153 | Loss_1=0.7321 | Loss_2=0.6341 | Loss_3=0.6024 | Totol_Loss=0.9732 | Dice_coeff=0.3976 | IoU=0.2481
# [TRAIN] Epoch 14/150 | Batch 40/153 | Loss_1=0.7247 | Loss_2=0.6759 | Loss_3=0.6783 | Totol_Loss=1.0646 | Dice_coeff=0.3217 | IoU=0.1917
# [TRAIN] Epoch 14/150 | Batch 50/153 | Loss_1=0.5195 | Loss_2=0.4212 | Loss_3=0.4183 | Totol_Loss=0.6700 | Dice_coeff=0.5817 | IoU=0.4101
# [TRAIN] Epoch 14/150 | Batch 60/153 | Loss_1=0.5561 | Loss_2=0.4290 | Loss_3=0.4591 | Totol_Loss=0.7197 | Dice_coeff=0.5409 | IoU=0.3707
# [TRAIN] Epoch 14/150 | Batch 70/153 | Loss_1=0.5701 | Loss_2=0.4553 | Loss_3=0.4423 | Totol_Loss=0.7156 | Dice_coeff=0.5577 | IoU=0.3867
# [TRAIN] Epoch 14/150 | Batch 80/153 | Loss_1=0.5649 | Loss_2=0.4178 | Loss_3=0.4286 | Totol_Loss=0.6861 | Dice_coeff=0.5714 | IoU=0.4000
# [TRAIN] Epoch 14/150 | Batch 90/153 | Loss_1=0.4921 | Loss_2=0.3467 | Loss_3=0.3251 | Totol_Loss=0.5425 | Dice_coeff=0.6749 | IoU=0.5094
# [TRAIN] Epoch 14/150 | Batch 100/153 | Loss_1=0.6214 | Loss_2=0.5336 | Loss_3=0.5283 | Totol_Loss=0.8412 | Dice_coeff=0.4717 | IoU=0.3086
# [TRAIN] Epoch 14/150 | Batch 110/153 | Loss_1=0.6129 | Loss_2=0.5152 | Loss_3=0.4923 | Totol_Loss=0.7964 | Dice_coeff=0.5077 | IoU=0.3403
# [TRAIN] Epoch 14/150 | Batch 120/153 | Loss_1=0.4414 | Loss_2=0.2515 | Loss_3=0.2418 | Totol_Loss=0.4130 | Dice_coeff=0.7582 | IoU=0.6106
# [TRAIN] Epoch 14/150 | Batch 130/153 | Loss_1=0.3204 | Loss_2=0.2159 | Loss_3=0.2326 | Totol_Loss=0.3702 | Dice_coeff=0.7674 | IoU=0.6226
# [TRAIN] Epoch 14/150 | Batch 140/153 | Loss_1=0.6538 | Loss_2=0.5470 | Loss_3=0.5180 | Totol_Loss=0.8414 | Dice_coeff=0.4820 | IoU=0.3175
# [TRAIN] Epoch 14/150 | Batch 150/153 | Loss_1=0.7589 | Loss_2=0.6579 | Loss_3=0.6293 | Totol_Loss=1.0139 | Dice_coeff=0.3707 | IoU=0.2275
#  Train Loss_1: 0.6184 | Loss_2: 0.5058 | Loss_3: 0.4968 | Total_Loss: 0.7980 | Avg_dice_coeff: 0.5032 | Avg_IoU: 0.3430
# Running Validation...
#  Valid Loss_1: 0.5886 | Loss_2: 0.4522 | Loss_3: 0.4556
#  Total_Loss: 0.7307 | Dice_coeff: 0.5444 | IoU: 0.3993
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch13.pt
# ========== Epoch 15 / 150 ==========
# Training...
# [TRAIN] Epoch 15/150 | Batch 10/153 | Loss_1=0.7258 | Loss_2=0.6024 | Loss_3=0.6157 | Totol_Loss=0.9728 | Dice_coeff=0.3843 | IoU=0.2378
# [TRAIN] Epoch 15/150 | Batch 20/153 | Loss_1=0.5879 | Loss_2=0.4817 | Loss_3=0.5093 | Totol_Loss=0.7960 | Dice_coeff=0.4907 | IoU=0.3252
# [TRAIN] Epoch 15/150 | Batch 30/153 | Loss_1=0.5723 | Loss_2=0.4071 | Loss_3=0.3934 | Totol_Loss=0.6478 | Dice_coeff=0.6066 | IoU=0.4353
# [TRAIN] Epoch 15/150 | Batch 40/153 | Loss_1=0.5355 | Loss_2=0.3190 | Loss_3=0.3174 | Totol_Loss=0.5306 | Dice_coeff=0.6826 | IoU=0.5182
# [TRAIN] Epoch 15/150 | Batch 50/153 | Loss_1=0.7498 | Loss_2=0.6013 | Loss_3=0.5715 | Totol_Loss=0.9320 | Dice_coeff=0.4285 | IoU=0.2726
# [TRAIN] Epoch 15/150 | Batch 60/153 | Loss_1=0.6811 | Loss_2=0.5334 | Loss_3=0.5224 | Totol_Loss=0.8447 | Dice_coeff=0.4776 | IoU=0.3137
# [TRAIN] Epoch 15/150 | Batch 70/153 | Loss_1=0.7733 | Loss_2=0.6044 | Loss_3=0.5843 | Totol_Loss=0.9498 | Dice_coeff=0.4157 | IoU=0.2624
# [TRAIN] Epoch 15/150 | Batch 80/153 | Loss_1=0.6156 | Loss_2=0.5074 | Loss_3=0.4935 | Totol_Loss=0.7949 | Dice_coeff=0.5065 | IoU=0.3391
# [TRAIN] Epoch 15/150 | Batch 90/153 | Loss_1=0.7151 | Loss_2=0.6352 | Loss_3=0.6453 | Totol_Loss=1.0138 | Dice_coeff=0.3547 | IoU=0.2156
# [TRAIN] Epoch 15/150 | Batch 100/153 | Loss_1=0.4975 | Loss_2=0.4216 | Loss_3=0.4526 | Totol_Loss=0.7008 | Dice_coeff=0.5474 | IoU=0.3768
# [TRAIN] Epoch 15/150 | Batch 110/153 | Loss_1=0.5006 | Loss_2=0.3983 | Loss_3=0.3957 | Totol_Loss=0.6352 | Dice_coeff=0.6043 | IoU=0.4329
# [TRAIN] Epoch 15/150 | Batch 120/153 | Loss_1=0.6460 | Loss_2=0.4073 | Loss_3=0.4057 | Totol_Loss=0.6720 | Dice_coeff=0.5943 | IoU=0.4228
# [TRAIN] Epoch 15/150 | Batch 130/153 | Loss_1=0.7075 | Loss_2=0.5127 | Loss_3=0.4804 | Totol_Loss=0.7987 | Dice_coeff=0.5196 | IoU=0.3510
# [TRAIN] Epoch 15/150 | Batch 140/153 | Loss_1=0.7131 | Loss_2=0.6492 | Loss_3=0.6177 | Totol_Loss=0.9915 | Dice_coeff=0.3823 | IoU=0.2363
# [TRAIN] Epoch 15/150 | Batch 150/153 | Loss_1=0.6186 | Loss_2=0.5021 | Loss_3=0.4852 | Totol_Loss=0.7850 | Dice_coeff=0.5148 | IoU=0.3466
#  Train Loss_1: 0.6359 | Loss_2: 0.4993 | Loss_3: 0.4920 | Total_Loss: 0.7935 | Avg_dice_coeff: 0.5080 | Avg_IoU: 0.3467
# Running Validation...
#  Valid Loss_1: 0.5815 | Loss_2: 0.4630 | Loss_3: 0.4645
#  Total_Loss: 0.7428 | Dice_coeff: 0.5355 | IoU: 0.3929
# No improvement in validation loss for 2 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch14.pt
# ========== Epoch 16 / 150 ==========
# Training...
# [TRAIN] Epoch 16/150 | Batch 10/153 | Loss_1=0.5233 | Loss_2=0.4467 | Loss_3=0.4358 | Totol_Loss=0.6982 | Dice_coeff=0.5642 | IoU=0.3929
# [TRAIN] Epoch 16/150 | Batch 20/153 | Loss_1=0.4339 | Loss_2=0.2985 | Loss_3=0.2904 | Totol_Loss=0.4793 | Dice_coeff=0.7096 | IoU=0.5499
# [TRAIN] Epoch 16/150 | Batch 30/153 | Loss_1=0.6156 | Loss_2=0.5062 | Loss_3=0.4990 | Totol_Loss=0.7999 | Dice_coeff=0.5010 | IoU=0.3342
# [TRAIN] Epoch 16/150 | Batch 40/153 | Loss_1=0.6654 | Loss_2=0.5842 | Loss_3=0.5524 | Totol_Loss=0.8925 | Dice_coeff=0.4476 | IoU=0.2883
# [TRAIN] Epoch 16/150 | Batch 50/153 | Loss_1=0.7312 | Loss_2=0.6776 | Loss_3=0.6661 | Totol_Loss=1.0542 | Dice_coeff=0.3339 | IoU=0.2004
# [TRAIN] Epoch 16/150 | Batch 60/153 | Loss_1=0.6164 | Loss_2=0.4983 | Loss_3=0.4842 | Totol_Loss=0.7821 | Dice_coeff=0.5158 | IoU=0.3476
# [TRAIN] Epoch 16/150 | Batch 70/153 | Loss_1=0.7545 | Loss_2=0.6867 | Loss_3=0.6707 | Totol_Loss=1.0661 | Dice_coeff=0.3293 | IoU=0.1971
# [TRAIN] Epoch 16/150 | Batch 80/153 | Loss_1=0.6994 | Loss_2=0.5635 | Loss_3=0.5609 | Totol_Loss=0.8982 | Dice_coeff=0.4391 | IoU=0.2813
# [TRAIN] Epoch 16/150 | Batch 90/153 | Loss_1=0.6296 | Loss_2=0.4698 | Loss_3=0.4665 | Totol_Loss=0.7552 | Dice_coeff=0.5335 | IoU=0.3638
# [TRAIN] Epoch 16/150 | Batch 100/153 | Loss_1=0.7406 | Loss_2=0.6617 | Loss_3=0.6160 | Totol_Loss=0.9992 | Dice_coeff=0.3840 | IoU=0.2376
# [TRAIN] Epoch 16/150 | Batch 110/153 | Loss_1=0.5909 | Loss_2=0.4076 | Loss_3=0.4152 | Totol_Loss=0.6728 | Dice_coeff=0.5848 | IoU=0.4132
# [TRAIN] Epoch 16/150 | Batch 120/153 | Loss_1=0.6107 | Loss_2=0.4574 | Loss_3=0.4188 | Totol_Loss=0.6995 | Dice_coeff=0.5812 | IoU=0.4096
# [TRAIN] Epoch 16/150 | Batch 130/153 | Loss_1=0.5470 | Loss_2=0.4089 | Loss_3=0.4425 | Totol_Loss=0.6936 | Dice_coeff=0.5575 | IoU=0.3864
# [TRAIN] Epoch 16/150 | Batch 140/153 | Loss_1=0.6040 | Loss_2=0.3828 | Loss_3=0.3673 | Totol_Loss=0.6170 | Dice_coeff=0.6327 | IoU=0.4627
# [TRAIN] Epoch 16/150 | Batch 150/153 | Loss_1=0.5342 | Loss_2=0.4287 | Loss_3=0.4569 | Totol_Loss=0.7139 | Dice_coeff=0.5431 | IoU=0.3727
#  Train Loss_1: 0.6093 | Loss_2: 0.4803 | Loss_3: 0.4744 | Total_Loss: 0.7640 | Avg_dice_coeff: 0.5256 | Avg_IoU: 0.3619
# Running Validation...
#  Valid Loss_1: 0.6176 | Loss_2: 0.5005 | Loss_3: 0.4816
#  Total_Loss: 0.7806 | Dice_coeff: 0.5184 | IoU: 0.3746
# No improvement in validation loss for 3 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch15.pt
# ========== Epoch 17 / 150 ==========
# Training...
# [TRAIN] Epoch 17/150 | Batch 10/153 | Loss_1=0.6453 | Loss_2=0.4970 | Loss_3=0.4843 | Totol_Loss=0.7864 | Dice_coeff=0.5157 | IoU=0.3474
# [TRAIN] Epoch 17/150 | Batch 20/153 | Loss_1=0.6998 | Loss_2=0.5924 | Loss_3=0.6235 | Totol_Loss=0.9724 | Dice_coeff=0.3765 | IoU=0.2319
# [TRAIN] Epoch 17/150 | Batch 30/153 | Loss_1=0.5903 | Loss_2=0.4257 | Loss_3=0.4197 | Totol_Loss=0.6844 | Dice_coeff=0.5803 | IoU=0.4087
# [TRAIN] Epoch 17/150 | Batch 40/153 | Loss_1=0.6738 | Loss_2=0.5634 | Loss_3=0.5599 | Totol_Loss=0.8930 | Dice_coeff=0.4401 | IoU=0.2821
# [TRAIN] Epoch 17/150 | Batch 50/153 | Loss_1=0.7549 | Loss_2=0.7519 | Loss_3=0.7539 | Totol_Loss=1.1755 | Dice_coeff=0.2461 | IoU=0.1403
# [TRAIN] Epoch 17/150 | Batch 60/153 | Loss_1=0.5383 | Loss_2=0.4126 | Loss_3=0.4155 | Totol_Loss=0.6667 | Dice_coeff=0.5845 | IoU=0.4129
# [TRAIN] Epoch 17/150 | Batch 70/153 | Loss_1=0.5172 | Loss_2=0.3457 | Loss_3=0.3463 | Totol_Loss=0.5674 | Dice_coeff=0.6537 | IoU=0.4855
# [TRAIN] Epoch 17/150 | Batch 80/153 | Loss_1=0.7331 | Loss_2=0.6327 | Loss_3=0.5952 | Totol_Loss=0.9655 | Dice_coeff=0.4048 | IoU=0.2538
# [TRAIN] Epoch 17/150 | Batch 90/153 | Loss_1=0.6120 | Loss_2=0.4644 | Loss_3=0.4657 | Totol_Loss=0.7493 | Dice_coeff=0.5343 | IoU=0.3646
# [TRAIN] Epoch 17/150 | Batch 100/153 | Loss_1=0.6006 | Loss_2=0.4306 | Loss_3=0.4280 | Totol_Loss=0.6963 | Dice_coeff=0.5720 | IoU=0.4006
# [TRAIN] Epoch 17/150 | Batch 110/153 | Loss_1=0.5511 | Loss_2=0.4340 | Loss_3=0.4340 | Totol_Loss=0.6958 | Dice_coeff=0.5660 | IoU=0.3947
# [TRAIN] Epoch 17/150 | Batch 120/153 | Loss_1=0.7369 | Loss_2=0.6447 | Loss_3=0.6192 | Totol_Loss=0.9950 | Dice_coeff=0.3808 | IoU=0.2352
# [TRAIN] Epoch 17/150 | Batch 130/153 | Loss_1=0.6698 | Loss_2=0.5744 | Loss_3=0.5556 | Totol_Loss=0.8925 | Dice_coeff=0.4444 | IoU=0.2857
# [TRAIN] Epoch 17/150 | Batch 140/153 | Loss_1=0.5787 | Loss_2=0.3711 | Loss_3=0.3802 | Totol_Loss=0.6212 | Dice_coeff=0.6198 | IoU=0.4491
# [TRAIN] Epoch 17/150 | Batch 150/153 | Loss_1=0.7188 | Loss_2=0.5398 | Loss_3=0.5451 | Totol_Loss=0.8760 | Dice_coeff=0.4549 | IoU=0.2944
#  Train Loss_1: 0.6115 | Loss_2: 0.4721 | Loss_3: 0.4661 | Total_Loss: 0.7528 | Avg_dice_coeff: 0.5339 | Avg_IoU: 0.3707
# Running Validation...
#  Valid Loss_1: 0.5853 | Loss_2: 0.4403 | Loss_3: 0.4384
#  Total_Loss: 0.7081 | Dice_coeff: 0.5616 | IoU: 0.4207
# Validation loss improved from 0.4500 to 0.4384. Saving model...
# Model saved to ==> 20-06-2025_08-42-41/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-42-41/model_epoch16.pt
# ========== Epoch 18 / 150 ==========
# Training...
# [TRAIN] Epoch 18/150 | Batch 10/153 | Loss_1=0.5995 | Loss_2=0.4798 | Loss_3=0.4538 | Totol_Loss=0.7417 | Dice_coeff=0.5462 | IoU=0.3757
# [TRAIN] Epoch 18/150 | Batch 20/153 | Loss_1=0.6485 | Loss_2=0.5326 | Loss_3=0.5044 | Totol_Loss=0.8212 | Dice_coeff=0.4956 | IoU=0.3295
# [TRAIN] Epoch 18/150 | Batch 30/153 | Loss_1=0.6698 | Loss_2=0.5862 | Loss_3=0.5770 | Totol_Loss=0.9187 | Dice_coeff=0.4230 | IoU=0.2682
# [TRAIN] Epoch 18/150 | Batch 40/153 | Loss_1=0.6174 | Loss_2=0.4640 | Loss_3=0.4650 | Totol_Loss=0.7493 | Dice_coeff=0.5350 | IoU=0.3652
# [TRAIN] Epoch 18/150 | Batch 50/153 | Loss_1=0.6606 | Loss_2=0.5653 | Loss_3=0.5304 | Totol_Loss=0.8622 | Dice_coeff=0.4696 | IoU=0.3069
# [TRAIN] Epoch 18/150 | Batch 60/153 | Loss_1=0.5718 | Loss_2=0.4294 | Loss_3=0.4529 | Totol_Loss=0.7162 | Dice_coeff=0.5471 | IoU=0.3765
# [TRAIN] Epoch 18/150 | Batch 70/153 | Loss_1=0.6729 | Loss_2=0.5459 | Loss_3=0.5652 | Totol_Loss=0.8913 | Dice_coeff=0.4348 | IoU=0.2778
# [TRAIN] Epoch 18/150 | Batch 80/153 | Loss_1=0.6258 | Loss_2=0.4511 | Loss_3=0.4259 | Totol_Loss=0.7065 | Dice_coeff=0.5741 | IoU=0.4026
# [TRAIN] Epoch 18/150 | Batch 90/153 | Loss_1=0.6219 | Loss_2=0.4246 | Loss_3=0.4202 | Totol_Loss=0.6895 | Dice_coeff=0.5798 | IoU=0.4083
# [TRAIN] Epoch 18/150 | Batch 100/153 | Loss_1=0.7019 | Loss_2=0.6220 | Loss_3=0.5887 | Totol_Loss=0.9498 | Dice_coeff=0.4113 | IoU=0.2589
# [TRAIN] Epoch 18/150 | Batch 110/153 | Loss_1=0.5528 | Loss_2=0.4312 | Loss_3=0.4465 | Totol_Loss=0.7074 | Dice_coeff=0.5535 | IoU=0.3827
# [TRAIN] Epoch 18/150 | Batch 120/153 | Loss_1=0.4175 | Loss_2=0.2668 | Loss_3=0.2633 | Totol_Loss=0.4368 | Dice_coeff=0.7367 | IoU=0.5832
# [TRAIN] Epoch 18/150 | Batch 130/153 | Loss_1=0.5763 | Loss_2=0.4641 | Loss_3=0.4580 | Totol_Loss=0.7359 | Dice_coeff=0.5420 | IoU=0.3717
# [TRAIN] Epoch 18/150 | Batch 140/153 | Loss_1=0.6677 | Loss_2=0.5549 | Loss_3=0.5360 | Totol_Loss=0.8648 | Dice_coeff=0.4640 | IoU=0.3021
# [TRAIN] Epoch 18/150 | Batch 150/153 | Loss_1=0.5646 | Loss_2=0.4487 | Loss_3=0.4614 | Totol_Loss=0.7312 | Dice_coeff=0.5386 | IoU=0.3685
#  Train Loss_1: 0.5996 | Loss_2: 0.4694 | Loss_3: 0.4620 | Total_Loss: 0.7457 | Avg_dice_coeff: 0.5380 | Avg_IoU: 0.3742
# Running Validation...
#  Valid Loss_1: 0.5810 | Loss_2: 0.4398 | Loss_3: 0.4395
#  Total_Loss: 0.7083 | Dice_coeff: 0.5605 | IoU: 0.4178
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch17.pt
# ========== Epoch 19 / 150 ==========
# Training...
# [TRAIN] Epoch 19/150 | Batch 10/153 | Loss_1=0.6423 | Loss_2=0.5496 | Loss_3=0.5490 | Totol_Loss=0.8716 | Dice_coeff=0.4510 | IoU=0.2912
# [TRAIN] Epoch 19/150 | Batch 20/153 | Loss_1=0.6207 | Loss_2=0.5391 | Loss_3=0.5222 | Totol_Loss=0.8371 | Dice_coeff=0.4778 | IoU=0.3139
# [TRAIN] Epoch 19/150 | Batch 30/153 | Loss_1=0.7705 | Loss_2=0.6534 | Loss_3=0.6477 | Totol_Loss=1.0323 | Dice_coeff=0.3523 | IoU=0.2138
# [TRAIN] Epoch 19/150 | Batch 40/153 | Loss_1=0.4961 | Loss_2=0.3511 | Loss_3=0.3406 | Totol_Loss=0.5605 | Dice_coeff=0.6594 | IoU=0.4918
# [TRAIN] Epoch 19/150 | Batch 50/153 | Loss_1=0.6580 | Loss_2=0.5306 | Loss_3=0.5079 | Totol_Loss=0.8254 | Dice_coeff=0.4921 | IoU=0.3264
# [TRAIN] Epoch 19/150 | Batch 60/153 | Loss_1=0.5985 | Loss_2=0.4761 | Loss_3=0.4648 | Totol_Loss=0.7510 | Dice_coeff=0.5352 | IoU=0.3653
# [TRAIN] Epoch 19/150 | Batch 70/153 | Loss_1=0.6883 | Loss_2=0.5710 | Loss_3=0.5367 | Totol_Loss=0.8752 | Dice_coeff=0.4633 | IoU=0.3015
# [TRAIN] Epoch 19/150 | Batch 80/153 | Loss_1=0.6178 | Loss_2=0.4865 | Loss_3=0.5119 | Totol_Loss=0.8054 | Dice_coeff=0.4881 | IoU=0.3228
# [TRAIN] Epoch 19/150 | Batch 90/153 | Loss_1=0.5900 | Loss_2=0.4765 | Loss_3=0.4569 | Totol_Loss=0.7419 | Dice_coeff=0.5431 | IoU=0.3728
# [TRAIN] Epoch 19/150 | Batch 100/153 | Loss_1=0.6083 | Loss_2=0.3914 | Loss_3=0.3724 | Totol_Loss=0.6263 | Dice_coeff=0.6276 | IoU=0.4573
# [TRAIN] Epoch 19/150 | Batch 110/153 | Loss_1=0.5903 | Loss_2=0.3927 | Loss_3=0.3692 | Totol_Loss=0.6207 | Dice_coeff=0.6308 | IoU=0.4607
# [TRAIN] Epoch 19/150 | Batch 120/153 | Loss_1=0.5607 | Loss_2=0.4666 | Loss_3=0.4462 | Totol_Loss=0.7226 | Dice_coeff=0.5538 | IoU=0.3829
# [TRAIN] Epoch 19/150 | Batch 130/153 | Loss_1=0.6414 | Loss_2=0.5001 | Loss_3=0.5131 | Totol_Loss=0.8157 | Dice_coeff=0.4869 | IoU=0.3218
# [TRAIN] Epoch 19/150 | Batch 140/153 | Loss_1=0.5926 | Loss_2=0.4248 | Loss_3=0.4393 | Totol_Loss=0.7040 | Dice_coeff=0.5607 | IoU=0.3896
# [TRAIN] Epoch 19/150 | Batch 150/153 | Loss_1=0.5591 | Loss_2=0.3738 | Loss_3=0.3883 | Totol_Loss=0.6273 | Dice_coeff=0.6117 | IoU=0.4406
#  Train Loss_1: 0.6004 | Loss_2: 0.4680 | Loss_3: 0.4625 | Total_Loss: 0.7457 | Avg_dice_coeff: 0.5375 | Avg_IoU: 0.3729
# Running Validation...
#  Valid Loss_1: 0.5836 | Loss_2: 0.4330 | Loss_3: 0.4227
#  Total_Loss: 0.6893 | Dice_coeff: 0.5773 | IoU: 0.4397
# Validation loss improved from 0.4384 to 0.4227. Saving model...
# Model saved to ==> 20-06-2025_08-42-41/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-42-41/model_epoch18.pt
# ========== Epoch 20 / 150 ==========
# Training...
# [TRAIN] Epoch 20/150 | Batch 10/153 | Loss_1=0.5799 | Loss_2=0.4903 | Loss_3=0.4820 | Totol_Loss=0.7709 | Dice_coeff=0.5180 | IoU=0.3495
# [TRAIN] Epoch 20/150 | Batch 20/153 | Loss_1=0.7483 | Loss_2=0.6584 | Loss_3=0.6171 | Totol_Loss=1.0001 | Dice_coeff=0.3829 | IoU=0.2368
# [TRAIN] Epoch 20/150 | Batch 30/153 | Loss_1=0.5570 | Loss_2=0.3870 | Loss_3=0.4062 | Totol_Loss=0.6501 | Dice_coeff=0.5938 | IoU=0.4223
# ...
# [TRAIN] Epoch 144/150 | Batch 110/153 | Loss_1=0.6734 | Loss_2=0.0613 | Loss_3=0.0574 | Totol_Loss=0.1897 | Dice_coeff=0.9426 | IoU=0.8914
# [TRAIN] Epoch 144/150 | Batch 120/153 | Loss_1=0.5764 | Loss_2=0.1024 | Loss_3=0.0965 | Totol_Loss=0.2297 | Dice_coeff=0.9035 | IoU=0.8240
# [TRAIN] Epoch 144/150 | Batch 130/153 | Loss_1=0.3825 | Loss_2=0.0698 | Loss_3=0.0644 | Totol_Loss=0.1536 | Dice_coeff=0.9356 | IoU=0.8789
# [TRAIN] Epoch 144/150 | Batch 140/153 | Loss_1=0.5051 | Loss_2=0.0857 | Loss_3=0.0835 | Totol_Loss=0.1986 | Dice_coeff=0.9165 | IoU=0.8458
# [TRAIN] Epoch 144/150 | Batch 150/153 | Loss_1=0.7073 | Loss_2=0.0602 | Loss_3=0.0569 | Totol_Loss=0.1941 | Dice_coeff=0.9431 | IoU=0.8924
#  Train Loss_1: 0.5014 | Loss_2: 0.0790 | Loss_3: 0.0751 | Total_Loss: 0.1869 | Avg_dice_coeff: 0.9249 | Avg_IoU: 0.8615
# Running Validation...
#  Valid Loss_1: 0.4941 | Loss_2: 0.2203 | Loss_3: 0.2177
#  Total_Loss: 0.3849 | Dice_coeff: 0.7823 | IoU: 0.6533
# No improvement in validation loss for 36 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch143.pt
# ========== Epoch 145 / 150 ==========
# Training...
# [TRAIN] Epoch 145/150 | Batch 10/153 | Loss_1=0.5367 | Loss_2=0.0696 | Loss_3=0.0659 | Totol_Loss=0.1797 | Dice_coeff=0.9341 | IoU=0.8763
# [TRAIN] Epoch 145/150 | Batch 20/153 | Loss_1=0.4736 | Loss_2=0.0630 | Loss_3=0.0616 | Totol_Loss=0.1626 | Dice_coeff=0.9384 | IoU=0.8840
# [TRAIN] Epoch 145/150 | Batch 30/153 | Loss_1=0.3230 | Loss_2=0.0824 | Loss_3=0.0812 | Totol_Loss=0.1658 | Dice_coeff=0.9188 | IoU=0.8498
# [TRAIN] Epoch 145/150 | Batch 40/153 | Loss_1=0.5878 | Loss_2=0.0980 | Loss_3=0.0911 | Totol_Loss=0.2244 | Dice_coeff=0.9089 | IoU=0.8330
# [TRAIN] Epoch 145/150 | Batch 50/153 | Loss_1=0.5333 | Loss_2=0.0616 | Loss_3=0.0588 | Totol_Loss=0.1688 | Dice_coeff=0.9412 | IoU=0.8889
# [TRAIN] Epoch 145/150 | Batch 60/153 | Loss_1=0.5222 | Loss_2=0.1198 | Loss_3=0.1153 | Totol_Loss=0.2468 | Dice_coeff=0.8847 | IoU=0.7933
# [TRAIN] Epoch 145/150 | Batch 70/153 | Loss_1=0.4163 | Loss_2=0.0518 | Loss_3=0.0497 | Totol_Loss=0.1370 | Dice_coeff=0.9503 | IoU=0.9054
# [TRAIN] Epoch 145/150 | Batch 80/153 | Loss_1=0.5336 | Loss_2=0.0880 | Loss_3=0.0817 | Totol_Loss=0.2023 | Dice_coeff=0.9183 | IoU=0.8490
# [TRAIN] Epoch 145/150 | Batch 90/153 | Loss_1=0.3909 | Loss_2=0.0625 | Loss_3=0.0604 | Totol_Loss=0.1480 | Dice_coeff=0.9396 | IoU=0.8861
# [TRAIN] Epoch 145/150 | Batch 100/153 | Loss_1=0.4492 | Loss_2=0.0495 | Loss_3=0.0464 | Totol_Loss=0.1381 | Dice_coeff=0.9536 | IoU=0.9113
# [TRAIN] Epoch 145/150 | Batch 110/153 | Loss_1=0.2932 | Loss_2=0.0667 | Loss_3=0.0637 | Totol_Loss=0.1373 | Dice_coeff=0.9363 | IoU=0.8802
# [TRAIN] Epoch 145/150 | Batch 120/153 | Loss_1=0.3902 | Loss_2=0.0513 | Loss_3=0.0478 | Totol_Loss=0.1308 | Dice_coeff=0.9522 | IoU=0.9087
# [TRAIN] Epoch 145/150 | Batch 130/153 | Loss_1=0.5286 | Loss_2=0.0848 | Loss_3=0.0822 | Totol_Loss=0.2007 | Dice_coeff=0.9178 | IoU=0.8481
# [TRAIN] Epoch 145/150 | Batch 140/153 | Loss_1=0.7395 | Loss_2=0.0740 | Loss_3=0.0687 | Totol_Loss=0.2167 | Dice_coeff=0.9313 | IoU=0.8714
# [TRAIN] Epoch 145/150 | Batch 150/153 | Loss_1=0.5980 | Loss_2=0.1020 | Loss_3=0.0981 | Totol_Loss=0.2346 | Dice_coeff=0.9019 | IoU=0.8212
#  Train Loss_1: 0.5008 | Loss_2: 0.0789 | Loss_3: 0.0750 | Total_Loss: 0.1867 | Avg_dice_coeff: 0.9250 | Avg_IoU: 0.8613
# Running Validation...
#  Valid Loss_1: 0.4942 | Loss_2: 0.2203 | Loss_3: 0.2176
#  Total_Loss: 0.3848 | Dice_coeff: 0.7824 | IoU: 0.6534
# No improvement in validation loss for 37 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch144.pt
# ========== Epoch 146 / 150 ==========
# Training...
# [TRAIN] Epoch 146/150 | Batch 10/153 | Loss_1=0.4218 | Loss_2=0.0468 | Loss_3=0.0425 | Totol_Loss=0.1287 | Dice_coeff=0.9575 | IoU=0.9185
# [TRAIN] Epoch 146/150 | Batch 20/153 | Loss_1=0.5740 | Loss_2=0.1394 | Loss_3=0.1348 | Totol_Loss=0.2824 | Dice_coeff=0.8652 | IoU=0.7624
# [TRAIN] Epoch 146/150 | Batch 30/153 | Loss_1=0.5674 | Loss_2=0.0680 | Loss_3=0.0614 | Totol_Loss=0.1794 | Dice_coeff=0.9386 | IoU=0.8843
# [TRAIN] Epoch 146/150 | Batch 40/153 | Loss_1=0.4594 | Loss_2=0.0623 | Loss_3=0.0591 | Totol_Loss=0.1575 | Dice_coeff=0.9409 | IoU=0.8884
# [TRAIN] Epoch 146/150 | Batch 50/153 | Loss_1=0.4934 | Loss_2=0.1049 | Loss_3=0.0984 | Totol_Loss=0.2194 | Dice_coeff=0.9016 | IoU=0.8208
# [TRAIN] Epoch 146/150 | Batch 60/153 | Loss_1=0.4728 | Loss_2=0.0729 | Loss_3=0.0713 | Totol_Loss=0.1761 | Dice_coeff=0.9287 | IoU=0.8669
# [TRAIN] Epoch 146/150 | Batch 70/153 | Loss_1=0.4593 | Loss_2=0.0912 | Loss_3=0.0884 | Totol_Loss=0.1984 | Dice_coeff=0.9116 | IoU=0.8376
# [TRAIN] Epoch 146/150 | Batch 80/153 | Loss_1=0.3027 | Loss_2=0.0741 | Loss_3=0.0693 | Totol_Loss=0.1474 | Dice_coeff=0.9307 | IoU=0.8704
# [TRAIN] Epoch 146/150 | Batch 90/153 | Loss_1=0.3146 | Loss_2=0.1007 | Loss_3=0.0960 | Totol_Loss=0.1867 | Dice_coeff=0.9040 | IoU=0.8248
# [TRAIN] Epoch 146/150 | Batch 100/153 | Loss_1=0.5068 | Loss_2=0.0661 | Loss_3=0.0624 | Totol_Loss=0.1699 | Dice_coeff=0.9376 | IoU=0.8825
# [TRAIN] Epoch 146/150 | Batch 110/153 | Loss_1=0.5285 | Loss_2=0.0844 | Loss_3=0.0805 | Totol_Loss=0.1988 | Dice_coeff=0.9195 | IoU=0.8510
# [TRAIN] Epoch 146/150 | Batch 120/153 | Loss_1=0.5491 | Loss_2=0.0810 | Loss_3=0.0770 | Totol_Loss=0.1972 | Dice_coeff=0.9230 | IoU=0.8571
# [TRAIN] Epoch 146/150 | Batch 130/153 | Loss_1=0.3808 | Loss_2=0.0840 | Loss_3=0.0831 | Totol_Loss=0.1777 | Dice_coeff=0.9169 | IoU=0.8465
# [TRAIN] Epoch 146/150 | Batch 140/153 | Loss_1=0.5109 | Loss_2=0.0575 | Loss_3=0.0509 | Totol_Loss=0.1557 | Dice_coeff=0.9491 | IoU=0.9030
# [TRAIN] Epoch 146/150 | Batch 150/153 | Loss_1=0.4788 | Loss_2=0.0725 | Loss_3=0.0674 | Totol_Loss=0.1730 | Dice_coeff=0.9326 | IoU=0.8737
#  Train Loss_1: 0.5024 | Loss_2: 0.0793 | Loss_3: 0.0753 | Total_Loss: 0.1874 | Avg_dice_coeff: 0.9247 | Avg_IoU: 0.8610
# Running Validation...
#  Valid Loss_1: 0.4941 | Loss_2: 0.2200 | Loss_3: 0.2173
#  Total_Loss: 0.3844 | Dice_coeff: 0.7827 | IoU: 0.6538
# No improvement in validation loss for 38 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch145.pt
# ========== Epoch 147 / 150 ==========
# Training...
# [TRAIN] Epoch 147/150 | Batch 10/153 | Loss_1=0.5609 | Loss_2=0.0711 | Loss_3=0.0703 | Totol_Loss=0.1885 | Dice_coeff=0.9297 | IoU=0.8686
# [TRAIN] Epoch 147/150 | Batch 20/153 | Loss_1=0.5998 | Loss_2=0.0631 | Loss_3=0.0581 | Totol_Loss=0.1793 | Dice_coeff=0.9419 | IoU=0.8902
# [TRAIN] Epoch 147/150 | Batch 30/153 | Loss_1=0.4768 | Loss_2=0.0447 | Loss_3=0.0430 | Totol_Loss=0.1372 | Dice_coeff=0.9570 | IoU=0.9175
# [TRAIN] Epoch 147/150 | Batch 40/153 | Loss_1=0.5223 | Loss_2=0.1501 | Loss_3=0.1470 | Totol_Loss=0.2906 | Dice_coeff=0.8530 | IoU=0.7436
# [TRAIN] Epoch 147/150 | Batch 50/153 | Loss_1=0.5260 | Loss_2=0.0888 | Loss_3=0.0859 | Totol_Loss=0.2056 | Dice_coeff=0.9141 | IoU=0.8418
# [TRAIN] Epoch 147/150 | Batch 60/153 | Loss_1=0.5486 | Loss_2=0.0870 | Loss_3=0.0847 | Totol_Loss=0.2073 | Dice_coeff=0.9153 | IoU=0.8438
# [TRAIN] Epoch 147/150 | Batch 70/153 | Loss_1=0.5695 | Loss_2=0.1125 | Loss_3=0.1087 | Totol_Loss=0.2449 | Dice_coeff=0.8913 | IoU=0.8038
# [TRAIN] Epoch 147/150 | Batch 80/153 | Loss_1=0.4974 | Loss_2=0.0417 | Loss_3=0.0384 | Totol_Loss=0.1347 | Dice_coeff=0.9616 | IoU=0.9259
# [TRAIN] Epoch 147/150 | Batch 90/153 | Loss_1=0.4257 | Loss_2=0.0562 | Loss_3=0.0533 | Totol_Loss=0.1439 | Dice_coeff=0.9467 | IoU=0.8988
# [TRAIN] Epoch 147/150 | Batch 100/153 | Loss_1=0.4171 | Loss_2=0.0528 | Loss_3=0.0491 | Totol_Loss=0.1369 | Dice_coeff=0.9509 | IoU=0.9065
# [TRAIN] Epoch 147/150 | Batch 110/153 | Loss_1=0.3347 | Loss_2=0.0606 | Loss_3=0.0583 | Totol_Loss=0.1361 | Dice_coeff=0.9417 | IoU=0.8898
# [TRAIN] Epoch 147/150 | Batch 120/153 | Loss_1=0.5571 | Loss_2=0.0596 | Loss_3=0.0523 | Totol_Loss=0.1653 | Dice_coeff=0.9477 | IoU=0.9006
# [TRAIN] Epoch 147/150 | Batch 130/153 | Loss_1=0.4588 | Loss_2=0.0619 | Loss_3=0.0573 | Totol_Loss=0.1555 | Dice_coeff=0.9427 | IoU=0.8916
# [TRAIN] Epoch 147/150 | Batch 140/153 | Loss_1=0.4325 | Loss_2=0.1100 | Loss_3=0.1069 | Totol_Loss=0.2201 | Dice_coeff=0.8931 | IoU=0.8068
# [TRAIN] Epoch 147/150 | Batch 150/153 | Loss_1=0.6318 | Loss_2=0.0650 | Loss_3=0.0600 | Totol_Loss=0.1870 | Dice_coeff=0.9400 | IoU=0.8868
#  Train Loss_1: 0.5001 | Loss_2: 0.0798 | Loss_3: 0.0757 | Total_Loss: 0.1876 | Avg_dice_coeff: 0.9243 | Avg_IoU: 0.8604
# Running Validation...
#  Valid Loss_1: 0.4941 | Loss_2: 0.2199 | Loss_3: 0.2173
#  Total_Loss: 0.3843 | Dice_coeff: 0.7827 | IoU: 0.6539
# No improvement in validation loss for 39 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch146.pt
# ========== Epoch 148 / 150 ==========
# Training...
# [TRAIN] Epoch 148/150 | Batch 10/153 | Loss_1=0.3887 | Loss_2=0.0782 | Loss_3=0.0733 | Totol_Loss=0.1668 | Dice_coeff=0.9267 | IoU=0.8634
# [TRAIN] Epoch 148/150 | Batch 20/153 | Loss_1=0.3909 | Loss_2=0.0860 | Loss_3=0.0840 | Totol_Loss=0.1809 | Dice_coeff=0.9160 | IoU=0.8450
# [TRAIN] Epoch 148/150 | Batch 30/153 | Loss_1=0.4425 | Loss_2=0.0637 | Loss_3=0.0596 | Totol_Loss=0.1559 | Dice_coeff=0.9404 | IoU=0.8874
# [TRAIN] Epoch 148/150 | Batch 40/153 | Loss_1=0.4583 | Loss_2=0.0781 | Loss_3=0.0753 | Totol_Loss=0.1798 | Dice_coeff=0.9247 | IoU=0.8600
# [TRAIN] Epoch 148/150 | Batch 50/153 | Loss_1=0.4616 | Loss_2=0.0577 | Loss_3=0.0522 | Totol_Loss=0.1491 | Dice_coeff=0.9478 | IoU=0.9008
# [TRAIN] Epoch 148/150 | Batch 60/153 | Loss_1=0.3124 | Loss_2=0.0643 | Loss_3=0.0602 | Totol_Loss=0.1359 | Dice_coeff=0.9398 | IoU=0.8865
# [TRAIN] Epoch 148/150 | Batch 70/153 | Loss_1=0.5107 | Loss_2=0.0861 | Loss_3=0.0816 | Totol_Loss=0.1978 | Dice_coeff=0.9184 | IoU=0.8490
# [TRAIN] Epoch 148/150 | Batch 80/153 | Loss_1=0.4047 | Loss_2=0.0523 | Loss_3=0.0507 | Totol_Loss=0.1364 | Dice_coeff=0.9493 | IoU=0.9035
# [TRAIN] Epoch 148/150 | Batch 90/153 | Loss_1=0.5751 | Loss_2=0.0779 | Loss_3=0.0742 | Totol_Loss=0.1974 | Dice_coeff=0.9258 | IoU=0.8618
# [TRAIN] Epoch 148/150 | Batch 100/153 | Loss_1=0.7569 | Loss_2=0.0841 | Loss_3=0.0760 | Totol_Loss=0.2308 | Dice_coeff=0.9240 | IoU=0.8587
# [TRAIN] Epoch 148/150 | Batch 110/153 | Loss_1=0.5775 | Loss_2=0.0551 | Loss_3=0.0491 | Totol_Loss=0.1635 | Dice_coeff=0.9509 | IoU=0.9065
# [TRAIN] Epoch 148/150 | Batch 120/153 | Loss_1=0.3927 | Loss_2=0.0600 | Loss_3=0.0569 | Totol_Loss=0.1438 | Dice_coeff=0.9431 | IoU=0.8923
# [TRAIN] Epoch 148/150 | Batch 130/153 | Loss_1=0.4711 | Loss_2=0.0699 | Loss_3=0.0641 | Totol_Loss=0.1675 | Dice_coeff=0.9359 | IoU=0.8795
# [TRAIN] Epoch 148/150 | Batch 140/153 | Loss_1=0.4167 | Loss_2=0.0777 | Loss_3=0.0740 | Totol_Loss=0.1718 | Dice_coeff=0.9260 | IoU=0.8621
# [TRAIN] Epoch 148/150 | Batch 150/153 | Loss_1=0.4354 | Loss_2=0.0483 | Loss_3=0.0449 | Totol_Loss=0.1339 | Dice_coeff=0.9551 | IoU=0.9141
#  Train Loss_1: 0.4998 | Loss_2: 0.0781 | Loss_3: 0.0740 | Total_Loss: 0.1852 | Avg_dice_coeff: 0.9260 | Avg_IoU: 0.8628
# Running Validation...
#  Valid Loss_1: 0.4941 | Loss_2: 0.2202 | Loss_3: 0.2176
#  Total_Loss: 0.3847 | Dice_coeff: 0.7824 | IoU: 0.6535
# No improvement in validation loss for 40 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch147.pt
# ========== Epoch 149 / 150 ==========
# Training...
# [TRAIN] Epoch 149/150 | Batch 10/153 | Loss_1=0.6058 | Loss_2=0.0731 | Loss_3=0.0684 | Totol_Loss=0.1945 | Dice_coeff=0.9316 | IoU=0.8720
# [TRAIN] Epoch 149/150 | Batch 20/153 | Loss_1=0.6079 | Loss_2=0.0756 | Loss_3=0.0702 | Totol_Loss=0.1977 | Dice_coeff=0.9298 | IoU=0.8687
# [TRAIN] Epoch 149/150 | Batch 30/153 | Loss_1=0.5589 | Loss_2=0.0771 | Loss_3=0.0731 | Totol_Loss=0.1934 | Dice_coeff=0.9269 | IoU=0.8638
# [TRAIN] Epoch 149/150 | Batch 40/153 | Loss_1=0.4948 | Loss_2=0.1543 | Loss_3=0.1516 | Totol_Loss=0.2925 | Dice_coeff=0.8484 | IoU=0.7367
# [TRAIN] Epoch 149/150 | Batch 50/153 | Loss_1=0.5303 | Loss_2=0.0699 | Loss_3=0.0658 | Totol_Loss=0.1786 | Dice_coeff=0.9342 | IoU=0.8766
# [TRAIN] Epoch 149/150 | Batch 60/153 | Loss_1=0.4146 | Loss_2=0.0644 | Loss_3=0.0596 | Totol_Loss=0.1517 | Dice_coeff=0.9404 | IoU=0.8875
# [TRAIN] Epoch 149/150 | Batch 70/153 | Loss_1=0.4227 | Loss_2=0.0597 | Loss_3=0.0558 | Totol_Loss=0.1473 | Dice_coeff=0.9442 | IoU=0.8943
# [TRAIN] Epoch 149/150 | Batch 80/153 | Loss_1=0.5365 | Loss_2=0.1119 | Loss_3=0.1083 | Totol_Loss=0.2389 | Dice_coeff=0.8917 | IoU=0.8046
# [TRAIN] Epoch 149/150 | Batch 90/153 | Loss_1=0.4237 | Loss_2=0.0565 | Loss_3=0.0523 | Totol_Loss=0.1427 | Dice_coeff=0.9477 | IoU=0.9005
# [TRAIN] Epoch 149/150 | Batch 100/153 | Loss_1=0.6578 | Loss_2=0.0926 | Loss_3=0.0879 | Totol_Loss=0.2301 | Dice_coeff=0.9121 | IoU=0.8385
# [TRAIN] Epoch 149/150 | Batch 110/153 | Loss_1=0.3715 | Loss_2=0.0759 | Loss_3=0.0713 | Totol_Loss=0.1611 | Dice_coeff=0.9287 | IoU=0.8668
# [TRAIN] Epoch 149/150 | Batch 120/153 | Loss_1=0.4131 | Loss_2=0.1031 | Loss_3=0.0983 | Totol_Loss=0.2056 | Dice_coeff=0.9017 | IoU=0.8211
# [TRAIN] Epoch 149/150 | Batch 130/153 | Loss_1=0.3950 | Loss_2=0.0666 | Loss_3=0.0637 | Totol_Loss=0.1536 | Dice_coeff=0.9363 | IoU=0.8802
# [TRAIN] Epoch 149/150 | Batch 140/153 | Loss_1=0.5806 | Loss_2=0.0823 | Loss_3=0.0788 | Totol_Loss=0.2046 | Dice_coeff=0.9212 | IoU=0.8539
# [TRAIN] Epoch 149/150 | Batch 150/153 | Loss_1=0.4649 | Loss_2=0.0532 | Loss_3=0.0519 | Totol_Loss=0.1476 | Dice_coeff=0.9481 | IoU=0.9013
#  Train Loss_1: 0.5021 | Loss_2: 0.0782 | Loss_3: 0.0740 | Total_Loss: 0.1857 | Avg_dice_coeff: 0.9260 | Avg_IoU: 0.8631
# Running Validation...
#  Valid Loss_1: 0.4939 | Loss_2: 0.2201 | Loss_3: 0.2174
#  Total_Loss: 0.3845 | Dice_coeff: 0.7826 | IoU: 0.6537
# No improvement in validation loss for 41 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch148.pt
# ========== Epoch 150 / 150 ==========
# Training...
# [TRAIN] Epoch 150/150 | Batch 10/153 | Loss_1=0.4959 | Loss_2=0.0748 | Loss_3=0.0717 | Totol_Loss=0.1809 | Dice_coeff=0.9283 | IoU=0.8662
# [TRAIN] Epoch 150/150 | Batch 20/153 | Loss_1=0.5598 | Loss_2=0.1004 | Loss_3=0.0971 | Totol_Loss=0.2269 | Dice_coeff=0.9029 | IoU=0.8229
# [TRAIN] Epoch 150/150 | Batch 30/153 | Loss_1=0.3246 | Loss_2=0.0573 | Loss_3=0.0537 | Totol_Loss=0.1286 | Dice_coeff=0.9463 | IoU=0.8980
# [TRAIN] Epoch 150/150 | Batch 40/153 | Loss_1=0.5227 | Loss_2=0.0838 | Loss_3=0.0775 | Totol_Loss=0.1947 | Dice_coeff=0.9225 | IoU=0.8561
# [TRAIN] Epoch 150/150 | Batch 50/153 | Loss_1=0.5610 | Loss_2=0.1067 | Loss_3=0.1050 | Totol_Loss=0.2375 | Dice_coeff=0.8950 | IoU=0.8099
# [TRAIN] Epoch 150/150 | Batch 60/153 | Loss_1=0.4727 | Loss_2=0.0889 | Loss_3=0.0847 | Totol_Loss=0.1959 | Dice_coeff=0.9153 | IoU=0.8439
# [TRAIN] Epoch 150/150 | Batch 70/153 | Loss_1=0.4021 | Loss_2=0.0543 | Loss_3=0.0509 | Totol_Loss=0.1370 | Dice_coeff=0.9491 | IoU=0.9031
# [TRAIN] Epoch 150/150 | Batch 80/153 | Loss_1=0.4228 | Loss_2=0.0594 | Loss_3=0.0565 | Totol_Loss=0.1479 | Dice_coeff=0.9435 | IoU=0.8931
# [TRAIN] Epoch 150/150 | Batch 90/153 | Loss_1=0.6059 | Loss_2=0.0927 | Loss_3=0.0864 | Totol_Loss=0.2204 | Dice_coeff=0.9136 | IoU=0.8409
# [TRAIN] Epoch 150/150 | Batch 100/153 | Loss_1=0.4038 | Loss_2=0.0644 | Loss_3=0.0601 | Totol_Loss=0.1505 | Dice_coeff=0.9399 | IoU=0.8866
# [TRAIN] Epoch 150/150 | Batch 110/153 | Loss_1=0.5455 | Loss_2=0.0591 | Loss_3=0.0560 | Totol_Loss=0.1669 | Dice_coeff=0.9440 | IoU=0.8939
# [TRAIN] Epoch 150/150 | Batch 120/153 | Loss_1=0.3944 | Loss_2=0.1286 | Loss_3=0.1255 | Totol_Loss=0.2400 | Dice_coeff=0.8745 | IoU=0.7770
# [TRAIN] Epoch 150/150 | Batch 130/153 | Loss_1=0.3229 | Loss_2=0.0614 | Loss_3=0.0563 | Totol_Loss=0.1325 | Dice_coeff=0.9437 | IoU=0.8934
# [TRAIN] Epoch 150/150 | Batch 140/153 | Loss_1=0.4845 | Loss_2=0.0687 | Loss_3=0.0624 | Totol_Loss=0.1674 | Dice_coeff=0.9376 | IoU=0.8826
# [TRAIN] Epoch 150/150 | Batch 150/153 | Loss_1=0.3805 | Loss_2=0.0632 | Loss_3=0.0597 | Totol_Loss=0.1458 | Dice_coeff=0.9403 | IoU=0.8874
#  Train Loss_1: 0.5008 | Loss_2: 0.0782 | Loss_3: 0.0740 | Total_Loss: 0.1854 | Avg_dice_coeff: 0.9260 | Avg_IoU: 0.8630
# Running Validation...
#  Valid Loss_1: 0.4940 | Loss_2: 0.2201 | Loss_3: 0.2175
#  Total_Loss: 0.3846 | Dice_coeff: 0.7825 | IoU: 0.6536
# No improvement in validation loss for 42 epochs.
# Model saved to ==> 20-06-2025_08-42-41/model_epoch149.pt
# Training complete!

# %%
trainer.visualize_scores()

# %%
test_loader = DataLoader(dataset=valid_dataset, batch_size=1, shuffle=False)

trainer.eval(test_loader)
# Out:
# [Test] Batch 100/611 | Test Loss_1=0.2577 | Loss_2=0.0712 | Loss_3=0.0745 | Total_Loss=0.1443
# [Test] Batch 200/611 | Test Loss_1=0.6637 | Loss_2=0.2652 | Loss_3=0.2718 | Total_Loss=0.4841
# [Test] Batch 300/611 | Test Loss_1=0.9925 | Loss_2=0.9488 | Loss_3=0.8915 | Total_Loss=1.4299
# [Test] Batch 400/611 | Test Loss_1=0.9910 | Loss_2=0.6095 | Loss_3=0.4712 | Total_Loss=0.8736
# [Test] Batch 500/611 | Test Loss_1=0.2030 | Loss_2=0.0988 | Loss_3=0.0961 | Total_Loss=0.1681
# [Test] Batch 600/611 | Test Loss_1=0.6170 | Loss_2=0.1588 | Loss_3=0.1405 | Total_Loss=0.3027
#  Test Loss_1: 0.5223 | Loss_2: 0.2892 | Loss_2: 0.2880
#  Total_Loss: 0.4873 | Dice_coeff: 0.7120 | IoU: 0.6197

# %%
width = 4
columns = 3
n_examples = 12

fig, axs = plt.subplots(columns, width, figsize=(3*width , 3*columns), constrained_layout=True)
red_patch = mpatches.Patch(color='red', label='The red data')
fig.legend(loc='upper right',handles=[
    mpatches.Patch(color='red', label='Ground truth'),
    mpatches.Patch(color='green', label='Predicted abnormality')])
i = 0
with torch.no_grad():
    for data in test_loader:
        image, mask = data
        image, mask = image.to(config.DEVICE), mask.to(config.DEVICE)
        
        if not mask.byte().any():
            continue
        image = image.to(config.DEVICE)
        s = torch.zeros_like(mask).to(config.DEVICE)
        h = torch.zeros(mask.size(0), 512, 16, 16).to(config.DEVICE)
        prediction = trainer.model(image, h, s)[-1][0][0]
        prediction = torch.where(prediction > 0.5, 1, 0)
        # prediction_edges = prediction - binary_dilation(prediction)
        # ground_truth = mask - binary_dilation(mask)
        # image[0, 0, ground_truth.bool()[0]] = 255
        # image[0, 1, prediction_edges.bool()] = 255
        
        axs[i//width][i%width].imshow(image[0].to('cpu').permute(1, 2, 0))
        axs[i//width][i%width].imshow(mask.cpu()[0][0], alpha=0.5)
        axs[i//width][i%width].imshow(prediction.cpu(), alpha=0.5)
        # axs[i//width][i%width].imshow(prediction.unsqueeze(0).to('cpu').permute(1, 2, 0), alpha=0.2)
        if n_examples == i + 1:
            break
        i += 1
