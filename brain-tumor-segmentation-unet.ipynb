# %%
import os
import cv2
import time
import numpy as np
import pandas as pd
from glob import glob
from tqdm import tqdm
import numpy as np 
import cv2 as cv
import zipfile
import io
import requests
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW, lr_scheduler
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
from sklearn.impute import SimpleImputer
# import albumentations
from sklearn.model_selection import train_test_split
from scipy.ndimage.morphology import binary_dilation
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, models, transforms
import torchvision.transforms.functional as TF
from torchvision.utils import make_grid
from datetime import datetime
from enum import Enum
import math
# import hdf5storage
import h5py
from typing import Dict, List, Tuple, Optional, Union

from PIL import Image

# You can use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass

warnings.warn = warn
warnings.filterwarnings('ignore')
# Out:
# /tmp/ipykernel_19/368343941.py:23: DeprecationWarning: Please import `binary_dilation` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.morphology import binary_dilation

# %%
class Config:
    def __init__(self):
        # Dataset and DataLoader Parameters
        self.IMG_SIZE = (256, 256)
        self.BATCH_SIZE = 16
        self.TRAIN_RATIO = 0.8
        self.TEST_RATIO = 0.2

        # Training Parameters
        self.EPOCHS = 150
        self.LEARNING_RATE = 1e-3
        self.WEIGHT_DECAY = 1e-4
        self.LEARNING_RATE_MIN = 1e-6
        self.ACCUMALATION_STEPS = 1
        self.DICE_LOSS = True
        self.PATIENCE = 150

        # Model Parameters
        self.IN_CHANNELS = 1
        self.OUT_CLASSES = 1
        self.DEPTH = 5
        self.INIT_FEATURES = 34
        self.NORMALIZATION = 'batch'
        self.INTERPOLATION = 'nearest'
        self.OUT_ACTIVATION = 'sigmoid'
        self.USE_MULTIPLIER = False

        # Other Parameters
        self.DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.SEED = 42
        self.ROOT = "/kaggle/input/brain-tumor-dataset/data/"
        self.SAVE_DIR = '/kaggle/working/unet_checkpoint'

config = Config()

# %%
def set_all_seeds(seed):
    # NumPy
    np.random.seed(seed)
    # PyTorch
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # For multi-GPU setups
    # Ensures that the CUDA convolutions are deterministic, but might slow down training
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False # Set to False for reproducibility

set_all_seeds(config.SEED)

# %%
class ClassesLabels(Enum):
    """Brain tumor classification labels"""
    Meningioma = 1  # U màng não
    Glioma = 2      # U thần kinh đệm  
    Pituitary = 3   # Tuyến uyên
    
    def __len__(self):
        return 3


class BrainTumorDataset(Dataset):
    """
    Brain tumor dataset with balanced class distribution
    
    Args:
        root: Root directory containing class folders
        train: If True, creates training set; if False, creates test set 
        classes: Tuple of classes to include
        test_freq: Fraction of data to use for testing
        random_seed: Random seed for reproducible splits
        normalize_image: Whether to normalize images to 0-255 range
        verbose: Whether to print dataset statistics
    """
    
    CLASS_FOLDERS = {
        ClassesLabels.Meningioma: 'meningioma',
        ClassesLabels.Glioma: 'glioma',
        ClassesLabels.Pituitary: 'pituitary'
    }
    
    def __init__(
        self,
        root: str,
        train: bool = True,
        classes: Tuple[ClassesLabels, ...] = (ClassesLabels.Meningioma, ClassesLabels.Glioma, ClassesLabels.Pituitary),
        test_freq: float = 0.15,
        random_seed: int = 42,
        normalize_image: bool = True,
        verbose: bool = True
    ):
        super().__init__()
        self.root = self._validate_path(root)
        self.train = train
        self.classes = classes
        self.test_freq = test_freq
        self.normalize_image = normalize_image
        
        # Set random seed for reproducible splits
        np.random.seed(random_seed)
        
        # Load and split data
        self.items, self.class_info = self._load_and_split_data()
        
        if verbose:
            self._print_stats()
    
    def _validate_path(self, path: str) -> str:
        """Validate and normalize root path"""
        if not os.path.exists(path):
            raise ValueError(f"Root path does not exist: {path}")
        return os.path.normpath(path)
    
    def _load_and_split_data(self) -> Tuple[List[str], Dict]:
        """Load files and split into train/test per class"""
        items = []
        class_info = {}
        
        for class_label in self.classes:
            folder_name = self.CLASS_FOLDERS[class_label]
            folder_path = os.path.join(self.root, folder_name)
            
            if not os.path.exists(folder_path):
                print(f"Warning: Folder {folder_path} does not exist!")
                continue
            
            # Get all valid files for this class
            all_files = self._get_valid_files(folder_path)
            if not all_files:
                print(f"Warning: No valid files found in {folder_path}")
                continue
            
            # Split files for this class
            train_files, test_files = self._split_files(all_files)
            selected_files = train_files if self.train else test_files
            
            # Add to items with folder prefix
            items.extend([f'{folder_name}/{f}' for f in selected_files])
            
            # Store class statistics
            class_info[class_label.name] = {
                'total': len(all_files),
                'train': len(train_files),
                'test': len(test_files),
                'selected': len(selected_files)
            }
        
        return items, class_info
    
    def _get_valid_files(self, folder_path: str) -> List[str]:
        """Get all valid data files from folder"""
        valid_extensions = ('.mat', '.h5', '.hdf5')
        files = [f for f in os.listdir(folder_path) 
                if f.lower().endswith(valid_extensions)]
        return sorted(files)  # Sort for consistent ordering
    
    def _split_files(self, files: List[str]) -> Tuple[List[str], List[str]]:
        """Split files into train and test sets"""
        files_shuffled = files.copy()
        np.random.shuffle(files_shuffled)
        
        split_point = math.floor((1 - self.test_freq) * len(files_shuffled))
        train_files = files_shuffled[:split_point]
        test_files = files_shuffled[split_point:]
        
        return train_files, test_files
    
    def _normalize_image(self, image: np.ndarray) -> np.ndarray:
        """Normalize image to 0-255 range using MATLAB formula"""
        im1 = image.astype(np.float64)
        min_val, max_val = np.min(im1), np.max(im1)
        
        if max_val == min_val:
            return np.zeros_like(im1, dtype=np.uint8)
        
        im_normalized = 255.0 * (im1 - min_val) / (max_val - min_val)
        return im_normalized.astype(np.uint8)
    
    def _print_stats(self):
        """Print dataset statistics"""
        mode = "Training" if self.train else "Testing"
        print(f"\n=== {mode} Dataset Statistics ===")
        print(f"Total samples: {len(self.items)}")
        print(f"Test frequency: {self.test_freq}")
        
        if self.class_info:
            print("\nClass breakdown:")
            total_selected = sum(info['selected'] for info in self.class_info.values())
            
            for class_name, info in self.class_info.items():
                percentage = (info['selected'] / total_selected * 100) if total_selected > 0 else 0
                print(f"  {class_name}: {info['selected']} ({percentage:.1f}%) "
                      f"[Total: {info['total']}, Train: {info['train']}, Test: {info['test']}]")
        print("=" * 50)
    
    def get_class_distribution(self) -> Dict[str, int]:
        """Get class distribution in current dataset"""
        return {name: info['selected'] for name, info in self.class_info.items()}
    
    def __len__(self) -> int:
        return len(self.items)
    
    def __getitem__(self, idx: int) -> Dict:
        if not (0 <= idx < len(self.items)):
            raise IndexError(f"Index {idx} out of range [0, {len(self.items)})")
        
        file_path = os.path.join(self.root, self.items[idx])
        
        try:
            with h5py.File(file_path, 'r') as f:
                data = f['cjdata']
                
                raw_image = data['image'][:]
                mask = data['tumorMask'][:]
                label = int(data['label'][0][0])
                
                # Apply normalization if requested
                image = self._normalize_image(raw_image) if self.normalize_image else raw_image
                
                return {
                    "label": label,
                    "image": image,
                    "mask": mask,
                    "file_path": self.items[idx]
                }
        
        except Exception as e:
            raise RuntimeError(f"Error loading {file_path}: {str(e)}")


class BrainTumorDatasetMask(BrainTumorDataset):
    """Dataset that returns (image, mask) tuples for backward compatibility"""
    
    def __init__(self, root: str, train: bool = True, transform=None, **kwargs):
        super().__init__(root=root, train=train, **kwargs)
        self.transform = transform
    
    def __getitem__(self, idx: int) -> Union[Tuple[np.ndarray, np.ndarray], any]:
        metadata = super().__getitem__(idx)
        sample = (metadata["image"], metadata["mask"])
        
        return self.transform(*sample) if self.transform else sample

# %%
def inspect_sample(dataset: BrainTumorDataset, idx: int = 0):
    """Inspect a dataset sample"""
    if len(dataset) == 0:
        print("Dataset is empty!")
        return
    
    sample = dataset[idx]
    print(f"\n=== Sample {idx} Inspection ===")
    
    if isinstance(sample, dict):
        print(f"Label: {sample['label']}")
        print(f"Image shape: {sample['image'].shape}, dtype: {sample['image'].dtype}")
        print(f"Image range: [{sample['image'].min()}, {sample['image'].max()}]")
        print(f"Mask shape: {sample['mask'].shape}, dtype: {sample['mask'].dtype}")
        print(f"File: {sample['file_path']}")
    else:
        print(f"Sample type: {type(sample)}")
        if isinstance(sample, tuple) and len(sample) == 2:
            image, mask = sample
            print(f"Image shape: {image.shape}, dtype: {image.dtype}")
            print(f"Mask shape: {mask.shape}, dtype: {mask.dtype}")
    
    print("=" * 35)

# %%
dataset_mask = BrainTumorDatasetMask(root=config.ROOT, train=True, test_freq=0.2)
sample_mask = dataset_mask[0]  # Trả về (image, mask)
print(f"Mask dataset sample type: {type(sample_mask)}")

inspect_sample(dataset_mask, 0)
# Out:
# === Training Dataset Statistics ===
# Total samples: 2438
# Test frequency: 0.2
#
# Class breakdown:
#   Meningioma: 566 (23.2%) [Total: 708, Train: 566, Test: 142]
#   Glioma: 1140 (46.8%) [Total: 1426, Train: 1140, Test: 286]
#   Pituitary: 732 (30.0%) [Total: 915, Train: 732, Test: 183]
# ==================================================
# Mask dataset sample type: <class 'tuple'>
#
# === Sample 0 Inspection ===
# Sample type: <class 'tuple'>
# Image shape: (512, 512), dtype: uint8
# Mask shape: (512, 512), dtype: uint8
# ===================================

# %%
# Visualize function
def visualize(images, masks, original_images=None, original_masks=None):
    fontsize=18
    
    # Xử lý trường hợp input là single sample
    if not isinstance(images, (list, tuple)):
        images = [images]
        masks = [masks]
        if original_images is not None:
            original_images = [original_images]
        if original_masks is not None:
            original_masks = [original_masks]
    
    num_samples = len(images)
    
    if original_images is None and original_masks is None:
        # Hiển thị 2 hàng: hàng 1 là images, hàng 2 là masks
        f, ax = plt.subplots(2, num_samples, figsize=(4*num_samples, 8))
        
        # Nếu chỉ có 1 sample, ax sẽ là 1D array
        if num_samples == 1:
            ax = ax.reshape(2, 1)
        
        for i in range(num_samples):
            ax[0, i].imshow(images[i], cmap='gray')
            ax[0, i].set_title(f'Image {i+1}', fontsize=fontsize)
            ax[0, i].axis('off')
            
            ax[1, i].imshow(masks[i], cmap='gray')
            ax[1, i].set_title(f'Mask {i+1}', fontsize=fontsize)
            ax[1, i].axis('off')
    else:
        # Hiển thị 4 hàng: original images, original masks, transformed images, transformed masks
        f, ax = plt.subplots(4, num_samples, figsize=(4*num_samples, 16))
        
        # Nếu chỉ có 1 sample, ax sẽ là 1D array
        if num_samples == 1:
            ax = ax.reshape(4, 1)
        
        for i in range(num_samples):
            ax[0, i].imshow(original_images[i], cmap='gray')
            ax[0, i].set_title(f'Original Image {i+1}', fontsize=fontsize)
            ax[0, i].axis('off')
            
            ax[1, i].imshow(original_masks[i], cmap='gray')
            ax[1, i].set_title(f'Original Mask {i+1}', fontsize=fontsize)
            ax[1, i].axis('off')
            
            ax[2, i].imshow(images[i], cmap='gray')
            ax[2, i].set_title(f'Transformed Image {i+1}', fontsize=fontsize)
            ax[2, i].axis('off')
            
            ax[3, i].imshow(masks[i], cmap='gray')
            ax[3, i].set_title(f'Transformed Mask {i+1}', fontsize=fontsize)
            ax[3, i].axis('off')
    
    plt.tight_layout()
    plt.show()

# Ví dụ sử dụng với multiple samples
def visualize_multiple_samples(dataset, indices, with_preprocessing=True):
    """
    Hiển thị nhiều samples từ dataset
    
    Args:
        dataset: Dataset object
        indices: List các index muốn hiển thị
        with_preprocessing: Có hiển thị ảnh trước và sau preprocessing không
    """
    images = []
    masks = []
    original_images = []
    original_masks = []
    
    for idx in indices:
        if with_preprocessing and hasattr(dataset, 'transform') and dataset.transform is not None:
            # Lấy dữ liệu gốc (không preprocessing)
            dataset_temp = dataset.__class__(dataset.root, dataset.train, transform=None, classes=dataset.classes)
            orig_img, orig_mask = dataset_temp[idx]
            original_images.append(orig_img)
            original_masks.append(orig_mask)
            
            # Lấy dữ liệu đã preprocessing
            proc_img, proc_mask = dataset[idx]
            images.append(proc_img.squeeze() if hasattr(proc_img, 'squeeze') else proc_img)
            masks.append(proc_mask.squeeze() if hasattr(proc_mask, 'squeeze') else proc_mask)
        else:
            # Chỉ lấy dữ liệu hiện tại
            img, mask = dataset[idx]
            images.append(img.squeeze() if hasattr(img, 'squeeze') else img)
            masks.append(mask.squeeze() if hasattr(mask, 'squeeze') else mask)
    
    if with_preprocessing and original_images:
        visualize(images, masks, original_images, original_masks)
    else:
        visualize(images, masks)

# Hàm tiền xử lí dữ liệu
def preprocessing(image, mask):
    image_transformer = transforms.Compose([
        transforms.ToTensor(),
        transforms.Resize(config.IMG_SIZE, interpolation=0),
        # transforms.Normalize(mean=(0.5,), std=(0.5,))  # Normalize image
        ])
    mask_transformer = transforms.Compose([
        transforms.Lambda(lambda x: transforms.ToPILImage()(transforms.ToTensor()(x).float().squeeze())),
        transforms.ToTensor(),
        transforms.Resize(config.IMG_SIZE, interpolation=0),
    ])
    # image = np.transpose(np.array(image)) / 65535.0
    # image = image * 2 - 1
    image = np.transpose(np.array(image))
    mask = np.transpose(np.array(mask))
    mask = mask_transformer(mask)
    mask = mask / mask.max()
    mask = torch.where(mask > 0.5, 1, 0).float()
    return image_transformer(image).float(), mask

# %%
# Khởi tạo dataset
dataset = BrainTumorDatasetMask(root='/kaggle/input/brain-tumor-dataset/data/', train=True, transform=preprocessing)
original_image, original_mask = dataset[3]
print(f'#=>Original image: {type(original_image)}')
print(f'#=>Original mask: {type(original_mask)}')
# Out:
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
# #=>Original image: <class 'torch.Tensor'>
# #=>Original mask: <class 'torch.Tensor'>

# %%
visualize(original_image.squeeze(), original_mask.squeeze())

# %%
visualize_multiple_samples(dataset, [0, 1, 2, 3])
# Out:
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
#
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
#
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
#
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================

# %%
class PreActivateDoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(PreActivateDoubleConv, self).__init__()
        self.double_conv = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        )

    def forward(self, x):
        return self.double_conv(x)

class PreActivateResUpBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(PreActivateResUpBlock, self).__init__()
        self.ch_avg = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels))
        self.up_sample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        self.ch_avg = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels))
        self.double_conv = PreActivateDoubleConv(in_channels, out_channels)

    def forward(self, down_input, skip_input):
        x = self.up_sample(down_input)
        x = torch.cat([x, skip_input], dim=1)
        return self.double_conv(x) + self.ch_avg(x)

class PreActivateResBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(PreActivateResBlock, self).__init__()
        self.ch_avg = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels))

        self.double_conv = PreActivateDoubleConv(in_channels, out_channels)
        self.down_sample = nn.MaxPool2d(2)

    def forward(self, x):
        identity = self.ch_avg(x)
        out = self.double_conv(x)
        out = out + identity
        return self.down_sample(out), out

class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DoubleConv, self).__init__()
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.double_conv(x)

class ResBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ResBlock, self).__init__()
        self.downsample = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels))
        self.double_conv = DoubleConv(in_channels, out_channels)
        self.down_sample = nn.MaxPool2d(2)
        self.relu = nn.ReLU()

    def forward(self, x):
        identity = self.downsample(x)
        out = self.double_conv(x)
        out = self.relu(out + identity)
        return self.down_sample(out), out


class DownBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DownBlock, self).__init__()
        self.double_conv = DoubleConv(in_channels, out_channels)
        self.down_sample = nn.MaxPool2d(2)

    def forward(self, x):
        skip_out = self.double_conv(x)
        down_out = self.down_sample(skip_out)
        return (down_out, skip_out)

class UpBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(UpBlock, self).__init__()
        self.up_sample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        self.double_conv = DoubleConv(in_channels, out_channels)

    def forward(self, down_input, skip_input):
        x = self.up_sample(down_input)
        x = torch.cat([x, skip_input], dim=1)
        return self.double_conv(x)

class UNet(nn.Module):
    def __init__(self, out_classes=1):
        super(UNet, self).__init__()

        self.down_conv1 = DownBlock(1, 64)
        self.down_conv2 = DownBlock(64, 128)
        self.down_conv3 = DownBlock(128, 256)
        self.down_conv4 = DownBlock(256, 512)

        self.double_conv = DoubleConv(512, 1024)

        self.up_conv4 = UpBlock(512 + 1024, 512)
        self.up_conv3 = UpBlock(256 + 512, 256)
        self.up_conv2 = UpBlock(128 + 256, 128)
        self.up_conv1 = UpBlock(128 + 64, 64)

        self.conv_last = nn.Conv2d(64, out_classes, kernel_size=1)
        self.act_last = nn.Sigmoid()

    def forward(self, x):
        x, skip1_out = self.down_conv1(x)
        x, skip2_out = self.down_conv2(x)
        x, skip3_out = self.down_conv3(x)
        x, skip4_out = self.down_conv4(x)
        x = self.double_conv(x)
        x = self.up_conv4(x, skip4_out)
        x = self.up_conv3(x, skip3_out)
        x = self.up_conv2(x, skip2_out)
        x = self.up_conv1(x, skip1_out)
        x = self.conv_last(x)
        x = self.act_last(x)
        return x

class DeepResUNet(nn.Module):
    def __init__(self, out_classes=1):
        super(DeepResUNet, self).__init__()

        self.down_conv1 = PreActivateResBlock(1, 64)
        self.down_conv2 = PreActivateResBlock(64, 128)
        self.down_conv3 = PreActivateResBlock(128, 256)
        self.down_conv4 = PreActivateResBlock(256, 512)

        self.double_conv = PreActivateDoubleConv(512, 1024)

        self.up_conv4 = PreActivateResUpBlock(512 + 1024, 512)
        self.up_conv3 = PreActivateResUpBlock(256 + 512, 256)
        self.up_conv2 = PreActivateResUpBlock(128 + 256, 128)
        self.up_conv1 = PreActivateResUpBlock(128 + 64, 64)

        self.conv_last = nn.Conv2d(64, out_classes, kernel_size=1)

    def forward(self, x):
        x, skip1_out = self.down_conv1(x)
        x, skip2_out = self.down_conv2(x)
        x, skip3_out = self.down_conv3(x)
        x, skip4_out = self.down_conv4(x)
        x = self.double_conv(x)
        x = self.up_conv4(x, skip4_out)
        x = self.up_conv3(x, skip3_out)
        x = self.up_conv2(x, skip2_out)
        x = self.up_conv1(x, skip1_out)
        x = self.conv_last(x)
        return x

class ResUNet(nn.Module):
    """
    Hybrid solution of resnet blocks and double conv blocks
    """
    def __init__(self, out_classes=1):
        super(ResUNet, self).__init__()

        self.down_conv1 = ResBlock(1, 64)
        self.down_conv2 = ResBlock(64, 128)
        self.down_conv3 = ResBlock(128, 256)
        self.down_conv4 = ResBlock(256, 512)

        self.double_conv = DoubleConv(512, 1024)

        self.up_conv4 = UpBlock(512 + 1024, 512)
        self.up_conv3 = UpBlock(256 + 512, 256)
        self.up_conv2 = UpBlock(128 + 256, 128)
        self.up_conv1 = UpBlock(128 + 64, 64)

        self.conv_last = nn.Conv2d(64, out_classes, kernel_size=1)

    def forward(self, x):
        x, skip1_out = self.down_conv1(x)
        x, skip2_out = self.down_conv2(x)
        x, skip3_out = self.down_conv3(x)
        x, skip4_out = self.down_conv4(x)
        x = self.double_conv(x)
        x = self.up_conv4(x, skip4_out)
        x = self.up_conv3(x, skip3_out)
        x = self.up_conv2(x, skip2_out)
        x = self.up_conv1(x, skip1_out)
        x = self.conv_last(x)
        return x

class ONet(nn.Module):
    def __init__(self, alpha=470, beta=40, out_classes=1):
        super(ONet, self).__init__()
        self.alpha = alpha
        self.beta = beta
        self.down_conv1 = ResBlock(1, 64)
        self.down_conv2 = ResBlock(64, 128)
        self.down_conv3 = ResBlock(128, 256)
        self.down_conv4 = ResBlock(256, 512)

        self.double_conv = DoubleConv(512, 1024)

        self.up_conv4 = UpBlock(512 + 1024, 512)
        self.up_conv3 = UpBlock(256 + 512, 256)
        self.up_conv2 = UpBlock(128 + 256, 128)
        self.up_conv1 = UpBlock(128 + 64, 64)

        self.conv_last = nn.Conv2d(64, 1, kernel_size=1)
        self.input_output_conv = nn.Conv2d(2, 1, kernel_size=1)


    def forward(self, inputs):
        input_tensor, bounding = inputs
        x, skip1_out = self.down_conv1(input_tensor + (bounding * self.alpha))
        x, skip2_out = self.down_conv2(x)
        x, skip3_out = self.down_conv3(x)
        x, skip4_out = self.down_conv4(x)
        x = self.double_conv(x)
        x = self.up_conv4(x, skip4_out)
        x = self.up_conv3(x, skip3_out)
        x = self.up_conv2(x, skip2_out)
        x = self.up_conv1(x, skip1_out)
        x = self.conv_last(x)
        input_output = torch.cat([x, bounding * self.beta], dim=1)
        x = self.input_output_conv(input_output)
        return x

# %%
class Trainer():
    def __init__(self,
                 model,
                 train_dataloader,
                 valid_dataloader,
                 epochs=10,
                 save_dir=None,
                 device='cpu',
                 accumalation_steps=4,
                 patience=5):  # Add patience for early stopping
        self.device = device
        self.accumalation_steps = accumalation_steps

        self.model = model.to(self.device)

        self.train_losses = []
        self.train_dice_coeff_values = []
        self.train_iou_values = []
        self.val_losses = []
        self.val_dice_coeff_values = []
        self.val_iou_values = []
        self.patience = patience  # Early stopping patience
        self.early_stop = False  # Flag for early stopping
        self.best_valid_loss = float('inf')  # Initialize best loss

        if save_dir != None and os.path.exists(save_dir):
            print("Load weight from file:{}".format(save_dir))
            self.save_dir = save_dir
            epcho_checkpoint_path = glob.glob("{}/model_epoch*".format(self.save_dir))
            if len(epcho_checkpoint_path) == 0:
                print("No checkpoint found in: {}\nCheck save_dir...".format(self.save_dir))
            else:
                self.load_checkpoint(epcho_checkpoint_path[0])
                print("Restore weight successful from: {}".format(epcho_checkpoint_path))
        else:
            self.save_dir = datetime.now().strftime("%d-%m-%Y_%H-%M-%S")
            os.makedirs(self.save_dir)
            print("Training new model, save to: {}".format(self.save_dir))

        self.train_dataloader = train_dataloader
        self.valid_dataloader = valid_dataloader
        self.epochs = epochs

    def save_checkpoint(self, save_path):
        state_dict = {'model_state_dict': self.model.state_dict(),
                      'train_losses': self.train_losses,
                      'train_dice_coeff_values': self.train_dice_coeff_values,
                      'train_iou_values': self.train_iou_values,
                      'val_losses': self.val_losses,
                      'val_dice_coeff_values': self.val_dice_coeff_values,
                      'val_iou_values': self.val_iou_values
                     }
        torch.save(state_dict, save_path)
        print(f"Model saved to ==> {save_path}")

    def load_checkpoint(self, load_path):
        state_dict = torch.load(load_path, map_location=self.device)
        print(f"Model restored from <== {load_path}")
        self.model.load_state_dict(state_dict["model_state_dict"])
        self.train_losses = state_dict["train_losses"]
        self.train_dice_coeff_values = state_dict["train_dice_coeff_values"]
        self.train_iou_values = state_dict['train_iou_values']
        self.val_losses = state_dict["val_losses"]
        self.val_dice_coeff_values = state_dict["val_dice_coeff_values"]
        self.val_iou_values = state_dict['val_iou_values']

    @staticmethod
    def iou(pred_mask, true_mask):
        # Làm phẳng các tensor
        pred_mask = pred_mask.view(-1)
        true_mask = true_mask.view(-1)
    
        # Tính toán phần giao nhau và hợp nhất
        intersection = torch.sum(pred_mask * true_mask)
        union = torch.sum(pred_mask) + torch.sum(true_mask) - intersection
    
        # Tính IoU
        iou = intersection / union
    
        return iou

    @staticmethod
    def dice_loss(pred, target, smooth=1e-6):
        pred = pred.view(-1)
        target = target.view(-1)
        
        # Flatten the tensors to calculate the intersection and union of predicted and true masks
        intersection = torch.sum(pred * target)
        union = torch.sum(pred) + torch.sum(target)
        
        # Compute Dice coefficient
        dice = (2. * intersection + smooth) / (union + smooth)
        
        return 1 - dice

    @staticmethod
    def dice_coeff(pred, target, smooth=1e-6, threshold=0.5):
        pred = pred.view(-1)
        target = target.view(-1)
        # pred = (pred > threshold).float()
        
        intersection = torch.sum(pred * target)
        union = torch.sum(pred) + torch.sum(target)
        return (2. * intersection + smooth) / (union + smooth)
    
    def train(self):
        if config.DICE_LOSS:
            criterion = self.dice_loss
        else:
            criterion = nn.BCELoss()
            
        optimizer = torch.optim.AdamW(self.model.parameters(), lr=config.LEARNING_RATE, weight_decay=config.WEIGHT_DECAY)
        scheduler = lr_scheduler.CosineAnnealingLR(optimizer, T_max=config.EPOCHS, eta_min=config.LEARNING_RATE_MIN)
        
        patience_counter = 0  # Track epochs without improvement
        for epoch_i in range(0, self.epochs):
            if self.early_stop:  # Check if early stopping is triggered
                print("Early stopping triggered. Training stopped.")
                break

            print('========== Epoch {:} / {:} =========='.format(epoch_i + 1, self.epochs))
            print('Training...')

            total_loss = 0
            self.model.train()
            nb_train_steps = 0
            train_iou = 0
            train_dice_coeff = 0

            for step, batch in enumerate(self.train_dataloader):
                img, mask = batch
                img, mask = img.to(self.device), mask.to(self.device)
                
                outputs = self.model(img)

                dice = self.dice_coeff(outputs.detach(), mask).item()
                train_dice_coeff += dice
                iou = self.iou(outputs.detach(), mask).item()
                train_iou += iou

                loss = criterion(outputs, mask) / self.accumalation_steps
                total_loss += loss.item() * self.accumalation_steps
                
                nb_train_steps += 1

                loss.backward()
                if (step + 1) % self.accumalation_steps == 0:
                    optimizer.step()
                    # scheduler.step()
                    optimizer.zero_grad()

                if (step + 1) % 10 == 0:
                    print("[TRAIN] Epoch {}/{} | Batch {}/{} | Loss={:.4f} | Dice_coeff={:.4f} | IoU={:.4f}".format(epoch_i + 1, self.epochs, step + 1, len(self.train_dataloader), loss.item(), dice, iou))

            scheduler.step()
            avg_train_loss = total_loss / len(self.train_dataloader)
            avg_train_dice_coeff = train_dice_coeff / nb_train_steps
            avg_train_iou = train_iou / nb_train_steps
            print(" Train Loss: {:.4f} | Avg_dice_coeff: {:.4f} | Avg_IoU: {:.4f}".format(avg_train_loss, avg_train_dice_coeff, avg_train_iou))

            self.train_losses.append(avg_train_loss)
            self.train_dice_coeff_values.append(avg_train_dice_coeff)
            self.train_iou_values.append(avg_train_iou)

            print("Running Validation...")
            self.model.eval()
            eval_loss = 0
            eval_iou = 0
            eval_dice_coeff = 0
            nb_eval_steps = 0

            for batch in self.valid_dataloader:
                img, mask = batch
                img, mask = img.to(self.device), mask.to(self.device)

                with torch.no_grad():
                    outputs = self.model(img)

                    loss = criterion(outputs, mask)       
                    eval_dice_coeff += self.dice_coeff(outputs.detach(), mask).item()
                    eval_iou += self.iou(outputs.detach(), mask).item()
                    eval_loss += loss.item()
                    nb_eval_steps += 1

            avg_val_loss = eval_loss / nb_eval_steps
            avg_val_dice_coeff = eval_dice_coeff / nb_eval_steps
            avg_val_iou = eval_iou / nb_eval_steps
            
            print(f" Valid Loss: {avg_val_loss:.4f} | Dice_coeff: {avg_val_dice_coeff:.4f} | IoU: {avg_val_iou:.4f}")

            self.val_losses.append(avg_val_loss)
            self.val_dice_coeff_values.append(avg_val_dice_coeff)
            self.val_iou_values.append(avg_val_iou)

            # Early stopping logic
            if avg_val_loss  < self.best_valid_loss:
                print(f"Validation loss improved from {self.best_valid_loss:.4f} to {avg_val_loss:.4f}. Saving model...")
                self.best_valid_loss = avg_val_loss
                patience_counter = 0  # Reset patience counter
                best_valid_loss_path = "{}/model_best_valloss.pt".format(self.save_dir)
                self.save_checkpoint(best_valid_loss_path)
            else:
                patience_counter += 1
                print(f"No improvement in validation loss for {patience_counter} epochs.")
                if patience_counter >= self.patience:
                    print(f"Stopping early after {patience_counter} epochs without improvement.")
                    self.early_stop = True

            # Save checkpoint for current epoch
            epoch_i_path = "{}/model_epoch{}.pt".format(self.save_dir, epoch_i)
            self.save_checkpoint(epoch_i_path)

            # Remove the previous epoch's checkpoint
            if os.path.exists("{}/model_epoch{}.pt".format(self.save_dir, epoch_i-1)):
                os.remove("{}/model_epoch{}.pt".format(self.save_dir, epoch_i-1))

        print("Training complete!")
        
    def eval(self, dataloader):
        self.model.eval()
        if config.DICE_LOSS:
            criterion = self.dice_loss
        else:
            criterion = nn.BCELoss()
        nb_eval_steps = 0
        eval_loss = 0
        eval_iou = 0
        eval_dice_coeff = 0
        for step, batch in enumerate(dataloader):
            img, mask = batch
            img, mask = img.to(self.device), mask.to(self.device)

            with torch.no_grad():
                outputs = self.model(img)

                loss = criterion(outputs, mask)
                
                eval_dice_coeff += self.dice_coeff(outputs.detach(), mask).item()
                eval_iou += self.iou(outputs.detach(), mask).item()
                eval_loss += loss.item()
                nb_eval_steps += 1
                
            if (step + 1) % 100 == 0:
                    print("[Test] Batch {}/{} | Test Loss={:.4f}".format(step + 1, len(dataloader), loss))
        avg_val_loss = eval_loss / nb_eval_steps
        avg_dice_coeff = eval_dice_coeff / nb_eval_steps
        avg_iou = eval_iou / nb_eval_steps
        
        print(f" Test Loss: {avg_val_loss:.4f} | Dice_coeff: {avg_dice_coeff:.4f} | IoU: {avg_iou:.4f}")
        return

    def visualize_scores(self):
        num_epoches = range(1, len(self.train_losses) + 1)
        # Vẽ Loss
        plt.figure(figsize=(12, 6))
        plt.plot(num_epoches, self.train_losses, label='Train Loss', marker='o', color='blue')
        plt.plot(num_epoches, self.val_losses, label='Test Loss', marker='o', color='orange')
        plt.title('Training and Testing Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        plt.grid(True)
        plt.show()
        
        # Vẽ Dice Coeff
        plt.figure(figsize=(12, 6))
        plt.plot(num_epoches, self.train_dice_coeff_values, label='Train Dice Coeff', marker='o', color='green')
        plt.plot(num_epoches, self.val_dice_coeff_values, label='Test Dice Coeff', marker='o', color='red')
        plt.title('Training and Testing Dice Coeff')
        plt.xlabel('Epochs')
        plt.ylabel('Dice Coeff')
        plt.legend()
        plt.grid(True)
        plt.show()

        # Vẽ IoU
        plt.figure(figsize=(12, 6))
        plt.plot(num_epoches, self.train_iou_values, label='Train IoU', marker='o', color='green')
        plt.plot(num_epoches, self.val_iou_values, label='Test IoU', marker='o', color='red')
        plt.title('Training and Testing IoU')
        plt.xlabel('Epochs')
        plt.ylabel('IoU')
        plt.legend()
        plt.grid(True)
        plt.show()

# %%
train_dataset = BrainTumorDatasetMask(root=config.ROOT, train=True, 
                                      test_freq=config.TEST_RATIO, transform=preprocessing)
valid_dataset = BrainTumorDatasetMask(root=config.ROOT, train=False, 
                                      test_freq=config.TEST_RATIO, transform=preprocessing)
print(f'Length of train dataset: {len(train_dataset)}')
print(f'Length of test dataset: {len(valid_dataset)}')

train_loader = DataLoader(dataset=train_dataset, batch_size=config.BATCH_SIZE, shuffle=True)
valid_loader = DataLoader(dataset=valid_dataset, batch_size=config.BATCH_SIZE, shuffle=False)
print(f'Length of train loader: {len(train_loader)}')
print(f'Length of test loader: {len(valid_loader)}')
# Out:
# === Training Dataset Statistics ===
# Total samples: 2438
# Test frequency: 0.2
#
# Class breakdown:
#   Meningioma: 566 (23.2%) [Total: 708, Train: 566, Test: 142]
#   Glioma: 1140 (46.8%) [Total: 1426, Train: 1140, Test: 286]
#   Pituitary: 732 (30.0%) [Total: 915, Train: 732, Test: 183]
# ==================================================
#
# === Testing Dataset Statistics ===
# Total samples: 611
# Test frequency: 0.2
#
# Class breakdown:
#   Meningioma: 142 (23.2%) [Total: 708, Train: 566, Test: 142]
#   Glioma: 286 (46.8%) [Total: 1426, Train: 1140, Test: 286]
#   Pituitary: 183 (30.0%) [Total: 915, Train: 732, Test: 183]
# ==================================================
# Length of train dataset: 2438
# Length of test dataset: 611
# Length of train loader: 153
# Length of test loader: 39

# %%
 def init_weights_with_kaiming_uniform(m):
        '''Initialize the weights of the model with kaiming uniform initialization.'''
        if type(m) == nn.Conv2d:
            torch.nn.init.kaiming_uniform_(m.weight)
            
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
model = UNet().to(config.DEVICE)
model = nn.DataParallel(model)
model.apply(init_weights_with_kaiming_uniform) # default init is xaiver uniform
    
print("Number parameters:", count_parameters(model))
# Out:
# Number parameters: 31389569

# %%
trainer = Trainer(
    model=model,
    train_dataloader=train_loader,
    valid_dataloader=valid_loader,
    epochs=config.EPOCHS,
    save_dir=config.SAVE_DIR,
    device=config.DEVICE,
    accumalation_steps=config.ACCUMALATION_STEPS,
    patience = config.PATIENCE
)
# Out:
# Training new model, save to: 18-06-2025_04-14-53

# %%
# trainer.load_checkpoint('/kaggle/working/17-06-2025_08-00-35/model_epoch0.pt')

# %%
trainer.train()
# Out:
# ========== Epoch 1 / 150 ==========
# Training...
# [TRAIN] Epoch 1/150 | Batch 10/153 | Loss=0.8407 | Dice_coeff=0.1593 | IoU=0.0865
# [TRAIN] Epoch 1/150 | Batch 20/153 | Loss=0.8625 | Dice_coeff=0.1375 | IoU=0.0738
# [TRAIN] Epoch 1/150 | Batch 30/153 | Loss=0.7943 | Dice_coeff=0.2057 | IoU=0.1146
# [TRAIN] Epoch 1/150 | Batch 40/153 | Loss=0.7626 | Dice_coeff=0.2374 | IoU=0.1347
# [TRAIN] Epoch 1/150 | Batch 50/153 | Loss=0.7690 | Dice_coeff=0.2310 | IoU=0.1306
# [TRAIN] Epoch 1/150 | Batch 60/153 | Loss=0.7710 | Dice_coeff=0.2290 | IoU=0.1293
# [TRAIN] Epoch 1/150 | Batch 70/153 | Loss=0.6712 | Dice_coeff=0.3288 | IoU=0.1968
# [TRAIN] Epoch 1/150 | Batch 80/153 | Loss=0.7259 | Dice_coeff=0.2741 | IoU=0.1588
# [TRAIN] Epoch 1/150 | Batch 90/153 | Loss=0.6613 | Dice_coeff=0.3387 | IoU=0.2039
# [TRAIN] Epoch 1/150 | Batch 100/153 | Loss=0.6313 | Dice_coeff=0.3687 | IoU=0.2260
# [TRAIN] Epoch 1/150 | Batch 110/153 | Loss=0.6164 | Dice_coeff=0.3836 | IoU=0.2373
# [TRAIN] Epoch 1/150 | Batch 120/153 | Loss=0.5896 | Dice_coeff=0.4104 | IoU=0.2582
# [TRAIN] Epoch 1/150 | Batch 130/153 | Loss=0.6070 | Dice_coeff=0.3930 | IoU=0.2446
# [TRAIN] Epoch 1/150 | Batch 140/153 | Loss=0.5006 | Dice_coeff=0.4994 | IoU=0.3328
# [TRAIN] Epoch 1/150 | Batch 150/153 | Loss=0.5181 | Dice_coeff=0.4819 | IoU=0.3174
#  Train Loss: 0.6901 | Avg_dice_coeff: 0.3099 | Avg_IoU: 0.1908
# Running Validation...
#  Valid Loss: 0.6916 | Dice_coeff: 0.3084 | IoU: 0.1887
# Validation loss improved from inf to 0.6916. Saving model...
# Model saved to ==> 18-06-2025_04-14-53/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-14-53/model_epoch0.pt
# ========== Epoch 2 / 150 ==========
# Training...
# [TRAIN] Epoch 2/150 | Batch 10/153 | Loss=0.5949 | Dice_coeff=0.4051 | IoU=0.2540
# [TRAIN] Epoch 2/150 | Batch 20/153 | Loss=0.5345 | Dice_coeff=0.4655 | IoU=0.3033
# [TRAIN] Epoch 2/150 | Batch 30/153 | Loss=0.5204 | Dice_coeff=0.4796 | IoU=0.3154
# [TRAIN] Epoch 2/150 | Batch 40/153 | Loss=0.4496 | Dice_coeff=0.5504 | IoU=0.3797
# [TRAIN] Epoch 2/150 | Batch 50/153 | Loss=0.5128 | Dice_coeff=0.4872 | IoU=0.3220
# [TRAIN] Epoch 2/150 | Batch 60/153 | Loss=0.5196 | Dice_coeff=0.4804 | IoU=0.3161
# [TRAIN] Epoch 2/150 | Batch 70/153 | Loss=0.5064 | Dice_coeff=0.4936 | IoU=0.3277
# [TRAIN] Epoch 2/150 | Batch 80/153 | Loss=0.5149 | Dice_coeff=0.4851 | IoU=0.3202
# [TRAIN] Epoch 2/150 | Batch 90/153 | Loss=0.4414 | Dice_coeff=0.5586 | IoU=0.3875
# [TRAIN] Epoch 2/150 | Batch 100/153 | Loss=0.3447 | Dice_coeff=0.6553 | IoU=0.4873
# [TRAIN] Epoch 2/150 | Batch 110/153 | Loss=0.6533 | Dice_coeff=0.3467 | IoU=0.2097
# [TRAIN] Epoch 2/150 | Batch 120/153 | Loss=0.4700 | Dice_coeff=0.5300 | IoU=0.3606
# [TRAIN] Epoch 2/150 | Batch 130/153 | Loss=0.3774 | Dice_coeff=0.6226 | IoU=0.4520
# [TRAIN] Epoch 2/150 | Batch 140/153 | Loss=0.4293 | Dice_coeff=0.5707 | IoU=0.3993
# [TRAIN] Epoch 2/150 | Batch 150/153 | Loss=0.4751 | Dice_coeff=0.5249 | IoU=0.3559
#  Train Loss: 0.4764 | Avg_dice_coeff: 0.5236 | Avg_IoU: 0.3589
# Running Validation...
#  Valid Loss: 0.4654 | Dice_coeff: 0.5346 | IoU: 0.3716
# Validation loss improved from 0.6916 to 0.4654. Saving model...
# Model saved to ==> 18-06-2025_04-14-53/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-14-53/model_epoch1.pt
# ========== Epoch 3 / 150 ==========
# Training...
# [TRAIN] Epoch 3/150 | Batch 10/153 | Loss=0.3993 | Dice_coeff=0.6007 | IoU=0.4293
# [TRAIN] Epoch 3/150 | Batch 20/153 | Loss=0.3163 | Dice_coeff=0.6837 | IoU=0.5194
# [TRAIN] Epoch 3/150 | Batch 30/153 | Loss=0.3515 | Dice_coeff=0.6485 | IoU=0.4799
# [TRAIN] Epoch 3/150 | Batch 40/153 | Loss=0.4202 | Dice_coeff=0.5798 | IoU=0.4083
# [TRAIN] Epoch 3/150 | Batch 50/153 | Loss=0.4126 | Dice_coeff=0.5874 | IoU=0.4158
# [TRAIN] Epoch 3/150 | Batch 60/153 | Loss=0.3465 | Dice_coeff=0.6535 | IoU=0.4854
# [TRAIN] Epoch 3/150 | Batch 70/153 | Loss=0.2441 | Dice_coeff=0.7559 | IoU=0.6076
# [TRAIN] Epoch 3/150 | Batch 80/153 | Loss=0.5857 | Dice_coeff=0.4143 | IoU=0.2613
# [TRAIN] Epoch 3/150 | Batch 90/153 | Loss=0.6838 | Dice_coeff=0.3162 | IoU=0.1878
# [TRAIN] Epoch 3/150 | Batch 100/153 | Loss=0.5948 | Dice_coeff=0.4052 | IoU=0.2541
# [TRAIN] Epoch 3/150 | Batch 110/153 | Loss=0.4629 | Dice_coeff=0.5371 | IoU=0.3672
# [TRAIN] Epoch 3/150 | Batch 120/153 | Loss=0.4391 | Dice_coeff=0.5609 | IoU=0.3898
# [TRAIN] Epoch 3/150 | Batch 130/153 | Loss=0.4005 | Dice_coeff=0.5995 | IoU=0.4281
# [TRAIN] Epoch 3/150 | Batch 140/153 | Loss=0.3080 | Dice_coeff=0.6920 | IoU=0.5290
# [TRAIN] Epoch 3/150 | Batch 150/153 | Loss=0.3958 | Dice_coeff=0.6042 | IoU=0.4329
#  Train Loss: 0.4227 | Avg_dice_coeff: 0.5773 | Avg_IoU: 0.4111
# Running Validation...
#  Valid Loss: 0.4004 | Dice_coeff: 0.5996 | IoU: 0.4439
# Validation loss improved from 0.4654 to 0.4004. Saving model...
# Model saved to ==> 18-06-2025_04-14-53/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-14-53/model_epoch2.pt
# ========== Epoch 4 / 150 ==========
# Training...
# [TRAIN] Epoch 4/150 | Batch 10/153 | Loss=0.3105 | Dice_coeff=0.6895 | IoU=0.5262
# [TRAIN] Epoch 4/150 | Batch 20/153 | Loss=0.3657 | Dice_coeff=0.6343 | IoU=0.4644
# [TRAIN] Epoch 4/150 | Batch 30/153 | Loss=0.2999 | Dice_coeff=0.7001 | IoU=0.5386
# [TRAIN] Epoch 4/150 | Batch 40/153 | Loss=0.4714 | Dice_coeff=0.5286 | IoU=0.3593
# [TRAIN] Epoch 4/150 | Batch 50/153 | Loss=0.3138 | Dice_coeff=0.6862 | IoU=0.5224
# [TRAIN] Epoch 4/150 | Batch 60/153 | Loss=0.3965 | Dice_coeff=0.6035 | IoU=0.4321
# [TRAIN] Epoch 4/150 | Batch 70/153 | Loss=0.4437 | Dice_coeff=0.5563 | IoU=0.3853
# [TRAIN] Epoch 4/150 | Batch 80/153 | Loss=0.3816 | Dice_coeff=0.6184 | IoU=0.4476
# [TRAIN] Epoch 4/150 | Batch 90/153 | Loss=0.2724 | Dice_coeff=0.7276 | IoU=0.5718
# [TRAIN] Epoch 4/150 | Batch 100/153 | Loss=0.2947 | Dice_coeff=0.7053 | IoU=0.5448
# [TRAIN] Epoch 4/150 | Batch 110/153 | Loss=0.4196 | Dice_coeff=0.5804 | IoU=0.4089
# [TRAIN] Epoch 4/150 | Batch 120/153 | Loss=0.4296 | Dice_coeff=0.5704 | IoU=0.3990
# [TRAIN] Epoch 4/150 | Batch 130/153 | Loss=0.3703 | Dice_coeff=0.6297 | IoU=0.4595
# [TRAIN] Epoch 4/150 | Batch 140/153 | Loss=0.4589 | Dice_coeff=0.5411 | IoU=0.3709
# [TRAIN] Epoch 4/150 | Batch 150/153 | Loss=0.5094 | Dice_coeff=0.4906 | IoU=0.3251
#  Train Loss: 0.3759 | Avg_dice_coeff: 0.6241 | Avg_IoU: 0.4582
# Running Validation...
#  Valid Loss: 0.3756 | Dice_coeff: 0.6244 | IoU: 0.4655
# Validation loss improved from 0.4004 to 0.3756. Saving model...
# Model saved to ==> 18-06-2025_04-14-53/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-14-53/model_epoch3.pt
# ========== Epoch 5 / 150 ==========
# Training...
# [TRAIN] Epoch 5/150 | Batch 10/153 | Loss=0.4010 | Dice_coeff=0.5990 | IoU=0.4276
# [TRAIN] Epoch 5/150 | Batch 20/153 | Loss=0.3648 | Dice_coeff=0.6352 | IoU=0.4654
# [TRAIN] Epoch 5/150 | Batch 30/153 | Loss=0.3821 | Dice_coeff=0.6179 | IoU=0.4471
# [TRAIN] Epoch 5/150 | Batch 40/153 | Loss=0.4965 | Dice_coeff=0.5035 | IoU=0.3365
# [TRAIN] Epoch 5/150 | Batch 50/153 | Loss=0.2602 | Dice_coeff=0.7398 | IoU=0.5871
# [TRAIN] Epoch 5/150 | Batch 60/153 | Loss=0.2353 | Dice_coeff=0.7647 | IoU=0.6191
# [TRAIN] Epoch 5/150 | Batch 70/153 | Loss=0.2544 | Dice_coeff=0.7456 | IoU=0.5943
# [TRAIN] Epoch 5/150 | Batch 80/153 | Loss=0.4816 | Dice_coeff=0.5184 | IoU=0.3499
# [TRAIN] Epoch 5/150 | Batch 90/153 | Loss=0.5895 | Dice_coeff=0.4105 | IoU=0.2582
# [TRAIN] Epoch 5/150 | Batch 100/153 | Loss=0.2170 | Dice_coeff=0.7830 | IoU=0.6434
# [TRAIN] Epoch 5/150 | Batch 110/153 | Loss=0.2599 | Dice_coeff=0.7401 | IoU=0.5875
# [TRAIN] Epoch 5/150 | Batch 120/153 | Loss=0.3311 | Dice_coeff=0.6689 | IoU=0.5025
# [TRAIN] Epoch 5/150 | Batch 130/153 | Loss=0.4191 | Dice_coeff=0.5809 | IoU=0.4094
# [TRAIN] Epoch 5/150 | Batch 140/153 | Loss=0.2580 | Dice_coeff=0.7420 | IoU=0.5899
# [TRAIN] Epoch 5/150 | Batch 150/153 | Loss=0.4244 | Dice_coeff=0.5756 | IoU=0.4041
#  Train Loss: 0.3400 | Avg_dice_coeff: 0.6600 | Avg_IoU: 0.4974
# Running Validation...
#  Valid Loss: 0.3645 | Dice_coeff: 0.6355 | IoU: 0.4776
# Validation loss improved from 0.3756 to 0.3645. Saving model...
# Model saved to ==> 18-06-2025_04-14-53/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-14-53/model_epoch4.pt
# ========== Epoch 6 / 150 ==========
# Training...
# [TRAIN] Epoch 6/150 | Batch 10/153 | Loss=0.3629 | Dice_coeff=0.6371 | IoU=0.4675
# [TRAIN] Epoch 6/150 | Batch 20/153 | Loss=0.3735 | Dice_coeff=0.6265 | IoU=0.4561
# [TRAIN] Epoch 6/150 | Batch 30/153 | Loss=0.1624 | Dice_coeff=0.8376 | IoU=0.7206
# [TRAIN] Epoch 6/150 | Batch 40/153 | Loss=0.1993 | Dice_coeff=0.8007 | IoU=0.6676
# [TRAIN] Epoch 6/150 | Batch 50/153 | Loss=0.2449 | Dice_coeff=0.7551 | IoU=0.6065
# [TRAIN] Epoch 6/150 | Batch 60/153 | Loss=0.2114 | Dice_coeff=0.7886 | IoU=0.6509
# [TRAIN] Epoch 6/150 | Batch 70/153 | Loss=0.3627 | Dice_coeff=0.6373 | IoU=0.4676
# [TRAIN] Epoch 6/150 | Batch 80/153 | Loss=0.2817 | Dice_coeff=0.7183 | IoU=0.5604
# [TRAIN] Epoch 6/150 | Batch 90/153 | Loss=0.2791 | Dice_coeff=0.7209 | IoU=0.5636
# [TRAIN] Epoch 6/150 | Batch 100/153 | Loss=0.3206 | Dice_coeff=0.6794 | IoU=0.5144
# [TRAIN] Epoch 6/150 | Batch 110/153 | Loss=0.3643 | Dice_coeff=0.6357 | IoU=0.4660
# [TRAIN] Epoch 6/150 | Batch 120/153 | Loss=0.2054 | Dice_coeff=0.7946 | IoU=0.6593
# [TRAIN] Epoch 6/150 | Batch 130/153 | Loss=0.3376 | Dice_coeff=0.6624 | IoU=0.4953
# [TRAIN] Epoch 6/150 | Batch 140/153 | Loss=0.1989 | Dice_coeff=0.8011 | IoU=0.6682
# [TRAIN] Epoch 6/150 | Batch 150/153 | Loss=0.3743 | Dice_coeff=0.6257 | IoU=0.4553
#  Train Loss: 0.3090 | Avg_dice_coeff: 0.6910 | Avg_IoU: 0.5326
# Running Validation...
#  Valid Loss: 0.2947 | Dice_coeff: 0.7053 | IoU: 0.5621
# Validation loss improved from 0.3645 to 0.2947. Saving model...
# Model saved to ==> 18-06-2025_04-14-53/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-14-53/model_epoch5.pt
# ========== Epoch 7 / 150 ==========
# Training...
# [TRAIN] Epoch 7/150 | Batch 10/153 | Loss=0.3495 | Dice_coeff=0.6505 | IoU=0.4820
# [TRAIN] Epoch 7/150 | Batch 20/153 | Loss=0.1788 | Dice_coeff=0.8212 | IoU=0.6966
# [TRAIN] Epoch 7/150 | Batch 30/153 | Loss=0.2378 | Dice_coeff=0.7622 | IoU=0.6158
# [TRAIN] Epoch 7/150 | Batch 40/153 | Loss=0.2290 | Dice_coeff=0.7710 | IoU=0.6274
# [TRAIN] Epoch 7/150 | Batch 50/153 | Loss=0.2541 | Dice_coeff=0.7459 | IoU=0.5948
# [TRAIN] Epoch 7/150 | Batch 60/153 | Loss=0.2529 | Dice_coeff=0.7471 | IoU=0.5963
# [TRAIN] Epoch 7/150 | Batch 70/153 | Loss=0.2580 | Dice_coeff=0.7420 | IoU=0.5899
# [TRAIN] Epoch 7/150 | Batch 80/153 | Loss=0.2050 | Dice_coeff=0.7950 | IoU=0.6597
# [TRAIN] Epoch 7/150 | Batch 90/153 | Loss=0.3365 | Dice_coeff=0.6635 | IoU=0.4964
# [TRAIN] Epoch 7/150 | Batch 100/153 | Loss=0.3277 | Dice_coeff=0.6723 | IoU=0.5063
# [TRAIN] Epoch 7/150 | Batch 110/153 | Loss=0.2367 | Dice_coeff=0.7633 | IoU=0.6171
# [TRAIN] Epoch 7/150 | Batch 120/153 | Loss=0.2761 | Dice_coeff=0.7239 | IoU=0.5672
# [TRAIN] Epoch 7/150 | Batch 130/153 | Loss=0.4292 | Dice_coeff=0.5708 | IoU=0.3993
# [TRAIN] Epoch 7/150 | Batch 140/153 | Loss=0.2780 | Dice_coeff=0.7220 | IoU=0.5649
# [TRAIN] Epoch 7/150 | Batch 150/153 | Loss=0.2540 | Dice_coeff=0.7460 | IoU=0.5949
#  Train Loss: 0.3027 | Avg_dice_coeff: 0.6973 | Avg_IoU: 0.5410
# Running Validation...
#  Valid Loss: 0.3321 | Dice_coeff: 0.6679 | IoU: 0.5151
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch6.pt
# ========== Epoch 8 / 150 ==========
# Training...
# [TRAIN] Epoch 8/150 | Batch 10/153 | Loss=0.3072 | Dice_coeff=0.6928 | IoU=0.5300
# [TRAIN] Epoch 8/150 | Batch 20/153 | Loss=0.3530 | Dice_coeff=0.6470 | IoU=0.4782
# [TRAIN] Epoch 8/150 | Batch 30/153 | Loss=0.3362 | Dice_coeff=0.6638 | IoU=0.4968
# [TRAIN] Epoch 8/150 | Batch 40/153 | Loss=0.2971 | Dice_coeff=0.7029 | IoU=0.5419
# [TRAIN] Epoch 8/150 | Batch 50/153 | Loss=0.2228 | Dice_coeff=0.7772 | IoU=0.6355
# [TRAIN] Epoch 8/150 | Batch 60/153 | Loss=0.2550 | Dice_coeff=0.7450 | IoU=0.5936
# [TRAIN] Epoch 8/150 | Batch 70/153 | Loss=0.2981 | Dice_coeff=0.7019 | IoU=0.5408
# [TRAIN] Epoch 8/150 | Batch 80/153 | Loss=0.2355 | Dice_coeff=0.7645 | IoU=0.6188
# [TRAIN] Epoch 8/150 | Batch 90/153 | Loss=0.2318 | Dice_coeff=0.7682 | IoU=0.6236
# [TRAIN] Epoch 8/150 | Batch 100/153 | Loss=0.2819 | Dice_coeff=0.7181 | IoU=0.5602
# [TRAIN] Epoch 8/150 | Batch 110/153 | Loss=0.2369 | Dice_coeff=0.7631 | IoU=0.6169
# [TRAIN] Epoch 8/150 | Batch 120/153 | Loss=0.3560 | Dice_coeff=0.6440 | IoU=0.4750
# [TRAIN] Epoch 8/150 | Batch 130/153 | Loss=0.3143 | Dice_coeff=0.6857 | IoU=0.5217
# [TRAIN] Epoch 8/150 | Batch 140/153 | Loss=0.3784 | Dice_coeff=0.6216 | IoU=0.4509
# [TRAIN] Epoch 8/150 | Batch 150/153 | Loss=0.2038 | Dice_coeff=0.7962 | IoU=0.6614
#  Train Loss: 0.2867 | Avg_dice_coeff: 0.7133 | Avg_IoU: 0.5584
# Running Validation...
#  Valid Loss: 0.2841 | Dice_coeff: 0.7159 | IoU: 0.5764
# Validation loss improved from 0.2947 to 0.2841. Saving model...
# Model saved to ==> 18-06-2025_04-14-53/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-14-53/model_epoch7.pt
# ========== Epoch 9 / 150 ==========
# Training...
# [TRAIN] Epoch 9/150 | Batch 10/153 | Loss=0.2497 | Dice_coeff=0.7503 | IoU=0.6003
# [TRAIN] Epoch 9/150 | Batch 20/153 | Loss=0.3366 | Dice_coeff=0.6634 | IoU=0.4963
# [TRAIN] Epoch 9/150 | Batch 30/153 | Loss=0.2133 | Dice_coeff=0.7867 | IoU=0.6484
# [TRAIN] Epoch 9/150 | Batch 40/153 | Loss=0.2035 | Dice_coeff=0.7965 | IoU=0.6619
# [TRAIN] Epoch 9/150 | Batch 50/153 | Loss=0.2073 | Dice_coeff=0.7927 | IoU=0.6566
# [TRAIN] Epoch 9/150 | Batch 60/153 | Loss=0.2535 | Dice_coeff=0.7465 | IoU=0.5956
# [TRAIN] Epoch 9/150 | Batch 70/153 | Loss=0.2705 | Dice_coeff=0.7295 | IoU=0.5742
# [TRAIN] Epoch 9/150 | Batch 80/153 | Loss=0.2669 | Dice_coeff=0.7331 | IoU=0.5787
# [TRAIN] Epoch 9/150 | Batch 90/153 | Loss=0.2356 | Dice_coeff=0.7644 | IoU=0.6186
# [TRAIN] Epoch 9/150 | Batch 100/153 | Loss=0.2739 | Dice_coeff=0.7261 | IoU=0.5700
# [TRAIN] Epoch 9/150 | Batch 110/153 | Loss=0.1819 | Dice_coeff=0.8181 | IoU=0.6922
# [TRAIN] Epoch 9/150 | Batch 120/153 | Loss=0.2192 | Dice_coeff=0.7808 | IoU=0.6405
# [TRAIN] Epoch 9/150 | Batch 130/153 | Loss=0.2969 | Dice_coeff=0.7031 | IoU=0.5421
# [TRAIN] Epoch 9/150 | Batch 140/153 | Loss=0.2576 | Dice_coeff=0.7424 | IoU=0.5903
# [TRAIN] Epoch 9/150 | Batch 150/153 | Loss=0.3110 | Dice_coeff=0.6890 | IoU=0.5255
#  Train Loss: 0.2607 | Avg_dice_coeff: 0.7393 | Avg_IoU: 0.5901
# Running Validation...
#  Valid Loss: 0.2551 | Dice_coeff: 0.7449 | IoU: 0.6046
# Validation loss improved from 0.2841 to 0.2551. Saving model...
# Model saved to ==> 18-06-2025_04-14-53/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-14-53/model_epoch8.pt
# ========== Epoch 10 / 150 ==========
# Training...
# [TRAIN] Epoch 10/150 | Batch 10/153 | Loss=0.3159 | Dice_coeff=0.6841 | IoU=0.5199
# [TRAIN] Epoch 10/150 | Batch 20/153 | Loss=0.1967 | Dice_coeff=0.8033 | IoU=0.6713
# [TRAIN] Epoch 10/150 | Batch 30/153 | Loss=0.2302 | Dice_coeff=0.7698 | IoU=0.6258
# [TRAIN] Epoch 10/150 | Batch 40/153 | Loss=0.2678 | Dice_coeff=0.7322 | IoU=0.5776
# [TRAIN] Epoch 10/150 | Batch 50/153 | Loss=0.2283 | Dice_coeff=0.7717 | IoU=0.6283
# [TRAIN] Epoch 10/150 | Batch 60/153 | Loss=0.2628 | Dice_coeff=0.7372 | IoU=0.5838
# [TRAIN] Epoch 10/150 | Batch 70/153 | Loss=0.3502 | Dice_coeff=0.6498 | IoU=0.4813
# [TRAIN] Epoch 10/150 | Batch 80/153 | Loss=0.2550 | Dice_coeff=0.7450 | IoU=0.5937
# [TRAIN] Epoch 10/150 | Batch 90/153 | Loss=0.2172 | Dice_coeff=0.7828 | IoU=0.6431
# [TRAIN] Epoch 10/150 | Batch 100/153 | Loss=0.2836 | Dice_coeff=0.7164 | IoU=0.5581
# [TRAIN] Epoch 10/150 | Batch 110/153 | Loss=0.2324 | Dice_coeff=0.7676 | IoU=0.6228
# [TRAIN] Epoch 10/150 | Batch 120/153 | Loss=0.3726 | Dice_coeff=0.6274 | IoU=0.4571
# [TRAIN] Epoch 10/150 | Batch 130/153 | Loss=0.1799 | Dice_coeff=0.8201 | IoU=0.6951
# [TRAIN] Epoch 10/150 | Batch 140/153 | Loss=0.3143 | Dice_coeff=0.6857 | IoU=0.5217
# [TRAIN] Epoch 10/150 | Batch 150/153 | Loss=0.3013 | Dice_coeff=0.6987 | IoU=0.5369
#  Train Loss: 0.2603 | Avg_dice_coeff: 0.7397 | Avg_IoU: 0.5915
# Running Validation...
#  Valid Loss: 0.3360 | Dice_coeff: 0.6640 | IoU: 0.5230
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch9.pt
# ========== Epoch 11 / 150 ==========
# Training...
# [TRAIN] Epoch 11/150 | Batch 10/153 | Loss=0.1767 | Dice_coeff=0.8233 | IoU=0.6997
# [TRAIN] Epoch 11/150 | Batch 20/153 | Loss=0.1464 | Dice_coeff=0.8536 | IoU=0.7446
# [TRAIN] Epoch 11/150 | Batch 30/153 | Loss=0.1656 | Dice_coeff=0.8344 | IoU=0.7159
# [TRAIN] Epoch 11/150 | Batch 40/153 | Loss=0.2202 | Dice_coeff=0.7798 | IoU=0.6391
# [TRAIN] Epoch 11/150 | Batch 50/153 | Loss=0.2531 | Dice_coeff=0.7469 | IoU=0.5960
# [TRAIN] Epoch 11/150 | Batch 60/153 | Loss=0.2490 | Dice_coeff=0.7510 | IoU=0.6012
# [TRAIN] Epoch 11/150 | Batch 70/153 | Loss=0.1316 | Dice_coeff=0.8684 | IoU=0.7674
# [TRAIN] Epoch 11/150 | Batch 80/153 | Loss=0.2672 | Dice_coeff=0.7328 | IoU=0.5783
# [TRAIN] Epoch 11/150 | Batch 90/153 | Loss=0.2534 | Dice_coeff=0.7466 | IoU=0.5957
# [TRAIN] Epoch 11/150 | Batch 100/153 | Loss=0.1825 | Dice_coeff=0.8175 | IoU=0.6913
# [TRAIN] Epoch 11/150 | Batch 110/153 | Loss=0.2204 | Dice_coeff=0.7796 | IoU=0.6388
# [TRAIN] Epoch 11/150 | Batch 120/153 | Loss=0.2898 | Dice_coeff=0.7102 | IoU=0.5507
# [TRAIN] Epoch 11/150 | Batch 130/153 | Loss=0.3416 | Dice_coeff=0.6584 | IoU=0.4908
# [TRAIN] Epoch 11/150 | Batch 140/153 | Loss=0.2618 | Dice_coeff=0.7382 | IoU=0.5850
# [TRAIN] Epoch 11/150 | Batch 150/153 | Loss=0.1593 | Dice_coeff=0.8407 | IoU=0.7251
#  Train Loss: 0.2398 | Avg_dice_coeff: 0.7602 | Avg_IoU: 0.6183
# Running Validation...
#  Valid Loss: 0.3014 | Dice_coeff: 0.6986 | IoU: 0.5562
# No improvement in validation loss for 2 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch10.pt
# ========== Epoch 12 / 150 ==========
# Training...
# [TRAIN] Epoch 12/150 | Batch 10/153 | Loss=0.1551 | Dice_coeff=0.8449 | IoU=0.7315
# [TRAIN] Epoch 12/150 | Batch 20/153 | Loss=0.3351 | Dice_coeff=0.6649 | IoU=0.4980
# [TRAIN] Epoch 12/150 | Batch 30/153 | Loss=0.2110 | Dice_coeff=0.7890 | IoU=0.6515
# [TRAIN] Epoch 12/150 | Batch 40/153 | Loss=0.3014 | Dice_coeff=0.6986 | IoU=0.5369
# [TRAIN] Epoch 12/150 | Batch 50/153 | Loss=0.1970 | Dice_coeff=0.8030 | IoU=0.6709
# [TRAIN] Epoch 12/150 | Batch 60/153 | Loss=0.2416 | Dice_coeff=0.7584 | IoU=0.6108
# [TRAIN] Epoch 12/150 | Batch 70/153 | Loss=0.3214 | Dice_coeff=0.6786 | IoU=0.5136
# [TRAIN] Epoch 12/150 | Batch 80/153 | Loss=0.2208 | Dice_coeff=0.7792 | IoU=0.6383
# [TRAIN] Epoch 12/150 | Batch 90/153 | Loss=0.2374 | Dice_coeff=0.7626 | IoU=0.6162
# [TRAIN] Epoch 12/150 | Batch 100/153 | Loss=0.2857 | Dice_coeff=0.7143 | IoU=0.5555
# [TRAIN] Epoch 12/150 | Batch 110/153 | Loss=0.3245 | Dice_coeff=0.6755 | IoU=0.5100
# [TRAIN] Epoch 12/150 | Batch 120/153 | Loss=0.2635 | Dice_coeff=0.7365 | IoU=0.5829
# [TRAIN] Epoch 12/150 | Batch 130/153 | Loss=0.2287 | Dice_coeff=0.7713 | IoU=0.6277
# [TRAIN] Epoch 12/150 | Batch 140/153 | Loss=0.2631 | Dice_coeff=0.7369 | IoU=0.5834
# [TRAIN] Epoch 12/150 | Batch 150/153 | Loss=0.1595 | Dice_coeff=0.8405 | IoU=0.7249
#  Train Loss: 0.2270 | Avg_dice_coeff: 0.7730 | Avg_IoU: 0.6335
# Running Validation...
#  Valid Loss: 0.2850 | Dice_coeff: 0.7150 | IoU: 0.5657
# No improvement in validation loss for 3 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch11.pt
# ========== Epoch 13 / 150 ==========
# Training...
# [TRAIN] Epoch 13/150 | Batch 10/153 | Loss=0.1818 | Dice_coeff=0.8182 | IoU=0.6923
# [TRAIN] Epoch 13/150 | Batch 20/153 | Loss=0.1821 | Dice_coeff=0.8179 | IoU=0.6919
# [TRAIN] Epoch 13/150 | Batch 30/153 | Loss=0.3027 | Dice_coeff=0.6973 | IoU=0.5352
# [TRAIN] Epoch 13/150 | Batch 40/153 | Loss=0.1425 | Dice_coeff=0.8575 | IoU=0.7505
# [TRAIN] Epoch 13/150 | Batch 50/153 | Loss=0.1528 | Dice_coeff=0.8472 | IoU=0.7349
# [TRAIN] Epoch 13/150 | Batch 60/153 | Loss=0.2194 | Dice_coeff=0.7806 | IoU=0.6402
# [TRAIN] Epoch 13/150 | Batch 70/153 | Loss=0.1608 | Dice_coeff=0.8392 | IoU=0.7229
# [TRAIN] Epoch 13/150 | Batch 80/153 | Loss=0.2381 | Dice_coeff=0.7619 | IoU=0.6154
# [TRAIN] Epoch 13/150 | Batch 90/153 | Loss=0.2594 | Dice_coeff=0.7406 | IoU=0.5880
# [TRAIN] Epoch 13/150 | Batch 100/153 | Loss=0.1973 | Dice_coeff=0.8027 | IoU=0.6704
# [TRAIN] Epoch 13/150 | Batch 110/153 | Loss=0.3036 | Dice_coeff=0.6964 | IoU=0.5342
# [TRAIN] Epoch 13/150 | Batch 120/153 | Loss=0.2003 | Dice_coeff=0.7997 | IoU=0.6663
# [TRAIN] Epoch 13/150 | Batch 130/153 | Loss=0.2635 | Dice_coeff=0.7365 | IoU=0.5829
# [TRAIN] Epoch 13/150 | Batch 140/153 | Loss=0.1593 | Dice_coeff=0.8407 | IoU=0.7252
# [TRAIN] Epoch 13/150 | Batch 150/153 | Loss=0.1957 | Dice_coeff=0.8043 | IoU=0.6726
#  Train Loss: 0.2184 | Avg_dice_coeff: 0.7816 | Avg_IoU: 0.6452
# Running Validation...
#  Valid Loss: 0.2730 | Dice_coeff: 0.7270 | IoU: 0.5843
# No improvement in validation loss for 4 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch12.pt
# ========== Epoch 14 / 150 ==========
# Training...
# [TRAIN] Epoch 14/150 | Batch 10/153 | Loss=0.2082 | Dice_coeff=0.7918 | IoU=0.6553
# [TRAIN] Epoch 14/150 | Batch 20/153 | Loss=0.2712 | Dice_coeff=0.7288 | IoU=0.5733
# [TRAIN] Epoch 14/150 | Batch 30/153 | Loss=0.1461 | Dice_coeff=0.8539 | IoU=0.7451
# [TRAIN] Epoch 14/150 | Batch 40/153 | Loss=0.2548 | Dice_coeff=0.7452 | IoU=0.5939
# [TRAIN] Epoch 14/150 | Batch 50/153 | Loss=0.1301 | Dice_coeff=0.8699 | IoU=0.7697
# [TRAIN] Epoch 14/150 | Batch 60/153 | Loss=0.2197 | Dice_coeff=0.7803 | IoU=0.6397
# [TRAIN] Epoch 14/150 | Batch 70/153 | Loss=0.1404 | Dice_coeff=0.8596 | IoU=0.7538
# [TRAIN] Epoch 14/150 | Batch 80/153 | Loss=0.1735 | Dice_coeff=0.8265 | IoU=0.7042
# [TRAIN] Epoch 14/150 | Batch 90/153 | Loss=0.1745 | Dice_coeff=0.8255 | IoU=0.7029
# [TRAIN] Epoch 14/150 | Batch 100/153 | Loss=0.1720 | Dice_coeff=0.8280 | IoU=0.7064
# [TRAIN] Epoch 14/150 | Batch 110/153 | Loss=0.1937 | Dice_coeff=0.8063 | IoU=0.6755
# [TRAIN] Epoch 14/150 | Batch 120/153 | Loss=0.2513 | Dice_coeff=0.7487 | IoU=0.5983
# [TRAIN] Epoch 14/150 | Batch 130/153 | Loss=0.2382 | Dice_coeff=0.7618 | IoU=0.6153
# [TRAIN] Epoch 14/150 | Batch 140/153 | Loss=0.1930 | Dice_coeff=0.8070 | IoU=0.6764
# [TRAIN] Epoch 14/150 | Batch 150/153 | Loss=0.3231 | Dice_coeff=0.6769 | IoU=0.5116
#  Train Loss: 0.2104 | Avg_dice_coeff: 0.7896 | Avg_IoU: 0.6565
# Running Validation...
#  Valid Loss: 0.2905 | Dice_coeff: 0.7095 | IoU: 0.5601
# No improvement in validation loss for 5 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch13.pt
# ========== Epoch 15 / 150 ==========
# Training...
# [TRAIN] Epoch 15/150 | Batch 10/153 | Loss=0.3033 | Dice_coeff=0.6967 | IoU=0.5346
# [TRAIN] Epoch 15/150 | Batch 20/153 | Loss=0.1696 | Dice_coeff=0.8304 | IoU=0.7100
# [TRAIN] Epoch 15/150 | Batch 30/153 | Loss=0.1786 | Dice_coeff=0.8214 | IoU=0.6970
# [TRAIN] Epoch 15/150 | Batch 40/153 | Loss=0.2273 | Dice_coeff=0.7727 | IoU=0.6296
# [TRAIN] Epoch 15/150 | Batch 50/153 | Loss=0.2400 | Dice_coeff=0.7600 | IoU=0.6129
# [TRAIN] Epoch 15/150 | Batch 60/153 | Loss=0.1142 | Dice_coeff=0.8858 | IoU=0.7950
# [TRAIN] Epoch 15/150 | Batch 70/153 | Loss=0.1702 | Dice_coeff=0.8298 | IoU=0.7092
# [TRAIN] Epoch 15/150 | Batch 80/153 | Loss=0.1578 | Dice_coeff=0.8422 | IoU=0.7274
# [TRAIN] Epoch 15/150 | Batch 90/153 | Loss=0.1974 | Dice_coeff=0.8026 | IoU=0.6702
# [TRAIN] Epoch 15/150 | Batch 100/153 | Loss=0.0968 | Dice_coeff=0.9032 | IoU=0.8235
# [TRAIN] Epoch 15/150 | Batch 110/153 | Loss=0.1525 | Dice_coeff=0.8475 | IoU=0.7353
# [TRAIN] Epoch 15/150 | Batch 120/153 | Loss=0.1412 | Dice_coeff=0.8588 | IoU=0.7525
# [TRAIN] Epoch 15/150 | Batch 130/153 | Loss=0.1759 | Dice_coeff=0.8241 | IoU=0.7008
# [TRAIN] Epoch 15/150 | Batch 140/153 | Loss=0.1765 | Dice_coeff=0.8235 | IoU=0.7000
# [TRAIN] Epoch 15/150 | Batch 150/153 | Loss=0.1523 | Dice_coeff=0.8477 | IoU=0.7356
#  Train Loss: 0.1977 | Avg_dice_coeff: 0.8023 | Avg_IoU: 0.6736
# Running Validation...
#  Valid Loss: 0.2054 | Dice_coeff: 0.7946 | IoU: 0.6681
# Validation loss improved from 0.2551 to 0.2054. Saving model...
# Model saved to ==> 18-06-2025_04-14-53/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-14-53/model_epoch14.pt
# ========== Epoch 16 / 150 ==========
# Training...
# [TRAIN] Epoch 16/150 | Batch 10/153 | Loss=0.2133 | Dice_coeff=0.7867 | IoU=0.6484
# [TRAIN] Epoch 16/150 | Batch 20/153 | Loss=0.2115 | Dice_coeff=0.7885 | IoU=0.6508
# [TRAIN] Epoch 16/150 | Batch 30/153 | Loss=0.2041 | Dice_coeff=0.7959 | IoU=0.6610
# [TRAIN] Epoch 16/150 | Batch 40/153 | Loss=0.1717 | Dice_coeff=0.8283 | IoU=0.7070
# [TRAIN] Epoch 16/150 | Batch 50/153 | Loss=0.1560 | Dice_coeff=0.8440 | IoU=0.7301
# [TRAIN] Epoch 16/150 | Batch 60/153 | Loss=0.2425 | Dice_coeff=0.7575 | IoU=0.6097
# [TRAIN] Epoch 16/150 | Batch 70/153 | Loss=0.1168 | Dice_coeff=0.8832 | IoU=0.7909
# [TRAIN] Epoch 16/150 | Batch 80/153 | Loss=0.1772 | Dice_coeff=0.8228 | IoU=0.6990
# [TRAIN] Epoch 16/150 | Batch 90/153 | Loss=0.1750 | Dice_coeff=0.8250 | IoU=0.7021
# [TRAIN] Epoch 16/150 | Batch 100/153 | Loss=0.1730 | Dice_coeff=0.8270 | IoU=0.7050
# [TRAIN] Epoch 16/150 | Batch 110/153 | Loss=0.1884 | Dice_coeff=0.8116 | IoU=0.6830
# [TRAIN] Epoch 16/150 | Batch 120/153 | Loss=0.2458 | Dice_coeff=0.7542 | IoU=0.6054
# [TRAIN] Epoch 16/150 | Batch 130/153 | Loss=0.2046 | Dice_coeff=0.7954 | IoU=0.6604
# [TRAIN] Epoch 16/150 | Batch 140/153 | Loss=0.1933 | Dice_coeff=0.8067 | IoU=0.6761
# [TRAIN] Epoch 16/150 | Batch 150/153 | Loss=0.1503 | Dice_coeff=0.8497 | IoU=0.7387
#  Train Loss: 0.1894 | Avg_dice_coeff: 0.8106 | Avg_IoU: 0.6845
# Running Validation...
#  Valid Loss: 0.2218 | Dice_coeff: 0.7782 | IoU: 0.6487
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch15.pt
# ========== Epoch 17 / 150 ==========
# Training...
# [TRAIN] Epoch 17/150 | Batch 10/153 | Loss=0.1347 | Dice_coeff=0.8653 | IoU=0.7626
# [TRAIN] Epoch 17/150 | Batch 20/153 | Loss=0.1851 | Dice_coeff=0.8149 | IoU=0.6876
# [TRAIN] Epoch 17/150 | Batch 30/153 | Loss=0.2333 | Dice_coeff=0.7667 | IoU=0.6216
# [TRAIN] Epoch 17/150 | Batch 40/153 | Loss=0.2335 | Dice_coeff=0.7665 | IoU=0.6214
# [TRAIN] Epoch 17/150 | Batch 50/153 | Loss=0.1771 | Dice_coeff=0.8229 | IoU=0.6991
# [TRAIN] Epoch 17/150 | Batch 60/153 | Loss=0.1923 | Dice_coeff=0.8077 | IoU=0.6774
# [TRAIN] Epoch 17/150 | Batch 70/153 | Loss=0.2899 | Dice_coeff=0.7101 | IoU=0.5505
# [TRAIN] Epoch 17/150 | Batch 80/153 | Loss=0.0777 | Dice_coeff=0.9223 | IoU=0.8558
# [TRAIN] Epoch 17/150 | Batch 90/153 | Loss=0.2444 | Dice_coeff=0.7556 | IoU=0.6072
# [TRAIN] Epoch 17/150 | Batch 100/153 | Loss=0.1384 | Dice_coeff=0.8616 | IoU=0.7569
# [TRAIN] Epoch 17/150 | Batch 110/153 | Loss=0.1540 | Dice_coeff=0.8460 | IoU=0.7331
# [TRAIN] Epoch 17/150 | Batch 120/153 | Loss=0.1877 | Dice_coeff=0.8123 | IoU=0.6839
# [TRAIN] Epoch 17/150 | Batch 130/153 | Loss=0.1479 | Dice_coeff=0.8521 | IoU=0.7423
# [TRAIN] Epoch 17/150 | Batch 140/153 | Loss=0.2445 | Dice_coeff=0.7555 | IoU=0.6071
# [TRAIN] Epoch 17/150 | Batch 150/153 | Loss=0.1401 | Dice_coeff=0.8599 | IoU=0.7543
#  Train Loss: 0.1821 | Avg_dice_coeff: 0.8179 | Avg_IoU: 0.6953
# Running Validation...
#  Valid Loss: 0.2076 | Dice_coeff: 0.7924 | IoU: 0.6654
# No improvement in validation loss for 2 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch16.pt
# ========== Epoch 18 / 150 ==========
# Training...
# [TRAIN] Epoch 18/150 | Batch 10/153 | Loss=0.1341 | Dice_coeff=0.8659 | IoU=0.7635
# [TRAIN] Epoch 18/150 | Batch 20/153 | Loss=0.1549 | Dice_coeff=0.8451 | IoU=0.7318
# [TRAIN] Epoch 18/150 | Batch 30/153 | Loss=0.1312 | Dice_coeff=0.8688 | IoU=0.7680
# [TRAIN] Epoch 18/150 | Batch 40/153 | Loss=0.1028 | Dice_coeff=0.8972 | IoU=0.8136
# [TRAIN] Epoch 18/150 | Batch 50/153 | Loss=0.1497 | Dice_coeff=0.8503 | IoU=0.7396
# [TRAIN] Epoch 18/150 | Batch 60/153 | Loss=0.1298 | Dice_coeff=0.8702 | IoU=0.7702
# [TRAIN] Epoch 18/150 | Batch 70/153 | Loss=0.1096 | Dice_coeff=0.8904 | IoU=0.8025
# [TRAIN] Epoch 18/150 | Batch 80/153 | Loss=0.1711 | Dice_coeff=0.8289 | IoU=0.7078
# [TRAIN] Epoch 18/150 | Batch 90/153 | Loss=0.2243 | Dice_coeff=0.7757 | IoU=0.6336
# [TRAIN] Epoch 18/150 | Batch 100/153 | Loss=0.1892 | Dice_coeff=0.8108 | IoU=0.6818
# [TRAIN] Epoch 18/150 | Batch 110/153 | Loss=0.1842 | Dice_coeff=0.8158 | IoU=0.6889
# [TRAIN] Epoch 18/150 | Batch 120/153 | Loss=0.2338 | Dice_coeff=0.7662 | IoU=0.6210
# [TRAIN] Epoch 18/150 | Batch 130/153 | Loss=0.1217 | Dice_coeff=0.8783 | IoU=0.7830
# [TRAIN] Epoch 18/150 | Batch 140/153 | Loss=0.1332 | Dice_coeff=0.8668 | IoU=0.7649
# [TRAIN] Epoch 18/150 | Batch 150/153 | Loss=0.1407 | Dice_coeff=0.8593 | IoU=0.7533
#  Train Loss: 0.1854 | Avg_dice_coeff: 0.8146 | Avg_IoU: 0.6918
# Running Validation...
#  Valid Loss: 0.2287 | Dice_coeff: 0.7713 | IoU: 0.6391
# No improvement in validation loss for 3 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch17.pt
# ========== Epoch 19 / 150 ==========
# Training...
# [TRAIN] Epoch 19/150 | Batch 10/153 | Loss=0.2006 | Dice_coeff=0.7994 | IoU=0.6658
# [TRAIN] Epoch 19/150 | Batch 20/153 | Loss=0.1847 | Dice_coeff=0.8153 | IoU=0.6883
# [TRAIN] Epoch 19/150 | Batch 30/153 | Loss=0.3072 | Dice_coeff=0.6928 | IoU=0.5300
# [TRAIN] Epoch 19/150 | Batch 40/153 | Loss=0.1369 | Dice_coeff=0.8631 | IoU=0.7592
# [TRAIN] Epoch 19/150 | Batch 50/153 | Loss=0.1834 | Dice_coeff=0.8166 | IoU=0.6900
# [TRAIN] Epoch 19/150 | Batch 60/153 | Loss=0.1968 | Dice_coeff=0.8032 | IoU=0.6711
# [TRAIN] Epoch 19/150 | Batch 70/153 | Loss=0.1867 | Dice_coeff=0.8133 | IoU=0.6853
# [TRAIN] Epoch 19/150 | Batch 80/153 | Loss=0.1658 | Dice_coeff=0.8342 | IoU=0.7156
# [TRAIN] Epoch 19/150 | Batch 90/153 | Loss=0.1664 | Dice_coeff=0.8336 | IoU=0.7147
# [TRAIN] Epoch 19/150 | Batch 100/153 | Loss=0.1155 | Dice_coeff=0.8845 | IoU=0.7930
# [TRAIN] Epoch 19/150 | Batch 110/153 | Loss=0.1857 | Dice_coeff=0.8143 | IoU=0.6867
# [TRAIN] Epoch 19/150 | Batch 120/153 | Loss=0.1477 | Dice_coeff=0.8523 | IoU=0.7425
# [TRAIN] Epoch 19/150 | Batch 130/153 | Loss=0.2711 | Dice_coeff=0.7289 | IoU=0.5734
# [TRAIN] Epoch 19/150 | Batch 140/153 | Loss=0.2517 | Dice_coeff=0.7483 | IoU=0.5978
# [TRAIN] Epoch 19/150 | Batch 150/153 | Loss=0.2649 | Dice_coeff=0.7351 | IoU=0.5812
#  Train Loss: 0.1805 | Avg_dice_coeff: 0.8195 | Avg_IoU: 0.6972
# Running Validation...
#  Valid Loss: 0.2468 | Dice_coeff: 0.7532 | IoU: 0.6160
# No improvement in validation loss for 4 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch18.pt
# ========== Epoch 20 / 150 ==========
# Training...
# [TRAIN] Epoch 20/150 | Batch 10/153 | Loss=0.1322 | Dice_coeff=0.8678 | IoU=0.7665
# [TRAIN] Epoch 20/150 | Batch 20/153 | Loss=0.1157 | Dice_coeff=0.8843 | IoU=0.7927
# [TRAIN] Epoch 20/150 | Batch 30/153 | Loss=0.2101 | Dice_coeff=0.7899 | IoU=0.6527
# [TRAIN] Epoch 20/150 | Batch 40/153 | Loss=0.1585 | Dice_coeff=0.8415 | IoU=0.7263
# [TRAIN] Epoch 20/150 | Batch 50/153 | Loss=0.1113 | Dice_coeff=0.8887 | IoU=0.7996
# [TRAIN] Epoch 20/150 | Batch 60/153 | Loss=0.1375 | Dice_coeff=0.8625 | IoU=0.7583
# [TRAIN] Epoch 20/150 | Batch 70/153 | Loss=0.2485 | Dice_coeff=0.7515 | IoU=0.6019
# [TRAIN] Epoch 20/150 | Batch 80/153 | Loss=0.1454 | Dice_coeff=0.8546 | IoU=0.7462
# [TRAIN] Epoch 20/150 | Batch 90/153 | Loss=0.1699 | Dice_coeff=0.8301 | IoU=0.7096
# [TRAIN] Epoch 20/150 | Batch 100/153 | Loss=0.2179 | Dice_coeff=0.7821 | IoU=0.6422
# [TRAIN] Epoch 20/150 | Batch 110/153 | Loss=0.0989 | Dice_coeff=0.9011 | IoU=0.8200
# [TRAIN] Epoch 20/150 | Batch 120/153 | Loss=0.2008 | Dice_coeff=0.7992 | IoU=0.6656
# [TRAIN] Epoch 20/150 | Batch 130/153 | Loss=0.1071 | Dice_coeff=0.8929 | IoU=0.8065
# [TRAIN] Epoch 20/150 | Batch 140/153 | Loss=0.2342 | Dice_coeff=0.7658 | IoU=0.6204
# [TRAIN] Epoch 20/150 | Batch 150/153 | Loss=0.1276 | Dice_coeff=0.8724 | IoU=0.7737
#  Train Loss: 0.1677 | Avg_dice_coeff: 0.8323 | Avg_IoU: 0.7154
# Running Validation...
#  Valid Loss: 0.2108 | Dice_coeff: 0.7892 | IoU: 0.6593
# No improvement in validation loss for 5 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch19.pt
# ========== Epoch 21 / 150 ==========
# Training...
# [TRAIN] Epoch 21/150 | Batch 10/153 | Loss=0.1230 | Dice_coeff=0.8770 | IoU=0.7809
# [TRAIN] Epoch 21/150 | Batch 20/153 | Loss=0.1188 | Dice_coeff=0.8812 | IoU=0.7876
# [TRAIN] Epoch 21/150 | Batch 30/153 | Loss=0.1905 | Dice_coeff=0.8095 | IoU=0.6799
# [TRAIN] Epoch 21/150 | Batch 40/153 | Loss=0.1195 | Dice_coeff=0.8805 | IoU=0.7865
# [TRAIN] Epoch 21/150 | Batch 50/153 | Loss=0.1497 | Dice_coeff=0.8503 | IoU=0.7396
# [TRAIN] Epoch 21/150 | Batch 60/153 | Loss=0.1102 | Dice_coeff=0.8898 | IoU=0.8015
# [TRAIN] Epoch 21/150 | Batch 70/153 | Loss=0.2197 | Dice_coeff=0.7803 | IoU=0.6398
# [TRAIN] Epoch 21/150 | Batch 80/153 | Loss=0.1387 | Dice_coeff=0.8613 | IoU=0.7563
# [TRAIN] Epoch 21/150 | Batch 90/153 | Loss=0.1911 | Dice_coeff=0.8089 | IoU=0.6791
# [TRAIN] Epoch 21/150 | Batch 100/153 | Loss=0.1304 | Dice_coeff=0.8696 | IoU=0.7692
# [TRAIN] Epoch 21/150 | Batch 110/153 | Loss=0.2218 | Dice_coeff=0.7782 | IoU=0.6369
# [TRAIN] Epoch 21/150 | Batch 120/153 | Loss=0.1493 | Dice_coeff=0.8507 | IoU=0.7402
# [TRAIN] Epoch 21/150 | Batch 130/153 | Loss=0.1804 | Dice_coeff=0.8196 | IoU=0.6944
# [TRAIN] Epoch 21/150 | Batch 140/153 | Loss=0.1234 | Dice_coeff=0.8766 | IoU=0.7804
# [TRAIN] Epoch 21/150 | Batch 150/153 | Loss=0.1674 | Dice_coeff=0.8326 | IoU=0.7132
#  Train Loss: 0.1611 | Avg_dice_coeff: 0.8389 | Avg_IoU: 0.7254
# Running Validation...
#  Valid Loss: 0.1979 | Dice_coeff: 0.8021 | IoU: 0.6778
# Validation loss improved from 0.2054 to 0.1979. Saving model...
# Model saved to ==> 18-06-2025_04-14-53/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-14-53/model_epoch20.pt
# ========== Epoch 22 / 150 ==========
# Training...
# [TRAIN] Epoch 22/150 | Batch 10/153 | Loss=0.1190 | Dice_coeff=0.8810 | IoU=0.7872
# [TRAIN] Epoch 22/150 | Batch 20/153 | Loss=0.1369 | Dice_coeff=0.8631 | IoU=0.7592
# [TRAIN] Epoch 22/150 | Batch 30/153 | Loss=0.1891 | Dice_coeff=0.8109 | IoU=0.6820
# [TRAIN] Epoch 22/150 | Batch 40/153 | Loss=0.0925 | Dice_coeff=0.9075 | IoU=0.8307
# [TRAIN] Epoch 22/150 | Batch 50/153 | Loss=0.1879 | Dice_coeff=0.8121 | IoU=0.6837
# [TRAIN] Epoch 22/150 | Batch 60/153 | Loss=0.1521 | Dice_coeff=0.8479 | IoU=0.7359
# [TRAIN] Epoch 22/150 | Batch 70/153 | Loss=0.2947 | Dice_coeff=0.7053 | IoU=0.5447
# [TRAIN] Epoch 22/150 | Batch 80/153 | Loss=0.1335 | Dice_coeff=0.8665 | IoU=0.7645
# [TRAIN] Epoch 22/150 | Batch 90/153 | Loss=0.1123 | Dice_coeff=0.8877 | IoU=0.7980
# [TRAIN] Epoch 22/150 | Batch 100/153 | Loss=0.1307 | Dice_coeff=0.8693 | IoU=0.7688
# [TRAIN] Epoch 22/150 | Batch 110/153 | Loss=0.1104 | Dice_coeff=0.8896 | IoU=0.8012
# [TRAIN] Epoch 22/150 | Batch 120/153 | Loss=0.1633 | Dice_coeff=0.8367 | IoU=0.7193
# [TRAIN] Epoch 22/150 | Batch 130/153 | Loss=0.1134 | Dice_coeff=0.8866 | IoU=0.7964
# [TRAIN] Epoch 22/150 | Batch 140/153 | Loss=0.2397 | Dice_coeff=0.7603 | IoU=0.6133
# [TRAIN] Epoch 22/150 | Batch 150/153 | Loss=0.1709 | Dice_coeff=0.8291 | IoU=0.7080
#  Train Loss: 0.1651 | Avg_dice_coeff: 0.8349 | Avg_IoU: 0.7194
# Running Validation...
#  Valid Loss: 0.2049 | Dice_coeff: 0.7951 | IoU: 0.6683
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch21.pt
# ========== Epoch 23 / 150 ==========
# Training...
# [TRAIN] Epoch 23/150 | Batch 10/153 | Loss=0.2088 | Dice_coeff=0.7912 | IoU=0.6545
# [TRAIN] Epoch 23/150 | Batch 20/153 | Loss=0.1774 | Dice_coeff=0.8226 | IoU=0.6987
# [TRAIN] Epoch 23/150 | Batch 30/153 | Loss=0.2362 | Dice_coeff=0.7638 | IoU=0.6179
# [TRAIN] Epoch 23/150 | Batch 40/153 | Loss=0.2488 | Dice_coeff=0.7512 | IoU=0.6016
# [TRAIN] Epoch 23/150 | Batch 50/153 | Loss=0.1525 | Dice_coeff=0.8475 | IoU=0.7353
# [TRAIN] Epoch 23/150 | Batch 60/153 | Loss=0.1061 | Dice_coeff=0.8939 | IoU=0.8081
# [TRAIN] Epoch 23/150 | Batch 70/153 | Loss=0.1184 | Dice_coeff=0.8816 | IoU=0.7882
# [TRAIN] Epoch 23/150 | Batch 80/153 | Loss=0.1279 | Dice_coeff=0.8721 | IoU=0.7731
# [TRAIN] Epoch 23/150 | Batch 90/153 | Loss=0.1979 | Dice_coeff=0.8021 | IoU=0.6695
# [TRAIN] Epoch 23/150 | Batch 100/153 | Loss=0.1201 | Dice_coeff=0.8799 | IoU=0.7856
# [TRAIN] Epoch 23/150 | Batch 110/153 | Loss=0.1678 | Dice_coeff=0.8322 | IoU=0.7126
# [TRAIN] Epoch 23/150 | Batch 120/153 | Loss=0.1987 | Dice_coeff=0.8013 | IoU=0.6684
# [TRAIN] Epoch 23/150 | Batch 130/153 | Loss=0.1259 | Dice_coeff=0.8741 | IoU=0.7764
# [TRAIN] Epoch 23/150 | Batch 140/153 | Loss=0.1924 | Dice_coeff=0.8076 | IoU=0.6773
# [TRAIN] Epoch 23/150 | Batch 150/153 | Loss=0.1337 | Dice_coeff=0.8663 | IoU=0.7641
#  Train Loss: 0.1781 | Avg_dice_coeff: 0.8219 | Avg_IoU: 0.7008
# Running Validation...
#  Valid Loss: 0.1984 | Dice_coeff: 0.8016 | IoU: 0.6802
# No improvement in validation loss for 2 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch22.pt
# ========== Epoch 24 / 150 ==========
# Training...
# [TRAIN] Epoch 24/150 | Batch 10/153 | Loss=0.1670 | Dice_coeff=0.8330 | IoU=0.7139
# [TRAIN] Epoch 24/150 | Batch 20/153 | Loss=0.0901 | Dice_coeff=0.9099 | IoU=0.8348
# [TRAIN] Epoch 24/150 | Batch 30/153 | Loss=0.1284 | Dice_coeff=0.8716 | IoU=0.7723
# [TRAIN] Epoch 24/150 | Batch 40/153 | Loss=0.1795 | Dice_coeff=0.8205 | IoU=0.6957
# [TRAIN] Epoch 24/150 | Batch 50/153 | Loss=0.1778 | Dice_coeff=0.8222 | IoU=0.6981
# [TRAIN] Epoch 24/150 | Batch 60/153 | Loss=0.1271 | Dice_coeff=0.8729 | IoU=0.7745
# [TRAIN] Epoch 24/150 | Batch 70/153 | Loss=0.1303 | Dice_coeff=0.8697 | IoU=0.7694
# [TRAIN] Epoch 24/150 | Batch 80/153 | Loss=0.1522 | Dice_coeff=0.8478 | IoU=0.7358
# [TRAIN] Epoch 24/150 | Batch 90/153 | Loss=0.2398 | Dice_coeff=0.7602 | IoU=0.6131
# [TRAIN] Epoch 24/150 | Batch 100/153 | Loss=0.1344 | Dice_coeff=0.8656 | IoU=0.7630
# [TRAIN] Epoch 24/150 | Batch 110/153 | Loss=0.1157 | Dice_coeff=0.8843 | IoU=0.7926
# [TRAIN] Epoch 24/150 | Batch 120/153 | Loss=0.1538 | Dice_coeff=0.8462 | IoU=0.7335
# [TRAIN] Epoch 24/150 | Batch 130/153 | Loss=0.2527 | Dice_coeff=0.7473 | IoU=0.5966
# [TRAIN] Epoch 24/150 | Batch 140/153 | Loss=0.1306 | Dice_coeff=0.8694 | IoU=0.7690
# [TRAIN] Epoch 24/150 | Batch 150/153 | Loss=0.1665 | Dice_coeff=0.8335 | IoU=0.7146
#  Train Loss: 0.1505 | Avg_dice_coeff: 0.8495 | Avg_IoU: 0.7412
# Running Validation...
#  Valid Loss: 0.1920 | Dice_coeff: 0.8080 | IoU: 0.6871
# Validation loss improved from 0.1979 to 0.1920. Saving model...
# Model saved to ==> 18-06-2025_04-14-53/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-14-53/model_epoch23.pt
# ========== Epoch 25 / 150 ==========
# Training...
# [TRAIN] Epoch 25/150 | Batch 10/153 | Loss=0.1440 | Dice_coeff=0.8560 | IoU=0.7482
# [TRAIN] Epoch 25/150 | Batch 20/153 | Loss=0.1437 | Dice_coeff=0.8563 | IoU=0.7488
# [TRAIN] Epoch 25/150 | Batch 30/153 | Loss=0.1700 | Dice_coeff=0.8300 | IoU=0.7094
# [TRAIN] Epoch 25/150 | Batch 40/153 | Loss=0.1619 | Dice_coeff=0.8381 | IoU=0.7213
# [TRAIN] Epoch 25/150 | Batch 50/153 | Loss=0.1043 | Dice_coeff=0.8957 | IoU=0.8111
# [TRAIN] Epoch 25/150 | Batch 60/153 | Loss=0.0881 | Dice_coeff=0.9119 | IoU=0.8382
# [TRAIN] Epoch 25/150 | Batch 70/153 | Loss=0.1156 | Dice_coeff=0.8844 | IoU=0.7928
# [TRAIN] Epoch 25/150 | Batch 80/153 | Loss=0.1451 | Dice_coeff=0.8549 | IoU=0.7466
# [TRAIN] Epoch 25/150 | Batch 90/153 | Loss=0.1597 | Dice_coeff=0.8403 | IoU=0.7246
# [TRAIN] Epoch 25/150 | Batch 100/153 | Loss=0.1193 | Dice_coeff=0.8807 | IoU=0.7869
# [TRAIN] Epoch 25/150 | Batch 110/153 | Loss=0.1829 | Dice_coeff=0.8171 | IoU=0.6908
# [TRAIN] Epoch 25/150 | Batch 120/153 | Loss=0.1589 | Dice_coeff=0.8411 | IoU=0.7258
# [TRAIN] Epoch 25/150 | Batch 130/153 | Loss=0.1088 | Dice_coeff=0.8912 | IoU=0.8038
# [TRAIN] Epoch 25/150 | Batch 140/153 | Loss=0.1321 | Dice_coeff=0.8679 | IoU=0.7667
# [TRAIN] Epoch 25/150 | Batch 150/153 | Loss=0.1379 | Dice_coeff=0.8621 | IoU=0.7576
#  Train Loss: 0.1403 | Avg_dice_coeff: 0.8597 | Avg_IoU: 0.7558
# Running Validation...
#  Valid Loss: 0.2075 | Dice_coeff: 0.7925 | IoU: 0.6666
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch24.pt
# ========== Epoch 26 / 150 ==========
# Training...
# [TRAIN] Epoch 26/150 | Batch 10/153 | Loss=0.2158 | Dice_coeff=0.7842 | IoU=0.6450
# [TRAIN] Epoch 26/150 | Batch 20/153 | Loss=0.2066 | Dice_coeff=0.7934 | IoU=0.6575
# [TRAIN] Epoch 26/150 | Batch 30/153 | Loss=0.1701 | Dice_coeff=0.8299 | IoU=0.7093
# [TRAIN] Epoch 26/150 | Batch 40/153 | Loss=0.1548 | Dice_coeff=0.8452 | IoU=0.7319
# [TRAIN] Epoch 26/150 | Batch 50/153 | Loss=0.1569 | Dice_coeff=0.8431 | IoU=0.7287
# [TRAIN] Epoch 26/150 | Batch 60/153 | Loss=0.1369 | Dice_coeff=0.8631 | IoU=0.7592
# [TRAIN] Epoch 26/150 | Batch 70/153 | Loss=0.0873 | Dice_coeff=0.9127 | IoU=0.8395
# [TRAIN] Epoch 26/150 | Batch 80/153 | Loss=0.0964 | Dice_coeff=0.9036 | IoU=0.8241
# [TRAIN] Epoch 26/150 | Batch 90/153 | Loss=0.1005 | Dice_coeff=0.8995 | IoU=0.8173
# [TRAIN] Epoch 26/150 | Batch 100/153 | Loss=0.1071 | Dice_coeff=0.8929 | IoU=0.8066
# [TRAIN] Epoch 26/150 | Batch 110/153 | Loss=0.1205 | Dice_coeff=0.8795 | IoU=0.7849
# [TRAIN] Epoch 26/150 | Batch 120/153 | Loss=0.1550 | Dice_coeff=0.8450 | IoU=0.7316
# [TRAIN] Epoch 26/150 | Batch 130/153 | Loss=0.1005 | Dice_coeff=0.8995 | IoU=0.8173
# [TRAIN] Epoch 26/150 | Batch 140/153 | Loss=0.0766 | Dice_coeff=0.9234 | IoU=0.8578
# [TRAIN] Epoch 26/150 | Batch 150/153 | Loss=0.1228 | Dice_coeff=0.8772 | IoU=0.7813
#  Train Loss: 0.1393 | Avg_dice_coeff: 0.8607 | Avg_IoU: 0.7576
# Running Validation...
#  Valid Loss: 0.1814 | Dice_coeff: 0.8186 | IoU: 0.7019
# Validation loss improved from 0.1920 to 0.1814. Saving model...
# Model saved to ==> 18-06-2025_04-14-53/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-14-53/model_epoch25.pt
# ========== Epoch 27 / 150 ==========
# Training...
# [TRAIN] Epoch 27/150 | Batch 10/153 | Loss=0.1755 | Dice_coeff=0.8245 | IoU=0.7014
# [TRAIN] Epoch 27/150 | Batch 20/153 | Loss=0.1190 | Dice_coeff=0.8810 | IoU=0.7873
# [TRAIN] Epoch 27/150 | Batch 30/153 | Loss=0.0819 | Dice_coeff=0.9181 | IoU=0.8486
# [TRAIN] Epoch 27/150 | Batch 40/153 | Loss=0.1347 | Dice_coeff=0.8653 | IoU=0.7626
# [TRAIN] Epoch 27/150 | Batch 50/153 | Loss=0.1236 | Dice_coeff=0.8764 | IoU=0.7800
# [TRAIN] Epoch 27/150 | Batch 60/153 | Loss=0.0681 | Dice_coeff=0.9319 | IoU=0.8726
# [TRAIN] Epoch 27/150 | Batch 70/153 | Loss=0.1068 | Dice_coeff=0.8932 | IoU=0.8070
# [TRAIN] Epoch 27/150 | Batch 80/153 | Loss=0.1831 | Dice_coeff=0.8169 | IoU=0.6904
# [TRAIN] Epoch 27/150 | Batch 90/153 | Loss=0.1798 | Dice_coeff=0.8202 | IoU=0.6953
# [TRAIN] Epoch 27/150 | Batch 100/153 | Loss=0.0811 | Dice_coeff=0.9189 | IoU=0.8499
# [TRAIN] Epoch 27/150 | Batch 110/153 | Loss=0.1381 | Dice_coeff=0.8619 | IoU=0.7573
# [TRAIN] Epoch 27/150 | Batch 120/153 | Loss=0.0914 | Dice_coeff=0.9086 | IoU=0.8326
# [TRAIN] Epoch 27/150 | Batch 130/153 | Loss=0.1136 | Dice_coeff=0.8864 | IoU=0.7960
# [TRAIN] Epoch 27/150 | Batch 140/153 | Loss=0.1901 | Dice_coeff=0.8099 | IoU=0.6805
# [TRAIN] Epoch 27/150 | Batch 150/153 | Loss=0.0956 | Dice_coeff=0.9044 | IoU=0.8254
#  Train Loss: 0.1360 | Avg_dice_coeff: 0.8640 | Avg_IoU: 0.7626
# Running Validation...
#  Valid Loss: 0.1952 | Dice_coeff: 0.8048 | IoU: 0.6816
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch26.pt
# ========== Epoch 28 / 150 ==========
# Training...
# [TRAIN] Epoch 28/150 | Batch 10/153 | Loss=0.1296 | Dice_coeff=0.8704 | IoU=0.7706
# [TRAIN] Epoch 28/150 | Batch 20/153 | Loss=0.1284 | Dice_coeff=0.8716 | IoU=0.7724
# [TRAIN] Epoch 28/150 | Batch 30/153 | Loss=0.2285 | Dice_coeff=0.7715 | IoU=0.6280
# [TRAIN] Epoch 28/150 | Batch 40/153 | Loss=0.1008 | Dice_coeff=0.8992 | IoU=0.8168
# [TRAIN] Epoch 28/150 | Batch 50/153 | Loss=0.1543 | Dice_coeff=0.8457 | IoU=0.7327
# [TRAIN] Epoch 28/150 | Batch 60/153 | Loss=0.1004 | Dice_coeff=0.8996 | IoU=0.8175
# [TRAIN] Epoch 28/150 | Batch 70/153 | Loss=0.1436 | Dice_coeff=0.8564 | IoU=0.7489
# [TRAIN] Epoch 28/150 | Batch 80/153 | Loss=0.1541 | Dice_coeff=0.8459 | IoU=0.7329
# [TRAIN] Epoch 28/150 | Batch 90/153 | Loss=0.1140 | Dice_coeff=0.8860 | IoU=0.7953
# [TRAIN] Epoch 28/150 | Batch 100/153 | Loss=0.0612 | Dice_coeff=0.9388 | IoU=0.8846
# [TRAIN] Epoch 28/150 | Batch 110/153 | Loss=0.0847 | Dice_coeff=0.9153 | IoU=0.8438
# [TRAIN] Epoch 28/150 | Batch 120/153 | Loss=0.1117 | Dice_coeff=0.8883 | IoU=0.7990
# [TRAIN] Epoch 28/150 | Batch 130/153 | Loss=0.2105 | Dice_coeff=0.7895 | IoU=0.6522
# [TRAIN] Epoch 28/150 | Batch 140/153 | Loss=0.1137 | Dice_coeff=0.8863 | IoU=0.7959
# [TRAIN] Epoch 28/150 | Batch 150/153 | Loss=0.0974 | Dice_coeff=0.9026 | IoU=0.8225
#  Train Loss: 0.1365 | Avg_dice_coeff: 0.8635 | Avg_IoU: 0.7618
# Running Validation...
#  Valid Loss: 0.1869 | Dice_coeff: 0.8131 | IoU: 0.6938
# No improvement in validation loss for 2 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch27.pt
# ========== Epoch 29 / 150 ==========
# Training...
# [TRAIN] Epoch 29/150 | Batch 10/153 | Loss=0.1199 | Dice_coeff=0.8801 | IoU=0.7859
# [TRAIN] Epoch 29/150 | Batch 20/153 | Loss=0.1070 | Dice_coeff=0.8930 | IoU=0.8067
# [TRAIN] Epoch 29/150 | Batch 30/153 | Loss=0.1370 | Dice_coeff=0.8630 | IoU=0.7591
# [TRAIN] Epoch 29/150 | Batch 40/153 | Loss=0.0838 | Dice_coeff=0.9162 | IoU=0.8453
# [TRAIN] Epoch 29/150 | Batch 50/153 | Loss=0.1208 | Dice_coeff=0.8792 | IoU=0.7844
# [TRAIN] Epoch 29/150 | Batch 60/153 | Loss=0.1392 | Dice_coeff=0.8608 | IoU=0.7557
# [TRAIN] Epoch 29/150 | Batch 70/153 | Loss=0.1007 | Dice_coeff=0.8993 | IoU=0.8170
# [TRAIN] Epoch 29/150 | Batch 80/153 | Loss=0.1437 | Dice_coeff=0.8563 | IoU=0.7487
# [TRAIN] Epoch 29/150 | Batch 90/153 | Loss=0.0946 | Dice_coeff=0.9054 | IoU=0.8272
# [TRAIN] Epoch 29/150 | Batch 100/153 | Loss=0.1065 | Dice_coeff=0.8935 | IoU=0.8074
# [TRAIN] Epoch 29/150 | Batch 110/153 | Loss=0.1254 | Dice_coeff=0.8746 | IoU=0.7771
# [TRAIN] Epoch 29/150 | Batch 120/153 | Loss=0.1005 | Dice_coeff=0.8995 | IoU=0.8174
# [TRAIN] Epoch 29/150 | Batch 130/153 | Loss=0.0806 | Dice_coeff=0.9194 | IoU=0.8508
# [TRAIN] Epoch 29/150 | Batch 140/153 | Loss=0.0829 | Dice_coeff=0.9171 | IoU=0.8469
# [TRAIN] Epoch 29/150 | Batch 150/153 | Loss=0.1126 | Dice_coeff=0.8874 | IoU=0.7976
#  Train Loss: 0.1299 | Avg_dice_coeff: 0.8701 | Avg_IoU: 0.7718
# Running Validation...
#  Valid Loss: 0.1873 | Dice_coeff: 0.8127 | IoU: 0.6926
# No improvement in validation loss for 3 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch28.pt
# ========== Epoch 30 / 150 ==========
# Training...
# [TRAIN] Epoch 30/150 | Batch 10/153 | Loss=0.2260 | Dice_coeff=0.7740 | IoU=0.6314
# [TRAIN] Epoch 30/150 | Batch 20/153 | Loss=0.1495 | Dice_coeff=0.8505 | IoU=0.7399
# [TRAIN] Epoch 30/150 | Batch 30/153 | Loss=0.1049 | Dice_coeff=0.8951 | IoU=0.8101
# [TRAIN] Epoch 30/150 | Batch 40/153 | Loss=0.1271 | Dice_coeff=0.8729 | IoU=0.7745
# [TRAIN] Epoch 30/150 | Batch 50/153 | Loss=0.1430 | Dice_coeff=0.8570 | IoU=0.7498
# [TRAIN] Epoch 30/150 | Batch 60/153 | Loss=0.1337 | Dice_coeff=0.8663 | IoU=0.7642
# [TRAIN] Epoch 30/150 | Batch 70/153 | Loss=0.0790 | Dice_coeff=0.9210 | IoU=0.8535
# [TRAIN] Epoch 30/150 | Batch 80/153 | Loss=0.0675 | Dice_coeff=0.9325 | IoU=0.8735
# [TRAIN] Epoch 30/150 | Batch 90/153 | Loss=0.1169 | Dice_coeff=0.8831 | IoU=0.7906
# [TRAIN] Epoch 30/150 | Batch 100/153 | Loss=0.1282 | Dice_coeff=0.8718 | IoU=0.7727
# [TRAIN] Epoch 30/150 | Batch 110/153 | Loss=0.1025 | Dice_coeff=0.8975 | IoU=0.8140
# [TRAIN] Epoch 30/150 | Batch 120/153 | Loss=0.0880 | Dice_coeff=0.9120 | IoU=0.8383
# [TRAIN] Epoch 30/150 | Batch 130/153 | Loss=0.1114 | Dice_coeff=0.8886 | IoU=0.7995
# [TRAIN] Epoch 30/150 | Batch 140/153 | Loss=0.1316 | Dice_coeff=0.8684 | IoU=0.7674
# [TRAIN] Epoch 30/150 | Batch 150/153 | Loss=0.0876 | Dice_coeff=0.9124 | IoU=0.8390
#  Train Loss: 0.1298 | Avg_dice_coeff: 0.8702 | Avg_IoU: 0.7725
# Running Validation...
#  Valid Loss: 0.1789 | Dice_coeff: 0.8211 | IoU: 0.7030
# Validation loss improved from 0.1814 to 0.1789. Saving model...
# Model saved to ==> 18-06-2025_04-14-53/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-14-53/model_epoch29.pt
# ========== Epoch 31 / 150 ==========
# Training...
# [TRAIN] Epoch 31/150 | Batch 10/153 | Loss=0.1303 | Dice_coeff=0.8697 | IoU=0.7694
# [TRAIN] Epoch 31/150 | Batch 20/153 | Loss=0.1386 | Dice_coeff=0.8614 | IoU=0.7565
# [TRAIN] Epoch 31/150 | Batch 30/153 | Loss=0.1471 | Dice_coeff=0.8529 | IoU=0.7435
# [TRAIN] Epoch 31/150 | Batch 40/153 | Loss=0.1167 | Dice_coeff=0.8833 | IoU=0.7910
# [TRAIN] Epoch 31/150 | Batch 50/153 | Loss=0.0643 | Dice_coeff=0.9357 | IoU=0.8792
# [TRAIN] Epoch 31/150 | Batch 60/153 | Loss=0.1184 | Dice_coeff=0.8816 | IoU=0.7883
# [TRAIN] Epoch 31/150 | Batch 70/153 | Loss=0.2082 | Dice_coeff=0.7918 | IoU=0.6553
# [TRAIN] Epoch 31/150 | Batch 80/153 | Loss=0.1719 | Dice_coeff=0.8281 | IoU=0.7066
# [TRAIN] Epoch 31/150 | Batch 90/153 | Loss=0.1769 | Dice_coeff=0.8231 | IoU=0.6993
# ...
# [TRAIN] Epoch 140/150 | Batch 150/153 | Loss=0.0206 | Dice_coeff=0.9794 | IoU=0.9596
#  Train Loss: 0.0219 | Avg_dice_coeff: 0.9781 | Avg_IoU: 0.9573
# Running Validation...
#  Valid Loss: 0.1479 | Dice_coeff: 0.8521 | IoU: 0.7483
# No improvement in validation loss for 41 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch139.pt
# ========== Epoch 141 / 150 ==========
# Training...
# [TRAIN] Epoch 141/150 | Batch 10/153 | Loss=0.0629 | Dice_coeff=0.9371 | IoU=0.8816
# [TRAIN] Epoch 141/150 | Batch 20/153 | Loss=0.0120 | Dice_coeff=0.9880 | IoU=0.9762
# [TRAIN] Epoch 141/150 | Batch 30/153 | Loss=0.0188 | Dice_coeff=0.9812 | IoU=0.9631
# [TRAIN] Epoch 141/150 | Batch 40/153 | Loss=0.0120 | Dice_coeff=0.9880 | IoU=0.9763
# [TRAIN] Epoch 141/150 | Batch 50/153 | Loss=0.0180 | Dice_coeff=0.9820 | IoU=0.9647
# [TRAIN] Epoch 141/150 | Batch 60/153 | Loss=0.0346 | Dice_coeff=0.9654 | IoU=0.9331
# [TRAIN] Epoch 141/150 | Batch 70/153 | Loss=0.0235 | Dice_coeff=0.9765 | IoU=0.9541
# [TRAIN] Epoch 141/150 | Batch 80/153 | Loss=0.0233 | Dice_coeff=0.9767 | IoU=0.9544
# [TRAIN] Epoch 141/150 | Batch 90/153 | Loss=0.0217 | Dice_coeff=0.9783 | IoU=0.9576
# [TRAIN] Epoch 141/150 | Batch 100/153 | Loss=0.0159 | Dice_coeff=0.9841 | IoU=0.9687
# [TRAIN] Epoch 141/150 | Batch 110/153 | Loss=0.0153 | Dice_coeff=0.9847 | IoU=0.9699
# [TRAIN] Epoch 141/150 | Batch 120/153 | Loss=0.0161 | Dice_coeff=0.9839 | IoU=0.9682
# [TRAIN] Epoch 141/150 | Batch 130/153 | Loss=0.0360 | Dice_coeff=0.9640 | IoU=0.9305
# [TRAIN] Epoch 141/150 | Batch 140/153 | Loss=0.0172 | Dice_coeff=0.9828 | IoU=0.9662
# [TRAIN] Epoch 141/150 | Batch 150/153 | Loss=0.0160 | Dice_coeff=0.9840 | IoU=0.9685
#  Train Loss: 0.0222 | Avg_dice_coeff: 0.9778 | Avg_IoU: 0.9569
# Running Validation...
#  Valid Loss: 0.1484 | Dice_coeff: 0.8516 | IoU: 0.7476
# No improvement in validation loss for 42 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch140.pt
# ========== Epoch 142 / 150 ==========
# Training...
# [TRAIN] Epoch 142/150 | Batch 10/153 | Loss=0.0188 | Dice_coeff=0.9812 | IoU=0.9631
# [TRAIN] Epoch 142/150 | Batch 20/153 | Loss=0.0372 | Dice_coeff=0.9628 | IoU=0.9283
# [TRAIN] Epoch 142/150 | Batch 30/153 | Loss=0.0118 | Dice_coeff=0.9882 | IoU=0.9766
# [TRAIN] Epoch 142/150 | Batch 40/153 | Loss=0.0191 | Dice_coeff=0.9809 | IoU=0.9626
# [TRAIN] Epoch 142/150 | Batch 50/153 | Loss=0.0225 | Dice_coeff=0.9775 | IoU=0.9560
# [TRAIN] Epoch 142/150 | Batch 60/153 | Loss=0.0281 | Dice_coeff=0.9719 | IoU=0.9453
# [TRAIN] Epoch 142/150 | Batch 70/153 | Loss=0.0150 | Dice_coeff=0.9850 | IoU=0.9705
# [TRAIN] Epoch 142/150 | Batch 80/153 | Loss=0.0162 | Dice_coeff=0.9838 | IoU=0.9680
# [TRAIN] Epoch 142/150 | Batch 90/153 | Loss=0.0179 | Dice_coeff=0.9821 | IoU=0.9649
# [TRAIN] Epoch 142/150 | Batch 100/153 | Loss=0.0226 | Dice_coeff=0.9774 | IoU=0.9559
# [TRAIN] Epoch 142/150 | Batch 110/153 | Loss=0.0183 | Dice_coeff=0.9817 | IoU=0.9641
# [TRAIN] Epoch 142/150 | Batch 120/153 | Loss=0.0208 | Dice_coeff=0.9792 | IoU=0.9593
# [TRAIN] Epoch 142/150 | Batch 130/153 | Loss=0.1410 | Dice_coeff=0.8590 | IoU=0.7529
# [TRAIN] Epoch 142/150 | Batch 140/153 | Loss=0.0170 | Dice_coeff=0.9830 | IoU=0.9665
# [TRAIN] Epoch 142/150 | Batch 150/153 | Loss=0.0205 | Dice_coeff=0.9795 | IoU=0.9599
#  Train Loss: 0.0219 | Avg_dice_coeff: 0.9781 | Avg_IoU: 0.9574
# Running Validation...
#  Valid Loss: 0.1487 | Dice_coeff: 0.8513 | IoU: 0.7471
# No improvement in validation loss for 43 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch141.pt
# ========== Epoch 143 / 150 ==========
# Training...
# [TRAIN] Epoch 143/150 | Batch 10/153 | Loss=0.0171 | Dice_coeff=0.9829 | IoU=0.9664
# [TRAIN] Epoch 143/150 | Batch 20/153 | Loss=0.0176 | Dice_coeff=0.9824 | IoU=0.9653
# [TRAIN] Epoch 143/150 | Batch 30/153 | Loss=0.0195 | Dice_coeff=0.9805 | IoU=0.9617
# [TRAIN] Epoch 143/150 | Batch 40/153 | Loss=0.0978 | Dice_coeff=0.9022 | IoU=0.8218
# [TRAIN] Epoch 143/150 | Batch 50/153 | Loss=0.0174 | Dice_coeff=0.9826 | IoU=0.9657
# [TRAIN] Epoch 143/150 | Batch 60/153 | Loss=0.0144 | Dice_coeff=0.9856 | IoU=0.9716
# [TRAIN] Epoch 143/150 | Batch 70/153 | Loss=0.0298 | Dice_coeff=0.9702 | IoU=0.9420
# [TRAIN] Epoch 143/150 | Batch 80/153 | Loss=0.0171 | Dice_coeff=0.9829 | IoU=0.9663
# [TRAIN] Epoch 143/150 | Batch 90/153 | Loss=0.0199 | Dice_coeff=0.9801 | IoU=0.9610
# [TRAIN] Epoch 143/150 | Batch 100/153 | Loss=0.0189 | Dice_coeff=0.9811 | IoU=0.9630
# [TRAIN] Epoch 143/150 | Batch 110/153 | Loss=0.0175 | Dice_coeff=0.9825 | IoU=0.9657
# [TRAIN] Epoch 143/150 | Batch 120/153 | Loss=0.0181 | Dice_coeff=0.9819 | IoU=0.9644
# [TRAIN] Epoch 143/150 | Batch 130/153 | Loss=0.0149 | Dice_coeff=0.9851 | IoU=0.9707
# [TRAIN] Epoch 143/150 | Batch 140/153 | Loss=0.0148 | Dice_coeff=0.9852 | IoU=0.9708
# [TRAIN] Epoch 143/150 | Batch 150/153 | Loss=0.0188 | Dice_coeff=0.9812 | IoU=0.9631
#  Train Loss: 0.0219 | Avg_dice_coeff: 0.9781 | Avg_IoU: 0.9575
# Running Validation...
#  Valid Loss: 0.1483 | Dice_coeff: 0.8517 | IoU: 0.7478
# No improvement in validation loss for 44 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch142.pt
# ========== Epoch 144 / 150 ==========
# Training...
# [TRAIN] Epoch 144/150 | Batch 10/153 | Loss=0.0145 | Dice_coeff=0.9855 | IoU=0.9715
# [TRAIN] Epoch 144/150 | Batch 20/153 | Loss=0.0144 | Dice_coeff=0.9856 | IoU=0.9717
# [TRAIN] Epoch 144/150 | Batch 30/153 | Loss=0.0241 | Dice_coeff=0.9759 | IoU=0.9530
# [TRAIN] Epoch 144/150 | Batch 40/153 | Loss=0.0140 | Dice_coeff=0.9860 | IoU=0.9724
# [TRAIN] Epoch 144/150 | Batch 50/153 | Loss=0.0234 | Dice_coeff=0.9766 | IoU=0.9544
# [TRAIN] Epoch 144/150 | Batch 60/153 | Loss=0.0227 | Dice_coeff=0.9773 | IoU=0.9556
# [TRAIN] Epoch 144/150 | Batch 70/153 | Loss=0.0878 | Dice_coeff=0.9122 | IoU=0.8386
# [TRAIN] Epoch 144/150 | Batch 80/153 | Loss=0.0145 | Dice_coeff=0.9855 | IoU=0.9714
# [TRAIN] Epoch 144/150 | Batch 90/153 | Loss=0.0275 | Dice_coeff=0.9725 | IoU=0.9465
# [TRAIN] Epoch 144/150 | Batch 100/153 | Loss=0.0345 | Dice_coeff=0.9655 | IoU=0.9334
# [TRAIN] Epoch 144/150 | Batch 110/153 | Loss=0.0279 | Dice_coeff=0.9721 | IoU=0.9458
# [TRAIN] Epoch 144/150 | Batch 120/153 | Loss=0.0234 | Dice_coeff=0.9766 | IoU=0.9543
# [TRAIN] Epoch 144/150 | Batch 130/153 | Loss=0.0520 | Dice_coeff=0.9480 | IoU=0.9012
# [TRAIN] Epoch 144/150 | Batch 140/153 | Loss=0.0192 | Dice_coeff=0.9808 | IoU=0.9623
# [TRAIN] Epoch 144/150 | Batch 150/153 | Loss=0.0172 | Dice_coeff=0.9828 | IoU=0.9661
#  Train Loss: 0.0217 | Avg_dice_coeff: 0.9783 | Avg_IoU: 0.9578
# Running Validation...
#  Valid Loss: 0.1483 | Dice_coeff: 0.8517 | IoU: 0.7477
# No improvement in validation loss for 45 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch143.pt
# ========== Epoch 145 / 150 ==========
# Training...
# [TRAIN] Epoch 145/150 | Batch 10/153 | Loss=0.0266 | Dice_coeff=0.9734 | IoU=0.9482
# [TRAIN] Epoch 145/150 | Batch 20/153 | Loss=0.0170 | Dice_coeff=0.9830 | IoU=0.9665
# [TRAIN] Epoch 145/150 | Batch 30/153 | Loss=0.0234 | Dice_coeff=0.9766 | IoU=0.9542
# [TRAIN] Epoch 145/150 | Batch 40/153 | Loss=0.0141 | Dice_coeff=0.9859 | IoU=0.9723
# [TRAIN] Epoch 145/150 | Batch 50/153 | Loss=0.0343 | Dice_coeff=0.9657 | IoU=0.9338
# [TRAIN] Epoch 145/150 | Batch 60/153 | Loss=0.0195 | Dice_coeff=0.9805 | IoU=0.9618
# [TRAIN] Epoch 145/150 | Batch 70/153 | Loss=0.0119 | Dice_coeff=0.9881 | IoU=0.9765
# [TRAIN] Epoch 145/150 | Batch 80/153 | Loss=0.0285 | Dice_coeff=0.9715 | IoU=0.9445
# [TRAIN] Epoch 145/150 | Batch 90/153 | Loss=0.0109 | Dice_coeff=0.9891 | IoU=0.9784
# [TRAIN] Epoch 145/150 | Batch 100/153 | Loss=0.0254 | Dice_coeff=0.9746 | IoU=0.9504
# [TRAIN] Epoch 145/150 | Batch 110/153 | Loss=0.0163 | Dice_coeff=0.9837 | IoU=0.9679
# [TRAIN] Epoch 145/150 | Batch 120/153 | Loss=0.0147 | Dice_coeff=0.9853 | IoU=0.9711
# [TRAIN] Epoch 145/150 | Batch 130/153 | Loss=0.0573 | Dice_coeff=0.9427 | IoU=0.8917
# [TRAIN] Epoch 145/150 | Batch 140/153 | Loss=0.0253 | Dice_coeff=0.9747 | IoU=0.9506
# [TRAIN] Epoch 145/150 | Batch 150/153 | Loss=0.0166 | Dice_coeff=0.9834 | IoU=0.9673
#  Train Loss: 0.0216 | Avg_dice_coeff: 0.9784 | Avg_IoU: 0.9579
# Running Validation...
#  Valid Loss: 0.1480 | Dice_coeff: 0.8520 | IoU: 0.7481
# No improvement in validation loss for 46 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch144.pt
# ========== Epoch 146 / 150 ==========
# Training...
# [TRAIN] Epoch 146/150 | Batch 10/153 | Loss=0.0686 | Dice_coeff=0.9314 | IoU=0.8717
# [TRAIN] Epoch 146/150 | Batch 20/153 | Loss=0.0147 | Dice_coeff=0.9853 | IoU=0.9710
# [TRAIN] Epoch 146/150 | Batch 30/153 | Loss=0.0365 | Dice_coeff=0.9635 | IoU=0.9295
# [TRAIN] Epoch 146/150 | Batch 40/153 | Loss=0.0169 | Dice_coeff=0.9831 | IoU=0.9668
# [TRAIN] Epoch 146/150 | Batch 50/153 | Loss=0.0145 | Dice_coeff=0.9855 | IoU=0.9713
# [TRAIN] Epoch 146/150 | Batch 60/153 | Loss=0.0752 | Dice_coeff=0.9248 | IoU=0.8601
# [TRAIN] Epoch 146/150 | Batch 70/153 | Loss=0.0148 | Dice_coeff=0.9852 | IoU=0.9708
# [TRAIN] Epoch 146/150 | Batch 80/153 | Loss=0.0152 | Dice_coeff=0.9848 | IoU=0.9701
# [TRAIN] Epoch 146/150 | Batch 90/153 | Loss=0.0271 | Dice_coeff=0.9729 | IoU=0.9472
# [TRAIN] Epoch 146/150 | Batch 100/153 | Loss=0.0136 | Dice_coeff=0.9864 | IoU=0.9732
# [TRAIN] Epoch 146/150 | Batch 110/153 | Loss=0.0332 | Dice_coeff=0.9668 | IoU=0.9358
# [TRAIN] Epoch 146/150 | Batch 120/153 | Loss=0.0184 | Dice_coeff=0.9816 | IoU=0.9638
# [TRAIN] Epoch 146/150 | Batch 130/153 | Loss=0.0244 | Dice_coeff=0.9756 | IoU=0.9524
# [TRAIN] Epoch 146/150 | Batch 140/153 | Loss=0.0261 | Dice_coeff=0.9739 | IoU=0.9491
# [TRAIN] Epoch 146/150 | Batch 150/153 | Loss=0.0134 | Dice_coeff=0.9866 | IoU=0.9736
#  Train Loss: 0.0213 | Avg_dice_coeff: 0.9787 | Avg_IoU: 0.9585
# Running Validation...
#  Valid Loss: 0.1481 | Dice_coeff: 0.8519 | IoU: 0.7481
# No improvement in validation loss for 47 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch145.pt
# ========== Epoch 147 / 150 ==========
# Training...
# [TRAIN] Epoch 147/150 | Batch 10/153 | Loss=0.0182 | Dice_coeff=0.9818 | IoU=0.9643
# [TRAIN] Epoch 147/150 | Batch 20/153 | Loss=0.0246 | Dice_coeff=0.9754 | IoU=0.9519
# [TRAIN] Epoch 147/150 | Batch 30/153 | Loss=0.0219 | Dice_coeff=0.9781 | IoU=0.9572
# [TRAIN] Epoch 147/150 | Batch 40/153 | Loss=0.0136 | Dice_coeff=0.9864 | IoU=0.9732
# [TRAIN] Epoch 147/150 | Batch 50/153 | Loss=0.0290 | Dice_coeff=0.9710 | IoU=0.9437
# [TRAIN] Epoch 147/150 | Batch 60/153 | Loss=0.0187 | Dice_coeff=0.9813 | IoU=0.9634
# [TRAIN] Epoch 147/150 | Batch 70/153 | Loss=0.0123 | Dice_coeff=0.9877 | IoU=0.9757
# [TRAIN] Epoch 147/150 | Batch 80/153 | Loss=0.0400 | Dice_coeff=0.9600 | IoU=0.9230
# [TRAIN] Epoch 147/150 | Batch 90/153 | Loss=0.0146 | Dice_coeff=0.9854 | IoU=0.9713
# [TRAIN] Epoch 147/150 | Batch 100/153 | Loss=0.0163 | Dice_coeff=0.9837 | IoU=0.9678
# [TRAIN] Epoch 147/150 | Batch 110/153 | Loss=0.0168 | Dice_coeff=0.9832 | IoU=0.9669
# [TRAIN] Epoch 147/150 | Batch 120/153 | Loss=0.0162 | Dice_coeff=0.9838 | IoU=0.9681
# [TRAIN] Epoch 147/150 | Batch 130/153 | Loss=0.0158 | Dice_coeff=0.9842 | IoU=0.9689
# [TRAIN] Epoch 147/150 | Batch 140/153 | Loss=0.0312 | Dice_coeff=0.9688 | IoU=0.9395
# [TRAIN] Epoch 147/150 | Batch 150/153 | Loss=0.0358 | Dice_coeff=0.9642 | IoU=0.9308
#  Train Loss: 0.0216 | Avg_dice_coeff: 0.9784 | Avg_IoU: 0.9580
# Running Validation...
#  Valid Loss: 0.1482 | Dice_coeff: 0.8518 | IoU: 0.7479
# No improvement in validation loss for 48 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch146.pt
# ========== Epoch 148 / 150 ==========
# Training...
# [TRAIN] Epoch 148/150 | Batch 10/153 | Loss=0.0128 | Dice_coeff=0.9872 | IoU=0.9748
# [TRAIN] Epoch 148/150 | Batch 20/153 | Loss=0.0253 | Dice_coeff=0.9747 | IoU=0.9507
# [TRAIN] Epoch 148/150 | Batch 30/153 | Loss=0.0154 | Dice_coeff=0.9846 | IoU=0.9696
# [TRAIN] Epoch 148/150 | Batch 40/153 | Loss=0.0165 | Dice_coeff=0.9835 | IoU=0.9675
# [TRAIN] Epoch 148/150 | Batch 50/153 | Loss=0.0126 | Dice_coeff=0.9874 | IoU=0.9752
# [TRAIN] Epoch 148/150 | Batch 60/153 | Loss=0.0147 | Dice_coeff=0.9853 | IoU=0.9710
# [TRAIN] Epoch 148/150 | Batch 70/153 | Loss=0.0247 | Dice_coeff=0.9753 | IoU=0.9518
# [TRAIN] Epoch 148/150 | Batch 80/153 | Loss=0.0193 | Dice_coeff=0.9807 | IoU=0.9621
# [TRAIN] Epoch 148/150 | Batch 90/153 | Loss=0.0168 | Dice_coeff=0.9832 | IoU=0.9670
# [TRAIN] Epoch 148/150 | Batch 100/153 | Loss=0.0219 | Dice_coeff=0.9781 | IoU=0.9572
# [TRAIN] Epoch 148/150 | Batch 110/153 | Loss=0.0170 | Dice_coeff=0.9830 | IoU=0.9665
# [TRAIN] Epoch 148/150 | Batch 120/153 | Loss=0.0143 | Dice_coeff=0.9857 | IoU=0.9718
# [TRAIN] Epoch 148/150 | Batch 130/153 | Loss=0.0188 | Dice_coeff=0.9812 | IoU=0.9631
# [TRAIN] Epoch 148/150 | Batch 140/153 | Loss=0.0224 | Dice_coeff=0.9776 | IoU=0.9562
# [TRAIN] Epoch 148/150 | Batch 150/153 | Loss=0.0179 | Dice_coeff=0.9821 | IoU=0.9649
#  Train Loss: 0.0215 | Avg_dice_coeff: 0.9785 | Avg_IoU: 0.9581
# Running Validation...
#  Valid Loss: 0.1482 | Dice_coeff: 0.8518 | IoU: 0.7479
# No improvement in validation loss for 49 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch147.pt
# ========== Epoch 149 / 150 ==========
# Training...
# [TRAIN] Epoch 149/150 | Batch 10/153 | Loss=0.0208 | Dice_coeff=0.9792 | IoU=0.9592
# [TRAIN] Epoch 149/150 | Batch 20/153 | Loss=0.0181 | Dice_coeff=0.9819 | IoU=0.9644
# [TRAIN] Epoch 149/150 | Batch 30/153 | Loss=0.0242 | Dice_coeff=0.9758 | IoU=0.9528
# [TRAIN] Epoch 149/150 | Batch 40/153 | Loss=0.0126 | Dice_coeff=0.9874 | IoU=0.9750
# [TRAIN] Epoch 149/150 | Batch 50/153 | Loss=0.0184 | Dice_coeff=0.9816 | IoU=0.9638
# [TRAIN] Epoch 149/150 | Batch 60/153 | Loss=0.0166 | Dice_coeff=0.9834 | IoU=0.9674
# [TRAIN] Epoch 149/150 | Batch 70/153 | Loss=0.0167 | Dice_coeff=0.9833 | IoU=0.9671
# [TRAIN] Epoch 149/150 | Batch 80/153 | Loss=0.0164 | Dice_coeff=0.9836 | IoU=0.9677
# [TRAIN] Epoch 149/150 | Batch 90/153 | Loss=0.0166 | Dice_coeff=0.9834 | IoU=0.9674
# [TRAIN] Epoch 149/150 | Batch 100/153 | Loss=0.0435 | Dice_coeff=0.9565 | IoU=0.9166
# [TRAIN] Epoch 149/150 | Batch 110/153 | Loss=0.0209 | Dice_coeff=0.9791 | IoU=0.9590
# [TRAIN] Epoch 149/150 | Batch 120/153 | Loss=0.0301 | Dice_coeff=0.9699 | IoU=0.9416
# [TRAIN] Epoch 149/150 | Batch 130/153 | Loss=0.0142 | Dice_coeff=0.9858 | IoU=0.9720
# [TRAIN] Epoch 149/150 | Batch 140/153 | Loss=0.0335 | Dice_coeff=0.9665 | IoU=0.9352
# [TRAIN] Epoch 149/150 | Batch 150/153 | Loss=0.0435 | Dice_coeff=0.9565 | IoU=0.9166
#  Train Loss: 0.0213 | Avg_dice_coeff: 0.9787 | Avg_IoU: 0.9585
# Running Validation...
#  Valid Loss: 0.1482 | Dice_coeff: 0.8518 | IoU: 0.7478
# No improvement in validation loss for 50 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch148.pt
# ========== Epoch 150 / 150 ==========
# Training...
# [TRAIN] Epoch 150/150 | Batch 10/153 | Loss=0.0182 | Dice_coeff=0.9818 | IoU=0.9643
# [TRAIN] Epoch 150/150 | Batch 20/153 | Loss=0.0218 | Dice_coeff=0.9782 | IoU=0.9573
# [TRAIN] Epoch 150/150 | Batch 30/153 | Loss=0.0153 | Dice_coeff=0.9847 | IoU=0.9699
# [TRAIN] Epoch 150/150 | Batch 40/153 | Loss=0.0217 | Dice_coeff=0.9783 | IoU=0.9576
# [TRAIN] Epoch 150/150 | Batch 50/153 | Loss=0.0400 | Dice_coeff=0.9600 | IoU=0.9231
# [TRAIN] Epoch 150/150 | Batch 60/153 | Loss=0.0238 | Dice_coeff=0.9762 | IoU=0.9535
# [TRAIN] Epoch 150/150 | Batch 70/153 | Loss=0.0153 | Dice_coeff=0.9847 | IoU=0.9698
# [TRAIN] Epoch 150/150 | Batch 80/153 | Loss=0.0136 | Dice_coeff=0.9864 | IoU=0.9731
# [TRAIN] Epoch 150/150 | Batch 90/153 | Loss=0.0136 | Dice_coeff=0.9864 | IoU=0.9733
# [TRAIN] Epoch 150/150 | Batch 100/153 | Loss=0.0189 | Dice_coeff=0.9811 | IoU=0.9629
# [TRAIN] Epoch 150/150 | Batch 110/153 | Loss=0.0215 | Dice_coeff=0.9785 | IoU=0.9579
# [TRAIN] Epoch 150/150 | Batch 120/153 | Loss=0.0203 | Dice_coeff=0.9797 | IoU=0.9603
# [TRAIN] Epoch 150/150 | Batch 130/153 | Loss=0.0315 | Dice_coeff=0.9685 | IoU=0.9389
# [TRAIN] Epoch 150/150 | Batch 140/153 | Loss=0.0270 | Dice_coeff=0.9730 | IoU=0.9474
# [TRAIN] Epoch 150/150 | Batch 150/153 | Loss=0.0218 | Dice_coeff=0.9782 | IoU=0.9573
#  Train Loss: 0.0217 | Avg_dice_coeff: 0.9783 | Avg_IoU: 0.9577
# Running Validation...
#  Valid Loss: 0.1481 | Dice_coeff: 0.8519 | IoU: 0.7480
# No improvement in validation loss for 51 epochs.
# Model saved to ==> 18-06-2025_04-14-53/model_epoch149.pt
# Training complete!

# %%
trainer.visualize_scores()

# %%
test_loader = DataLoader(dataset=valid_dataset, batch_size=1, shuffle=False)

trainer.eval(test_loader)
# Out:
# [Test] Batch 100/611 | Test Loss=0.0232
# [Test] Batch 200/611 | Test Loss=0.2211
# [Test] Batch 300/611 | Test Loss=0.1198
# [Test] Batch 400/611 | Test Loss=0.1999
# [Test] Batch 500/611 | Test Loss=0.6452
# [Test] Batch 600/611 | Test Loss=0.0660
#  Test Loss: 0.1950 | Dice_coeff: 0.8050 | IoU: 0.7232

# %%
width = 4
columns = 3
n_examples = 12

fig, axs = plt.subplots(columns, width, figsize=(3*width , 3*columns), constrained_layout=True)
i = 0
with torch.no_grad():
    for data in test_loader:
        image, mask = data
        mask = mask[0][0]
        if not mask.byte().any():
            continue
        image = image.to(config.DEVICE)
        prediction = trainer.model(image).to('cpu')[0][0]
        prediction = torch.where(prediction > 0.5, 1, 0)
        
        axs[i//width][i%width].imshow(image[0].to('cpu').permute(1, 2, 0))
        axs[i//width][i%width].imshow(mask, alpha=0.5)
        axs[i//width][i%width].imshow(prediction, alpha=0.5)
        if n_examples == i + 1:
            break
        i += 1
