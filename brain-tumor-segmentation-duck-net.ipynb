# %%
import os
import cv2
import time
import numpy as np
import pandas as pd
from glob import glob
from tqdm import tqdm
import numpy as np 
import cv2 as cv
import zipfile
import io
import requests
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW, lr_scheduler
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
from sklearn.impute import SimpleImputer
# import albumentations
from sklearn.model_selection import train_test_split
from scipy.ndimage.morphology import binary_dilation
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, models, transforms
import torchvision.transforms.functional as TF
from torchvision.utils import make_grid
from datetime import datetime
from enum import Enum
import math
# import hdf5storage
import h5py
from typing import Dict, List, Tuple, Optional, Union

from PIL import Image

# You can use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass

warnings.warn = warn
warnings.filterwarnings('ignore')
# Out:
# <ipython-input-1-2740f7023ce3>:23: DeprecationWarning: Please import `binary_dilation` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.morphology import binary_dilation

# %%
class Config:
    def __init__(self):
        # Dataset and DataLoader Parameters
        self.IMG_SIZE = (256, 256)
        self.BATCH_SIZE = 16
        self.TRAIN_RATIO = 0.8
        self.TEST_RATIO = 0.2

        # Training Parameters
        self.EPOCHS = 130
        self.LEARNING_RATE = 1e-3
        self.WEIGHT_DECAY = 1e-4
        self.LEARNING_RATE_MIN = 1e-6
        self.ACCUMALATION_STEPS = 1
        self.DICE_LOSS = True
        self.PATIENCE = 130

        # Model Parameters
        self.IN_CHANNELS = 1
        self.OUT_CLASSES = 1
        self.DEPTH = 5
        self.INIT_FEATURES = 17
        self.NORMALIZATION = 'batch'
        self.INTERPOLATION = 'nearest'
        self.OUT_ACTIVATION = 'sigmoid'
        self.USE_MULTIPLIER = False

        # Other Parameters
        self.DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.SEED = 42
        self.ROOT = "/kaggle/input/brain-tumor-dataset/data/"
        self.SAVE_DIR = '/kaggle/working/checkpoint'

config = Config()

# %%
def set_all_seeds(seed):
    # NumPy
    np.random.seed(seed)
    # PyTorch
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # For multi-GPU setups
    # Ensures that the CUDA convolutions are deterministic, but might slow down training
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False # Set to False for reproducibility

set_all_seeds(config.SEED)

# %%
class ClassesLabels(Enum):
    """Brain tumor classification labels"""
    Meningioma = 1  # U màng não
    Glioma = 2      # U thần kinh đệm  
    Pituitary = 3   # Tuyến uyên
    
    def __len__(self):
        return 3


class BrainTumorDataset(Dataset):
    """
    Brain tumor dataset with balanced class distribution
    
    Args:
        root: Root directory containing class folders
        train: If True, creates training set; if False, creates test set 
        classes: Tuple of classes to include
        test_freq: Fraction of data to use for testing
        random_seed: Random seed for reproducible splits
        normalize_image: Whether to normalize images to 0-255 range
        verbose: Whether to print dataset statistics
    """
    
    CLASS_FOLDERS = {
        ClassesLabels.Meningioma: 'meningioma',
        ClassesLabels.Glioma: 'glioma',
        ClassesLabels.Pituitary: 'pituitary'
    }
    
    def __init__(
        self,
        root: str,
        train: bool = True,
        classes: Tuple[ClassesLabels, ...] = (ClassesLabels.Meningioma, ClassesLabels.Glioma, ClassesLabels.Pituitary),
        test_freq: float = 0.15,
        random_seed: int = 42,
        normalize_image: bool = True,
        verbose: bool = True
    ):
        super().__init__()
        self.root = self._validate_path(root)
        self.train = train
        self.classes = classes
        self.test_freq = test_freq
        self.normalize_image = normalize_image
        
        # Set random seed for reproducible splits
        np.random.seed(random_seed)
        
        # Load and split data
        self.items, self.class_info = self._load_and_split_data()
        
        if verbose:
            self._print_stats()
    
    def _validate_path(self, path: str) -> str:
        """Validate and normalize root path"""
        if not os.path.exists(path):
            raise ValueError(f"Root path does not exist: {path}")
        return os.path.normpath(path)
    
    def _load_and_split_data(self) -> Tuple[List[str], Dict]:
        """Load files and split into train/test per class"""
        items = []
        class_info = {}
        
        for class_label in self.classes:
            folder_name = self.CLASS_FOLDERS[class_label]
            folder_path = os.path.join(self.root, folder_name)
            
            if not os.path.exists(folder_path):
                print(f"Warning: Folder {folder_path} does not exist!")
                continue
            
            # Get all valid files for this class
            all_files = self._get_valid_files(folder_path)
            if not all_files:
                print(f"Warning: No valid files found in {folder_path}")
                continue
            
            # Split files for this class
            train_files, test_files = self._split_files(all_files)
            selected_files = train_files if self.train else test_files
            
            # Add to items with folder prefix
            items.extend([f'{folder_name}/{f}' for f in selected_files])
            
            # Store class statistics
            class_info[class_label.name] = {
                'total': len(all_files),
                'train': len(train_files),
                'test': len(test_files),
                'selected': len(selected_files)
            }
        
        return items, class_info
    
    def _get_valid_files(self, folder_path: str) -> List[str]:
        """Get all valid data files from folder"""
        valid_extensions = ('.mat', '.h5', '.hdf5')
        files = [f for f in os.listdir(folder_path) 
                if f.lower().endswith(valid_extensions)]
        return sorted(files)  # Sort for consistent ordering
    
    def _split_files(self, files: List[str]) -> Tuple[List[str], List[str]]:
        """Split files into train and test sets"""
        files_shuffled = files.copy()
        np.random.shuffle(files_shuffled)
        
        split_point = math.floor((1 - self.test_freq) * len(files_shuffled))
        train_files = files_shuffled[:split_point]
        test_files = files_shuffled[split_point:]
        
        return train_files, test_files
    
    def _normalize_image(self, image: np.ndarray) -> np.ndarray:
        """Normalize image to 0-255 range using MATLAB formula"""
        im1 = image.astype(np.float64)
        min_val, max_val = np.min(im1), np.max(im1)
        
        if max_val == min_val:
            return np.zeros_like(im1, dtype=np.uint8)
        
        im_normalized = 255.0 * (im1 - min_val) / (max_val - min_val)
        return im_normalized.astype(np.uint8)
    
    def _print_stats(self):
        """Print dataset statistics"""
        mode = "Training" if self.train else "Testing"
        print(f"\n=== {mode} Dataset Statistics ===")
        print(f"Total samples: {len(self.items)}")
        print(f"Test frequency: {self.test_freq}")
        
        if self.class_info:
            print("\nClass breakdown:")
            total_selected = sum(info['selected'] for info in self.class_info.values())
            
            for class_name, info in self.class_info.items():
                percentage = (info['selected'] / total_selected * 100) if total_selected > 0 else 0
                print(f"  {class_name}: {info['selected']} ({percentage:.1f}%) "
                      f"[Total: {info['total']}, Train: {info['train']}, Test: {info['test']}]")
        print("=" * 50)
    
    def get_class_distribution(self) -> Dict[str, int]:
        """Get class distribution in current dataset"""
        return {name: info['selected'] for name, info in self.class_info.items()}
    
    def __len__(self) -> int:
        return len(self.items)
    
    def __getitem__(self, idx: int) -> Dict:
        if not (0 <= idx < len(self.items)):
            raise IndexError(f"Index {idx} out of range [0, {len(self.items)})")
        
        file_path = os.path.join(self.root, self.items[idx])
        
        try:
            with h5py.File(file_path, 'r') as f:
                data = f['cjdata']
                
                raw_image = data['image'][:]
                mask = data['tumorMask'][:]
                label = int(data['label'][0][0])
                
                # Apply normalization if requested
                image = self._normalize_image(raw_image) if self.normalize_image else raw_image
                
                return {
                    "label": label,
                    "image": image,
                    "mask": mask,
                    "file_path": self.items[idx]
                }
        
        except Exception as e:
            raise RuntimeError(f"Error loading {file_path}: {str(e)}")


class BrainTumorDatasetMask(BrainTumorDataset):
    """Dataset that returns (image, mask) tuples for backward compatibility"""
    
    def __init__(self, root: str, train: bool = True, transform=None, **kwargs):
        super().__init__(root=root, train=train, **kwargs)
        self.transform = transform
    
    def __getitem__(self, idx: int) -> Union[Tuple[np.ndarray, np.ndarray], any]:
        metadata = super().__getitem__(idx)
        sample = (metadata["image"], metadata["mask"])
        
        return self.transform(*sample) if self.transform else sample

# %%
def inspect_sample(dataset: BrainTumorDataset, idx: int = 0):
    """Inspect a dataset sample"""
    if len(dataset) == 0:
        print("Dataset is empty!")
        return
    
    sample = dataset[idx]
    print(f"\n=== Sample {idx} Inspection ===")
    
    if isinstance(sample, dict):
        print(f"Label: {sample['label']}")
        print(f"Image shape: {sample['image'].shape}, dtype: {sample['image'].dtype}")
        print(f"Image range: [{sample['image'].min()}, {sample['image'].max()}]")
        print(f"Mask shape: {sample['mask'].shape}, dtype: {sample['mask'].dtype}")
        print(f"File: {sample['file_path']}")
    else:
        print(f"Sample type: {type(sample)}")
        if isinstance(sample, tuple) and len(sample) == 2:
            image, mask = sample
            print(f"Image shape: {image.shape}, dtype: {image.dtype}")
            print(f"Mask shape: {mask.shape}, dtype: {mask.dtype}")
    
    print("=" * 35)

# %%
dataset_mask = BrainTumorDatasetMask(root=config.ROOT, train=True, test_freq=0.2)
sample_mask = dataset_mask[0]  # Trả về (image, mask)
print(f"Mask dataset sample type: {type(sample_mask)}")

inspect_sample(dataset_mask, 0)
# Out:
# === Training Dataset Statistics ===
# Total samples: 2438
# Test frequency: 0.2
#
# Class breakdown:
#   Meningioma: 566 (23.2%) [Total: 708, Train: 566, Test: 142]
#   Glioma: 1140 (46.8%) [Total: 1426, Train: 1140, Test: 286]
#   Pituitary: 732 (30.0%) [Total: 915, Train: 732, Test: 183]
# ==================================================
# Mask dataset sample type: <class 'tuple'>
#
# === Sample 0 Inspection ===
# Sample type: <class 'tuple'>
# Image shape: (512, 512), dtype: uint8
# Mask shape: (512, 512), dtype: uint8
# ===================================

# %%
# Visualize function
def visualize(images, masks, original_images=None, original_masks=None):
    fontsize=18
    
    # Xử lý trường hợp input là single sample
    if not isinstance(images, (list, tuple)):
        images = [images]
        masks = [masks]
        if original_images is not None:
            original_images = [original_images]
        if original_masks is not None:
            original_masks = [original_masks]
    
    num_samples = len(images)
    
    if original_images is None and original_masks is None:
        # Hiển thị 2 hàng: hàng 1 là images, hàng 2 là masks
        f, ax = plt.subplots(2, num_samples, figsize=(4*num_samples, 8))
        
        # Nếu chỉ có 1 sample, ax sẽ là 1D array
        if num_samples == 1:
            ax = ax.reshape(2, 1)
        
        for i in range(num_samples):
            ax[0, i].imshow(images[i], cmap='gray')
            ax[0, i].set_title(f'Image {i+1}', fontsize=fontsize)
            ax[0, i].axis('off')
            
            ax[1, i].imshow(masks[i], cmap='gray')
            ax[1, i].set_title(f'Mask {i+1}', fontsize=fontsize)
            ax[1, i].axis('off')
    else:
        # Hiển thị 4 hàng: original images, original masks, transformed images, transformed masks
        f, ax = plt.subplots(4, num_samples, figsize=(4*num_samples, 16))
        
        # Nếu chỉ có 1 sample, ax sẽ là 1D array
        if num_samples == 1:
            ax = ax.reshape(4, 1)
        
        for i in range(num_samples):
            ax[0, i].imshow(original_images[i], cmap='gray')
            ax[0, i].set_title(f'Original Image {i+1}', fontsize=fontsize)
            ax[0, i].axis('off')
            
            ax[1, i].imshow(original_masks[i], cmap='gray')
            ax[1, i].set_title(f'Original Mask {i+1}', fontsize=fontsize)
            ax[1, i].axis('off')
            
            ax[2, i].imshow(images[i], cmap='gray')
            ax[2, i].set_title(f'Transformed Image {i+1}', fontsize=fontsize)
            ax[2, i].axis('off')
            
            ax[3, i].imshow(masks[i], cmap='gray')
            ax[3, i].set_title(f'Transformed Mask {i+1}', fontsize=fontsize)
            ax[3, i].axis('off')
    
    plt.tight_layout()
    plt.show()

# Ví dụ sử dụng với multiple samples
def visualize_multiple_samples(dataset, indices, with_preprocessing=True):
    """
    Hiển thị nhiều samples từ dataset
    
    Args:
        dataset: Dataset object
        indices: List các index muốn hiển thị
        with_preprocessing: Có hiển thị ảnh trước và sau preprocessing không
    """
    images = []
    masks = []
    original_images = []
    original_masks = []
    
    for idx in indices:
        if with_preprocessing and hasattr(dataset, 'transform') and dataset.transform is not None:
            # Lấy dữ liệu gốc (không preprocessing)
            dataset_temp = dataset.__class__(dataset.root, dataset.train, transform=None, classes=dataset.classes)
            orig_img, orig_mask = dataset_temp[idx]
            original_images.append(orig_img)
            original_masks.append(orig_mask)
            
            # Lấy dữ liệu đã preprocessing
            proc_img, proc_mask = dataset[idx]
            images.append(proc_img.squeeze() if hasattr(proc_img, 'squeeze') else proc_img)
            masks.append(proc_mask.squeeze() if hasattr(proc_mask, 'squeeze') else proc_mask)
        else:
            # Chỉ lấy dữ liệu hiện tại
            img, mask = dataset[idx]
            images.append(img.squeeze() if hasattr(img, 'squeeze') else img)
            masks.append(mask.squeeze() if hasattr(mask, 'squeeze') else mask)
    
    if with_preprocessing and original_images:
        visualize(images, masks, original_images, original_masks)
    else:
        visualize(images, masks)

# Hàm tiền xử lí dữ liệu
def preprocessing(image, mask):
    image_transformer = transforms.Compose([
        transforms.ToTensor(),
        transforms.Resize(config.IMG_SIZE, interpolation=0),
        # transforms.Normalize(mean=(0.5,), std=(0.5,))  # Normalize image
        ])
    mask_transformer = transforms.Compose([
        transforms.Lambda(lambda x: transforms.ToPILImage()(transforms.ToTensor()(x).float().squeeze())),
        transforms.ToTensor(),
        transforms.Resize(config.IMG_SIZE, interpolation=0),
    ])
    # image = np.transpose(np.array(image)) / 65535.0
    # image = image * 2 - 1
    image = np.transpose(np.array(image))
    mask = np.transpose(np.array(mask))
    mask = mask_transformer(mask)
    mask = mask / mask.max()
    mask = torch.where(mask > 0.5, 1, 0).float()
    return image_transformer(image).float(), mask

# %%
# Khởi tạo dataset
dataset = BrainTumorDatasetMask(root='/kaggle/input/brain-tumor-dataset/data/', train=True, transform=preprocessing)
original_image, original_mask = dataset[3]
print(f'#=>Original image: {type(original_image)}')
print(f'#=>Original mask: {type(original_mask)}')
# Out:
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
# #=>Original image: <class 'torch.Tensor'>
# #=>Original mask: <class 'torch.Tensor'>

# %%
visualize(original_image.squeeze(), original_mask.squeeze())

# %%
visualize_multiple_samples(dataset, [0, 1, 2, 3])
# Out:
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
#
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
#
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
#
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================

# %%
class Normalization(nn.Module):
    def __init__(self, num_features, normalization='batch'):
        super(Normalization, self).__init__()
        self.num_features = num_features
        
        if normalization is None:
            self.norm = nn.Identity()
        elif normalization.lower() == 'batch':
            self.norm = nn.BatchNorm2d(num_features)
        elif normalization.lower() == 'instance':
            self.norm = nn.InstanceNorm2d(num_features)
        else:
            raise ValueError("Invalid normalization type. Supported types are None, 'batch', 'instance'")
        
    def forward(self, x):
        return self.norm(x)
    
    
class SeparatedConv2dBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernal_size=3, normalization='batch'):
        super(SeparatedConv2dBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, (1, kernal_size), stride=1, padding='same'),
            nn.ReLU(),
            Normalization(out_channels, normalization),
            nn.Conv2d(out_channels, out_channels, (kernal_size, 1), stride=1, padding='same'),
            nn.ReLU(),
            Normalization(out_channels, normalization)
        )
        
    def forward(self, x):
        return self.block(x)
    
    
class MidScopeConv2dBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, normalization='batch'):
        super(MidScopeConv2dBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride=1, padding='same', dilation=1),
            nn.ReLU(),
            Normalization(out_channels, normalization),
            nn.Conv2d(out_channels, out_channels, kernel_size, stride=1, padding='same', dilation=2),
            nn.ReLU(),
            Normalization(out_channels, normalization)
        )
    
    def forward(self, x):
        return self.block(x)
    
    
class WideScopeConv2dBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, normalization='batch'):
        super(WideScopeConv2dBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride=1, padding='same', dilation=1),
            nn.ReLU(),
            Normalization(out_channels, normalization),
            nn.Conv2d(out_channels, out_channels, kernel_size, stride=1, padding='same', dilation=2),
            nn.ReLU(),
            Normalization(out_channels, normalization),
            nn.Conv2d(out_channels, out_channels, kernel_size, stride=1, padding='same', dilation=3),
            nn.ReLU(),
            Normalization(out_channels, normalization)
        )
        
    def forward(self, x):
        return self.block(x)
    
    
class ResnetConv2dBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, normalization='batch', multiplier=1.0):
        super(ResnetConv2dBlock, self).__init__()
        
        self.shortcut = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, padding='same', dilation=1),
            nn.ReLU(),
        )
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride=1, padding='same', dilation=1),
            nn.ReLU(),
            Normalization(out_channels, normalization),
            nn.Conv2d(out_channels, out_channels, kernel_size, stride=1, padding='same', dilation=1),
            nn.ReLU(),
            Normalization(out_channels, normalization)
        )
        self.norm = Normalization(out_channels, normalization)
        self.multiplier = multiplier
        
    def forward(self, x):
        x1 = self.block(x)
        x2 = self.shortcut(x)
        x = self.multiplier * (x1 + x2)
        return self.norm(x)
    
    
class DoubleConv2dBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, normalization='batch'):
        super(DoubleConv2dBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride=1, padding='same', dilation=1),
            nn.ReLU(),
            Normalization(out_channels, normalization),
            nn.Conv2d(out_channels, out_channels, kernel_size, stride=1, padding='same', dilation=1),
            nn.ReLU(),
            Normalization(out_channels, normalization)
        )
        
    def forward(self, x):
        return self.block(x)
    
    
class DuckConv2dBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, normalization='batch', duck_multiplier=1.0, residual_block_multiplier=1.0):
        super(DuckConv2dBlock, self).__init__()
        self.norm1 = Normalization(in_channels, normalization)
        
        self.wide_scope = WideScopeConv2dBlock(in_channels, out_channels, kernel_size=kernel_size, normalization=normalization)
        self.mid_scope = MidScopeConv2dBlock(in_channels, out_channels, kernel_size=kernel_size, normalization=normalization)
        self.residual_block_1 = ResnetConv2dBlock(in_channels, out_channels, kernel_size=kernel_size, normalization=normalization, multiplier=residual_block_multiplier)
        self.residual_block_2 = nn.Sequential(
            ResnetConv2dBlock(in_channels, out_channels, kernel_size=kernel_size, normalization=normalization, multiplier=residual_block_multiplier),
            ResnetConv2dBlock(out_channels, out_channels, kernel_size=kernel_size, normalization=normalization, multiplier=residual_block_multiplier)
        )
        self.residual_block_3 = nn.Sequential(
            ResnetConv2dBlock(in_channels, out_channels, kernel_size=kernel_size, normalization=normalization, multiplier=residual_block_multiplier),
            ResnetConv2dBlock(out_channels, out_channels, kernel_size=kernel_size, normalization=normalization, multiplier=residual_block_multiplier),
            ResnetConv2dBlock(out_channels, out_channels, kernel_size=kernel_size, normalization=normalization, multiplier=residual_block_multiplier)
        )
        self.separated_block = SeparatedConv2dBlock(in_channels, out_channels, kernal_size=kernel_size, normalization=normalization)
        
        self.norm2 = Normalization(out_channels, normalization)
        self.duck_multiplier = duck_multiplier
        
    def forward(self, x):
        x = self.norm1(x)
        
        x1 = self.wide_scope(x)
        x2 = self.mid_scope(x)
        x3 = self.residual_block_1(x)
        x4 = self.residual_block_2(x)
        x5 = self.residual_block_3(x)
        x6 = self.separated_block(x)
        
        x = self.duck_multiplier * (x1 + x2 + x3 + x4 + x5 + x6)
        return self.norm2(x)
    
    
class DuckNet(nn.Module):
    def __init__(self, in_channels, out_channels, depth=5, init_features=32, normalization='batch', interpolation='nearest', out_activation='sigmoid', use_multiplier=False):
        """DUCK-Net for 2D image segmentation.
        Args:
            in_channels (int): input channels of the image
            out_channels (int): output channels of the image
            depth (int): depth of the network. Defaults to 5.
            init_features (int): base number of features. Defaults to 32.
            normalization (str): normalization type ['batch','instance',None]. Defaults to 'batch'.
            interpolation (str): interpolation type, see nn.Upsample(). Defaults to 'nearest'.
            out_activation (str): output activation type ['sigmoid','softmax','relu',None]. Defaults to 'sigmoid'.
            use_multiplier (bool): use multiplier for numerical stability. Defaults to False.
        """
        super(DuckNet, self).__init__()
        
        duck_multiplier = 1.0
        residual_block_multiplier = 1.0
        self.addition_multiplier = 1.0
        
        if use_multiplier:
            duck_multiplier = 1 / 6.0
            residual_block_multiplier = 0.5
            self.addition_multiplier = 0.5
        
        self.depth = depth
        
        # Multi-scale blocks for input
        self.multi_scale_blocks = nn.ModuleList([nn.Conv2d(in_channels, init_features*2, kernel_size=2, stride=2, padding=0)])
        for d in range(1, depth):
            self.multi_scale_blocks.append(nn.Conv2d(init_features*(2**d), init_features*(2**(d+1)), kernel_size=2, stride=2, padding=0))
        
        # encoder downsampling blocks
        self.down_blocks = nn.ModuleList([nn.Conv2d(init_features, init_features*2, kernel_size=2, stride=2, padding=0)])
        for d in range(1, depth):
            self.down_blocks.append(nn.Conv2d(init_features*(2**d), init_features*(2**(d+1)), kernel_size=2, stride=2, padding=0))
            
        # encoder duck blocks
        self.encoder_duck_blocks = nn.ModuleList([DuckConv2dBlock(in_channels, init_features, normalization=normalization, duck_multiplier=duck_multiplier, residual_block_multiplier=residual_block_multiplier)])
        for d in range(1, depth):
            self.encoder_duck_blocks.append(DuckConv2dBlock(init_features*(2**d), init_features*(2**d), normalization=normalization, duck_multiplier=duck_multiplier, residual_block_multiplier=residual_block_multiplier))
            
        # bottleneck residual block
        self.bottleneck = nn.Sequential(
            ResnetConv2dBlock(init_features*(2**depth), init_features*(2**depth), kernel_size=3, normalization=normalization, multiplier=residual_block_multiplier),
            ResnetConv2dBlock(init_features*(2**depth), init_features*(2**depth), kernel_size=3, normalization=normalization, multiplier=residual_block_multiplier),
            ResnetConv2dBlock(init_features*(2**depth), init_features*(2**(depth-1)), kernel_size=3, normalization=normalization, multiplier=residual_block_multiplier),
            ResnetConv2dBlock(init_features*(2**(depth-1)), init_features*(2**(depth-1)), kernel_size=3, normalization=normalization, multiplier=residual_block_multiplier),
        )
        
        # decoder upsampling blocks
        self.up_blocks = nn.ModuleList([nn.Upsample(scale_factor=2, mode=interpolation)] * depth)
        
        # decoder duck blocks
        self.decoder_duck_blocks = nn.ModuleList([DuckConv2dBlock(init_features, init_features, normalization=normalization, duck_multiplier=duck_multiplier, residual_block_multiplier=residual_block_multiplier)])
        for d in range(1, depth):
            self.decoder_duck_blocks.append(DuckConv2dBlock(init_features*(2**d), init_features*(2**(d-1)), normalization=normalization, duck_multiplier=duck_multiplier, residual_block_multiplier=residual_block_multiplier))
            
        self.out = nn.Conv2d(init_features, out_channels, kernel_size=1, stride=1, padding='same')
        
        if out_activation is None:
            self.out_activation = nn.Identity()
        elif out_activation.lower() == 'sigmoid':
            self.out_activation = nn.Sigmoid()
        elif out_activation.lower() == 'softmax':
            self.out_activation = nn.Softmax(dim=1)
        elif out_activation.lower() == 'relu':
            self.out_activation = nn.ReLU()
        else:
            raise ValueError("Invalid out_activation type. Supported type. Supported types are 'sigmoid', 'softmax', 'relu' and None")
        
    def forward(self, x):
        
        # dowsample block for input
        p = [self.multi_scale_blocks[0](x),] # multi-resolution input
        for i in range(1, self.depth):
            xp = self.multi_scale_blocks[i](p[i-1])
            p.append(xp)
            
        # encoder
        t = []
        for d in range(self.depth):
            x = self.encoder_duck_blocks[d](x)
            t.append(x)
            x = self.down_blocks[d](x)
            x = self.addition_multiplier * (x + p[d])
        
        # bottleneck
        x = self.bottleneck(x)
        
        # decoder
        for d in range(self.depth-1, -1, -1):
            x = self.up_blocks[d](x)
            x = self.addition_multiplier * (x + t[d])
            x = self.decoder_duck_blocks[d](x)
            
        x = self.out(x)
        return self.out_activation(x)

# %%
class Trainer():
    def __init__(self,
                 model,
                 train_dataloader,
                 valid_dataloader,
                 epochs=10,
                 save_dir=None,
                 device='cpu',
                 accumalation_steps=4,
                 patience=5):  # Add patience for early stopping
        self.device = device
        self.accumalation_steps = accumalation_steps

        self.model = model.to(self.device)

        self.train_losses = []
        self.train_dice_coeff_values = []
        self.train_iou_values = []
        self.val_losses = []
        self.val_dice_coeff_values = []
        self.val_iou_values = []
        self.patience = patience  # Early stopping patience
        self.early_stop = False  # Flag for early stopping
        self.best_valid_loss = float('inf')  # Initialize best loss

        if save_dir != None and os.path.exists(save_dir):
            print("Load weight from file:{}".format(save_dir))
            self.save_dir = save_dir
            epcho_checkpoint_path = glob.glob("{}/model_epoch*".format(self.save_dir))
            if len(epcho_checkpoint_path) == 0:
                print("No checkpoint found in: {}\nCheck save_dir...".format(self.save_dir))
            else:
                self.load_checkpoint(epcho_checkpoint_path[0])
                print("Restore weight successful from: {}".format(epcho_checkpoint_path))
        else:
            self.save_dir = datetime.now().strftime("%d-%m-%Y_%H-%M-%S")
            os.makedirs(self.save_dir)
            print("Training new model, save to: {}".format(self.save_dir))

        self.train_dataloader = train_dataloader
        self.valid_dataloader = valid_dataloader
        self.epochs = epochs

    def save_checkpoint(self, save_path):
        state_dict = {'model_state_dict': self.model.state_dict(),
                      'train_losses': self.train_losses,
                      'train_dice_coeff_values': self.train_dice_coeff_values,
                      'train_iou_values': self.train_iou_values,
                      'val_losses': self.val_losses,
                      'val_dice_coeff_values': self.val_dice_coeff_values,
                      'val_iou_values': self.val_iou_values
                     }
        torch.save(state_dict, save_path)
        print(f"Model saved to ==> {save_path}")

    def load_checkpoint(self, load_path):
        state_dict = torch.load(load_path, map_location=self.device)
        print(f"Model restored from <== {load_path}")
        self.model.load_state_dict(state_dict["model_state_dict"])
        self.train_losses = state_dict["train_losses"]
        self.train_dice_coeff_values = state_dict["train_dice_coeff_values"]
        self.train_iou_values = state_dict['train_iou_values']
        self.val_losses = state_dict["val_losses"]
        self.val_dice_coeff_values = state_dict["val_dice_coeff_values"]
        self.val_iou_values = state_dict['val_iou_values']

    @staticmethod
    def iou(pred_mask, true_mask):
        # Làm phẳng các tensor
        pred_mask = pred_mask.view(-1)
        true_mask = true_mask.view(-1)
    
        # Tính toán phần giao nhau và hợp nhất
        intersection = torch.sum(pred_mask * true_mask)
        union = torch.sum(pred_mask) + torch.sum(true_mask) - intersection
    
        # Tính IoU
        iou = intersection / union
    
        return iou

    @staticmethod
    def dice_loss(pred, target, smooth=1e-6):
        pred = pred.view(-1)
        target = target.view(-1)
        
        # Flatten the tensors to calculate the intersection and union of predicted and true masks
        intersection = torch.sum(pred * target)
        union = torch.sum(pred) + torch.sum(target)
        
        # Compute Dice coefficient
        dice = (2. * intersection + smooth) / (union + smooth)
        
        return 1 - dice

    @staticmethod
    def dice_coeff(pred, target, smooth=1e-6, threshold=0.5):
        pred = pred.view(-1)
        target = target.view(-1)
        # pred = (pred > threshold).float()
        
        intersection = torch.sum(pred * target)
        union = torch.sum(pred) + torch.sum(target)
        return (2. * intersection + smooth) / (union + smooth)
    
    def train(self):
        if config.DICE_LOSS:
            criterion = self.dice_loss
        else:
            criterion = nn.BCELoss()
            
        optimizer = torch.optim.AdamW(self.model.parameters(), lr=config.LEARNING_RATE, weight_decay=config.WEIGHT_DECAY)
        scheduler = lr_scheduler.CosineAnnealingLR(optimizer, T_max=config.EPOCHS, eta_min=config.LEARNING_RATE_MIN)
        
        patience_counter = 0  # Track epochs without improvement
        for epoch_i in range(0, self.epochs):
            if self.early_stop:  # Check if early stopping is triggered
                print("Early stopping triggered. Training stopped.")
                break

            print('========== Epoch {:} / {:} =========='.format(epoch_i + 1, self.epochs))
            print('Training...')

            total_loss = 0
            self.model.train()
            nb_train_steps = 0
            train_iou = 0
            train_dice_coeff = 0

            for step, batch in enumerate(self.train_dataloader):
                img, mask = batch
                img, mask = img.to(self.device), mask.to(self.device)
                
                outputs = self.model(img)

                dice = self.dice_coeff(outputs.detach(), mask).item()
                train_dice_coeff += dice
                iou = self.iou(outputs.detach(), mask).item()
                train_iou += iou

                loss = criterion(outputs, mask) / self.accumalation_steps
                total_loss += loss.item() * self.accumalation_steps
                
                nb_train_steps += 1

                loss.backward()
                if (step + 1) % self.accumalation_steps == 0:
                    optimizer.step()
                    # scheduler.step()
                    optimizer.zero_grad()

                if (step + 1) % 10 == 0:
                    print("[TRAIN] Epoch {}/{} | Batch {}/{} | Loss={:.4f} | Dice_coeff={:.4f} | IoU={:.4f}".format(epoch_i + 1, self.epochs, step + 1, len(self.train_dataloader), loss.item(), dice, iou))

            scheduler.step()
            avg_train_loss = total_loss / len(self.train_dataloader)
            avg_train_dice_coeff = train_dice_coeff / nb_train_steps
            avg_train_iou = train_iou / nb_train_steps
            print(" Train Loss: {:.4f} | Avg_dice_coeff: {:.4f} | Avg_IoU: {:.4f}".format(avg_train_loss, avg_train_dice_coeff, avg_train_iou))

            self.train_losses.append(avg_train_loss)
            self.train_dice_coeff_values.append(avg_train_dice_coeff)
            self.train_iou_values.append(avg_train_iou)

            print("Running Validation...")
            self.model.eval()
            eval_loss = 0
            eval_iou = 0
            eval_dice_coeff = 0
            nb_eval_steps = 0

            for batch in self.valid_dataloader:
                img, mask = batch
                img, mask = img.to(self.device), mask.to(self.device)

                with torch.no_grad():
                    outputs = self.model(img)

                    loss = criterion(outputs, mask)       
                    eval_dice_coeff += self.dice_coeff(outputs.detach(), mask).item()
                    eval_iou += self.iou(outputs.detach(), mask).item()
                    eval_loss += loss.item()
                    nb_eval_steps += 1

            avg_val_loss = eval_loss / nb_eval_steps
            avg_val_dice_coeff = eval_dice_coeff / nb_eval_steps
            avg_val_iou = eval_iou / nb_eval_steps
            
            print(f" Valid Loss: {avg_val_loss:.4f} | Dice_coeff: {avg_val_dice_coeff:.4f} | IoU: {avg_val_iou:.4f}")

            self.val_losses.append(avg_val_loss)
            self.val_dice_coeff_values.append(avg_val_dice_coeff)
            self.val_iou_values.append(avg_val_iou)

            # Early stopping logic
            if avg_val_loss  < self.best_valid_loss:
                print(f"Validation loss improved from {self.best_valid_loss:.4f} to {avg_val_loss:.4f}. Saving model...")
                self.best_valid_loss = avg_val_loss
                patience_counter = 0  # Reset patience counter
                best_valid_loss_path = "{}/model_best_valloss.pt".format(self.save_dir)
                self.save_checkpoint(best_valid_loss_path)
            else:
                patience_counter += 1
                print(f"No improvement in validation loss for {patience_counter} epochs.")
                if patience_counter >= self.patience:
                    print(f"Stopping early after {patience_counter} epochs without improvement.")
                    self.early_stop = True

            # Save checkpoint for current epoch
            epoch_i_path = "{}/model_epoch{}.pt".format(self.save_dir, epoch_i)
            self.save_checkpoint(epoch_i_path)

            # Remove the previous epoch's checkpoint
            if os.path.exists("{}/model_epoch{}.pt".format(self.save_dir, epoch_i-1)):
                os.remove("{}/model_epoch{}.pt".format(self.save_dir, epoch_i-1))

        print("Training complete!")
        
    def eval(self, dataloader):
        self.model.eval()
        if config.DICE_LOSS:
            criterion = self.dice_loss
        else:
            criterion = nn.BCELoss()
        nb_eval_steps = 0
        eval_loss = 0
        eval_iou = 0
        eval_dice_coeff = 0
        for step, batch in enumerate(dataloader):
            img, mask = batch
            img, mask = img.to(self.device), mask.to(self.device)

            with torch.no_grad():
                outputs = self.model(img)

                loss = criterion(outputs, mask)
                
                eval_dice_coeff += self.dice_coeff(outputs.detach(), mask).item()
                eval_iou += self.iou(outputs.detach(), mask).item()
                eval_loss += loss.item()
                nb_eval_steps += 1
                
            if (step + 1) % 100 == 0:
                    print("[Test] Batch {}/{} | Test Loss={:.4f}".format(step + 1, len(dataloader), loss))
        avg_val_loss = eval_loss / nb_eval_steps
        avg_dice_coeff = eval_dice_coeff / nb_eval_steps
        avg_iou = eval_iou / nb_eval_steps
        
        print(f" Test Loss: {avg_val_loss:.4f} | Dice_coeff: {avg_dice_coeff:.4f} | IoU: {avg_iou:.4f}")
        return

    def visualize_scores(self):
        num_epoches = range(1, len(self.train_losses) + 1)
        # Vẽ Loss
        plt.figure(figsize=(12, 6))
        plt.plot(num_epoches, self.train_losses, label='Train Loss', marker='o', color='blue')
        plt.plot(num_epoches, self.val_losses, label='Test Loss', marker='o', color='orange')
        plt.title('Training and Testing Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        plt.grid(True)
        plt.show()
        
        # Vẽ Dice Coeff
        plt.figure(figsize=(12, 6))
        plt.plot(num_epoches, self.train_dice_coeff_values, label='Train Dice Coeff', marker='o', color='green')
        plt.plot(num_epoches, self.val_dice_coeff_values, label='Test Dice Coeff', marker='o', color='red')
        plt.title('Training and Testing Dice Coeff')
        plt.xlabel('Epochs')
        plt.ylabel('Dice Coeff')
        plt.legend()
        plt.grid(True)
        plt.show()

        # Vẽ IoU
        plt.figure(figsize=(12, 6))
        plt.plot(num_epoches, self.train_iou_values, label='Train IoU', marker='o', color='green')
        plt.plot(num_epoches, self.val_iou_values, label='Test IoU', marker='o', color='red')
        plt.title('Training and Testing IoU')
        plt.xlabel('Epochs')
        plt.ylabel('IoU')
        plt.legend()
        plt.grid(True)
        plt.show()

# %%
train_dataset = BrainTumorDatasetMask(root=config.ROOT, train=True, 
                                      test_freq=config.TEST_RATIO, transform=preprocessing)
valid_dataset = BrainTumorDatasetMask(root=config.ROOT, train=False, 
                                      test_freq=config.TEST_RATIO, transform=preprocessing)
print(f'Length of train dataset: {len(train_dataset)}')
print(f'Length of test dataset: {len(valid_dataset)}')

train_loader = DataLoader(dataset=train_dataset, batch_size=config.BATCH_SIZE, shuffle=True)
valid_loader = DataLoader(dataset=valid_dataset, batch_size=config.BATCH_SIZE, shuffle=False)
print(f'Length of train loader: {len(train_loader)}')
print(f'Length of test loader: {len(valid_loader)}')
# Out:
# === Training Dataset Statistics ===
# Total samples: 2438
# Test frequency: 0.2
#
# Class breakdown:
#   Meningioma: 566 (23.2%) [Total: 708, Train: 566, Test: 142]
#   Glioma: 1140 (46.8%) [Total: 1426, Train: 1140, Test: 286]
#   Pituitary: 732 (30.0%) [Total: 915, Train: 732, Test: 183]
# ==================================================
#
# === Testing Dataset Statistics ===
# Total samples: 611
# Test frequency: 0.2
#
# Class breakdown:
#   Meningioma: 142 (23.2%) [Total: 708, Train: 566, Test: 142]
#   Glioma: 286 (46.8%) [Total: 1426, Train: 1140, Test: 286]
#   Pituitary: 183 (30.0%) [Total: 915, Train: 732, Test: 183]
# ==================================================
# Length of train dataset: 2438
# Length of test dataset: 611
# Length of train loader: 153
# Length of test loader: 39

# %%
 def init_weights_with_kaiming_uniform(m):
        '''Initialize the weights of the model with kaiming uniform initialization.'''
        if type(m) == nn.Conv2d:
            torch.nn.init.kaiming_uniform_(m.weight)
            
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
model = DuckNet(in_channels=config.IN_CHANNELS, 
                out_channels=config.OUT_CLASSES, 
                depth=config.DEPTH, 
                init_features=config.INIT_FEATURES, 
                normalization=config.NORMALIZATION, 
                interpolation=config.INTERPOLATION, 
                out_activation=config.OUT_ACTIVATION, 
                use_multiplier=config.USE_MULTIPLIER).to(config.DEVICE)
model = nn.DataParallel(model)
model.apply(init_weights_with_kaiming_uniform) # default init is xaiver uniform
    
print("Number parameters:", count_parameters(model))
# Out:
# Number parameters: 38052259

# %%
trainer = Trainer(
    model=model,
    train_dataloader=train_loader,
    valid_dataloader=valid_loader,
    epochs=config.EPOCHS,
    save_dir=config.SAVE_DIR,
    device=config.DEVICE,
    accumalation_steps=config.ACCUMALATION_STEPS,
    patience = config.PATIENCE
)
# Out:
# Training new model, save to: 23-06-2025_09-55-35

# %%
# trainer.load_checkpoint('/kaggle/working/17-06-2025_08-00-35/model_epoch0.pt')

# %%
trainer.train()
# Out:
# ========== Epoch 1 / 130 ==========
# Training...
# [TRAIN] Epoch 1/130 | Batch 10/153 | Loss=0.9285 | Dice_coeff=0.0715 | IoU=0.0371
# [TRAIN] Epoch 1/130 | Batch 20/153 | Loss=0.9007 | Dice_coeff=0.0993 | IoU=0.0523
# [TRAIN] Epoch 1/130 | Batch 30/153 | Loss=0.8856 | Dice_coeff=0.1144 | IoU=0.0607
# [TRAIN] Epoch 1/130 | Batch 40/153 | Loss=0.8594 | Dice_coeff=0.1406 | IoU=0.0756
# [TRAIN] Epoch 1/130 | Batch 50/153 | Loss=0.8625 | Dice_coeff=0.1375 | IoU=0.0738
# [TRAIN] Epoch 1/130 | Batch 60/153 | Loss=0.8561 | Dice_coeff=0.1439 | IoU=0.0775
# [TRAIN] Epoch 1/130 | Batch 70/153 | Loss=0.8388 | Dice_coeff=0.1612 | IoU=0.0877
# [TRAIN] Epoch 1/130 | Batch 80/153 | Loss=0.8063 | Dice_coeff=0.1937 | IoU=0.1072
# [TRAIN] Epoch 1/130 | Batch 90/153 | Loss=0.8232 | Dice_coeff=0.1768 | IoU=0.0970
# [TRAIN] Epoch 1/130 | Batch 100/153 | Loss=0.7688 | Dice_coeff=0.2312 | IoU=0.1307
# [TRAIN] Epoch 1/130 | Batch 110/153 | Loss=0.7765 | Dice_coeff=0.2235 | IoU=0.1258
# [TRAIN] Epoch 1/130 | Batch 120/153 | Loss=0.7937 | Dice_coeff=0.2063 | IoU=0.1150
# [TRAIN] Epoch 1/130 | Batch 130/153 | Loss=0.7225 | Dice_coeff=0.2775 | IoU=0.1611
# [TRAIN] Epoch 1/130 | Batch 140/153 | Loss=0.7492 | Dice_coeff=0.2508 | IoU=0.1434
# [TRAIN] Epoch 1/130 | Batch 150/153 | Loss=0.7314 | Dice_coeff=0.2686 | IoU=0.1551
#  Train Loss: 0.8213 | Avg_dice_coeff: 0.1787 | Avg_IoU: 0.0998
# Running Validation...
#  Valid Loss: 0.8676 | Dice_coeff: 0.1324 | IoU: 0.0716
# Validation loss improved from inf to 0.8676. Saving model...
# Model saved to ==> 23-06-2025_09-55-35/model_best_valloss.pt
# Model saved to ==> 23-06-2025_09-55-35/model_epoch0.pt
# ========== Epoch 2 / 130 ==========
# Training...
# [TRAIN] Epoch 2/130 | Batch 10/153 | Loss=0.6637 | Dice_coeff=0.3363 | IoU=0.2022
# [TRAIN] Epoch 2/130 | Batch 20/153 | Loss=0.5051 | Dice_coeff=0.4949 | IoU=0.3288
# [TRAIN] Epoch 2/130 | Batch 30/153 | Loss=0.6337 | Dice_coeff=0.3663 | IoU=0.2242
# [TRAIN] Epoch 2/130 | Batch 40/153 | Loss=0.5163 | Dice_coeff=0.4837 | IoU=0.3190
# [TRAIN] Epoch 2/130 | Batch 50/153 | Loss=0.5841 | Dice_coeff=0.4159 | IoU=0.2626
# [TRAIN] Epoch 2/130 | Batch 60/153 | Loss=0.5699 | Dice_coeff=0.4301 | IoU=0.2740
# [TRAIN] Epoch 2/130 | Batch 70/153 | Loss=0.5470 | Dice_coeff=0.4530 | IoU=0.2929
# [TRAIN] Epoch 2/130 | Batch 80/153 | Loss=0.5683 | Dice_coeff=0.4317 | IoU=0.2752
# [TRAIN] Epoch 2/130 | Batch 90/153 | Loss=0.5110 | Dice_coeff=0.4890 | IoU=0.3236
# [TRAIN] Epoch 2/130 | Batch 100/153 | Loss=0.4211 | Dice_coeff=0.5789 | IoU=0.4073
# [TRAIN] Epoch 2/130 | Batch 110/153 | Loss=0.4715 | Dice_coeff=0.5285 | IoU=0.3592
# [TRAIN] Epoch 2/130 | Batch 120/153 | Loss=0.5715 | Dice_coeff=0.4285 | IoU=0.2727
# [TRAIN] Epoch 2/130 | Batch 130/153 | Loss=0.4661 | Dice_coeff=0.5339 | IoU=0.3642
# [TRAIN] Epoch 2/130 | Batch 140/153 | Loss=0.6451 | Dice_coeff=0.3549 | IoU=0.2157
# [TRAIN] Epoch 2/130 | Batch 150/153 | Loss=0.4414 | Dice_coeff=0.5586 | IoU=0.3875
#  Train Loss: 0.5581 | Avg_dice_coeff: 0.4419 | Avg_IoU: 0.2892
# Running Validation...
#  Valid Loss: 0.4158 | Dice_coeff: 0.5842 | IoU: 0.4333
# Validation loss improved from 0.8676 to 0.4158. Saving model...
# Model saved to ==> 23-06-2025_09-55-35/model_best_valloss.pt
# Model saved to ==> 23-06-2025_09-55-35/model_epoch1.pt
# ========== Epoch 3 / 130 ==========
# Training...
# [TRAIN] Epoch 3/130 | Batch 10/153 | Loss=0.4645 | Dice_coeff=0.5355 | IoU=0.3657
# [TRAIN] Epoch 3/130 | Batch 20/153 | Loss=0.5114 | Dice_coeff=0.4886 | IoU=0.3233
# [TRAIN] Epoch 3/130 | Batch 30/153 | Loss=0.3062 | Dice_coeff=0.6938 | IoU=0.5312
# [TRAIN] Epoch 3/130 | Batch 40/153 | Loss=0.4972 | Dice_coeff=0.5028 | IoU=0.3358
# [TRAIN] Epoch 3/130 | Batch 50/153 | Loss=0.5454 | Dice_coeff=0.4546 | IoU=0.2942
# [TRAIN] Epoch 3/130 | Batch 60/153 | Loss=0.3426 | Dice_coeff=0.6574 | IoU=0.4897
# [TRAIN] Epoch 3/130 | Batch 70/153 | Loss=0.4292 | Dice_coeff=0.5708 | IoU=0.3994
# [TRAIN] Epoch 3/130 | Batch 80/153 | Loss=0.4647 | Dice_coeff=0.5353 | IoU=0.3655
# [TRAIN] Epoch 3/130 | Batch 90/153 | Loss=0.3948 | Dice_coeff=0.6052 | IoU=0.4339
# [TRAIN] Epoch 3/130 | Batch 100/153 | Loss=0.4622 | Dice_coeff=0.5378 | IoU=0.3678
# [TRAIN] Epoch 3/130 | Batch 110/153 | Loss=0.4692 | Dice_coeff=0.5308 | IoU=0.3613
# [TRAIN] Epoch 3/130 | Batch 120/153 | Loss=0.3387 | Dice_coeff=0.6613 | IoU=0.4939
# [TRAIN] Epoch 3/130 | Batch 130/153 | Loss=0.4607 | Dice_coeff=0.5393 | IoU=0.3692
# [TRAIN] Epoch 3/130 | Batch 140/153 | Loss=0.3382 | Dice_coeff=0.6618 | IoU=0.4946
# [TRAIN] Epoch 3/130 | Batch 150/153 | Loss=0.2829 | Dice_coeff=0.7171 | IoU=0.5590
#  Train Loss: 0.4077 | Avg_dice_coeff: 0.5923 | Avg_IoU: 0.4260
# Running Validation...
#  Valid Loss: 0.4558 | Dice_coeff: 0.5442 | IoU: 0.3825
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch2.pt
# ========== Epoch 4 / 130 ==========
# Training...
# [TRAIN] Epoch 4/130 | Batch 10/153 | Loss=0.4291 | Dice_coeff=0.5709 | IoU=0.3995
# [TRAIN] Epoch 4/130 | Batch 20/153 | Loss=0.3685 | Dice_coeff=0.6315 | IoU=0.4615
# [TRAIN] Epoch 4/130 | Batch 30/153 | Loss=0.2858 | Dice_coeff=0.7142 | IoU=0.5555
# [TRAIN] Epoch 4/130 | Batch 40/153 | Loss=0.3563 | Dice_coeff=0.6437 | IoU=0.4746
# [TRAIN] Epoch 4/130 | Batch 50/153 | Loss=0.3451 | Dice_coeff=0.6549 | IoU=0.4869
# [TRAIN] Epoch 4/130 | Batch 60/153 | Loss=0.3203 | Dice_coeff=0.6797 | IoU=0.5148
# [TRAIN] Epoch 4/130 | Batch 70/153 | Loss=0.2116 | Dice_coeff=0.7884 | IoU=0.6508
# [TRAIN] Epoch 4/130 | Batch 80/153 | Loss=0.1753 | Dice_coeff=0.8247 | IoU=0.7016
# [TRAIN] Epoch 4/130 | Batch 90/153 | Loss=0.3248 | Dice_coeff=0.6752 | IoU=0.5096
# [TRAIN] Epoch 4/130 | Batch 100/153 | Loss=0.3580 | Dice_coeff=0.6420 | IoU=0.4727
# [TRAIN] Epoch 4/130 | Batch 110/153 | Loss=0.3338 | Dice_coeff=0.6662 | IoU=0.4995
# [TRAIN] Epoch 4/130 | Batch 120/153 | Loss=0.4504 | Dice_coeff=0.5496 | IoU=0.3789
# [TRAIN] Epoch 4/130 | Batch 130/153 | Loss=0.2789 | Dice_coeff=0.7211 | IoU=0.5639
# [TRAIN] Epoch 4/130 | Batch 140/153 | Loss=0.3022 | Dice_coeff=0.6978 | IoU=0.5358
# [TRAIN] Epoch 4/130 | Batch 150/153 | Loss=0.3941 | Dice_coeff=0.6059 | IoU=0.4346
#  Train Loss: 0.3433 | Avg_dice_coeff: 0.6567 | Avg_IoU: 0.4955
# Running Validation...
#  Valid Loss: 0.3121 | Dice_coeff: 0.6879 | IoU: 0.5378
# Validation loss improved from 0.4158 to 0.3121. Saving model...
# Model saved to ==> 23-06-2025_09-55-35/model_best_valloss.pt
# Model saved to ==> 23-06-2025_09-55-35/model_epoch3.pt
# ========== Epoch 5 / 130 ==========
# Training...
# [TRAIN] Epoch 5/130 | Batch 10/153 | Loss=0.1773 | Dice_coeff=0.8227 | IoU=0.6988
# [TRAIN] Epoch 5/130 | Batch 20/153 | Loss=0.3246 | Dice_coeff=0.6754 | IoU=0.5098
# [TRAIN] Epoch 5/130 | Batch 30/153 | Loss=0.3073 | Dice_coeff=0.6927 | IoU=0.5299
# [TRAIN] Epoch 5/130 | Batch 40/153 | Loss=0.2473 | Dice_coeff=0.7527 | IoU=0.6034
# [TRAIN] Epoch 5/130 | Batch 50/153 | Loss=0.3465 | Dice_coeff=0.6535 | IoU=0.4854
# [TRAIN] Epoch 5/130 | Batch 60/153 | Loss=0.4086 | Dice_coeff=0.5914 | IoU=0.4198
# [TRAIN] Epoch 5/130 | Batch 70/153 | Loss=0.3893 | Dice_coeff=0.6107 | IoU=0.4396
# [TRAIN] Epoch 5/130 | Batch 80/153 | Loss=0.3330 | Dice_coeff=0.6670 | IoU=0.5004
# [TRAIN] Epoch 5/130 | Batch 90/153 | Loss=0.2694 | Dice_coeff=0.7306 | IoU=0.5755
# [TRAIN] Epoch 5/130 | Batch 100/153 | Loss=0.3398 | Dice_coeff=0.6602 | IoU=0.4928
# [TRAIN] Epoch 5/130 | Batch 110/153 | Loss=0.2562 | Dice_coeff=0.7438 | IoU=0.5921
# [TRAIN] Epoch 5/130 | Batch 120/153 | Loss=0.3767 | Dice_coeff=0.6233 | IoU=0.4527
# [TRAIN] Epoch 5/130 | Batch 130/153 | Loss=0.2224 | Dice_coeff=0.7776 | IoU=0.6362
# [TRAIN] Epoch 5/130 | Batch 140/153 | Loss=0.3980 | Dice_coeff=0.6020 | IoU=0.4306
# [TRAIN] Epoch 5/130 | Batch 150/153 | Loss=0.2224 | Dice_coeff=0.7776 | IoU=0.6361
#  Train Loss: 0.3143 | Avg_dice_coeff: 0.6857 | Avg_IoU: 0.5271
# Running Validation...
#  Valid Loss: 0.3329 | Dice_coeff: 0.6671 | IoU: 0.5161
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch4.pt
# ========== Epoch 6 / 130 ==========
# Training...
# [TRAIN] Epoch 6/130 | Batch 10/153 | Loss=0.2910 | Dice_coeff=0.7090 | IoU=0.5492
# [TRAIN] Epoch 6/130 | Batch 20/153 | Loss=0.3316 | Dice_coeff=0.6684 | IoU=0.5019
# [TRAIN] Epoch 6/130 | Batch 30/153 | Loss=0.3325 | Dice_coeff=0.6675 | IoU=0.5009
# [TRAIN] Epoch 6/130 | Batch 40/153 | Loss=0.3682 | Dice_coeff=0.6318 | IoU=0.4618
# [TRAIN] Epoch 6/130 | Batch 50/153 | Loss=0.2639 | Dice_coeff=0.7361 | IoU=0.5824
# [TRAIN] Epoch 6/130 | Batch 60/153 | Loss=0.2318 | Dice_coeff=0.7682 | IoU=0.6236
# [TRAIN] Epoch 6/130 | Batch 70/153 | Loss=0.3248 | Dice_coeff=0.6752 | IoU=0.5097
# [TRAIN] Epoch 6/130 | Batch 80/153 | Loss=0.1522 | Dice_coeff=0.8478 | IoU=0.7358
# [TRAIN] Epoch 6/130 | Batch 90/153 | Loss=0.2753 | Dice_coeff=0.7247 | IoU=0.5683
# [TRAIN] Epoch 6/130 | Batch 100/153 | Loss=0.3492 | Dice_coeff=0.6508 | IoU=0.4823
# [TRAIN] Epoch 6/130 | Batch 110/153 | Loss=0.4677 | Dice_coeff=0.5323 | IoU=0.3627
# [TRAIN] Epoch 6/130 | Batch 120/153 | Loss=0.1955 | Dice_coeff=0.8045 | IoU=0.6730
# [TRAIN] Epoch 6/130 | Batch 130/153 | Loss=0.3023 | Dice_coeff=0.6977 | IoU=0.5358
# [TRAIN] Epoch 6/130 | Batch 140/153 | Loss=0.2837 | Dice_coeff=0.7163 | IoU=0.5580
# [TRAIN] Epoch 6/130 | Batch 150/153 | Loss=0.2548 | Dice_coeff=0.7452 | IoU=0.5939
#  Train Loss: 0.2986 | Avg_dice_coeff: 0.7014 | Avg_IoU: 0.5457
# Running Validation...
#  Valid Loss: 0.2798 | Dice_coeff: 0.7202 | IoU: 0.5806
# Validation loss improved from 0.3121 to 0.2798. Saving model...
# Model saved to ==> 23-06-2025_09-55-35/model_best_valloss.pt
# Model saved to ==> 23-06-2025_09-55-35/model_epoch5.pt
# ========== Epoch 7 / 130 ==========
# Training...
# [TRAIN] Epoch 7/130 | Batch 10/153 | Loss=0.2447 | Dice_coeff=0.7553 | IoU=0.6068
# [TRAIN] Epoch 7/130 | Batch 20/153 | Loss=0.2690 | Dice_coeff=0.7310 | IoU=0.5760
# [TRAIN] Epoch 7/130 | Batch 30/153 | Loss=0.5802 | Dice_coeff=0.4198 | IoU=0.2657
# [TRAIN] Epoch 7/130 | Batch 40/153 | Loss=0.2114 | Dice_coeff=0.7886 | IoU=0.6510
# [TRAIN] Epoch 7/130 | Batch 50/153 | Loss=0.2200 | Dice_coeff=0.7800 | IoU=0.6394
# [TRAIN] Epoch 7/130 | Batch 60/153 | Loss=0.3468 | Dice_coeff=0.6532 | IoU=0.4850
# [TRAIN] Epoch 7/130 | Batch 70/153 | Loss=0.1966 | Dice_coeff=0.8034 | IoU=0.6714
# [TRAIN] Epoch 7/130 | Batch 80/153 | Loss=0.2937 | Dice_coeff=0.7063 | IoU=0.5459
# [TRAIN] Epoch 7/130 | Batch 90/153 | Loss=0.4904 | Dice_coeff=0.5096 | IoU=0.3419
# [TRAIN] Epoch 7/130 | Batch 100/153 | Loss=0.2945 | Dice_coeff=0.7055 | IoU=0.5450
# [TRAIN] Epoch 7/130 | Batch 110/153 | Loss=0.1523 | Dice_coeff=0.8477 | IoU=0.7357
# [TRAIN] Epoch 7/130 | Batch 120/153 | Loss=0.2356 | Dice_coeff=0.7644 | IoU=0.6186
# [TRAIN] Epoch 7/130 | Batch 130/153 | Loss=0.3302 | Dice_coeff=0.6698 | IoU=0.5036
# [TRAIN] Epoch 7/130 | Batch 140/153 | Loss=0.1971 | Dice_coeff=0.8029 | IoU=0.6706
# [TRAIN] Epoch 7/130 | Batch 150/153 | Loss=0.1105 | Dice_coeff=0.8895 | IoU=0.8009
#  Train Loss: 0.2643 | Avg_dice_coeff: 0.7357 | Avg_IoU: 0.5870
# Running Validation...
#  Valid Loss: 0.3150 | Dice_coeff: 0.6850 | IoU: 0.5485
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch6.pt
# ========== Epoch 8 / 130 ==========
# Training...
# [TRAIN] Epoch 8/130 | Batch 10/153 | Loss=0.1789 | Dice_coeff=0.8211 | IoU=0.6965
# [TRAIN] Epoch 8/130 | Batch 20/153 | Loss=0.3592 | Dice_coeff=0.6408 | IoU=0.4714
# [TRAIN] Epoch 8/130 | Batch 30/153 | Loss=0.3809 | Dice_coeff=0.6191 | IoU=0.4484
# [TRAIN] Epoch 8/130 | Batch 40/153 | Loss=0.2862 | Dice_coeff=0.7138 | IoU=0.5549
# [TRAIN] Epoch 8/130 | Batch 50/153 | Loss=0.2554 | Dice_coeff=0.7446 | IoU=0.5931
# [TRAIN] Epoch 8/130 | Batch 60/153 | Loss=0.3327 | Dice_coeff=0.6673 | IoU=0.5008
# [TRAIN] Epoch 8/130 | Batch 70/153 | Loss=0.2506 | Dice_coeff=0.7494 | IoU=0.5992
# [TRAIN] Epoch 8/130 | Batch 80/153 | Loss=0.2051 | Dice_coeff=0.7949 | IoU=0.6596
# [TRAIN] Epoch 8/130 | Batch 90/153 | Loss=0.3488 | Dice_coeff=0.6512 | IoU=0.4827
# [TRAIN] Epoch 8/130 | Batch 100/153 | Loss=0.4004 | Dice_coeff=0.5996 | IoU=0.4282
# [TRAIN] Epoch 8/130 | Batch 110/153 | Loss=0.3580 | Dice_coeff=0.6420 | IoU=0.4728
# [TRAIN] Epoch 8/130 | Batch 120/153 | Loss=0.3263 | Dice_coeff=0.6737 | IoU=0.5079
# [TRAIN] Epoch 8/130 | Batch 130/153 | Loss=0.1952 | Dice_coeff=0.8048 | IoU=0.6734
# [TRAIN] Epoch 8/130 | Batch 140/153 | Loss=0.2832 | Dice_coeff=0.7168 | IoU=0.5586
# [TRAIN] Epoch 8/130 | Batch 150/153 | Loss=0.2767 | Dice_coeff=0.7233 | IoU=0.5666
#  Train Loss: 0.2727 | Avg_dice_coeff: 0.7273 | Avg_IoU: 0.5778
# Running Validation...
#  Valid Loss: 0.2423 | Dice_coeff: 0.7577 | IoU: 0.6218
# Validation loss improved from 0.2798 to 0.2423. Saving model...
# Model saved to ==> 23-06-2025_09-55-35/model_best_valloss.pt
# Model saved to ==> 23-06-2025_09-55-35/model_epoch7.pt
# ========== Epoch 9 / 130 ==========
# Training...
# [TRAIN] Epoch 9/130 | Batch 10/153 | Loss=0.2082 | Dice_coeff=0.7918 | IoU=0.6554
# [TRAIN] Epoch 9/130 | Batch 20/153 | Loss=0.2626 | Dice_coeff=0.7374 | IoU=0.5841
# [TRAIN] Epoch 9/130 | Batch 30/153 | Loss=0.2421 | Dice_coeff=0.7579 | IoU=0.6102
# [TRAIN] Epoch 9/130 | Batch 40/153 | Loss=0.3145 | Dice_coeff=0.6855 | IoU=0.5215
# [TRAIN] Epoch 9/130 | Batch 50/153 | Loss=0.1990 | Dice_coeff=0.8010 | IoU=0.6681
# [TRAIN] Epoch 9/130 | Batch 60/153 | Loss=0.2009 | Dice_coeff=0.7991 | IoU=0.6654
# [TRAIN] Epoch 9/130 | Batch 70/153 | Loss=0.1307 | Dice_coeff=0.8693 | IoU=0.7688
# [TRAIN] Epoch 9/130 | Batch 80/153 | Loss=0.1465 | Dice_coeff=0.8535 | IoU=0.7445
# [TRAIN] Epoch 9/130 | Batch 90/153 | Loss=0.1896 | Dice_coeff=0.8104 | IoU=0.6812
# [TRAIN] Epoch 9/130 | Batch 100/153 | Loss=0.3075 | Dice_coeff=0.6925 | IoU=0.5296
# [TRAIN] Epoch 9/130 | Batch 110/153 | Loss=0.2432 | Dice_coeff=0.7568 | IoU=0.6087
# [TRAIN] Epoch 9/130 | Batch 120/153 | Loss=0.1947 | Dice_coeff=0.8053 | IoU=0.6741
# [TRAIN] Epoch 9/130 | Batch 130/153 | Loss=0.2581 | Dice_coeff=0.7419 | IoU=0.5897
# [TRAIN] Epoch 9/130 | Batch 140/153 | Loss=0.1884 | Dice_coeff=0.8116 | IoU=0.6830
# [TRAIN] Epoch 9/130 | Batch 150/153 | Loss=0.2204 | Dice_coeff=0.7796 | IoU=0.6388
#  Train Loss: 0.2445 | Avg_dice_coeff: 0.7555 | Avg_IoU: 0.6113
# Running Validation...
#  Valid Loss: 0.2483 | Dice_coeff: 0.7517 | IoU: 0.6186
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch8.pt
# ========== Epoch 10 / 130 ==========
# Training...
# [TRAIN] Epoch 10/130 | Batch 10/153 | Loss=0.1881 | Dice_coeff=0.8119 | IoU=0.6833
# [TRAIN] Epoch 10/130 | Batch 20/153 | Loss=0.1682 | Dice_coeff=0.8318 | IoU=0.7121
# [TRAIN] Epoch 10/130 | Batch 30/153 | Loss=0.2425 | Dice_coeff=0.7575 | IoU=0.6097
# [TRAIN] Epoch 10/130 | Batch 40/153 | Loss=0.1988 | Dice_coeff=0.8012 | IoU=0.6683
# [TRAIN] Epoch 10/130 | Batch 50/153 | Loss=0.3793 | Dice_coeff=0.6207 | IoU=0.4500
# [TRAIN] Epoch 10/130 | Batch 60/153 | Loss=0.1916 | Dice_coeff=0.8084 | IoU=0.6785
# [TRAIN] Epoch 10/130 | Batch 70/153 | Loss=0.3195 | Dice_coeff=0.6805 | IoU=0.5157
# [TRAIN] Epoch 10/130 | Batch 80/153 | Loss=0.1455 | Dice_coeff=0.8545 | IoU=0.7460
# [TRAIN] Epoch 10/130 | Batch 90/153 | Loss=0.1507 | Dice_coeff=0.8493 | IoU=0.7381
# [TRAIN] Epoch 10/130 | Batch 100/153 | Loss=0.3088 | Dice_coeff=0.6912 | IoU=0.5281
# [TRAIN] Epoch 10/130 | Batch 110/153 | Loss=0.1733 | Dice_coeff=0.8267 | IoU=0.7045
# [TRAIN] Epoch 10/130 | Batch 120/153 | Loss=0.2170 | Dice_coeff=0.7830 | IoU=0.6434
# [TRAIN] Epoch 10/130 | Batch 130/153 | Loss=0.3268 | Dice_coeff=0.6732 | IoU=0.5073
# [TRAIN] Epoch 10/130 | Batch 140/153 | Loss=0.2222 | Dice_coeff=0.7778 | IoU=0.6363
# [TRAIN] Epoch 10/130 | Batch 150/153 | Loss=0.2400 | Dice_coeff=0.7600 | IoU=0.6129
#  Train Loss: 0.2234 | Avg_dice_coeff: 0.7766 | Avg_IoU: 0.6392
# Running Validation...
#  Valid Loss: 0.2384 | Dice_coeff: 0.7616 | IoU: 0.6268
# Validation loss improved from 0.2423 to 0.2384. Saving model...
# Model saved to ==> 23-06-2025_09-55-35/model_best_valloss.pt
# Model saved to ==> 23-06-2025_09-55-35/model_epoch9.pt
# ========== Epoch 11 / 130 ==========
# Training...
# [TRAIN] Epoch 11/130 | Batch 10/153 | Loss=0.2787 | Dice_coeff=0.7213 | IoU=0.5640
# [TRAIN] Epoch 11/130 | Batch 20/153 | Loss=0.1360 | Dice_coeff=0.8640 | IoU=0.7606
# [TRAIN] Epoch 11/130 | Batch 30/153 | Loss=0.1926 | Dice_coeff=0.8074 | IoU=0.6770
# [TRAIN] Epoch 11/130 | Batch 40/153 | Loss=0.1199 | Dice_coeff=0.8801 | IoU=0.7859
# [TRAIN] Epoch 11/130 | Batch 50/153 | Loss=0.3457 | Dice_coeff=0.6543 | IoU=0.4862
# [TRAIN] Epoch 11/130 | Batch 60/153 | Loss=0.2295 | Dice_coeff=0.7705 | IoU=0.6267
# [TRAIN] Epoch 11/130 | Batch 70/153 | Loss=0.2729 | Dice_coeff=0.7271 | IoU=0.5712
# [TRAIN] Epoch 11/130 | Batch 80/153 | Loss=0.2084 | Dice_coeff=0.7916 | IoU=0.6551
# [TRAIN] Epoch 11/130 | Batch 90/153 | Loss=0.2439 | Dice_coeff=0.7561 | IoU=0.6079
# [TRAIN] Epoch 11/130 | Batch 100/153 | Loss=0.2653 | Dice_coeff=0.7347 | IoU=0.5806
# [TRAIN] Epoch 11/130 | Batch 110/153 | Loss=0.1548 | Dice_coeff=0.8452 | IoU=0.7319
# [TRAIN] Epoch 11/130 | Batch 120/153 | Loss=0.2056 | Dice_coeff=0.7944 | IoU=0.6590
# [TRAIN] Epoch 11/130 | Batch 130/153 | Loss=0.2706 | Dice_coeff=0.7294 | IoU=0.5741
# [TRAIN] Epoch 11/130 | Batch 140/153 | Loss=0.2521 | Dice_coeff=0.7479 | IoU=0.5973
# [TRAIN] Epoch 11/130 | Batch 150/153 | Loss=0.1406 | Dice_coeff=0.8594 | IoU=0.7534
#  Train Loss: 0.2326 | Avg_dice_coeff: 0.7674 | Avg_IoU: 0.6274
# Running Validation...
#  Valid Loss: 0.3035 | Dice_coeff: 0.6965 | IoU: 0.5503
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch10.pt
# ========== Epoch 12 / 130 ==========
# Training...
# [TRAIN] Epoch 12/130 | Batch 10/153 | Loss=0.1524 | Dice_coeff=0.8476 | IoU=0.7356
# [TRAIN] Epoch 12/130 | Batch 20/153 | Loss=0.1753 | Dice_coeff=0.8247 | IoU=0.7017
# [TRAIN] Epoch 12/130 | Batch 30/153 | Loss=0.1749 | Dice_coeff=0.8251 | IoU=0.7023
# [TRAIN] Epoch 12/130 | Batch 40/153 | Loss=0.2143 | Dice_coeff=0.7857 | IoU=0.6470
# [TRAIN] Epoch 12/130 | Batch 50/153 | Loss=0.1429 | Dice_coeff=0.8571 | IoU=0.7499
# [TRAIN] Epoch 12/130 | Batch 60/153 | Loss=0.1853 | Dice_coeff=0.8147 | IoU=0.6873
# [TRAIN] Epoch 12/130 | Batch 70/153 | Loss=0.1921 | Dice_coeff=0.8079 | IoU=0.6777
# [TRAIN] Epoch 12/130 | Batch 80/153 | Loss=0.1597 | Dice_coeff=0.8403 | IoU=0.7245
# [TRAIN] Epoch 12/130 | Batch 90/153 | Loss=0.2525 | Dice_coeff=0.7475 | IoU=0.5968
# [TRAIN] Epoch 12/130 | Batch 100/153 | Loss=0.2038 | Dice_coeff=0.7962 | IoU=0.6614
# [TRAIN] Epoch 12/130 | Batch 110/153 | Loss=0.1530 | Dice_coeff=0.8470 | IoU=0.7346
# [TRAIN] Epoch 12/130 | Batch 120/153 | Loss=0.2433 | Dice_coeff=0.7567 | IoU=0.6086
# [TRAIN] Epoch 12/130 | Batch 130/153 | Loss=0.2125 | Dice_coeff=0.7875 | IoU=0.6494
# [TRAIN] Epoch 12/130 | Batch 140/153 | Loss=0.2375 | Dice_coeff=0.7625 | IoU=0.6161
# [TRAIN] Epoch 12/130 | Batch 150/153 | Loss=0.2185 | Dice_coeff=0.7815 | IoU=0.6413
#  Train Loss: 0.2107 | Avg_dice_coeff: 0.7893 | Avg_IoU: 0.6559
# Running Validation...
#  Valid Loss: 0.2251 | Dice_coeff: 0.7749 | IoU: 0.6432
# Validation loss improved from 0.2384 to 0.2251. Saving model...
# Model saved to ==> 23-06-2025_09-55-35/model_best_valloss.pt
# Model saved to ==> 23-06-2025_09-55-35/model_epoch11.pt
# ========== Epoch 13 / 130 ==========
# Training...
# [TRAIN] Epoch 13/130 | Batch 10/153 | Loss=0.1270 | Dice_coeff=0.8730 | IoU=0.7746
# [TRAIN] Epoch 13/130 | Batch 20/153 | Loss=0.3070 | Dice_coeff=0.6930 | IoU=0.5303
# [TRAIN] Epoch 13/130 | Batch 30/153 | Loss=0.1675 | Dice_coeff=0.8325 | IoU=0.7131
# [TRAIN] Epoch 13/130 | Batch 40/153 | Loss=0.3035 | Dice_coeff=0.6965 | IoU=0.5343
# [TRAIN] Epoch 13/130 | Batch 50/153 | Loss=0.2011 | Dice_coeff=0.7989 | IoU=0.6652
# [TRAIN] Epoch 13/130 | Batch 60/153 | Loss=0.2584 | Dice_coeff=0.7416 | IoU=0.5893
# [TRAIN] Epoch 13/130 | Batch 70/153 | Loss=0.3589 | Dice_coeff=0.6411 | IoU=0.4718
# [TRAIN] Epoch 13/130 | Batch 80/153 | Loss=0.2603 | Dice_coeff=0.7397 | IoU=0.5869
# [TRAIN] Epoch 13/130 | Batch 90/153 | Loss=0.2496 | Dice_coeff=0.7504 | IoU=0.6005
# [TRAIN] Epoch 13/130 | Batch 100/153 | Loss=0.2055 | Dice_coeff=0.7945 | IoU=0.6591
# [TRAIN] Epoch 13/130 | Batch 110/153 | Loss=0.3097 | Dice_coeff=0.6903 | IoU=0.5271
# [TRAIN] Epoch 13/130 | Batch 120/153 | Loss=0.1604 | Dice_coeff=0.8396 | IoU=0.7235
# [TRAIN] Epoch 13/130 | Batch 130/153 | Loss=0.1902 | Dice_coeff=0.8098 | IoU=0.6804
# [TRAIN] Epoch 13/130 | Batch 140/153 | Loss=0.1713 | Dice_coeff=0.8287 | IoU=0.7075
# [TRAIN] Epoch 13/130 | Batch 150/153 | Loss=0.1442 | Dice_coeff=0.8558 | IoU=0.7480
#  Train Loss: 0.2220 | Avg_dice_coeff: 0.7780 | Avg_IoU: 0.6413
# Running Validation...
#  Valid Loss: 0.2153 | Dice_coeff: 0.7847 | IoU: 0.6579
# Validation loss improved from 0.2251 to 0.2153. Saving model...
# Model saved to ==> 23-06-2025_09-55-35/model_best_valloss.pt
# Model saved to ==> 23-06-2025_09-55-35/model_epoch12.pt
# ========== Epoch 14 / 130 ==========
# Training...
# [TRAIN] Epoch 14/130 | Batch 10/153 | Loss=0.1411 | Dice_coeff=0.8589 | IoU=0.7526
# [TRAIN] Epoch 14/130 | Batch 20/153 | Loss=0.1776 | Dice_coeff=0.8224 | IoU=0.6984
# [TRAIN] Epoch 14/130 | Batch 30/153 | Loss=0.1169 | Dice_coeff=0.8831 | IoU=0.7906
# [TRAIN] Epoch 14/130 | Batch 40/153 | Loss=0.1385 | Dice_coeff=0.8615 | IoU=0.7567
# [TRAIN] Epoch 14/130 | Batch 50/153 | Loss=0.1995 | Dice_coeff=0.8005 | IoU=0.6674
# [TRAIN] Epoch 14/130 | Batch 60/153 | Loss=0.3639 | Dice_coeff=0.6361 | IoU=0.4664
# [TRAIN] Epoch 14/130 | Batch 70/153 | Loss=0.3291 | Dice_coeff=0.6709 | IoU=0.5047
# [TRAIN] Epoch 14/130 | Batch 80/153 | Loss=0.1777 | Dice_coeff=0.8223 | IoU=0.6983
# [TRAIN] Epoch 14/130 | Batch 90/153 | Loss=0.2748 | Dice_coeff=0.7252 | IoU=0.5689
# [TRAIN] Epoch 14/130 | Batch 100/153 | Loss=0.1999 | Dice_coeff=0.8001 | IoU=0.6668
# [TRAIN] Epoch 14/130 | Batch 110/153 | Loss=0.2382 | Dice_coeff=0.7618 | IoU=0.6153
# [TRAIN] Epoch 14/130 | Batch 120/153 | Loss=0.2413 | Dice_coeff=0.7587 | IoU=0.6112
# [TRAIN] Epoch 14/130 | Batch 130/153 | Loss=0.1714 | Dice_coeff=0.8286 | IoU=0.7074
# [TRAIN] Epoch 14/130 | Batch 140/153 | Loss=0.1784 | Dice_coeff=0.8216 | IoU=0.6973
# [TRAIN] Epoch 14/130 | Batch 150/153 | Loss=0.2311 | Dice_coeff=0.7689 | IoU=0.6246
#  Train Loss: 0.1948 | Avg_dice_coeff: 0.8052 | Avg_IoU: 0.6779
# Running Validation...
#  Valid Loss: 0.2199 | Dice_coeff: 0.7801 | IoU: 0.6548
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch13.pt
# ========== Epoch 15 / 130 ==========
# Training...
# [TRAIN] Epoch 15/130 | Batch 10/153 | Loss=0.1822 | Dice_coeff=0.8178 | IoU=0.6917
# [TRAIN] Epoch 15/130 | Batch 20/153 | Loss=0.1781 | Dice_coeff=0.8219 | IoU=0.6976
# [TRAIN] Epoch 15/130 | Batch 30/153 | Loss=0.2093 | Dice_coeff=0.7907 | IoU=0.6539
# [TRAIN] Epoch 15/130 | Batch 40/153 | Loss=0.1817 | Dice_coeff=0.8183 | IoU=0.6925
# [TRAIN] Epoch 15/130 | Batch 50/153 | Loss=0.1650 | Dice_coeff=0.8350 | IoU=0.7168
# [TRAIN] Epoch 15/130 | Batch 60/153 | Loss=0.1468 | Dice_coeff=0.8532 | IoU=0.7440
# [TRAIN] Epoch 15/130 | Batch 70/153 | Loss=0.1556 | Dice_coeff=0.8444 | IoU=0.7308
# [TRAIN] Epoch 15/130 | Batch 80/153 | Loss=0.1681 | Dice_coeff=0.8319 | IoU=0.7121
# [TRAIN] Epoch 15/130 | Batch 90/153 | Loss=0.2405 | Dice_coeff=0.7595 | IoU=0.6122
# [TRAIN] Epoch 15/130 | Batch 100/153 | Loss=0.0992 | Dice_coeff=0.9008 | IoU=0.8195
# [TRAIN] Epoch 15/130 | Batch 110/153 | Loss=0.1367 | Dice_coeff=0.8633 | IoU=0.7595
# [TRAIN] Epoch 15/130 | Batch 120/153 | Loss=0.1608 | Dice_coeff=0.8392 | IoU=0.7230
# [TRAIN] Epoch 15/130 | Batch 130/153 | Loss=0.1494 | Dice_coeff=0.8506 | IoU=0.7400
# [TRAIN] Epoch 15/130 | Batch 140/153 | Loss=0.1935 | Dice_coeff=0.8065 | IoU=0.6757
# [TRAIN] Epoch 15/130 | Batch 150/153 | Loss=0.2257 | Dice_coeff=0.7743 | IoU=0.6317
#  Train Loss: 0.1834 | Avg_dice_coeff: 0.8166 | Avg_IoU: 0.6933
# Running Validation...
#  Valid Loss: 0.2436 | Dice_coeff: 0.7564 | IoU: 0.6230
# No improvement in validation loss for 2 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch14.pt
# ========== Epoch 16 / 130 ==========
# Training...
# [TRAIN] Epoch 16/130 | Batch 10/153 | Loss=0.3454 | Dice_coeff=0.6546 | IoU=0.4865
# [TRAIN] Epoch 16/130 | Batch 20/153 | Loss=0.1674 | Dice_coeff=0.8326 | IoU=0.7132
# [TRAIN] Epoch 16/130 | Batch 30/153 | Loss=0.1454 | Dice_coeff=0.8546 | IoU=0.7461
# [TRAIN] Epoch 16/130 | Batch 40/153 | Loss=0.1634 | Dice_coeff=0.8366 | IoU=0.7190
# [TRAIN] Epoch 16/130 | Batch 50/153 | Loss=0.2663 | Dice_coeff=0.7337 | IoU=0.5794
# [TRAIN] Epoch 16/130 | Batch 60/153 | Loss=0.1472 | Dice_coeff=0.8528 | IoU=0.7434
# [TRAIN] Epoch 16/130 | Batch 70/153 | Loss=0.2011 | Dice_coeff=0.7989 | IoU=0.6652
# [TRAIN] Epoch 16/130 | Batch 80/153 | Loss=0.2294 | Dice_coeff=0.7706 | IoU=0.6268
# [TRAIN] Epoch 16/130 | Batch 90/153 | Loss=0.0974 | Dice_coeff=0.9026 | IoU=0.8226
# [TRAIN] Epoch 16/130 | Batch 100/153 | Loss=0.0943 | Dice_coeff=0.9057 | IoU=0.8277
# [TRAIN] Epoch 16/130 | Batch 110/153 | Loss=0.1566 | Dice_coeff=0.8434 | IoU=0.7292
# [TRAIN] Epoch 16/130 | Batch 120/153 | Loss=0.1210 | Dice_coeff=0.8790 | IoU=0.7841
# [TRAIN] Epoch 16/130 | Batch 130/153 | Loss=0.1712 | Dice_coeff=0.8288 | IoU=0.7076
# [TRAIN] Epoch 16/130 | Batch 140/153 | Loss=0.1143 | Dice_coeff=0.8857 | IoU=0.7949
# [TRAIN] Epoch 16/130 | Batch 150/153 | Loss=0.2163 | Dice_coeff=0.7837 | IoU=0.6443
#  Train Loss: 0.1823 | Avg_dice_coeff: 0.8177 | Avg_IoU: 0.6947
# Running Validation...
#  Valid Loss: 0.1921 | Dice_coeff: 0.8079 | IoU: 0.6876
# Validation loss improved from 0.2153 to 0.1921. Saving model...
# Model saved to ==> 23-06-2025_09-55-35/model_best_valloss.pt
# Model saved to ==> 23-06-2025_09-55-35/model_epoch15.pt
# ========== Epoch 17 / 130 ==========
# Training...
# [TRAIN] Epoch 17/130 | Batch 10/153 | Loss=0.1343 | Dice_coeff=0.8657 | IoU=0.7632
# [TRAIN] Epoch 17/130 | Batch 20/153 | Loss=0.2392 | Dice_coeff=0.7608 | IoU=0.6140
# [TRAIN] Epoch 17/130 | Batch 30/153 | Loss=0.1475 | Dice_coeff=0.8525 | IoU=0.7430
# [TRAIN] Epoch 17/130 | Batch 40/153 | Loss=0.2553 | Dice_coeff=0.7447 | IoU=0.5932
# [TRAIN] Epoch 17/130 | Batch 50/153 | Loss=0.1228 | Dice_coeff=0.8772 | IoU=0.7813
# [TRAIN] Epoch 17/130 | Batch 60/153 | Loss=0.1880 | Dice_coeff=0.8120 | IoU=0.6836
# [TRAIN] Epoch 17/130 | Batch 70/153 | Loss=0.1345 | Dice_coeff=0.8655 | IoU=0.7629
# [TRAIN] Epoch 17/130 | Batch 80/153 | Loss=0.2267 | Dice_coeff=0.7733 | IoU=0.6304
# [TRAIN] Epoch 17/130 | Batch 90/153 | Loss=0.1651 | Dice_coeff=0.8349 | IoU=0.7166
# [TRAIN] Epoch 17/130 | Batch 100/153 | Loss=0.2000 | Dice_coeff=0.8000 | IoU=0.6667
# [TRAIN] Epoch 17/130 | Batch 110/153 | Loss=0.1845 | Dice_coeff=0.8155 | IoU=0.6885
# [TRAIN] Epoch 17/130 | Batch 120/153 | Loss=0.2203 | Dice_coeff=0.7797 | IoU=0.6390
# [TRAIN] Epoch 17/130 | Batch 130/153 | Loss=0.1342 | Dice_coeff=0.8658 | IoU=0.7633
# [TRAIN] Epoch 17/130 | Batch 140/153 | Loss=0.1998 | Dice_coeff=0.8002 | IoU=0.6670
# [TRAIN] Epoch 17/130 | Batch 150/153 | Loss=0.1924 | Dice_coeff=0.8076 | IoU=0.6773
#  Train Loss: 0.1746 | Avg_dice_coeff: 0.8254 | Avg_IoU: 0.7051
# Running Validation...
#  Valid Loss: 0.1942 | Dice_coeff: 0.8058 | IoU: 0.6836
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch16.pt
# ========== Epoch 18 / 130 ==========
# Training...
# [TRAIN] Epoch 18/130 | Batch 10/153 | Loss=0.1460 | Dice_coeff=0.8540 | IoU=0.7451
# [TRAIN] Epoch 18/130 | Batch 20/153 | Loss=0.2725 | Dice_coeff=0.7275 | IoU=0.5717
# [TRAIN] Epoch 18/130 | Batch 30/153 | Loss=0.1982 | Dice_coeff=0.8018 | IoU=0.6692
# [TRAIN] Epoch 18/130 | Batch 40/153 | Loss=0.1633 | Dice_coeff=0.8367 | IoU=0.7193
# [TRAIN] Epoch 18/130 | Batch 50/153 | Loss=0.1617 | Dice_coeff=0.8383 | IoU=0.7216
# [TRAIN] Epoch 18/130 | Batch 60/153 | Loss=0.1480 | Dice_coeff=0.8520 | IoU=0.7422
# [TRAIN] Epoch 18/130 | Batch 70/153 | Loss=0.1187 | Dice_coeff=0.8813 | IoU=0.7877
# [TRAIN] Epoch 18/130 | Batch 80/153 | Loss=0.2767 | Dice_coeff=0.7233 | IoU=0.5665
# [TRAIN] Epoch 18/130 | Batch 90/153 | Loss=0.3362 | Dice_coeff=0.6638 | IoU=0.4968
# [TRAIN] Epoch 18/130 | Batch 100/153 | Loss=0.2230 | Dice_coeff=0.7770 | IoU=0.6354
# [TRAIN] Epoch 18/130 | Batch 110/153 | Loss=0.2048 | Dice_coeff=0.7952 | IoU=0.6600
# [TRAIN] Epoch 18/130 | Batch 120/153 | Loss=0.1334 | Dice_coeff=0.8666 | IoU=0.7646
# [TRAIN] Epoch 18/130 | Batch 130/153 | Loss=0.2635 | Dice_coeff=0.7365 | IoU=0.5830
# [TRAIN] Epoch 18/130 | Batch 140/153 | Loss=0.1196 | Dice_coeff=0.8804 | IoU=0.7864
# [TRAIN] Epoch 18/130 | Batch 150/153 | Loss=0.1212 | Dice_coeff=0.8788 | IoU=0.7838
#  Train Loss: 0.1880 | Avg_dice_coeff: 0.8120 | Avg_IoU: 0.6872
# Running Validation...
#  Valid Loss: 0.2146 | Dice_coeff: 0.7854 | IoU: 0.6612
# No improvement in validation loss for 2 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch17.pt
# ========== Epoch 19 / 130 ==========
# Training...
# [TRAIN] Epoch 19/130 | Batch 10/153 | Loss=0.2005 | Dice_coeff=0.7995 | IoU=0.6659
# [TRAIN] Epoch 19/130 | Batch 20/153 | Loss=0.2211 | Dice_coeff=0.7789 | IoU=0.6379
# [TRAIN] Epoch 19/130 | Batch 30/153 | Loss=0.2031 | Dice_coeff=0.7969 | IoU=0.6623
# [TRAIN] Epoch 19/130 | Batch 40/153 | Loss=0.1099 | Dice_coeff=0.8901 | IoU=0.8019
# [TRAIN] Epoch 19/130 | Batch 50/153 | Loss=0.2526 | Dice_coeff=0.7474 | IoU=0.5967
# [TRAIN] Epoch 19/130 | Batch 60/153 | Loss=0.4931 | Dice_coeff=0.5069 | IoU=0.3395
# [TRAIN] Epoch 19/130 | Batch 70/153 | Loss=0.2004 | Dice_coeff=0.7996 | IoU=0.6661
# [TRAIN] Epoch 19/130 | Batch 80/153 | Loss=0.1914 | Dice_coeff=0.8086 | IoU=0.6787
# [TRAIN] Epoch 19/130 | Batch 90/153 | Loss=0.1568 | Dice_coeff=0.8432 | IoU=0.7289
# [TRAIN] Epoch 19/130 | Batch 100/153 | Loss=0.2667 | Dice_coeff=0.7333 | IoU=0.5790
# [TRAIN] Epoch 19/130 | Batch 110/153 | Loss=0.2085 | Dice_coeff=0.7915 | IoU=0.6550
# [TRAIN] Epoch 19/130 | Batch 120/153 | Loss=0.1832 | Dice_coeff=0.8168 | IoU=0.6903
# [TRAIN] Epoch 19/130 | Batch 130/153 | Loss=0.1409 | Dice_coeff=0.8591 | IoU=0.7530
# [TRAIN] Epoch 19/130 | Batch 140/153 | Loss=0.1640 | Dice_coeff=0.8360 | IoU=0.7182
# [TRAIN] Epoch 19/130 | Batch 150/153 | Loss=0.1189 | Dice_coeff=0.8811 | IoU=0.7875
#  Train Loss: 0.1885 | Avg_dice_coeff: 0.8115 | Avg_IoU: 0.6868
# Running Validation...
#  Valid Loss: 0.2096 | Dice_coeff: 0.7904 | IoU: 0.6653
# No improvement in validation loss for 3 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch18.pt
# ========== Epoch 20 / 130 ==========
# Training...
# [TRAIN] Epoch 20/130 | Batch 10/153 | Loss=0.2335 | Dice_coeff=0.7665 | IoU=0.6214
# [TRAIN] Epoch 20/130 | Batch 20/153 | Loss=0.1179 | Dice_coeff=0.8821 | IoU=0.7890
# [TRAIN] Epoch 20/130 | Batch 30/153 | Loss=0.2281 | Dice_coeff=0.7719 | IoU=0.6286
# [TRAIN] Epoch 20/130 | Batch 40/153 | Loss=0.1654 | Dice_coeff=0.8346 | IoU=0.7161
# [TRAIN] Epoch 20/130 | Batch 50/153 | Loss=0.2175 | Dice_coeff=0.7825 | IoU=0.6427
# [TRAIN] Epoch 20/130 | Batch 60/153 | Loss=0.1347 | Dice_coeff=0.8653 | IoU=0.7625
# [TRAIN] Epoch 20/130 | Batch 70/153 | Loss=0.1026 | Dice_coeff=0.8974 | IoU=0.8139
# [TRAIN] Epoch 20/130 | Batch 80/153 | Loss=0.1131 | Dice_coeff=0.8869 | IoU=0.7968
# [TRAIN] Epoch 20/130 | Batch 90/153 | Loss=0.1846 | Dice_coeff=0.8154 | IoU=0.6883
# [TRAIN] Epoch 20/130 | Batch 100/153 | Loss=0.1476 | Dice_coeff=0.8524 | IoU=0.7427
# [TRAIN] Epoch 20/130 | Batch 110/153 | Loss=0.1391 | Dice_coeff=0.8609 | IoU=0.7558
# [TRAIN] Epoch 20/130 | Batch 120/153 | Loss=0.1471 | Dice_coeff=0.8529 | IoU=0.7435
# [TRAIN] Epoch 20/130 | Batch 130/153 | Loss=0.1975 | Dice_coeff=0.8025 | IoU=0.6702
# [TRAIN] Epoch 20/130 | Batch 140/153 | Loss=0.1652 | Dice_coeff=0.8348 | IoU=0.7164
# [TRAIN] Epoch 20/130 | Batch 150/153 | Loss=0.3094 | Dice_coeff=0.6906 | IoU=0.5274
#  Train Loss: 0.1671 | Avg_dice_coeff: 0.8329 | Avg_IoU: 0.7162
# Running Validation...
#  Valid Loss: 0.2018 | Dice_coeff: 0.7982 | IoU: 0.6798
# No improvement in validation loss for 4 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch19.pt
# ========== Epoch 21 / 130 ==========
# Training...
# [TRAIN] Epoch 21/130 | Batch 10/153 | Loss=0.1710 | Dice_coeff=0.8290 | IoU=0.7079
# [TRAIN] Epoch 21/130 | Batch 20/153 | Loss=0.1806 | Dice_coeff=0.8194 | IoU=0.6941
# [TRAIN] Epoch 21/130 | Batch 30/153 | Loss=0.1606 | Dice_coeff=0.8394 | IoU=0.7233
# [TRAIN] Epoch 21/130 | Batch 40/153 | Loss=0.1201 | Dice_coeff=0.8799 | IoU=0.7856
# [TRAIN] Epoch 21/130 | Batch 50/153 | Loss=0.1685 | Dice_coeff=0.8315 | IoU=0.7116
# [TRAIN] Epoch 21/130 | Batch 60/153 | Loss=0.1566 | Dice_coeff=0.8434 | IoU=0.7292
# [TRAIN] Epoch 21/130 | Batch 70/153 | Loss=0.1525 | Dice_coeff=0.8475 | IoU=0.7353
# [TRAIN] Epoch 21/130 | Batch 80/153 | Loss=0.2239 | Dice_coeff=0.7761 | IoU=0.6341
# [TRAIN] Epoch 21/130 | Batch 90/153 | Loss=0.1108 | Dice_coeff=0.8892 | IoU=0.8006
# [TRAIN] Epoch 21/130 | Batch 100/153 | Loss=0.1576 | Dice_coeff=0.8424 | IoU=0.7277
# [TRAIN] Epoch 21/130 | Batch 110/153 | Loss=0.1464 | Dice_coeff=0.8536 | IoU=0.7446
# [TRAIN] Epoch 21/130 | Batch 120/153 | Loss=0.1791 | Dice_coeff=0.8209 | IoU=0.6962
# [TRAIN] Epoch 21/130 | Batch 130/153 | Loss=0.1762 | Dice_coeff=0.8238 | IoU=0.7003
# [TRAIN] Epoch 21/130 | Batch 140/153 | Loss=0.1924 | Dice_coeff=0.8076 | IoU=0.6773
# [TRAIN] Epoch 21/130 | Batch 150/153 | Loss=0.1744 | Dice_coeff=0.8256 | IoU=0.7030
#  Train Loss: 0.1593 | Avg_dice_coeff: 0.8407 | Avg_IoU: 0.7276
# Running Validation...
#  Valid Loss: 0.1822 | Dice_coeff: 0.8178 | IoU: 0.7019
# Validation loss improved from 0.1921 to 0.1822. Saving model...
# Model saved to ==> 23-06-2025_09-55-35/model_best_valloss.pt
# Model saved to ==> 23-06-2025_09-55-35/model_epoch20.pt
# ========== Epoch 22 / 130 ==========
# Training...
# [TRAIN] Epoch 22/130 | Batch 10/153 | Loss=0.1193 | Dice_coeff=0.8807 | IoU=0.7869
# [TRAIN] Epoch 22/130 | Batch 20/153 | Loss=0.1651 | Dice_coeff=0.8349 | IoU=0.7166
# [TRAIN] Epoch 22/130 | Batch 30/153 | Loss=0.1226 | Dice_coeff=0.8774 | IoU=0.7815
# [TRAIN] Epoch 22/130 | Batch 40/153 | Loss=0.1179 | Dice_coeff=0.8821 | IoU=0.7890
# [TRAIN] Epoch 22/130 | Batch 50/153 | Loss=0.1258 | Dice_coeff=0.8742 | IoU=0.7765
# [TRAIN] Epoch 22/130 | Batch 60/153 | Loss=0.1702 | Dice_coeff=0.8298 | IoU=0.7091
# [TRAIN] Epoch 22/130 | Batch 70/153 | Loss=0.2247 | Dice_coeff=0.7753 | IoU=0.6331
# [TRAIN] Epoch 22/130 | Batch 80/153 | Loss=0.1973 | Dice_coeff=0.8027 | IoU=0.6705
# [TRAIN] Epoch 22/130 | Batch 90/153 | Loss=0.2054 | Dice_coeff=0.7946 | IoU=0.6592
# [TRAIN] Epoch 22/130 | Batch 100/153 | Loss=0.0949 | Dice_coeff=0.9051 | IoU=0.8267
# [TRAIN] Epoch 22/130 | Batch 110/153 | Loss=0.1897 | Dice_coeff=0.8103 | IoU=0.6811
# [TRAIN] Epoch 22/130 | Batch 120/153 | Loss=0.1069 | Dice_coeff=0.8931 | IoU=0.8069
# [TRAIN] Epoch 22/130 | Batch 130/153 | Loss=0.1586 | Dice_coeff=0.8414 | IoU=0.7262
# [TRAIN] Epoch 22/130 | Batch 140/153 | Loss=0.0816 | Dice_coeff=0.9184 | IoU=0.8492
# [TRAIN] Epoch 22/130 | Batch 150/153 | Loss=0.1921 | Dice_coeff=0.8079 | IoU=0.6777
#  Train Loss: 0.1529 | Avg_dice_coeff: 0.8471 | Avg_IoU: 0.7377
# Running Validation...
#  Valid Loss: 0.1895 | Dice_coeff: 0.8105 | IoU: 0.6927
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch21.pt
# ========== Epoch 23 / 130 ==========
# Training...
# [TRAIN] Epoch 23/130 | Batch 10/153 | Loss=0.1132 | Dice_coeff=0.8868 | IoU=0.7966
# [TRAIN] Epoch 23/130 | Batch 20/153 | Loss=0.1994 | Dice_coeff=0.8006 | IoU=0.6674
# [TRAIN] Epoch 23/130 | Batch 30/153 | Loss=0.1916 | Dice_coeff=0.8084 | IoU=0.6784
# [TRAIN] Epoch 23/130 | Batch 40/153 | Loss=0.1972 | Dice_coeff=0.8028 | IoU=0.6705
# [TRAIN] Epoch 23/130 | Batch 50/153 | Loss=0.1797 | Dice_coeff=0.8203 | IoU=0.6954
# [TRAIN] Epoch 23/130 | Batch 60/153 | Loss=0.2240 | Dice_coeff=0.7760 | IoU=0.6340
# [TRAIN] Epoch 23/130 | Batch 70/153 | Loss=0.2077 | Dice_coeff=0.7923 | IoU=0.6561
# [TRAIN] Epoch 23/130 | Batch 80/153 | Loss=0.1794 | Dice_coeff=0.8206 | IoU=0.6958
# [TRAIN] Epoch 23/130 | Batch 90/153 | Loss=0.0681 | Dice_coeff=0.9319 | IoU=0.8725
# [TRAIN] Epoch 23/130 | Batch 100/153 | Loss=0.1248 | Dice_coeff=0.8752 | IoU=0.7780
# [TRAIN] Epoch 23/130 | Batch 110/153 | Loss=0.1454 | Dice_coeff=0.8546 | IoU=0.7461
# [TRAIN] Epoch 23/130 | Batch 120/153 | Loss=0.1301 | Dice_coeff=0.8699 | IoU=0.7697
# [TRAIN] Epoch 23/130 | Batch 130/153 | Loss=0.1204 | Dice_coeff=0.8796 | IoU=0.7851
# [TRAIN] Epoch 23/130 | Batch 140/153 | Loss=0.1713 | Dice_coeff=0.8287 | IoU=0.7075
# [TRAIN] Epoch 23/130 | Batch 150/153 | Loss=0.1490 | Dice_coeff=0.8510 | IoU=0.7406
#  Train Loss: 0.1565 | Avg_dice_coeff: 0.8435 | Avg_IoU: 0.7326
# Running Validation...
#  Valid Loss: 0.1909 | Dice_coeff: 0.8091 | IoU: 0.6894
# No improvement in validation loss for 2 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch22.pt
# ========== Epoch 24 / 130 ==========
# Training...
# [TRAIN] Epoch 24/130 | Batch 10/153 | Loss=0.1263 | Dice_coeff=0.8737 | IoU=0.7758
# [TRAIN] Epoch 24/130 | Batch 20/153 | Loss=0.1236 | Dice_coeff=0.8764 | IoU=0.7801
# [TRAIN] Epoch 24/130 | Batch 30/153 | Loss=0.0813 | Dice_coeff=0.9187 | IoU=0.8497
# [TRAIN] Epoch 24/130 | Batch 40/153 | Loss=0.0938 | Dice_coeff=0.9062 | IoU=0.8285
# [TRAIN] Epoch 24/130 | Batch 50/153 | Loss=0.1784 | Dice_coeff=0.8216 | IoU=0.6973
# [TRAIN] Epoch 24/130 | Batch 60/153 | Loss=0.1393 | Dice_coeff=0.8607 | IoU=0.7555
# [TRAIN] Epoch 24/130 | Batch 70/153 | Loss=0.0898 | Dice_coeff=0.9102 | IoU=0.8351
# [TRAIN] Epoch 24/130 | Batch 80/153 | Loss=0.1719 | Dice_coeff=0.8281 | IoU=0.7066
# [TRAIN] Epoch 24/130 | Batch 90/153 | Loss=0.1508 | Dice_coeff=0.8492 | IoU=0.7379
# [TRAIN] Epoch 24/130 | Batch 100/153 | Loss=0.1621 | Dice_coeff=0.8379 | IoU=0.7210
# [TRAIN] Epoch 24/130 | Batch 110/153 | Loss=0.2018 | Dice_coeff=0.7982 | IoU=0.6642
# [TRAIN] Epoch 24/130 | Batch 120/153 | Loss=0.2951 | Dice_coeff=0.7049 | IoU=0.5443
# [TRAIN] Epoch 24/130 | Batch 130/153 | Loss=0.1060 | Dice_coeff=0.8940 | IoU=0.8083
# [TRAIN] Epoch 24/130 | Batch 140/153 | Loss=0.1749 | Dice_coeff=0.8251 | IoU=0.7023
# [TRAIN] Epoch 24/130 | Batch 150/153 | Loss=0.1442 | Dice_coeff=0.8558 | IoU=0.7479
#  Train Loss: 0.1544 | Avg_dice_coeff: 0.8456 | Avg_IoU: 0.7357
# Running Validation...
#  Valid Loss: 0.1948 | Dice_coeff: 0.8052 | IoU: 0.6843
# No improvement in validation loss for 3 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch23.pt
# ========== Epoch 25 / 130 ==========
# Training...
# [TRAIN] Epoch 25/130 | Batch 10/153 | Loss=0.2132 | Dice_coeff=0.7868 | IoU=0.6485
# [TRAIN] Epoch 25/130 | Batch 20/153 | Loss=0.1488 | Dice_coeff=0.8512 | IoU=0.7409
# [TRAIN] Epoch 25/130 | Batch 30/153 | Loss=0.1347 | Dice_coeff=0.8653 | IoU=0.7627
# [TRAIN] Epoch 25/130 | Batch 40/153 | Loss=0.1262 | Dice_coeff=0.8738 | IoU=0.7759
# [TRAIN] Epoch 25/130 | Batch 50/153 | Loss=0.1080 | Dice_coeff=0.8920 | IoU=0.8051
# [TRAIN] Epoch 25/130 | Batch 60/153 | Loss=0.0870 | Dice_coeff=0.9130 | IoU=0.8400
# [TRAIN] Epoch 25/130 | Batch 70/153 | Loss=0.1182 | Dice_coeff=0.8818 | IoU=0.7887
# [TRAIN] Epoch 25/130 | Batch 80/153 | Loss=0.1906 | Dice_coeff=0.8094 | IoU=0.6798
# [TRAIN] Epoch 25/130 | Batch 90/153 | Loss=0.1449 | Dice_coeff=0.8551 | IoU=0.7469
# [TRAIN] Epoch 25/130 | Batch 100/153 | Loss=0.1998 | Dice_coeff=0.8002 | IoU=0.6669
# [TRAIN] Epoch 25/130 | Batch 110/153 | Loss=0.1529 | Dice_coeff=0.8471 | IoU=0.7347
# [TRAIN] Epoch 25/130 | Batch 120/153 | Loss=0.1293 | Dice_coeff=0.8707 | IoU=0.7710
# [TRAIN] Epoch 25/130 | Batch 130/153 | Loss=0.1004 | Dice_coeff=0.8996 | IoU=0.8175
# [TRAIN] Epoch 25/130 | Batch 140/153 | Loss=0.1764 | Dice_coeff=0.8236 | IoU=0.7002
# [TRAIN] Epoch 25/130 | Batch 150/153 | Loss=0.2243 | Dice_coeff=0.7757 | IoU=0.6336
#  Train Loss: 0.1466 | Avg_dice_coeff: 0.8534 | Avg_IoU: 0.7472
# Running Validation...
#  Valid Loss: 0.1909 | Dice_coeff: 0.8091 | IoU: 0.6912
# No improvement in validation loss for 4 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch24.pt
# ========== Epoch 26 / 130 ==========
# Training...
# [TRAIN] Epoch 26/130 | Batch 10/153 | Loss=0.0668 | Dice_coeff=0.9332 | IoU=0.8748
# [TRAIN] Epoch 26/130 | Batch 20/153 | Loss=0.1652 | Dice_coeff=0.8348 | IoU=0.7164
# [TRAIN] Epoch 26/130 | Batch 30/153 | Loss=0.0895 | Dice_coeff=0.9105 | IoU=0.8357
# [TRAIN] Epoch 26/130 | Batch 40/153 | Loss=0.1066 | Dice_coeff=0.8934 | IoU=0.8073
# [TRAIN] Epoch 26/130 | Batch 50/153 | Loss=0.1383 | Dice_coeff=0.8617 | IoU=0.7570
# [TRAIN] Epoch 26/130 | Batch 60/153 | Loss=0.0992 | Dice_coeff=0.9008 | IoU=0.8195
# [TRAIN] Epoch 26/130 | Batch 70/153 | Loss=0.1021 | Dice_coeff=0.8979 | IoU=0.8147
# [TRAIN] Epoch 26/130 | Batch 80/153 | Loss=0.0865 | Dice_coeff=0.9135 | IoU=0.8408
# [TRAIN] Epoch 26/130 | Batch 90/153 | Loss=0.1576 | Dice_coeff=0.8424 | IoU=0.7277
# [TRAIN] Epoch 26/130 | Batch 100/153 | Loss=0.1221 | Dice_coeff=0.8779 | IoU=0.7824
# [TRAIN] Epoch 26/130 | Batch 110/153 | Loss=0.0667 | Dice_coeff=0.9333 | IoU=0.8750
# [TRAIN] Epoch 26/130 | Batch 120/153 | Loss=0.1225 | Dice_coeff=0.8775 | IoU=0.7818
# [TRAIN] Epoch 26/130 | Batch 130/153 | Loss=0.2114 | Dice_coeff=0.7886 | IoU=0.6509
# [TRAIN] Epoch 26/130 | Batch 140/153 | Loss=0.0850 | Dice_coeff=0.9150 | IoU=0.8433
# [TRAIN] Epoch 26/130 | Batch 150/153 | Loss=0.1425 | Dice_coeff=0.8575 | IoU=0.7505
#  Train Loss: 0.1347 | Avg_dice_coeff: 0.8653 | Avg_IoU: 0.7649
# Running Validation...
#  Valid Loss: 0.1792 | Dice_coeff: 0.8208 | IoU: 0.7045
# Validation loss improved from 0.1822 to 0.1792. Saving model...
# Model saved to ==> 23-06-2025_09-55-35/model_best_valloss.pt
# Model saved to ==> 23-06-2025_09-55-35/model_epoch25.pt
# ========== Epoch 27 / 130 ==========
# Training...
# [TRAIN] Epoch 27/130 | Batch 10/153 | Loss=0.1706 | Dice_coeff=0.8294 | IoU=0.7086
# [TRAIN] Epoch 27/130 | Batch 20/153 | Loss=0.1275 | Dice_coeff=0.8725 | IoU=0.7739
# [TRAIN] Epoch 27/130 | Batch 30/153 | Loss=0.0809 | Dice_coeff=0.9191 | IoU=0.8503
# [TRAIN] Epoch 27/130 | Batch 40/153 | Loss=0.1777 | Dice_coeff=0.8223 | IoU=0.6983
# [TRAIN] Epoch 27/130 | Batch 50/153 | Loss=0.1045 | Dice_coeff=0.8955 | IoU=0.8107
# [TRAIN] Epoch 27/130 | Batch 60/153 | Loss=0.1656 | Dice_coeff=0.8344 | IoU=0.7158
# [TRAIN] Epoch 27/130 | Batch 70/153 | Loss=0.1107 | Dice_coeff=0.8893 | IoU=0.8006
# [TRAIN] Epoch 27/130 | Batch 80/153 | Loss=0.1004 | Dice_coeff=0.8996 | IoU=0.8175
# [TRAIN] Epoch 27/130 | Batch 90/153 | Loss=0.1682 | Dice_coeff=0.8318 | IoU=0.7120
# [TRAIN] Epoch 27/130 | Batch 100/153 | Loss=0.1846 | Dice_coeff=0.8154 | IoU=0.6883
# [TRAIN] Epoch 27/130 | Batch 110/153 | Loss=0.1132 | Dice_coeff=0.8868 | IoU=0.7966
# [TRAIN] Epoch 27/130 | Batch 120/153 | Loss=0.1246 | Dice_coeff=0.8754 | IoU=0.7784
# [TRAIN] Epoch 27/130 | Batch 130/153 | Loss=0.1316 | Dice_coeff=0.8684 | IoU=0.7673
# [TRAIN] Epoch 27/130 | Batch 140/153 | Loss=0.0724 | Dice_coeff=0.9276 | IoU=0.8649
# [TRAIN] Epoch 27/130 | Batch 150/153 | Loss=0.1121 | Dice_coeff=0.8879 | IoU=0.7984
#  Train Loss: 0.1369 | Avg_dice_coeff: 0.8631 | Avg_IoU: 0.7612
# Running Validation...
#  Valid Loss: 0.2076 | Dice_coeff: 0.7924 | IoU: 0.6660
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch26.pt
# ========== Epoch 28 / 130 ==========
# Training...
# [TRAIN] Epoch 28/130 | Batch 10/153 | Loss=0.1061 | Dice_coeff=0.8939 | IoU=0.8082
# [TRAIN] Epoch 28/130 | Batch 20/153 | Loss=0.1051 | Dice_coeff=0.8949 | IoU=0.8098
# [TRAIN] Epoch 28/130 | Batch 30/153 | Loss=0.1733 | Dice_coeff=0.8267 | IoU=0.7045
# [TRAIN] Epoch 28/130 | Batch 40/153 | Loss=0.1044 | Dice_coeff=0.8956 | IoU=0.8109
# [TRAIN] Epoch 28/130 | Batch 50/153 | Loss=0.1100 | Dice_coeff=0.8900 | IoU=0.8018
# [TRAIN] Epoch 28/130 | Batch 60/153 | Loss=0.1722 | Dice_coeff=0.8278 | IoU=0.7062
# [TRAIN] Epoch 28/130 | Batch 70/153 | Loss=0.0637 | Dice_coeff=0.9363 | IoU=0.8803
# [TRAIN] Epoch 28/130 | Batch 80/153 | Loss=0.1327 | Dice_coeff=0.8673 | IoU=0.7657
# [TRAIN] Epoch 28/130 | Batch 90/153 | Loss=0.2193 | Dice_coeff=0.7807 | IoU=0.6403
# [TRAIN] Epoch 28/130 | Batch 100/153 | Loss=0.1209 | Dice_coeff=0.8791 | IoU=0.7843
# [TRAIN] Epoch 28/130 | Batch 110/153 | Loss=0.0965 | Dice_coeff=0.9035 | IoU=0.8240
# [TRAIN] Epoch 28/130 | Batch 120/153 | Loss=0.1301 | Dice_coeff=0.8699 | IoU=0.7697
# [TRAIN] Epoch 28/130 | Batch 130/153 | Loss=0.1513 | Dice_coeff=0.8487 | IoU=0.7372
# [TRAIN] Epoch 28/130 | Batch 140/153 | Loss=0.1827 | Dice_coeff=0.8173 | IoU=0.6910
# [TRAIN] Epoch 28/130 | Batch 150/153 | Loss=0.1351 | Dice_coeff=0.8649 | IoU=0.7620
#  Train Loss: 0.1395 | Avg_dice_coeff: 0.8605 | Avg_IoU: 0.7578
# Running Validation...
#  Valid Loss: 0.1844 | Dice_coeff: 0.8156 | IoU: 0.6954
# No improvement in validation loss for 2 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch27.pt
# ========== Epoch 29 / 130 ==========
# Training...
# [TRAIN] Epoch 29/130 | Batch 10/153 | Loss=0.2017 | Dice_coeff=0.7983 | IoU=0.6644
# [TRAIN] Epoch 29/130 | Batch 20/153 | Loss=0.1208 | Dice_coeff=0.8792 | IoU=0.7844
# [TRAIN] Epoch 29/130 | Batch 30/153 | Loss=0.1690 | Dice_coeff=0.8310 | IoU=0.7109
# [TRAIN] Epoch 29/130 | Batch 40/153 | Loss=0.1380 | Dice_coeff=0.8620 | IoU=0.7575
# [TRAIN] Epoch 29/130 | Batch 50/153 | Loss=0.1080 | Dice_coeff=0.8920 | IoU=0.8051
# [TRAIN] Epoch 29/130 | Batch 60/153 | Loss=0.1405 | Dice_coeff=0.8595 | IoU=0.7536
# [TRAIN] Epoch 29/130 | Batch 70/153 | Loss=0.2034 | Dice_coeff=0.7966 | IoU=0.6619
# [TRAIN] Epoch 29/130 | Batch 80/153 | Loss=0.2145 | Dice_coeff=0.7855 | IoU=0.6467
# [TRAIN] Epoch 29/130 | Batch 90/153 | Loss=0.1588 | Dice_coeff=0.8412 | IoU=0.7259
# [TRAIN] Epoch 29/130 | Batch 100/153 | Loss=0.1490 | Dice_coeff=0.8510 | IoU=0.7406
# [TRAIN] Epoch 29/130 | Batch 110/153 | Loss=0.2443 | Dice_coeff=0.7557 | IoU=0.6073
# [TRAIN] Epoch 29/130 | Batch 120/153 | Loss=0.1497 | Dice_coeff=0.8503 | IoU=0.7396
# [TRAIN] Epoch 29/130 | Batch 130/153 | Loss=0.2791 | Dice_coeff=0.7209 | IoU=0.5636
# [TRAIN] Epoch 29/130 | Batch 140/153 | Loss=0.0779 | Dice_coeff=0.9221 | IoU=0.8555
# [TRAIN] Epoch 29/130 | Batch 150/153 | Loss=0.1208 | Dice_coeff=0.8792 | IoU=0.7844
#  Train Loss: 0.1590 | Avg_dice_coeff: 0.8410 | Avg_IoU: 0.7291
# Running Validation...
#  Valid Loss: 0.1967 | Dice_coeff: 0.8033 | IoU: 0.6810
# No improvement in validation loss for 3 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch28.pt
# ========== Epoch 30 / 130 ==========
# Training...
# [TRAIN] Epoch 30/130 | Batch 10/153 | Loss=0.1594 | Dice_coeff=0.8406 | IoU=0.7250
# [TRAIN] Epoch 30/130 | Batch 20/153 | Loss=0.1605 | Dice_coeff=0.8395 | IoU=0.7234
# [TRAIN] Epoch 30/130 | Batch 30/153 | Loss=0.1838 | Dice_coeff=0.8162 | IoU=0.6895
# [TRAIN] Epoch 30/130 | Batch 40/153 | Loss=0.1661 | Dice_coeff=0.8339 | IoU=0.7151
# [TRAIN] Epoch 30/130 | Batch 50/153 | Loss=0.1806 | Dice_coeff=0.8194 | IoU=0.6941
# [TRAIN] Epoch 30/130 | Batch 60/153 | Loss=0.2006 | Dice_coeff=0.7994 | IoU=0.6659
# [TRAIN] Epoch 30/130 | Batch 70/153 | Loss=0.1694 | Dice_coeff=0.8306 | IoU=0.7103
# [TRAIN] Epoch 30/130 | Batch 80/153 | Loss=0.1771 | Dice_coeff=0.8229 | IoU=0.6990
# [TRAIN] Epoch 30/130 | Batch 90/153 | Loss=0.1819 | Dice_coeff=0.8181 | IoU=0.6922
# [TRAIN] Epoch 30/130 | Batch 100/153 | Loss=0.1423 | Dice_coeff=0.8577 | IoU=0.7508
# [TRAIN] Epoch 30/130 | Batch 110/153 | Loss=0.1784 | Dice_coeff=0.8216 | IoU=0.6972
# [TRAIN] Epoch 30/130 | Batch 120/153 | Loss=0.0704 | Dice_coeff=0.9296 | IoU=0.8685
# [TRAIN] Epoch 30/130 | Batch 130/153 | Loss=0.1660 | Dice_coeff=0.8340 | IoU=0.7153
# [TRAIN] Epoch 30/130 | Batch 140/153 | Loss=0.1794 | Dice_coeff=0.8206 | IoU=0.6957
# [TRAIN] Epoch 30/130 | Batch 150/153 | Loss=0.1430 | Dice_coeff=0.8570 | IoU=0.7497
#  Train Loss: 0.1537 | Avg_dice_coeff: 0.8463 | Avg_IoU: 0.7358
# Running Validation...
#  Valid Loss: 0.1809 | Dice_coeff: 0.8191 | IoU: 0.7020
# No improvement in validation loss for 4 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch29.pt
# ========== Epoch 31 / 130 ==========
# Training...
# [TRAIN] Epoch 31/130 | Batch 10/153 | Loss=0.1461 | Dice_coeff=0.8539 | IoU=0.7450
# [TRAIN] Epoch 31/130 | Batch 20/153 | Loss=0.1712 | Dice_coeff=0.8288 | IoU=0.7076
# [TRAIN] Epoch 31/130 | Batch 30/153 | Loss=0.1524 | Dice_coeff=0.8476 | IoU=0.7355
# [TRAIN] Epoch 31/130 | Batch 40/153 | Loss=0.1242 | Dice_coeff=0.8758 | IoU=0.7791
# [TRAIN] Epoch 31/130 | Batch 50/153 | Loss=0.1122 | Dice_coeff=0.8878 | IoU=0.7983
# [TRAIN] Epoch 31/130 | Batch 60/153 | Loss=0.1653 | Dice_coeff=0.8347 | IoU=0.7164
# [TRAIN] Epoch 31/130 | Batch 70/153 | Loss=0.1199 | Dice_coeff=0.8801 | IoU=0.7859
# [TRAIN] Epoch 31/130 | Batch 80/153 | Loss=0.1275 | Dice_coeff=0.8725 | IoU=0.7738
# [TRAIN] Epoch 31/130 | Batch 90/153 | Loss=0.1482 | Dice_coeff=0.8518 | IoU=0.7419
# [TRAIN] Epoch 31/130 | Batch 100/153 | Loss=0.1547 | Dice_coeff=0.8453 | IoU=0.7321
# [TRAIN] Epoch 31/130 | Batch 110/153 | Loss=0.1092 | Dice_coeff=0.8908 | IoU=0.8030
# ...
# [TRAIN] Epoch 120/130 | Batch 150/153 | Loss=0.0263 | Dice_coeff=0.9737 | IoU=0.9488
#  Train Loss: 0.0257 | Avg_dice_coeff: 0.9743 | Avg_IoU: 0.9502
# Running Validation...
#  Valid Loss: 0.1486 | Dice_coeff: 0.8514 | IoU: 0.7470
# No improvement in validation loss for 36 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch119.pt
# ========== Epoch 121 / 130 ==========
# Training...
# [TRAIN] Epoch 121/130 | Batch 10/153 | Loss=0.0200 | Dice_coeff=0.9800 | IoU=0.9607
# [TRAIN] Epoch 121/130 | Batch 20/153 | Loss=0.0321 | Dice_coeff=0.9679 | IoU=0.9378
# [TRAIN] Epoch 121/130 | Batch 30/153 | Loss=0.0194 | Dice_coeff=0.9806 | IoU=0.9619
# [TRAIN] Epoch 121/130 | Batch 40/153 | Loss=0.0269 | Dice_coeff=0.9731 | IoU=0.9476
# [TRAIN] Epoch 121/130 | Batch 50/153 | Loss=0.0218 | Dice_coeff=0.9782 | IoU=0.9573
# [TRAIN] Epoch 121/130 | Batch 60/153 | Loss=0.0260 | Dice_coeff=0.9740 | IoU=0.9492
# [TRAIN] Epoch 121/130 | Batch 70/153 | Loss=0.0227 | Dice_coeff=0.9773 | IoU=0.9555
# [TRAIN] Epoch 121/130 | Batch 80/153 | Loss=0.0222 | Dice_coeff=0.9778 | IoU=0.9565
# [TRAIN] Epoch 121/130 | Batch 90/153 | Loss=0.0272 | Dice_coeff=0.9728 | IoU=0.9470
# [TRAIN] Epoch 121/130 | Batch 100/153 | Loss=0.0431 | Dice_coeff=0.9569 | IoU=0.9173
# [TRAIN] Epoch 121/130 | Batch 110/153 | Loss=0.0532 | Dice_coeff=0.9468 | IoU=0.8990
# [TRAIN] Epoch 121/130 | Batch 120/153 | Loss=0.0300 | Dice_coeff=0.9700 | IoU=0.9418
# [TRAIN] Epoch 121/130 | Batch 130/153 | Loss=0.0454 | Dice_coeff=0.9546 | IoU=0.9132
# [TRAIN] Epoch 121/130 | Batch 140/153 | Loss=0.0266 | Dice_coeff=0.9734 | IoU=0.9482
# [TRAIN] Epoch 121/130 | Batch 150/153 | Loss=0.0324 | Dice_coeff=0.9676 | IoU=0.9372
#  Train Loss: 0.0254 | Avg_dice_coeff: 0.9746 | Avg_IoU: 0.9506
# Running Validation...
#  Valid Loss: 0.1493 | Dice_coeff: 0.8507 | IoU: 0.7458
# No improvement in validation loss for 37 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch120.pt
# ========== Epoch 122 / 130 ==========
# Training...
# [TRAIN] Epoch 122/130 | Batch 10/153 | Loss=0.0363 | Dice_coeff=0.9637 | IoU=0.9300
# [TRAIN] Epoch 122/130 | Batch 20/153 | Loss=0.0290 | Dice_coeff=0.9710 | IoU=0.9437
# [TRAIN] Epoch 122/130 | Batch 30/153 | Loss=0.0186 | Dice_coeff=0.9814 | IoU=0.9634
# [TRAIN] Epoch 122/130 | Batch 40/153 | Loss=0.0254 | Dice_coeff=0.9746 | IoU=0.9504
# [TRAIN] Epoch 122/130 | Batch 50/153 | Loss=0.0172 | Dice_coeff=0.9828 | IoU=0.9663
# [TRAIN] Epoch 122/130 | Batch 60/153 | Loss=0.0146 | Dice_coeff=0.9854 | IoU=0.9712
# [TRAIN] Epoch 122/130 | Batch 70/153 | Loss=0.0231 | Dice_coeff=0.9769 | IoU=0.9549
# [TRAIN] Epoch 122/130 | Batch 80/153 | Loss=0.0213 | Dice_coeff=0.9787 | IoU=0.9584
# [TRAIN] Epoch 122/130 | Batch 90/153 | Loss=0.0329 | Dice_coeff=0.9671 | IoU=0.9363
# [TRAIN] Epoch 122/130 | Batch 100/153 | Loss=0.0153 | Dice_coeff=0.9847 | IoU=0.9698
# [TRAIN] Epoch 122/130 | Batch 110/153 | Loss=0.0192 | Dice_coeff=0.9808 | IoU=0.9623
# [TRAIN] Epoch 122/130 | Batch 120/153 | Loss=0.0228 | Dice_coeff=0.9772 | IoU=0.9555
# [TRAIN] Epoch 122/130 | Batch 130/153 | Loss=0.0157 | Dice_coeff=0.9843 | IoU=0.9691
# [TRAIN] Epoch 122/130 | Batch 140/153 | Loss=0.0297 | Dice_coeff=0.9703 | IoU=0.9423
# [TRAIN] Epoch 122/130 | Batch 150/153 | Loss=0.0376 | Dice_coeff=0.9624 | IoU=0.9275
#  Train Loss: 0.0252 | Avg_dice_coeff: 0.9748 | Avg_IoU: 0.9510
# Running Validation...
#  Valid Loss: 0.1492 | Dice_coeff: 0.8508 | IoU: 0.7461
# No improvement in validation loss for 38 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch121.pt
# ========== Epoch 123 / 130 ==========
# Training...
# [TRAIN] Epoch 123/130 | Batch 10/153 | Loss=0.0326 | Dice_coeff=0.9674 | IoU=0.9369
# [TRAIN] Epoch 123/130 | Batch 20/153 | Loss=0.0166 | Dice_coeff=0.9834 | IoU=0.9673
# [TRAIN] Epoch 123/130 | Batch 30/153 | Loss=0.0490 | Dice_coeff=0.9510 | IoU=0.9065
# [TRAIN] Epoch 123/130 | Batch 40/153 | Loss=0.0199 | Dice_coeff=0.9801 | IoU=0.9610
# [TRAIN] Epoch 123/130 | Batch 50/153 | Loss=0.0268 | Dice_coeff=0.9732 | IoU=0.9478
# [TRAIN] Epoch 123/130 | Batch 60/153 | Loss=0.0181 | Dice_coeff=0.9819 | IoU=0.9644
# [TRAIN] Epoch 123/130 | Batch 70/153 | Loss=0.0224 | Dice_coeff=0.9776 | IoU=0.9563
# [TRAIN] Epoch 123/130 | Batch 80/153 | Loss=0.0191 | Dice_coeff=0.9809 | IoU=0.9625
# [TRAIN] Epoch 123/130 | Batch 90/153 | Loss=0.0192 | Dice_coeff=0.9808 | IoU=0.9623
# [TRAIN] Epoch 123/130 | Batch 100/153 | Loss=0.0197 | Dice_coeff=0.9803 | IoU=0.9613
# [TRAIN] Epoch 123/130 | Batch 110/153 | Loss=0.0225 | Dice_coeff=0.9775 | IoU=0.9560
# [TRAIN] Epoch 123/130 | Batch 120/153 | Loss=0.0235 | Dice_coeff=0.9765 | IoU=0.9541
# [TRAIN] Epoch 123/130 | Batch 130/153 | Loss=0.0275 | Dice_coeff=0.9725 | IoU=0.9465
# [TRAIN] Epoch 123/130 | Batch 140/153 | Loss=0.0198 | Dice_coeff=0.9802 | IoU=0.9611
# [TRAIN] Epoch 123/130 | Batch 150/153 | Loss=0.0246 | Dice_coeff=0.9754 | IoU=0.9519
#  Train Loss: 0.0248 | Avg_dice_coeff: 0.9752 | Avg_IoU: 0.9517
# Running Validation...
#  Valid Loss: 0.1492 | Dice_coeff: 0.8508 | IoU: 0.7460
# No improvement in validation loss for 39 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch122.pt
# ========== Epoch 124 / 130 ==========
# Training...
# [TRAIN] Epoch 124/130 | Batch 10/153 | Loss=0.0192 | Dice_coeff=0.9808 | IoU=0.9623
# [TRAIN] Epoch 124/130 | Batch 20/153 | Loss=0.0201 | Dice_coeff=0.9799 | IoU=0.9607
# [TRAIN] Epoch 124/130 | Batch 30/153 | Loss=0.0222 | Dice_coeff=0.9778 | IoU=0.9565
# [TRAIN] Epoch 124/130 | Batch 40/153 | Loss=0.0298 | Dice_coeff=0.9702 | IoU=0.9421
# [TRAIN] Epoch 124/130 | Batch 50/153 | Loss=0.0175 | Dice_coeff=0.9825 | IoU=0.9655
# [TRAIN] Epoch 124/130 | Batch 60/153 | Loss=0.0167 | Dice_coeff=0.9833 | IoU=0.9672
# [TRAIN] Epoch 124/130 | Batch 70/153 | Loss=0.0233 | Dice_coeff=0.9767 | IoU=0.9545
# [TRAIN] Epoch 124/130 | Batch 80/153 | Loss=0.0184 | Dice_coeff=0.9816 | IoU=0.9639
# [TRAIN] Epoch 124/130 | Batch 90/153 | Loss=0.0240 | Dice_coeff=0.9760 | IoU=0.9531
# [TRAIN] Epoch 124/130 | Batch 100/153 | Loss=0.0215 | Dice_coeff=0.9785 | IoU=0.9578
# [TRAIN] Epoch 124/130 | Batch 110/153 | Loss=0.0215 | Dice_coeff=0.9785 | IoU=0.9579
# [TRAIN] Epoch 124/130 | Batch 120/153 | Loss=0.0205 | Dice_coeff=0.9795 | IoU=0.9598
# [TRAIN] Epoch 124/130 | Batch 130/153 | Loss=0.0384 | Dice_coeff=0.9616 | IoU=0.9261
# [TRAIN] Epoch 124/130 | Batch 140/153 | Loss=0.0159 | Dice_coeff=0.9841 | IoU=0.9687
# [TRAIN] Epoch 124/130 | Batch 150/153 | Loss=0.0407 | Dice_coeff=0.9593 | IoU=0.9218
#  Train Loss: 0.0252 | Avg_dice_coeff: 0.9748 | Avg_IoU: 0.9512
# Running Validation...
#  Valid Loss: 0.1490 | Dice_coeff: 0.8510 | IoU: 0.7463
# No improvement in validation loss for 40 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch123.pt
# ========== Epoch 125 / 130 ==========
# Training...
# [TRAIN] Epoch 125/130 | Batch 10/153 | Loss=0.0156 | Dice_coeff=0.9844 | IoU=0.9693
# [TRAIN] Epoch 125/130 | Batch 20/153 | Loss=0.0534 | Dice_coeff=0.9466 | IoU=0.8987
# [TRAIN] Epoch 125/130 | Batch 30/153 | Loss=0.0193 | Dice_coeff=0.9807 | IoU=0.9621
# [TRAIN] Epoch 125/130 | Batch 40/153 | Loss=0.0316 | Dice_coeff=0.9684 | IoU=0.9387
# [TRAIN] Epoch 125/130 | Batch 50/153 | Loss=0.0223 | Dice_coeff=0.9777 | IoU=0.9564
# [TRAIN] Epoch 125/130 | Batch 60/153 | Loss=0.0224 | Dice_coeff=0.9776 | IoU=0.9562
# [TRAIN] Epoch 125/130 | Batch 70/153 | Loss=0.0197 | Dice_coeff=0.9803 | IoU=0.9613
# [TRAIN] Epoch 125/130 | Batch 80/153 | Loss=0.0184 | Dice_coeff=0.9816 | IoU=0.9639
# [TRAIN] Epoch 125/130 | Batch 90/153 | Loss=0.0227 | Dice_coeff=0.9773 | IoU=0.9556
# [TRAIN] Epoch 125/130 | Batch 100/153 | Loss=0.0207 | Dice_coeff=0.9793 | IoU=0.9594
# [TRAIN] Epoch 125/130 | Batch 110/153 | Loss=0.0178 | Dice_coeff=0.9822 | IoU=0.9649
# [TRAIN] Epoch 125/130 | Batch 120/153 | Loss=0.0212 | Dice_coeff=0.9788 | IoU=0.9585
# [TRAIN] Epoch 125/130 | Batch 130/153 | Loss=0.0260 | Dice_coeff=0.9740 | IoU=0.9494
# [TRAIN] Epoch 125/130 | Batch 140/153 | Loss=0.0190 | Dice_coeff=0.9810 | IoU=0.9627
# [TRAIN] Epoch 125/130 | Batch 150/153 | Loss=0.0203 | Dice_coeff=0.9797 | IoU=0.9602
#  Train Loss: 0.0251 | Avg_dice_coeff: 0.9749 | Avg_IoU: 0.9513
# Running Validation...
#  Valid Loss: 0.1490 | Dice_coeff: 0.8510 | IoU: 0.7463
# No improvement in validation loss for 41 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch124.pt
# ========== Epoch 126 / 130 ==========
# Training...
# [TRAIN] Epoch 126/130 | Batch 10/153 | Loss=0.0262 | Dice_coeff=0.9738 | IoU=0.9490
# [TRAIN] Epoch 126/130 | Batch 20/153 | Loss=0.0318 | Dice_coeff=0.9682 | IoU=0.9384
# [TRAIN] Epoch 126/130 | Batch 30/153 | Loss=0.0196 | Dice_coeff=0.9804 | IoU=0.9615
# [TRAIN] Epoch 126/130 | Batch 40/153 | Loss=0.0293 | Dice_coeff=0.9707 | IoU=0.9431
# [TRAIN] Epoch 126/130 | Batch 50/153 | Loss=0.0784 | Dice_coeff=0.9216 | IoU=0.8547
# [TRAIN] Epoch 126/130 | Batch 60/153 | Loss=0.0197 | Dice_coeff=0.9803 | IoU=0.9613
# [TRAIN] Epoch 126/130 | Batch 70/153 | Loss=0.0173 | Dice_coeff=0.9827 | IoU=0.9659
# [TRAIN] Epoch 126/130 | Batch 80/153 | Loss=0.0178 | Dice_coeff=0.9822 | IoU=0.9651
# [TRAIN] Epoch 126/130 | Batch 90/153 | Loss=0.0249 | Dice_coeff=0.9751 | IoU=0.9514
# [TRAIN] Epoch 126/130 | Batch 100/153 | Loss=0.0634 | Dice_coeff=0.9366 | IoU=0.8808
# [TRAIN] Epoch 126/130 | Batch 110/153 | Loss=0.0199 | Dice_coeff=0.9801 | IoU=0.9609
# [TRAIN] Epoch 126/130 | Batch 120/153 | Loss=0.0204 | Dice_coeff=0.9796 | IoU=0.9601
# [TRAIN] Epoch 126/130 | Batch 130/153 | Loss=0.0206 | Dice_coeff=0.9794 | IoU=0.9597
# [TRAIN] Epoch 126/130 | Batch 140/153 | Loss=0.0224 | Dice_coeff=0.9776 | IoU=0.9561
# [TRAIN] Epoch 126/130 | Batch 150/153 | Loss=0.0251 | Dice_coeff=0.9749 | IoU=0.9510
#  Train Loss: 0.0250 | Avg_dice_coeff: 0.9750 | Avg_IoU: 0.9515
# Running Validation...
#  Valid Loss: 0.1495 | Dice_coeff: 0.8505 | IoU: 0.7457
# No improvement in validation loss for 42 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch125.pt
# ========== Epoch 127 / 130 ==========
# Training...
# [TRAIN] Epoch 127/130 | Batch 10/153 | Loss=0.0172 | Dice_coeff=0.9828 | IoU=0.9662
# [TRAIN] Epoch 127/130 | Batch 20/153 | Loss=0.0355 | Dice_coeff=0.9645 | IoU=0.9314
# [TRAIN] Epoch 127/130 | Batch 30/153 | Loss=0.0245 | Dice_coeff=0.9755 | IoU=0.9522
# [TRAIN] Epoch 127/130 | Batch 40/153 | Loss=0.0218 | Dice_coeff=0.9782 | IoU=0.9573
# [TRAIN] Epoch 127/130 | Batch 50/153 | Loss=0.0218 | Dice_coeff=0.9782 | IoU=0.9573
# [TRAIN] Epoch 127/130 | Batch 60/153 | Loss=0.0266 | Dice_coeff=0.9734 | IoU=0.9483
# [TRAIN] Epoch 127/130 | Batch 70/153 | Loss=0.0234 | Dice_coeff=0.9766 | IoU=0.9543
# [TRAIN] Epoch 127/130 | Batch 80/153 | Loss=0.0201 | Dice_coeff=0.9799 | IoU=0.9607
# [TRAIN] Epoch 127/130 | Batch 90/153 | Loss=0.0317 | Dice_coeff=0.9683 | IoU=0.9386
# [TRAIN] Epoch 127/130 | Batch 100/153 | Loss=0.0177 | Dice_coeff=0.9823 | IoU=0.9653
# [TRAIN] Epoch 127/130 | Batch 110/153 | Loss=0.0164 | Dice_coeff=0.9836 | IoU=0.9677
# [TRAIN] Epoch 127/130 | Batch 120/153 | Loss=0.0175 | Dice_coeff=0.9825 | IoU=0.9655
# [TRAIN] Epoch 127/130 | Batch 130/153 | Loss=0.0627 | Dice_coeff=0.9373 | IoU=0.8819
# [TRAIN] Epoch 127/130 | Batch 140/153 | Loss=0.0219 | Dice_coeff=0.9781 | IoU=0.9571
# [TRAIN] Epoch 127/130 | Batch 150/153 | Loss=0.0269 | Dice_coeff=0.9731 | IoU=0.9476
#  Train Loss: 0.0250 | Avg_dice_coeff: 0.9750 | Avg_IoU: 0.9515
# Running Validation...
#  Valid Loss: 0.1493 | Dice_coeff: 0.8507 | IoU: 0.7460
# No improvement in validation loss for 43 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch126.pt
# ========== Epoch 128 / 130 ==========
# Training...
# [TRAIN] Epoch 128/130 | Batch 10/153 | Loss=0.0267 | Dice_coeff=0.9733 | IoU=0.9479
# [TRAIN] Epoch 128/130 | Batch 20/153 | Loss=0.0179 | Dice_coeff=0.9821 | IoU=0.9649
# [TRAIN] Epoch 128/130 | Batch 30/153 | Loss=0.0206 | Dice_coeff=0.9794 | IoU=0.9596
# [TRAIN] Epoch 128/130 | Batch 40/153 | Loss=0.0287 | Dice_coeff=0.9713 | IoU=0.9441
# [TRAIN] Epoch 128/130 | Batch 50/153 | Loss=0.0294 | Dice_coeff=0.9706 | IoU=0.9429
# [TRAIN] Epoch 128/130 | Batch 60/153 | Loss=0.0211 | Dice_coeff=0.9789 | IoU=0.9587
# [TRAIN] Epoch 128/130 | Batch 70/153 | Loss=0.0213 | Dice_coeff=0.9787 | IoU=0.9582
# [TRAIN] Epoch 128/130 | Batch 80/153 | Loss=0.0316 | Dice_coeff=0.9684 | IoU=0.9388
# [TRAIN] Epoch 128/130 | Batch 90/153 | Loss=0.0268 | Dice_coeff=0.9732 | IoU=0.9479
# [TRAIN] Epoch 128/130 | Batch 100/153 | Loss=0.0173 | Dice_coeff=0.9827 | IoU=0.9660
# [TRAIN] Epoch 128/130 | Batch 110/153 | Loss=0.0240 | Dice_coeff=0.9760 | IoU=0.9531
# [TRAIN] Epoch 128/130 | Batch 120/153 | Loss=0.0190 | Dice_coeff=0.9810 | IoU=0.9628
# [TRAIN] Epoch 128/130 | Batch 130/153 | Loss=0.0236 | Dice_coeff=0.9764 | IoU=0.9538
# [TRAIN] Epoch 128/130 | Batch 140/153 | Loss=0.0295 | Dice_coeff=0.9705 | IoU=0.9428
# [TRAIN] Epoch 128/130 | Batch 150/153 | Loss=0.0315 | Dice_coeff=0.9685 | IoU=0.9390
#  Train Loss: 0.0244 | Avg_dice_coeff: 0.9756 | Avg_IoU: 0.9525
# Running Validation...
#  Valid Loss: 0.1489 | Dice_coeff: 0.8511 | IoU: 0.7466
# No improvement in validation loss for 44 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch127.pt
# ========== Epoch 129 / 130 ==========
# Training...
# [TRAIN] Epoch 129/130 | Batch 10/153 | Loss=0.0200 | Dice_coeff=0.9800 | IoU=0.9608
# [TRAIN] Epoch 129/130 | Batch 20/153 | Loss=0.0342 | Dice_coeff=0.9658 | IoU=0.9338
# [TRAIN] Epoch 129/130 | Batch 30/153 | Loss=0.0290 | Dice_coeff=0.9710 | IoU=0.9436
# [TRAIN] Epoch 129/130 | Batch 40/153 | Loss=0.0236 | Dice_coeff=0.9764 | IoU=0.9538
# [TRAIN] Epoch 129/130 | Batch 50/153 | Loss=0.0236 | Dice_coeff=0.9764 | IoU=0.9539
# [TRAIN] Epoch 129/130 | Batch 60/153 | Loss=0.0202 | Dice_coeff=0.9798 | IoU=0.9604
# [TRAIN] Epoch 129/130 | Batch 70/153 | Loss=0.0217 | Dice_coeff=0.9783 | IoU=0.9576
# [TRAIN] Epoch 129/130 | Batch 80/153 | Loss=0.0162 | Dice_coeff=0.9838 | IoU=0.9681
# [TRAIN] Epoch 129/130 | Batch 90/153 | Loss=0.0212 | Dice_coeff=0.9788 | IoU=0.9585
# [TRAIN] Epoch 129/130 | Batch 100/153 | Loss=0.0269 | Dice_coeff=0.9731 | IoU=0.9477
# [TRAIN] Epoch 129/130 | Batch 110/153 | Loss=0.0236 | Dice_coeff=0.9764 | IoU=0.9540
# [TRAIN] Epoch 129/130 | Batch 120/153 | Loss=0.0214 | Dice_coeff=0.9786 | IoU=0.9581
# [TRAIN] Epoch 129/130 | Batch 130/153 | Loss=0.0168 | Dice_coeff=0.9832 | IoU=0.9669
# [TRAIN] Epoch 129/130 | Batch 140/153 | Loss=0.0168 | Dice_coeff=0.9832 | IoU=0.9670
# [TRAIN] Epoch 129/130 | Batch 150/153 | Loss=0.0205 | Dice_coeff=0.9795 | IoU=0.9598
#  Train Loss: 0.0250 | Avg_dice_coeff: 0.9750 | Avg_IoU: 0.9514
# Running Validation...
#  Valid Loss: 0.1494 | Dice_coeff: 0.8506 | IoU: 0.7457
# No improvement in validation loss for 45 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch128.pt
# ========== Epoch 130 / 130 ==========
# Training...
# [TRAIN] Epoch 130/130 | Batch 10/153 | Loss=0.0254 | Dice_coeff=0.9746 | IoU=0.9505
# [TRAIN] Epoch 130/130 | Batch 20/153 | Loss=0.0202 | Dice_coeff=0.9798 | IoU=0.9605
# [TRAIN] Epoch 130/130 | Batch 30/153 | Loss=0.0234 | Dice_coeff=0.9766 | IoU=0.9543
# [TRAIN] Epoch 130/130 | Batch 40/153 | Loss=0.0268 | Dice_coeff=0.9732 | IoU=0.9478
# [TRAIN] Epoch 130/130 | Batch 50/153 | Loss=0.0167 | Dice_coeff=0.9833 | IoU=0.9672
# [TRAIN] Epoch 130/130 | Batch 60/153 | Loss=0.0148 | Dice_coeff=0.9852 | IoU=0.9707
# [TRAIN] Epoch 130/130 | Batch 70/153 | Loss=0.0158 | Dice_coeff=0.9842 | IoU=0.9688
# [TRAIN] Epoch 130/130 | Batch 80/153 | Loss=0.0198 | Dice_coeff=0.9802 | IoU=0.9612
# [TRAIN] Epoch 130/130 | Batch 90/153 | Loss=0.0278 | Dice_coeff=0.9722 | IoU=0.9459
# [TRAIN] Epoch 130/130 | Batch 100/153 | Loss=0.0208 | Dice_coeff=0.9792 | IoU=0.9593
# [TRAIN] Epoch 130/130 | Batch 110/153 | Loss=0.0226 | Dice_coeff=0.9774 | IoU=0.9559
# [TRAIN] Epoch 130/130 | Batch 120/153 | Loss=0.0315 | Dice_coeff=0.9685 | IoU=0.9389
# [TRAIN] Epoch 130/130 | Batch 130/153 | Loss=0.0229 | Dice_coeff=0.9771 | IoU=0.9552
# [TRAIN] Epoch 130/130 | Batch 140/153 | Loss=0.0167 | Dice_coeff=0.9833 | IoU=0.9672
# [TRAIN] Epoch 130/130 | Batch 150/153 | Loss=0.0363 | Dice_coeff=0.9637 | IoU=0.9299
#  Train Loss: 0.0247 | Avg_dice_coeff: 0.9753 | Avg_IoU: 0.9520
# Running Validation...
#  Valid Loss: 0.1492 | Dice_coeff: 0.8508 | IoU: 0.7461
# No improvement in validation loss for 46 epochs.
# Model saved to ==> 23-06-2025_09-55-35/model_epoch129.pt
# Training complete!

# %%
trainer.visualize_scores()

# %%
test_loader = DataLoader(dataset=valid_dataset, batch_size=1, shuffle=False)

trainer.eval(test_loader)
# Out:
# [Test] Batch 100/611 | Test Loss=0.0312
# [Test] Batch 200/611 | Test Loss=0.1146
# [Test] Batch 300/611 | Test Loss=0.0919
# [Test] Batch 400/611 | Test Loss=0.4131
# [Test] Batch 500/611 | Test Loss=0.0695
# [Test] Batch 600/611 | Test Loss=0.0686
#  Test Loss: 0.1968 | Dice_coeff: 0.8032 | IoU: 0.7224

# %%
width = 4
columns = 3
n_examples = 12

fig, axs = plt.subplots(columns, width, figsize=(3*width , 3*columns), constrained_layout=True)
i = 0
with torch.no_grad():
    for data in test_loader:
        image, mask = data
        mask = mask[0][0]
        if not mask.byte().any():
            continue
        image = image.to(config.DEVICE)
        prediction = trainer.model(image).to('cpu')[0][0]
        prediction = torch.where(prediction > 0.5, 1, 0)
        
        axs[i//width][i%width].imshow(image[0].to('cpu').permute(1, 2, 0))
        axs[i//width][i%width].imshow(mask, alpha=0.5)
        axs[i//width][i%width].imshow(prediction, alpha=0.5)
        if n_examples == i + 1:
            break
        i += 1
