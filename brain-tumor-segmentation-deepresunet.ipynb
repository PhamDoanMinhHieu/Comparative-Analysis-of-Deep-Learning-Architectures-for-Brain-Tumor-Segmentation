# %%
import os
import cv2
import time
import numpy as np
import pandas as pd
from glob import glob
from tqdm import tqdm
import numpy as np 
import cv2 as cv
import zipfile
import io
import requests
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW, lr_scheduler
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
from sklearn.impute import SimpleImputer
# import albumentations
from sklearn.model_selection import train_test_split
from scipy.ndimage.morphology import binary_dilation
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, models, transforms
import torchvision.transforms.functional as TF
from torchvision.utils import make_grid
from datetime import datetime
from enum import Enum
import math
# import hdf5storage
import h5py
from typing import Dict, List, Tuple, Optional, Union

from PIL import Image

# You can use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass

warnings.warn = warn
warnings.filterwarnings('ignore')
# Out:
# /tmp/ipykernel_19/368343941.py:23: DeprecationWarning: Please import `binary_dilation` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.morphology import binary_dilation

# %%
class Config:
    def __init__(self):
        # Dataset and DataLoader Parameters
        self.IMG_SIZE = (256, 256)
        self.BATCH_SIZE = 16
        self.TRAIN_RATIO = 0.8
        self.TEST_RATIO = 0.2

        # Training Parameters
        self.EPOCHS = 150
        self.LEARNING_RATE = 1e-3
        self.WEIGHT_DECAY = 1e-4
        self.LEARNING_RATE_MIN = 1e-6
        self.ACCUMALATION_STEPS = 1
        self.DICE_LOSS = True
        self.PATIENCE = 150

        # Model Parameters
        self.IN_CHANNELS = 1
        self.OUT_CLASSES = 1
        self.DEPTH = 5
        self.INIT_FEATURES = 34
        self.NORMALIZATION = 'batch'
        self.INTERPOLATION = 'nearest'
        self.OUT_ACTIVATION = 'sigmoid'
        self.USE_MULTIPLIER = False

        # Other Parameters
        self.DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.SEED = 42
        self.ROOT = "/kaggle/input/brain-tumor-dataset-2/data/"
        self.SAVE_DIR = '/kaggle/working/deepresunetcheckpoint'

config = Config()

# %%
def set_all_seeds(seed):
    # NumPy
    np.random.seed(seed)
    # PyTorch
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # For multi-GPU setups
    # Ensures that the CUDA convolutions are deterministic, but might slow down training
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False # Set to False for reproducibility

set_all_seeds(config.SEED)

# %%
class ClassesLabels(Enum):
    """Brain tumor classification labels"""
    Meningioma = 1  # U màng não
    Glioma = 2      # U thần kinh đệm  
    Pituitary = 3   # Tuyến uyên
    
    def __len__(self):
        return 3


class BrainTumorDataset(Dataset):
    """
    Brain tumor dataset with balanced class distribution
    
    Args:
        root: Root directory containing class folders
        train: If True, creates training set; if False, creates test set 
        classes: Tuple of classes to include
        test_freq: Fraction of data to use for testing
        random_seed: Random seed for reproducible splits
        normalize_image: Whether to normalize images to 0-255 range
        verbose: Whether to print dataset statistics
    """
    
    CLASS_FOLDERS = {
        ClassesLabels.Meningioma: 'meningioma',
        ClassesLabels.Glioma: 'glioma',
        ClassesLabels.Pituitary: 'pituitary'
    }
    
    def __init__(
        self,
        root: str,
        train: bool = True,
        classes: Tuple[ClassesLabels, ...] = (ClassesLabels.Meningioma, ClassesLabels.Glioma, ClassesLabels.Pituitary),
        test_freq: float = 0.15,
        random_seed: int = 42,
        normalize_image: bool = True,
        verbose: bool = True
    ):
        super().__init__()
        self.root = self._validate_path(root)
        self.train = train
        self.classes = classes
        self.test_freq = test_freq
        self.normalize_image = normalize_image
        
        # Set random seed for reproducible splits
        np.random.seed(random_seed)
        
        # Load and split data
        self.items, self.class_info = self._load_and_split_data()
        
        if verbose:
            self._print_stats()
    
    def _validate_path(self, path: str) -> str:
        """Validate and normalize root path"""
        if not os.path.exists(path):
            raise ValueError(f"Root path does not exist: {path}")
        return os.path.normpath(path)
    
    def _load_and_split_data(self) -> Tuple[List[str], Dict]:
        """Load files and split into train/test per class"""
        items = []
        class_info = {}
        
        for class_label in self.classes:
            folder_name = self.CLASS_FOLDERS[class_label]
            folder_path = os.path.join(self.root, folder_name)
            
            if not os.path.exists(folder_path):
                print(f"Warning: Folder {folder_path} does not exist!")
                continue
            
            # Get all valid files for this class
            all_files = self._get_valid_files(folder_path)
            if not all_files:
                print(f"Warning: No valid files found in {folder_path}")
                continue
            
            # Split files for this class
            train_files, test_files = self._split_files(all_files)
            selected_files = train_files if self.train else test_files
            
            # Add to items with folder prefix
            items.extend([f'{folder_name}/{f}' for f in selected_files])
            
            # Store class statistics
            class_info[class_label.name] = {
                'total': len(all_files),
                'train': len(train_files),
                'test': len(test_files),
                'selected': len(selected_files)
            }
        
        return items, class_info
    
    def _get_valid_files(self, folder_path: str) -> List[str]:
        """Get all valid data files from folder"""
        valid_extensions = ('.mat', '.h5', '.hdf5')
        files = [f for f in os.listdir(folder_path) 
                if f.lower().endswith(valid_extensions)]
        return sorted(files)  # Sort for consistent ordering
    
    def _split_files(self, files: List[str]) -> Tuple[List[str], List[str]]:
        """Split files into train and test sets"""
        files_shuffled = files.copy()
        np.random.shuffle(files_shuffled)
        
        split_point = math.floor((1 - self.test_freq) * len(files_shuffled))
        train_files = files_shuffled[:split_point]
        test_files = files_shuffled[split_point:]
        
        return train_files, test_files
    
    def _normalize_image(self, image: np.ndarray) -> np.ndarray:
        """Normalize image to 0-255 range using MATLAB formula"""
        im1 = image.astype(np.float64)
        min_val, max_val = np.min(im1), np.max(im1)
        
        if max_val == min_val:
            return np.zeros_like(im1, dtype=np.uint8)
        
        im_normalized = 255.0 * (im1 - min_val) / (max_val - min_val)
        return im_normalized.astype(np.uint8)
    
    def _print_stats(self):
        """Print dataset statistics"""
        mode = "Training" if self.train else "Testing"
        print(f"\n=== {mode} Dataset Statistics ===")
        print(f"Total samples: {len(self.items)}")
        print(f"Test frequency: {self.test_freq}")
        
        if self.class_info:
            print("\nClass breakdown:")
            total_selected = sum(info['selected'] for info in self.class_info.values())
            
            for class_name, info in self.class_info.items():
                percentage = (info['selected'] / total_selected * 100) if total_selected > 0 else 0
                print(f"  {class_name}: {info['selected']} ({percentage:.1f}%) "
                      f"[Total: {info['total']}, Train: {info['train']}, Test: {info['test']}]")
        print("=" * 50)
    
    def get_class_distribution(self) -> Dict[str, int]:
        """Get class distribution in current dataset"""
        return {name: info['selected'] for name, info in self.class_info.items()}
    
    def __len__(self) -> int:
        return len(self.items)
    
    def __getitem__(self, idx: int) -> Dict:
        if not (0 <= idx < len(self.items)):
            raise IndexError(f"Index {idx} out of range [0, {len(self.items)})")
        
        file_path = os.path.join(self.root, self.items[idx])
        
        try:
            with h5py.File(file_path, 'r') as f:
                data = f['cjdata']
                
                raw_image = data['image'][:]
                mask = data['tumorMask'][:]
                label = int(data['label'][0][0])
                
                # Apply normalization if requested
                image = self._normalize_image(raw_image) if self.normalize_image else raw_image
                
                return {
                    "label": label,
                    "image": image,
                    "mask": mask,
                    "file_path": self.items[idx]
                }
        
        except Exception as e:
            raise RuntimeError(f"Error loading {file_path}: {str(e)}")


class BrainTumorDatasetMask(BrainTumorDataset):
    """Dataset that returns (image, mask) tuples for backward compatibility"""
    
    def __init__(self, root: str, train: bool = True, transform=None, **kwargs):
        super().__init__(root=root, train=train, **kwargs)
        self.transform = transform
    
    def __getitem__(self, idx: int) -> Union[Tuple[np.ndarray, np.ndarray], any]:
        metadata = super().__getitem__(idx)
        sample = (metadata["image"], metadata["mask"])
        
        return self.transform(*sample) if self.transform else sample

# %%
def inspect_sample(dataset: BrainTumorDataset, idx: int = 0):
    """Inspect a dataset sample"""
    if len(dataset) == 0:
        print("Dataset is empty!")
        return
    
    sample = dataset[idx]
    print(f"\n=== Sample {idx} Inspection ===")
    
    if isinstance(sample, dict):
        print(f"Label: {sample['label']}")
        print(f"Image shape: {sample['image'].shape}, dtype: {sample['image'].dtype}")
        print(f"Image range: [{sample['image'].min()}, {sample['image'].max()}]")
        print(f"Mask shape: {sample['mask'].shape}, dtype: {sample['mask'].dtype}")
        print(f"File: {sample['file_path']}")
    else:
        print(f"Sample type: {type(sample)}")
        if isinstance(sample, tuple) and len(sample) == 2:
            image, mask = sample
            print(f"Image shape: {image.shape}, dtype: {image.dtype}")
            print(f"Mask shape: {mask.shape}, dtype: {mask.dtype}")
    
    print("=" * 35)

# %%
dataset_mask = BrainTumorDatasetMask(root=config.ROOT, train=True, test_freq=0.2)
sample_mask = dataset_mask[0]  # Trả về (image, mask)
print(f"Mask dataset sample type: {type(sample_mask)}")

inspect_sample(dataset_mask, 0)
# Out:
# === Training Dataset Statistics ===
# Total samples: 2438
# Test frequency: 0.2
#
# Class breakdown:
#   Meningioma: 566 (23.2%) [Total: 708, Train: 566, Test: 142]
#   Glioma: 1140 (46.8%) [Total: 1426, Train: 1140, Test: 286]
#   Pituitary: 732 (30.0%) [Total: 915, Train: 732, Test: 183]
# ==================================================
# Mask dataset sample type: <class 'tuple'>
#
# === Sample 0 Inspection ===
# Sample type: <class 'tuple'>
# Image shape: (512, 512), dtype: uint8
# Mask shape: (512, 512), dtype: uint8
# ===================================

# %%
# Visualize function
def visualize(images, masks, original_images=None, original_masks=None):
    fontsize=18
    
    # Xử lý trường hợp input là single sample
    if not isinstance(images, (list, tuple)):
        images = [images]
        masks = [masks]
        if original_images is not None:
            original_images = [original_images]
        if original_masks is not None:
            original_masks = [original_masks]
    
    num_samples = len(images)
    
    if original_images is None and original_masks is None:
        # Hiển thị 2 hàng: hàng 1 là images, hàng 2 là masks
        f, ax = plt.subplots(2, num_samples, figsize=(4*num_samples, 8))
        
        # Nếu chỉ có 1 sample, ax sẽ là 1D array
        if num_samples == 1:
            ax = ax.reshape(2, 1)
        
        for i in range(num_samples):
            ax[0, i].imshow(images[i], cmap='gray')
            ax[0, i].set_title(f'Image {i+1}', fontsize=fontsize)
            ax[0, i].axis('off')
            
            ax[1, i].imshow(masks[i], cmap='gray')
            ax[1, i].set_title(f'Mask {i+1}', fontsize=fontsize)
            ax[1, i].axis('off')
    else:
        # Hiển thị 4 hàng: original images, original masks, transformed images, transformed masks
        f, ax = plt.subplots(4, num_samples, figsize=(4*num_samples, 16))
        
        # Nếu chỉ có 1 sample, ax sẽ là 1D array
        if num_samples == 1:
            ax = ax.reshape(4, 1)
        
        for i in range(num_samples):
            ax[0, i].imshow(original_images[i], cmap='gray')
            ax[0, i].set_title(f'Original Image {i+1}', fontsize=fontsize)
            ax[0, i].axis('off')
            
            ax[1, i].imshow(original_masks[i], cmap='gray')
            ax[1, i].set_title(f'Original Mask {i+1}', fontsize=fontsize)
            ax[1, i].axis('off')
            
            ax[2, i].imshow(images[i], cmap='gray')
            ax[2, i].set_title(f'Transformed Image {i+1}', fontsize=fontsize)
            ax[2, i].axis('off')
            
            ax[3, i].imshow(masks[i], cmap='gray')
            ax[3, i].set_title(f'Transformed Mask {i+1}', fontsize=fontsize)
            ax[3, i].axis('off')
    
    plt.tight_layout()
    plt.show()

# Ví dụ sử dụng với multiple samples
def visualize_multiple_samples(dataset, indices, with_preprocessing=True):
    """
    Hiển thị nhiều samples từ dataset
    
    Args:
        dataset: Dataset object
        indices: List các index muốn hiển thị
        with_preprocessing: Có hiển thị ảnh trước và sau preprocessing không
    """
    images = []
    masks = []
    original_images = []
    original_masks = []
    
    for idx in indices:
        if with_preprocessing and hasattr(dataset, 'transform') and dataset.transform is not None:
            # Lấy dữ liệu gốc (không preprocessing)
            dataset_temp = dataset.__class__(dataset.root, dataset.train, transform=None, classes=dataset.classes)
            orig_img, orig_mask = dataset_temp[idx]
            original_images.append(orig_img)
            original_masks.append(orig_mask)
            
            # Lấy dữ liệu đã preprocessing
            proc_img, proc_mask = dataset[idx]
            images.append(proc_img.squeeze() if hasattr(proc_img, 'squeeze') else proc_img)
            masks.append(proc_mask.squeeze() if hasattr(proc_mask, 'squeeze') else proc_mask)
        else:
            # Chỉ lấy dữ liệu hiện tại
            img, mask = dataset[idx]
            images.append(img.squeeze() if hasattr(img, 'squeeze') else img)
            masks.append(mask.squeeze() if hasattr(mask, 'squeeze') else mask)
    
    if with_preprocessing and original_images:
        visualize(images, masks, original_images, original_masks)
    else:
        visualize(images, masks)

# Hàm tiền xử lí dữ liệu
def preprocessing(image, mask):
    image_transformer = transforms.Compose([
        transforms.ToTensor(),
        transforms.Resize(config.IMG_SIZE, interpolation=0),
        # transforms.Normalize(mean=(0.5,), std=(0.5,))  # Normalize image
        ])
    mask_transformer = transforms.Compose([
        transforms.Lambda(lambda x: transforms.ToPILImage()(transforms.ToTensor()(x).float().squeeze())),
        transforms.ToTensor(),
        transforms.Resize(config.IMG_SIZE, interpolation=0),
    ])
    # image = np.transpose(np.array(image)) / 65535.0
    # image = image * 2 - 1
    image = np.transpose(np.array(image))
    mask = np.transpose(np.array(mask))
    mask = mask_transformer(mask)
    mask = mask / mask.max()
    mask = torch.where(mask > 0.5, 1, 0).float()
    return image_transformer(image).float(), mask

# %%
# Khởi tạo dataset
dataset = BrainTumorDatasetMask(root='/kaggle/input/brain-tumor-dataset-2/data/', train=True, transform=preprocessing)
original_image, original_mask = dataset[3]
print(f'#=>Original image: {type(original_image)}')
print(f'#=>Original mask: {type(original_mask)}')
# Out:
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
# #=>Original image: <class 'torch.Tensor'>
# #=>Original mask: <class 'torch.Tensor'>

# %%
visualize(original_image.squeeze(), original_mask.squeeze())

# %%
visualize_multiple_samples(dataset, [0, 1, 2, 3])
# Out:
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
#
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
#
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
#
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================

# %%
class PreActivateDoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(PreActivateDoubleConv, self).__init__()
        self.double_conv = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        )

    def forward(self, x):
        return self.double_conv(x)

class PreActivateResUpBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(PreActivateResUpBlock, self).__init__()
        self.ch_avg = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels))
        self.up_sample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        self.ch_avg = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels))
        self.double_conv = PreActivateDoubleConv(in_channels, out_channels)

    def forward(self, down_input, skip_input):
        x = self.up_sample(down_input)
        x = torch.cat([x, skip_input], dim=1)
        return self.double_conv(x) + self.ch_avg(x)

class PreActivateResBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(PreActivateResBlock, self).__init__()
        self.ch_avg = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels))

        self.double_conv = PreActivateDoubleConv(in_channels, out_channels)
        self.down_sample = nn.MaxPool2d(2)

    def forward(self, x):
        identity = self.ch_avg(x)
        out = self.double_conv(x)
        out = out + identity
        return self.down_sample(out), out

class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DoubleConv, self).__init__()
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.double_conv(x)

class ResBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ResBlock, self).__init__()
        self.downsample = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels))
        self.double_conv = DoubleConv(in_channels, out_channels)
        self.down_sample = nn.MaxPool2d(2)
        self.relu = nn.ReLU()

    def forward(self, x):
        identity = self.downsample(x)
        out = self.double_conv(x)
        out = self.relu(out + identity)
        return self.down_sample(out), out


class DownBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DownBlock, self).__init__()
        self.double_conv = DoubleConv(in_channels, out_channels)
        self.down_sample = nn.MaxPool2d(2)

    def forward(self, x):
        skip_out = self.double_conv(x)
        down_out = self.down_sample(skip_out)
        return (down_out, skip_out)

class UpBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(UpBlock, self).__init__()
        self.up_sample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        self.double_conv = DoubleConv(in_channels, out_channels)

    def forward(self, down_input, skip_input):
        x = self.up_sample(down_input)
        x = torch.cat([x, skip_input], dim=1)
        return self.double_conv(x)

class UNet(nn.Module):
    def __init__(self, out_classes=1):
        super(UNet, self).__init__()

        self.down_conv1 = DownBlock(1, 64)
        self.down_conv2 = DownBlock(64, 128)
        self.down_conv3 = DownBlock(128, 256)
        self.down_conv4 = DownBlock(256, 512)

        self.double_conv = DoubleConv(512, 1024)

        self.up_conv4 = UpBlock(512 + 1024, 512)
        self.up_conv3 = UpBlock(256 + 512, 256)
        self.up_conv2 = UpBlock(128 + 256, 128)
        self.up_conv1 = UpBlock(128 + 64, 64)

        self.conv_last = nn.Conv2d(64, out_classes, kernel_size=1)
        self.act_last = nn.Sigmoid()

    def forward(self, x):
        x, skip1_out = self.down_conv1(x)
        x, skip2_out = self.down_conv2(x)
        x, skip3_out = self.down_conv3(x)
        x, skip4_out = self.down_conv4(x)
        x = self.double_conv(x)
        x = self.up_conv4(x, skip4_out)
        x = self.up_conv3(x, skip3_out)
        x = self.up_conv2(x, skip2_out)
        x = self.up_conv1(x, skip1_out)
        x = self.conv_last(x)
        x = self.act_last(x)
        return x

class DeepResUNet(nn.Module):
    def __init__(self, out_classes=1):
        super(DeepResUNet, self).__init__()

        self.down_conv1 = PreActivateResBlock(1, 64)
        self.down_conv2 = PreActivateResBlock(64, 128)
        self.down_conv3 = PreActivateResBlock(128, 256)
        self.down_conv4 = PreActivateResBlock(256, 512)

        self.double_conv = PreActivateDoubleConv(512, 1024)

        self.up_conv4 = PreActivateResUpBlock(512 + 1024, 512)
        self.up_conv3 = PreActivateResUpBlock(256 + 512, 256)
        self.up_conv2 = PreActivateResUpBlock(128 + 256, 128)
        self.up_conv1 = PreActivateResUpBlock(128 + 64, 64)

        self.conv_last = nn.Conv2d(64, out_classes, kernel_size=1)
        self.act_last = nn.Sigmoid()

    def forward(self, x):
        x, skip1_out = self.down_conv1(x)
        x, skip2_out = self.down_conv2(x)
        x, skip3_out = self.down_conv3(x)
        x, skip4_out = self.down_conv4(x)
        x = self.double_conv(x)
        x = self.up_conv4(x, skip4_out)
        x = self.up_conv3(x, skip3_out)
        x = self.up_conv2(x, skip2_out)
        x = self.up_conv1(x, skip1_out)
        x = self.conv_last(x)
        x = self.act_last(x)
        return x

class ResUNet(nn.Module):
    """
    Hybrid solution of resnet blocks and double conv blocks
    """
    def __init__(self, out_classes=1):
        super(ResUNet, self).__init__()

        self.down_conv1 = ResBlock(1, 64)
        self.down_conv2 = ResBlock(64, 128)
        self.down_conv3 = ResBlock(128, 256)
        self.down_conv4 = ResBlock(256, 512)

        self.double_conv = DoubleConv(512, 1024)

        self.up_conv4 = UpBlock(512 + 1024, 512)
        self.up_conv3 = UpBlock(256 + 512, 256)
        self.up_conv2 = UpBlock(128 + 256, 128)
        self.up_conv1 = UpBlock(128 + 64, 64)

        self.conv_last = nn.Conv2d(64, out_classes, kernel_size=1)

    def forward(self, x):
        x, skip1_out = self.down_conv1(x)
        x, skip2_out = self.down_conv2(x)
        x, skip3_out = self.down_conv3(x)
        x, skip4_out = self.down_conv4(x)
        x = self.double_conv(x)
        x = self.up_conv4(x, skip4_out)
        x = self.up_conv3(x, skip3_out)
        x = self.up_conv2(x, skip2_out)
        x = self.up_conv1(x, skip1_out)
        x = self.conv_last(x)
        return x

class ONet(nn.Module):
    def __init__(self, alpha=470, beta=40, out_classes=1):
        super(ONet, self).__init__()
        self.alpha = alpha
        self.beta = beta
        self.down_conv1 = ResBlock(1, 64)
        self.down_conv2 = ResBlock(64, 128)
        self.down_conv3 = ResBlock(128, 256)
        self.down_conv4 = ResBlock(256, 512)

        self.double_conv = DoubleConv(512, 1024)

        self.up_conv4 = UpBlock(512 + 1024, 512)
        self.up_conv3 = UpBlock(256 + 512, 256)
        self.up_conv2 = UpBlock(128 + 256, 128)
        self.up_conv1 = UpBlock(128 + 64, 64)

        self.conv_last = nn.Conv2d(64, 1, kernel_size=1)
        self.input_output_conv = nn.Conv2d(2, 1, kernel_size=1)


    def forward(self, inputs):
        input_tensor, bounding = inputs
        x, skip1_out = self.down_conv1(input_tensor + (bounding * self.alpha))
        x, skip2_out = self.down_conv2(x)
        x, skip3_out = self.down_conv3(x)
        x, skip4_out = self.down_conv4(x)
        x = self.double_conv(x)
        x = self.up_conv4(x, skip4_out)
        x = self.up_conv3(x, skip3_out)
        x = self.up_conv2(x, skip2_out)
        x = self.up_conv1(x, skip1_out)
        x = self.conv_last(x)
        input_output = torch.cat([x, bounding * self.beta], dim=1)
        x = self.input_output_conv(input_output)
        return x

# %%
class Trainer():
    def __init__(self,
                 model,
                 train_dataloader,
                 valid_dataloader,
                 epochs=10,
                 save_dir=None,
                 device='cpu',
                 accumalation_steps=4,
                 patience=5):  # Add patience for early stopping
        self.device = device
        self.accumalation_steps = accumalation_steps

        self.model = model.to(self.device)

        self.train_losses = []
        self.train_dice_coeff_values = []
        self.train_iou_values = []
        self.val_losses = []
        self.val_dice_coeff_values = []
        self.val_iou_values = []
        self.patience = patience  # Early stopping patience
        self.early_stop = False  # Flag for early stopping
        self.best_valid_loss = float('inf')  # Initialize best loss

        if save_dir != None and os.path.exists(save_dir):
            print("Load weight from file:{}".format(save_dir))
            self.save_dir = save_dir
            epcho_checkpoint_path = glob.glob("{}/model_epoch*".format(self.save_dir))
            if len(epcho_checkpoint_path) == 0:
                print("No checkpoint found in: {}\nCheck save_dir...".format(self.save_dir))
            else:
                self.load_checkpoint(epcho_checkpoint_path[0])
                print("Restore weight successful from: {}".format(epcho_checkpoint_path))
        else:
            self.save_dir = datetime.now().strftime("%d-%m-%Y_%H-%M-%S")
            os.makedirs(self.save_dir)
            print("Training new model, save to: {}".format(self.save_dir))

        self.train_dataloader = train_dataloader
        self.valid_dataloader = valid_dataloader
        self.epochs = epochs

    def save_checkpoint(self, save_path):
        state_dict = {'model_state_dict': self.model.state_dict(),
                      'train_losses': self.train_losses,
                      'train_dice_coeff_values': self.train_dice_coeff_values,
                      'train_iou_values': self.train_iou_values,
                      'val_losses': self.val_losses,
                      'val_dice_coeff_values': self.val_dice_coeff_values,
                      'val_iou_values': self.val_iou_values
                     }
        torch.save(state_dict, save_path)
        print(f"Model saved to ==> {save_path}")

    def load_checkpoint(self, load_path):
        state_dict = torch.load(load_path, map_location=self.device)
        print(f"Model restored from <== {load_path}")
        self.model.load_state_dict(state_dict["model_state_dict"])
        self.train_losses = state_dict["train_losses"]
        self.train_dice_coeff_values = state_dict["train_dice_coeff_values"]
        self.train_iou_values = state_dict['train_iou_values']
        self.val_losses = state_dict["val_losses"]
        self.val_dice_coeff_values = state_dict["val_dice_coeff_values"]
        self.val_iou_values = state_dict['val_iou_values']

    @staticmethod
    def iou(pred_mask, true_mask):
        # Làm phẳng các tensor
        pred_mask = pred_mask.view(-1)
        true_mask = true_mask.view(-1)
    
        # Tính toán phần giao nhau và hợp nhất
        intersection = torch.sum(pred_mask * true_mask)
        union = torch.sum(pred_mask) + torch.sum(true_mask) - intersection
    
        # Tính IoU
        iou = intersection / union
    
        return iou

    @staticmethod
    def dice_loss(pred, target, smooth=1e-6):
        pred = pred.view(-1)
        target = target.view(-1)
        
        # Flatten the tensors to calculate the intersection and union of predicted and true masks
        intersection = torch.sum(pred * target)
        union = torch.sum(pred) + torch.sum(target)
        
        # Compute Dice coefficient
        dice = (2. * intersection + smooth) / (union + smooth)
        
        return 1 - dice

    @staticmethod
    def dice_coeff(pred, target, smooth=1e-6, threshold=0.5):
        pred = pred.view(-1)
        target = target.view(-1)
        # pred = (pred > threshold).float()
        
        intersection = torch.sum(pred * target)
        union = torch.sum(pred) + torch.sum(target)
        return (2. * intersection + smooth) / (union + smooth)
    
    def train(self):
        if config.DICE_LOSS:
            criterion = self.dice_loss
        else:
            criterion = nn.BCELoss()
            
        optimizer = torch.optim.AdamW(self.model.parameters(), lr=config.LEARNING_RATE, weight_decay=config.WEIGHT_DECAY)
        scheduler = lr_scheduler.CosineAnnealingLR(optimizer, T_max=config.EPOCHS, eta_min=config.LEARNING_RATE_MIN)
        
        patience_counter = 0  # Track epochs without improvement
        for epoch_i in range(0, self.epochs):
            if self.early_stop:  # Check if early stopping is triggered
                print("Early stopping triggered. Training stopped.")
                break

            print('========== Epoch {:} / {:} =========='.format(epoch_i + 1, self.epochs))
            print('Training...')

            total_loss = 0
            self.model.train()
            nb_train_steps = 0
            train_iou = 0
            train_dice_coeff = 0

            for step, batch in enumerate(self.train_dataloader):
                img, mask = batch
                img, mask = img.to(self.device), mask.to(self.device)
                
                outputs = self.model(img)

                dice = self.dice_coeff(outputs.detach(), mask).item()
                train_dice_coeff += dice
                iou = self.iou(outputs.detach(), mask).item()
                train_iou += iou

                loss = criterion(outputs, mask) / self.accumalation_steps
                total_loss += loss.item() * self.accumalation_steps
                
                nb_train_steps += 1

                loss.backward()
                if (step + 1) % self.accumalation_steps == 0:
                    optimizer.step()
                    # scheduler.step()
                    optimizer.zero_grad()

                if (step + 1) % 10 == 0:
                    print("[TRAIN] Epoch {}/{} | Batch {}/{} | Loss={:.4f} | Dice_coeff={:.4f} | IoU={:.4f}".format(epoch_i + 1, self.epochs, step + 1, len(self.train_dataloader), loss.item(), dice, iou))

            scheduler.step()
            avg_train_loss = total_loss / len(self.train_dataloader)
            avg_train_dice_coeff = train_dice_coeff / nb_train_steps
            avg_train_iou = train_iou / nb_train_steps
            print(" Train Loss: {:.4f} | Avg_dice_coeff: {:.4f} | Avg_IoU: {:.4f}".format(avg_train_loss, avg_train_dice_coeff, avg_train_iou))

            self.train_losses.append(avg_train_loss)
            self.train_dice_coeff_values.append(avg_train_dice_coeff)
            self.train_iou_values.append(avg_train_iou)

            print("Running Validation...")
            self.model.eval()
            eval_loss = 0
            eval_iou = 0
            eval_dice_coeff = 0
            nb_eval_steps = 0

            for batch in self.valid_dataloader:
                img, mask = batch
                img, mask = img.to(self.device), mask.to(self.device)

                with torch.no_grad():
                    outputs = self.model(img)

                    loss = criterion(outputs, mask)       
                    eval_dice_coeff += self.dice_coeff(outputs.detach(), mask).item()
                    eval_iou += self.iou(outputs.detach(), mask).item()
                    eval_loss += loss.item()
                    nb_eval_steps += 1

            avg_val_loss = eval_loss / nb_eval_steps
            avg_val_dice_coeff = eval_dice_coeff / nb_eval_steps
            avg_val_iou = eval_iou / nb_eval_steps
            
            print(f" Valid Loss: {avg_val_loss:.4f} | Dice_coeff: {avg_val_dice_coeff:.4f} | IoU: {avg_val_iou:.4f}")

            self.val_losses.append(avg_val_loss)
            self.val_dice_coeff_values.append(avg_val_dice_coeff)
            self.val_iou_values.append(avg_val_iou)

            # Early stopping logic
            if avg_val_loss  < self.best_valid_loss:
                print(f"Validation loss improved from {self.best_valid_loss:.4f} to {avg_val_loss:.4f}. Saving model...")
                self.best_valid_loss = avg_val_loss
                patience_counter = 0  # Reset patience counter
                best_valid_loss_path = "{}/model_best_valloss.pt".format(self.save_dir)
                self.save_checkpoint(best_valid_loss_path)
            else:
                patience_counter += 1
                print(f"No improvement in validation loss for {patience_counter} epochs.")
                if patience_counter >= self.patience:
                    print(f"Stopping early after {patience_counter} epochs without improvement.")
                    self.early_stop = True

            # Save checkpoint for current epoch
            epoch_i_path = "{}/model_epoch{}.pt".format(self.save_dir, epoch_i)
            self.save_checkpoint(epoch_i_path)

            # Remove the previous epoch's checkpoint
            if os.path.exists("{}/model_epoch{}.pt".format(self.save_dir, epoch_i-1)):
                os.remove("{}/model_epoch{}.pt".format(self.save_dir, epoch_i-1))

        print("Training complete!")
        
    def eval(self, dataloader):
        self.model.eval()
        if config.DICE_LOSS:
            criterion = self.dice_loss
        else:
            criterion = nn.BCELoss()
        nb_eval_steps = 0
        eval_loss = 0
        eval_iou = 0
        eval_dice_coeff = 0
        for step, batch in enumerate(dataloader):
            img, mask = batch
            img, mask = img.to(self.device), mask.to(self.device)

            with torch.no_grad():
                outputs = self.model(img)

                loss = criterion(outputs, mask)
                
                eval_dice_coeff += self.dice_coeff(outputs.detach(), mask).item()
                eval_iou += self.iou(outputs.detach(), mask).item()
                eval_loss += loss.item()
                nb_eval_steps += 1
                
            if (step + 1) % 100 == 0:
                    print("[Test] Batch {}/{} | Test Loss={:.4f}".format(step + 1, len(dataloader), loss))
        avg_val_loss = eval_loss / nb_eval_steps
        avg_dice_coeff = eval_dice_coeff / nb_eval_steps
        avg_iou = eval_iou / nb_eval_steps
        
        print(f" Test Loss: {avg_val_loss:.4f} | Dice_coeff: {avg_dice_coeff:.4f} | IoU: {avg_iou:.4f}")
        return

    def visualize_scores(self):
        num_epoches = range(1, len(self.train_losses) + 1)
        # Vẽ Loss
        plt.figure(figsize=(12, 6))
        plt.plot(num_epoches, self.train_losses, label='Train Loss', marker='o', color='blue')
        plt.plot(num_epoches, self.val_losses, label='Test Loss', marker='o', color='orange')
        plt.title('Training and Testing Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        plt.grid(True)
        plt.show()
        
        # Vẽ Dice Coeff
        plt.figure(figsize=(12, 6))
        plt.plot(num_epoches, self.train_dice_coeff_values, label='Train Dice Coeff', marker='o', color='green')
        plt.plot(num_epoches, self.val_dice_coeff_values, label='Test Dice Coeff', marker='o', color='red')
        plt.title('Training and Testing Dice Coeff')
        plt.xlabel('Epochs')
        plt.ylabel('Dice Coeff')
        plt.legend()
        plt.grid(True)
        plt.show()

        # Vẽ IoU
        plt.figure(figsize=(12, 6))
        plt.plot(num_epoches, self.train_iou_values, label='Train IoU', marker='o', color='green')
        plt.plot(num_epoches, self.val_iou_values, label='Test IoU', marker='o', color='red')
        plt.title('Training and Testing IoU')
        plt.xlabel('Epochs')
        plt.ylabel('IoU')
        plt.legend()
        plt.grid(True)
        plt.show()

# %%
train_dataset = BrainTumorDatasetMask(root=config.ROOT, train=True, 
                                      test_freq=config.TEST_RATIO, transform=preprocessing)
valid_dataset = BrainTumorDatasetMask(root=config.ROOT, train=False, 
                                      test_freq=config.TEST_RATIO, transform=preprocessing)
print(f'Length of train dataset: {len(train_dataset)}')
print(f'Length of test dataset: {len(valid_dataset)}')

train_loader = DataLoader(dataset=train_dataset, batch_size=config.BATCH_SIZE, shuffle=True)
valid_loader = DataLoader(dataset=valid_dataset, batch_size=config.BATCH_SIZE, shuffle=False)
print(f'Length of train loader: {len(train_loader)}')
print(f'Length of test loader: {len(valid_loader)}')
# Out:
# === Training Dataset Statistics ===
# Total samples: 2438
# Test frequency: 0.2
#
# Class breakdown:
#   Meningioma: 566 (23.2%) [Total: 708, Train: 566, Test: 142]
#   Glioma: 1140 (46.8%) [Total: 1426, Train: 1140, Test: 286]
#   Pituitary: 732 (30.0%) [Total: 915, Train: 732, Test: 183]
# ==================================================
#
# === Testing Dataset Statistics ===
# Total samples: 611
# Test frequency: 0.2
#
# Class breakdown:
#   Meningioma: 142 (23.2%) [Total: 708, Train: 566, Test: 142]
#   Glioma: 286 (46.8%) [Total: 1426, Train: 1140, Test: 286]
#   Pituitary: 183 (30.0%) [Total: 915, Train: 732, Test: 183]
# ==================================================
# Length of train dataset: 2438
# Length of test dataset: 611
# Length of train loader: 153
# Length of test loader: 39

# %%
 def init_weights_with_kaiming_uniform(m):
        '''Initialize the weights of the model with kaiming uniform initialization.'''
        if type(m) == nn.Conv2d:
            torch.nn.init.kaiming_uniform_(m.weight)
            
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
model = DeepResUNet().to(config.DEVICE)
model = nn.DataParallel(model)
model.apply(init_weights_with_kaiming_uniform) # default init is xaiver uniform
    
print("Number parameters:", count_parameters(model))
# Out:
# Number parameters: 32611779

# %%
trainer = Trainer(
    model=model,
    train_dataloader=train_loader,
    valid_dataloader=valid_loader,
    epochs=config.EPOCHS,
    save_dir=config.SAVE_DIR,
    device=config.DEVICE,
    accumalation_steps=config.ACCUMALATION_STEPS,
    patience = config.PATIENCE
)
# Out:
# Training new model, save to: 18-06-2025_04-10-51

# %%
# trainer.load_checkpoint('/kaggle/working/17-06-2025_08-00-35/model_epoch0.pt')

# %%
trainer.train()
# Out:
# ========== Epoch 1 / 150 ==========
# Training...
# [TRAIN] Epoch 1/150 | Batch 10/153 | Loss=0.8693 | Dice_coeff=0.1307 | IoU=0.0699
# [TRAIN] Epoch 1/150 | Batch 20/153 | Loss=0.8377 | Dice_coeff=0.1623 | IoU=0.0883
# [TRAIN] Epoch 1/150 | Batch 30/153 | Loss=0.5444 | Dice_coeff=0.4556 | IoU=0.2950
# [TRAIN] Epoch 1/150 | Batch 40/153 | Loss=0.6967 | Dice_coeff=0.3033 | IoU=0.1787
# [TRAIN] Epoch 1/150 | Batch 50/153 | Loss=0.5997 | Dice_coeff=0.4003 | IoU=0.2503
# [TRAIN] Epoch 1/150 | Batch 60/153 | Loss=0.4831 | Dice_coeff=0.5169 | IoU=0.3485
# [TRAIN] Epoch 1/150 | Batch 70/153 | Loss=0.4306 | Dice_coeff=0.5694 | IoU=0.3980
# [TRAIN] Epoch 1/150 | Batch 80/153 | Loss=0.3533 | Dice_coeff=0.6467 | IoU=0.4779
# [TRAIN] Epoch 1/150 | Batch 90/153 | Loss=0.5593 | Dice_coeff=0.4407 | IoU=0.2827
# [TRAIN] Epoch 1/150 | Batch 100/153 | Loss=0.4444 | Dice_coeff=0.5556 | IoU=0.3847
# [TRAIN] Epoch 1/150 | Batch 110/153 | Loss=0.5670 | Dice_coeff=0.4330 | IoU=0.2763
# [TRAIN] Epoch 1/150 | Batch 120/153 | Loss=0.4726 | Dice_coeff=0.5274 | IoU=0.3581
# [TRAIN] Epoch 1/150 | Batch 130/153 | Loss=0.4230 | Dice_coeff=0.5770 | IoU=0.4055
# [TRAIN] Epoch 1/150 | Batch 140/153 | Loss=0.4090 | Dice_coeff=0.5910 | IoU=0.4195
# [TRAIN] Epoch 1/150 | Batch 150/153 | Loss=0.4683 | Dice_coeff=0.5317 | IoU=0.3621
#  Train Loss: 0.5968 | Avg_dice_coeff: 0.4032 | Avg_IoU: 0.2641
# Running Validation...
#  Valid Loss: 0.5186 | Dice_coeff: 0.4814 | IoU: 0.3235
# Validation loss improved from inf to 0.5186. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch0.pt
# ========== Epoch 2 / 150 ==========
# Training...
# [TRAIN] Epoch 2/150 | Batch 10/153 | Loss=0.5782 | Dice_coeff=0.4218 | IoU=0.2672
# [TRAIN] Epoch 2/150 | Batch 20/153 | Loss=0.3914 | Dice_coeff=0.6086 | IoU=0.4374
# [TRAIN] Epoch 2/150 | Batch 30/153 | Loss=0.4407 | Dice_coeff=0.5593 | IoU=0.3882
# [TRAIN] Epoch 2/150 | Batch 40/153 | Loss=0.6391 | Dice_coeff=0.3609 | IoU=0.2202
# [TRAIN] Epoch 2/150 | Batch 50/153 | Loss=0.4176 | Dice_coeff=0.5824 | IoU=0.4109
# [TRAIN] Epoch 2/150 | Batch 60/153 | Loss=0.4526 | Dice_coeff=0.5474 | IoU=0.3768
# [TRAIN] Epoch 2/150 | Batch 70/153 | Loss=0.4295 | Dice_coeff=0.5705 | IoU=0.3990
# [TRAIN] Epoch 2/150 | Batch 80/153 | Loss=0.4072 | Dice_coeff=0.5928 | IoU=0.4212
# [TRAIN] Epoch 2/150 | Batch 90/153 | Loss=0.3804 | Dice_coeff=0.6196 | IoU=0.4489
# [TRAIN] Epoch 2/150 | Batch 100/153 | Loss=0.4138 | Dice_coeff=0.5862 | IoU=0.4146
# [TRAIN] Epoch 2/150 | Batch 110/153 | Loss=0.2754 | Dice_coeff=0.7246 | IoU=0.5681
# [TRAIN] Epoch 2/150 | Batch 120/153 | Loss=0.4172 | Dice_coeff=0.5828 | IoU=0.4112
# [TRAIN] Epoch 2/150 | Batch 130/153 | Loss=0.5817 | Dice_coeff=0.4183 | IoU=0.2645
# [TRAIN] Epoch 2/150 | Batch 140/153 | Loss=0.5020 | Dice_coeff=0.4980 | IoU=0.3316
# [TRAIN] Epoch 2/150 | Batch 150/153 | Loss=0.4194 | Dice_coeff=0.5806 | IoU=0.4091
#  Train Loss: 0.4387 | Avg_dice_coeff: 0.5613 | Avg_IoU: 0.3952
# Running Validation...
#  Valid Loss: 0.4351 | Dice_coeff: 0.5649 | IoU: 0.4082
# Validation loss improved from 0.5186 to 0.4351. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch1.pt
# ========== Epoch 3 / 150 ==========
# Training...
# [TRAIN] Epoch 3/150 | Batch 10/153 | Loss=0.4936 | Dice_coeff=0.5064 | IoU=0.3390
# [TRAIN] Epoch 3/150 | Batch 20/153 | Loss=0.2669 | Dice_coeff=0.7331 | IoU=0.5787
# [TRAIN] Epoch 3/150 | Batch 30/153 | Loss=0.4480 | Dice_coeff=0.5520 | IoU=0.3812
# [TRAIN] Epoch 3/150 | Batch 40/153 | Loss=0.5454 | Dice_coeff=0.4546 | IoU=0.2941
# [TRAIN] Epoch 3/150 | Batch 50/153 | Loss=0.4219 | Dice_coeff=0.5781 | IoU=0.4066
# [TRAIN] Epoch 3/150 | Batch 60/153 | Loss=0.3170 | Dice_coeff=0.6830 | IoU=0.5186
# [TRAIN] Epoch 3/150 | Batch 70/153 | Loss=0.4338 | Dice_coeff=0.5662 | IoU=0.3949
# [TRAIN] Epoch 3/150 | Batch 80/153 | Loss=0.4187 | Dice_coeff=0.5813 | IoU=0.4098
# [TRAIN] Epoch 3/150 | Batch 90/153 | Loss=0.4083 | Dice_coeff=0.5917 | IoU=0.4201
# [TRAIN] Epoch 3/150 | Batch 100/153 | Loss=0.2655 | Dice_coeff=0.7345 | IoU=0.5804
# [TRAIN] Epoch 3/150 | Batch 110/153 | Loss=0.4584 | Dice_coeff=0.5416 | IoU=0.3713
# [TRAIN] Epoch 3/150 | Batch 120/153 | Loss=0.2621 | Dice_coeff=0.7379 | IoU=0.5847
# [TRAIN] Epoch 3/150 | Batch 130/153 | Loss=0.5422 | Dice_coeff=0.4578 | IoU=0.2968
# [TRAIN] Epoch 3/150 | Batch 140/153 | Loss=0.5092 | Dice_coeff=0.4908 | IoU=0.3252
# [TRAIN] Epoch 3/150 | Batch 150/153 | Loss=0.3500 | Dice_coeff=0.6500 | IoU=0.4815
#  Train Loss: 0.3858 | Avg_dice_coeff: 0.6142 | Avg_IoU: 0.4494
# Running Validation...
#  Valid Loss: 0.4719 | Dice_coeff: 0.5281 | IoU: 0.3714
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch2.pt
# ========== Epoch 4 / 150 ==========
# Training...
# [TRAIN] Epoch 4/150 | Batch 10/153 | Loss=0.2894 | Dice_coeff=0.7106 | IoU=0.5511
# [TRAIN] Epoch 4/150 | Batch 20/153 | Loss=0.3268 | Dice_coeff=0.6732 | IoU=0.5074
# [TRAIN] Epoch 4/150 | Batch 30/153 | Loss=0.4405 | Dice_coeff=0.5595 | IoU=0.3884
# [TRAIN] Epoch 4/150 | Batch 40/153 | Loss=0.4170 | Dice_coeff=0.5830 | IoU=0.4115
# [TRAIN] Epoch 4/150 | Batch 50/153 | Loss=0.3719 | Dice_coeff=0.6281 | IoU=0.4578
# [TRAIN] Epoch 4/150 | Batch 60/153 | Loss=0.3779 | Dice_coeff=0.6221 | IoU=0.4515
# [TRAIN] Epoch 4/150 | Batch 70/153 | Loss=0.3630 | Dice_coeff=0.6370 | IoU=0.4673
# [TRAIN] Epoch 4/150 | Batch 80/153 | Loss=0.3569 | Dice_coeff=0.6431 | IoU=0.4739
# [TRAIN] Epoch 4/150 | Batch 90/153 | Loss=0.3405 | Dice_coeff=0.6595 | IoU=0.4920
# [TRAIN] Epoch 4/150 | Batch 100/153 | Loss=0.2553 | Dice_coeff=0.7447 | IoU=0.5933
# [TRAIN] Epoch 4/150 | Batch 110/153 | Loss=0.3961 | Dice_coeff=0.6039 | IoU=0.4326
# [TRAIN] Epoch 4/150 | Batch 120/153 | Loss=0.2862 | Dice_coeff=0.7138 | IoU=0.5549
# [TRAIN] Epoch 4/150 | Batch 130/153 | Loss=0.3566 | Dice_coeff=0.6434 | IoU=0.4743
# [TRAIN] Epoch 4/150 | Batch 140/153 | Loss=0.1733 | Dice_coeff=0.8267 | IoU=0.7045
# [TRAIN] Epoch 4/150 | Batch 150/153 | Loss=0.3152 | Dice_coeff=0.6848 | IoU=0.5206
#  Train Loss: 0.3563 | Avg_dice_coeff: 0.6437 | Avg_IoU: 0.4797
# Running Validation...
#  Valid Loss: 0.3630 | Dice_coeff: 0.6370 | IoU: 0.4949
# Validation loss improved from 0.4351 to 0.3630. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch3.pt
# ========== Epoch 5 / 150 ==========
# Training...
# [TRAIN] Epoch 5/150 | Batch 10/153 | Loss=0.3304 | Dice_coeff=0.6696 | IoU=0.5033
# [TRAIN] Epoch 5/150 | Batch 20/153 | Loss=0.3007 | Dice_coeff=0.6993 | IoU=0.5376
# [TRAIN] Epoch 5/150 | Batch 30/153 | Loss=0.4183 | Dice_coeff=0.5817 | IoU=0.4102
# [TRAIN] Epoch 5/150 | Batch 40/153 | Loss=0.2754 | Dice_coeff=0.7246 | IoU=0.5682
# [TRAIN] Epoch 5/150 | Batch 50/153 | Loss=0.4045 | Dice_coeff=0.5955 | IoU=0.4240
# [TRAIN] Epoch 5/150 | Batch 60/153 | Loss=0.3631 | Dice_coeff=0.6369 | IoU=0.4672
# [TRAIN] Epoch 5/150 | Batch 70/153 | Loss=0.2669 | Dice_coeff=0.7331 | IoU=0.5786
# [TRAIN] Epoch 5/150 | Batch 80/153 | Loss=0.2255 | Dice_coeff=0.7745 | IoU=0.6321
# [TRAIN] Epoch 5/150 | Batch 90/153 | Loss=0.3432 | Dice_coeff=0.6568 | IoU=0.4890
# [TRAIN] Epoch 5/150 | Batch 100/153 | Loss=0.3909 | Dice_coeff=0.6091 | IoU=0.4379
# [TRAIN] Epoch 5/150 | Batch 110/153 | Loss=0.2500 | Dice_coeff=0.7500 | IoU=0.6000
# [TRAIN] Epoch 5/150 | Batch 120/153 | Loss=0.4338 | Dice_coeff=0.5662 | IoU=0.3949
# [TRAIN] Epoch 5/150 | Batch 130/153 | Loss=0.3110 | Dice_coeff=0.6890 | IoU=0.5255
# [TRAIN] Epoch 5/150 | Batch 140/153 | Loss=0.2917 | Dice_coeff=0.7083 | IoU=0.5484
# [TRAIN] Epoch 5/150 | Batch 150/153 | Loss=0.3773 | Dice_coeff=0.6227 | IoU=0.4521
#  Train Loss: 0.3194 | Avg_dice_coeff: 0.6806 | Avg_IoU: 0.5213
# Running Validation...
#  Valid Loss: 0.3188 | Dice_coeff: 0.6812 | IoU: 0.5346
# Validation loss improved from 0.3630 to 0.3188. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch4.pt
# ========== Epoch 6 / 150 ==========
# Training...
# [TRAIN] Epoch 6/150 | Batch 10/153 | Loss=0.3588 | Dice_coeff=0.6412 | IoU=0.4718
# [TRAIN] Epoch 6/150 | Batch 20/153 | Loss=0.2551 | Dice_coeff=0.7449 | IoU=0.5935
# [TRAIN] Epoch 6/150 | Batch 30/153 | Loss=0.2743 | Dice_coeff=0.7257 | IoU=0.5695
# [TRAIN] Epoch 6/150 | Batch 40/153 | Loss=0.4016 | Dice_coeff=0.5984 | IoU=0.4270
# [TRAIN] Epoch 6/150 | Batch 50/153 | Loss=0.3531 | Dice_coeff=0.6469 | IoU=0.4781
# [TRAIN] Epoch 6/150 | Batch 60/153 | Loss=0.3298 | Dice_coeff=0.6702 | IoU=0.5040
# [TRAIN] Epoch 6/150 | Batch 70/153 | Loss=0.1643 | Dice_coeff=0.8357 | IoU=0.7178
# [TRAIN] Epoch 6/150 | Batch 80/153 | Loss=0.2765 | Dice_coeff=0.7235 | IoU=0.5668
# [TRAIN] Epoch 6/150 | Batch 90/153 | Loss=0.4459 | Dice_coeff=0.5541 | IoU=0.3832
# [TRAIN] Epoch 6/150 | Batch 100/153 | Loss=0.5056 | Dice_coeff=0.4944 | IoU=0.3284
# [TRAIN] Epoch 6/150 | Batch 110/153 | Loss=0.3977 | Dice_coeff=0.6023 | IoU=0.4310
# [TRAIN] Epoch 6/150 | Batch 120/153 | Loss=0.2840 | Dice_coeff=0.7160 | IoU=0.5576
# [TRAIN] Epoch 6/150 | Batch 130/153 | Loss=0.2304 | Dice_coeff=0.7696 | IoU=0.6255
# [TRAIN] Epoch 6/150 | Batch 140/153 | Loss=0.4169 | Dice_coeff=0.5831 | IoU=0.4115
# [TRAIN] Epoch 6/150 | Batch 150/153 | Loss=0.3111 | Dice_coeff=0.6889 | IoU=0.5254
#  Train Loss: 0.2984 | Avg_dice_coeff: 0.7016 | Avg_IoU: 0.5461
# Running Validation...
#  Valid Loss: 0.3919 | Dice_coeff: 0.6081 | IoU: 0.4461
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch5.pt
# ========== Epoch 7 / 150 ==========
# Training...
# [TRAIN] Epoch 7/150 | Batch 10/153 | Loss=0.1998 | Dice_coeff=0.8002 | IoU=0.6670
# [TRAIN] Epoch 7/150 | Batch 20/153 | Loss=0.3795 | Dice_coeff=0.6205 | IoU=0.4498
# [TRAIN] Epoch 7/150 | Batch 30/153 | Loss=0.4829 | Dice_coeff=0.5171 | IoU=0.3487
# [TRAIN] Epoch 7/150 | Batch 40/153 | Loss=0.2535 | Dice_coeff=0.7465 | IoU=0.5955
# [TRAIN] Epoch 7/150 | Batch 50/153 | Loss=0.2928 | Dice_coeff=0.7072 | IoU=0.5471
# [TRAIN] Epoch 7/150 | Batch 60/153 | Loss=0.2601 | Dice_coeff=0.7399 | IoU=0.5871
# [TRAIN] Epoch 7/150 | Batch 70/153 | Loss=0.2217 | Dice_coeff=0.7783 | IoU=0.6370
# [TRAIN] Epoch 7/150 | Batch 80/153 | Loss=0.2646 | Dice_coeff=0.7354 | IoU=0.5816
# [TRAIN] Epoch 7/150 | Batch 90/153 | Loss=0.2689 | Dice_coeff=0.7311 | IoU=0.5762
# [TRAIN] Epoch 7/150 | Batch 100/153 | Loss=0.2424 | Dice_coeff=0.7576 | IoU=0.6098
# [TRAIN] Epoch 7/150 | Batch 110/153 | Loss=0.1509 | Dice_coeff=0.8491 | IoU=0.7378
# [TRAIN] Epoch 7/150 | Batch 120/153 | Loss=0.2378 | Dice_coeff=0.7622 | IoU=0.6158
# [TRAIN] Epoch 7/150 | Batch 130/153 | Loss=0.3336 | Dice_coeff=0.6664 | IoU=0.4998
# [TRAIN] Epoch 7/150 | Batch 140/153 | Loss=0.3066 | Dice_coeff=0.6934 | IoU=0.5307
# [TRAIN] Epoch 7/150 | Batch 150/153 | Loss=0.1907 | Dice_coeff=0.8093 | IoU=0.6796
#  Train Loss: 0.2789 | Avg_dice_coeff: 0.7211 | Avg_IoU: 0.5701
# Running Validation...
#  Valid Loss: 0.2827 | Dice_coeff: 0.7173 | IoU: 0.5737
# Validation loss improved from 0.3188 to 0.2827. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch6.pt
# ========== Epoch 8 / 150 ==========
# Training...
# [TRAIN] Epoch 8/150 | Batch 10/153 | Loss=0.2281 | Dice_coeff=0.7719 | IoU=0.6286
# [TRAIN] Epoch 8/150 | Batch 20/153 | Loss=0.2118 | Dice_coeff=0.7882 | IoU=0.6504
# [TRAIN] Epoch 8/150 | Batch 30/153 | Loss=0.2525 | Dice_coeff=0.7475 | IoU=0.5968
# [TRAIN] Epoch 8/150 | Batch 40/153 | Loss=0.3174 | Dice_coeff=0.6826 | IoU=0.5181
# [TRAIN] Epoch 8/150 | Batch 50/153 | Loss=0.4073 | Dice_coeff=0.5927 | IoU=0.4212
# [TRAIN] Epoch 8/150 | Batch 60/153 | Loss=0.2326 | Dice_coeff=0.7674 | IoU=0.6226
# [TRAIN] Epoch 8/150 | Batch 70/153 | Loss=0.3353 | Dice_coeff=0.6647 | IoU=0.4978
# [TRAIN] Epoch 8/150 | Batch 80/153 | Loss=0.2152 | Dice_coeff=0.7848 | IoU=0.6458
# [TRAIN] Epoch 8/150 | Batch 90/153 | Loss=0.2530 | Dice_coeff=0.7470 | IoU=0.5962
# [TRAIN] Epoch 8/150 | Batch 100/153 | Loss=0.2768 | Dice_coeff=0.7232 | IoU=0.5664
# [TRAIN] Epoch 8/150 | Batch 110/153 | Loss=0.2844 | Dice_coeff=0.7156 | IoU=0.5572
# [TRAIN] Epoch 8/150 | Batch 120/153 | Loss=0.2186 | Dice_coeff=0.7814 | IoU=0.6412
# [TRAIN] Epoch 8/150 | Batch 130/153 | Loss=0.2196 | Dice_coeff=0.7804 | IoU=0.6399
# [TRAIN] Epoch 8/150 | Batch 140/153 | Loss=0.2437 | Dice_coeff=0.7563 | IoU=0.6082
# [TRAIN] Epoch 8/150 | Batch 150/153 | Loss=0.4466 | Dice_coeff=0.5534 | IoU=0.3825
#  Train Loss: 0.2591 | Avg_dice_coeff: 0.7409 | Avg_IoU: 0.5939
# Running Validation...
#  Valid Loss: 0.2760 | Dice_coeff: 0.7240 | IoU: 0.5822
# Validation loss improved from 0.2827 to 0.2760. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch7.pt
# ========== Epoch 9 / 150 ==========
# Training...
# [TRAIN] Epoch 9/150 | Batch 10/153 | Loss=0.2310 | Dice_coeff=0.7690 | IoU=0.6248
# [TRAIN] Epoch 9/150 | Batch 20/153 | Loss=0.2041 | Dice_coeff=0.7959 | IoU=0.6609
# [TRAIN] Epoch 9/150 | Batch 30/153 | Loss=0.2376 | Dice_coeff=0.7624 | IoU=0.6161
# [TRAIN] Epoch 9/150 | Batch 40/153 | Loss=0.2145 | Dice_coeff=0.7855 | IoU=0.6467
# [TRAIN] Epoch 9/150 | Batch 50/153 | Loss=0.2032 | Dice_coeff=0.7968 | IoU=0.6622
# [TRAIN] Epoch 9/150 | Batch 60/153 | Loss=0.2292 | Dice_coeff=0.7708 | IoU=0.6271
# [TRAIN] Epoch 9/150 | Batch 70/153 | Loss=0.3608 | Dice_coeff=0.6392 | IoU=0.4697
# [TRAIN] Epoch 9/150 | Batch 80/153 | Loss=0.2418 | Dice_coeff=0.7582 | IoU=0.6105
# [TRAIN] Epoch 9/150 | Batch 90/153 | Loss=0.1585 | Dice_coeff=0.8415 | IoU=0.7264
# [TRAIN] Epoch 9/150 | Batch 100/153 | Loss=0.2231 | Dice_coeff=0.7769 | IoU=0.6352
# [TRAIN] Epoch 9/150 | Batch 110/153 | Loss=0.1913 | Dice_coeff=0.8087 | IoU=0.6788
# [TRAIN] Epoch 9/150 | Batch 120/153 | Loss=0.1949 | Dice_coeff=0.8051 | IoU=0.6737
# [TRAIN] Epoch 9/150 | Batch 130/153 | Loss=0.2308 | Dice_coeff=0.7692 | IoU=0.6250
# [TRAIN] Epoch 9/150 | Batch 140/153 | Loss=0.3553 | Dice_coeff=0.6447 | IoU=0.4757
# [TRAIN] Epoch 9/150 | Batch 150/153 | Loss=0.1708 | Dice_coeff=0.8292 | IoU=0.7083
#  Train Loss: 0.2401 | Avg_dice_coeff: 0.7599 | Avg_IoU: 0.6170
# Running Validation...
#  Valid Loss: 0.2502 | Dice_coeff: 0.7498 | IoU: 0.6123
# Validation loss improved from 0.2760 to 0.2502. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch8.pt
# ========== Epoch 10 / 150 ==========
# Training...
# [TRAIN] Epoch 10/150 | Batch 10/153 | Loss=0.1461 | Dice_coeff=0.8539 | IoU=0.7451
# [TRAIN] Epoch 10/150 | Batch 20/153 | Loss=0.2852 | Dice_coeff=0.7148 | IoU=0.5562
# [TRAIN] Epoch 10/150 | Batch 30/153 | Loss=0.2707 | Dice_coeff=0.7293 | IoU=0.5740
# [TRAIN] Epoch 10/150 | Batch 40/153 | Loss=0.4162 | Dice_coeff=0.5838 | IoU=0.4123
# [TRAIN] Epoch 10/150 | Batch 50/153 | Loss=0.3176 | Dice_coeff=0.6824 | IoU=0.5179
# [TRAIN] Epoch 10/150 | Batch 60/153 | Loss=0.2608 | Dice_coeff=0.7392 | IoU=0.5863
# [TRAIN] Epoch 10/150 | Batch 70/153 | Loss=0.2327 | Dice_coeff=0.7673 | IoU=0.6225
# [TRAIN] Epoch 10/150 | Batch 80/153 | Loss=0.3439 | Dice_coeff=0.6561 | IoU=0.4882
# [TRAIN] Epoch 10/150 | Batch 90/153 | Loss=0.2384 | Dice_coeff=0.7616 | IoU=0.6150
# [TRAIN] Epoch 10/150 | Batch 100/153 | Loss=0.2299 | Dice_coeff=0.7701 | IoU=0.6261
# [TRAIN] Epoch 10/150 | Batch 110/153 | Loss=0.1663 | Dice_coeff=0.8337 | IoU=0.7149
# [TRAIN] Epoch 10/150 | Batch 120/153 | Loss=0.2031 | Dice_coeff=0.7969 | IoU=0.6624
# [TRAIN] Epoch 10/150 | Batch 130/153 | Loss=0.2459 | Dice_coeff=0.7541 | IoU=0.6053
# [TRAIN] Epoch 10/150 | Batch 140/153 | Loss=0.2240 | Dice_coeff=0.7760 | IoU=0.6340
# [TRAIN] Epoch 10/150 | Batch 150/153 | Loss=0.2249 | Dice_coeff=0.7751 | IoU=0.6328
#  Train Loss: 0.2323 | Avg_dice_coeff: 0.7677 | Avg_IoU: 0.6267
# Running Validation...
#  Valid Loss: 0.2572 | Dice_coeff: 0.7428 | IoU: 0.6011
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch9.pt
# ========== Epoch 11 / 150 ==========
# Training...
# [TRAIN] Epoch 11/150 | Batch 10/153 | Loss=0.3604 | Dice_coeff=0.6396 | IoU=0.4702
# [TRAIN] Epoch 11/150 | Batch 20/153 | Loss=0.1385 | Dice_coeff=0.8615 | IoU=0.7566
# [TRAIN] Epoch 11/150 | Batch 30/153 | Loss=0.1844 | Dice_coeff=0.8156 | IoU=0.6886
# [TRAIN] Epoch 11/150 | Batch 40/153 | Loss=0.2341 | Dice_coeff=0.7659 | IoU=0.6207
# [TRAIN] Epoch 11/150 | Batch 50/153 | Loss=0.2876 | Dice_coeff=0.7124 | IoU=0.5532
# [TRAIN] Epoch 11/150 | Batch 60/153 | Loss=0.3285 | Dice_coeff=0.6715 | IoU=0.5055
# [TRAIN] Epoch 11/150 | Batch 70/153 | Loss=0.2014 | Dice_coeff=0.7986 | IoU=0.6648
# [TRAIN] Epoch 11/150 | Batch 80/153 | Loss=0.2952 | Dice_coeff=0.7048 | IoU=0.5442
# [TRAIN] Epoch 11/150 | Batch 90/153 | Loss=0.2535 | Dice_coeff=0.7465 | IoU=0.5955
# [TRAIN] Epoch 11/150 | Batch 100/153 | Loss=0.2020 | Dice_coeff=0.7980 | IoU=0.6639
# [TRAIN] Epoch 11/150 | Batch 110/153 | Loss=0.2338 | Dice_coeff=0.7662 | IoU=0.6210
# [TRAIN] Epoch 11/150 | Batch 120/153 | Loss=0.1557 | Dice_coeff=0.8443 | IoU=0.7306
# [TRAIN] Epoch 11/150 | Batch 130/153 | Loss=0.2265 | Dice_coeff=0.7735 | IoU=0.6307
# [TRAIN] Epoch 11/150 | Batch 140/153 | Loss=0.2333 | Dice_coeff=0.7667 | IoU=0.6216
# [TRAIN] Epoch 11/150 | Batch 150/153 | Loss=0.1481 | Dice_coeff=0.8519 | IoU=0.7421
#  Train Loss: 0.2240 | Avg_dice_coeff: 0.7760 | Avg_IoU: 0.6375
# Running Validation...
#  Valid Loss: 0.2484 | Dice_coeff: 0.7516 | IoU: 0.6183
# Validation loss improved from 0.2502 to 0.2484. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch10.pt
# ========== Epoch 12 / 150 ==========
# Training...
# [TRAIN] Epoch 12/150 | Batch 10/153 | Loss=0.1787 | Dice_coeff=0.8213 | IoU=0.6967
# [TRAIN] Epoch 12/150 | Batch 20/153 | Loss=0.2023 | Dice_coeff=0.7977 | IoU=0.6634
# [TRAIN] Epoch 12/150 | Batch 30/153 | Loss=0.1276 | Dice_coeff=0.8724 | IoU=0.7737
# [TRAIN] Epoch 12/150 | Batch 40/153 | Loss=0.2095 | Dice_coeff=0.7905 | IoU=0.6535
# [TRAIN] Epoch 12/150 | Batch 50/153 | Loss=0.1806 | Dice_coeff=0.8194 | IoU=0.6940
# [TRAIN] Epoch 12/150 | Batch 60/153 | Loss=0.1429 | Dice_coeff=0.8571 | IoU=0.7499
# [TRAIN] Epoch 12/150 | Batch 70/153 | Loss=0.1617 | Dice_coeff=0.8383 | IoU=0.7216
# [TRAIN] Epoch 12/150 | Batch 80/153 | Loss=0.2023 | Dice_coeff=0.7977 | IoU=0.6635
# [TRAIN] Epoch 12/150 | Batch 90/153 | Loss=0.1603 | Dice_coeff=0.8397 | IoU=0.7237
# [TRAIN] Epoch 12/150 | Batch 100/153 | Loss=0.2258 | Dice_coeff=0.7742 | IoU=0.6316
# [TRAIN] Epoch 12/150 | Batch 110/153 | Loss=0.2989 | Dice_coeff=0.7011 | IoU=0.5397
# [TRAIN] Epoch 12/150 | Batch 120/153 | Loss=0.1692 | Dice_coeff=0.8308 | IoU=0.7106
# [TRAIN] Epoch 12/150 | Batch 130/153 | Loss=0.3202 | Dice_coeff=0.6798 | IoU=0.5149
# [TRAIN] Epoch 12/150 | Batch 140/153 | Loss=0.2371 | Dice_coeff=0.7629 | IoU=0.6166
# [TRAIN] Epoch 12/150 | Batch 150/153 | Loss=0.2933 | Dice_coeff=0.7067 | IoU=0.5464
#  Train Loss: 0.2054 | Avg_dice_coeff: 0.7946 | Avg_IoU: 0.6629
# Running Validation...
#  Valid Loss: 0.2322 | Dice_coeff: 0.7678 | IoU: 0.6391
# Validation loss improved from 0.2484 to 0.2322. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch11.pt
# ========== Epoch 13 / 150 ==========
# Training...
# [TRAIN] Epoch 13/150 | Batch 10/153 | Loss=0.1311 | Dice_coeff=0.8689 | IoU=0.7683
# [TRAIN] Epoch 13/150 | Batch 20/153 | Loss=0.2055 | Dice_coeff=0.7945 | IoU=0.6590
# [TRAIN] Epoch 13/150 | Batch 30/153 | Loss=0.1898 | Dice_coeff=0.8102 | IoU=0.6810
# [TRAIN] Epoch 13/150 | Batch 40/153 | Loss=0.2872 | Dice_coeff=0.7128 | IoU=0.5538
# [TRAIN] Epoch 13/150 | Batch 50/153 | Loss=0.2031 | Dice_coeff=0.7969 | IoU=0.6623
# [TRAIN] Epoch 13/150 | Batch 60/153 | Loss=0.2775 | Dice_coeff=0.7225 | IoU=0.5655
# [TRAIN] Epoch 13/150 | Batch 70/153 | Loss=0.3081 | Dice_coeff=0.6919 | IoU=0.5290
# [TRAIN] Epoch 13/150 | Batch 80/153 | Loss=0.2807 | Dice_coeff=0.7193 | IoU=0.5616
# [TRAIN] Epoch 13/150 | Batch 90/153 | Loss=0.1888 | Dice_coeff=0.8112 | IoU=0.6824
# [TRAIN] Epoch 13/150 | Batch 100/153 | Loss=0.2193 | Dice_coeff=0.7807 | IoU=0.6402
# [TRAIN] Epoch 13/150 | Batch 110/153 | Loss=0.1458 | Dice_coeff=0.8542 | IoU=0.7455
# [TRAIN] Epoch 13/150 | Batch 120/153 | Loss=0.2216 | Dice_coeff=0.7784 | IoU=0.6372
# [TRAIN] Epoch 13/150 | Batch 130/153 | Loss=0.1313 | Dice_coeff=0.8687 | IoU=0.7678
# [TRAIN] Epoch 13/150 | Batch 140/153 | Loss=0.1925 | Dice_coeff=0.8075 | IoU=0.6771
# [TRAIN] Epoch 13/150 | Batch 150/153 | Loss=0.2746 | Dice_coeff=0.7254 | IoU=0.5691
#  Train Loss: 0.1909 | Avg_dice_coeff: 0.8091 | Avg_IoU: 0.6828
# Running Validation...
#  Valid Loss: 0.2103 | Dice_coeff: 0.7897 | IoU: 0.6632
# Validation loss improved from 0.2322 to 0.2103. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch12.pt
# ========== Epoch 14 / 150 ==========
# Training...
# [TRAIN] Epoch 14/150 | Batch 10/153 | Loss=0.1882 | Dice_coeff=0.8118 | IoU=0.6833
# [TRAIN] Epoch 14/150 | Batch 20/153 | Loss=0.1595 | Dice_coeff=0.8405 | IoU=0.7248
# [TRAIN] Epoch 14/150 | Batch 30/153 | Loss=0.1148 | Dice_coeff=0.8852 | IoU=0.7940
# [TRAIN] Epoch 14/150 | Batch 40/153 | Loss=0.1584 | Dice_coeff=0.8416 | IoU=0.7265
# [TRAIN] Epoch 14/150 | Batch 50/153 | Loss=0.1321 | Dice_coeff=0.8679 | IoU=0.7666
# [TRAIN] Epoch 14/150 | Batch 60/153 | Loss=0.1878 | Dice_coeff=0.8122 | IoU=0.6838
# [TRAIN] Epoch 14/150 | Batch 70/153 | Loss=0.1178 | Dice_coeff=0.8822 | IoU=0.7893
# [TRAIN] Epoch 14/150 | Batch 80/153 | Loss=0.1413 | Dice_coeff=0.8587 | IoU=0.7525
# [TRAIN] Epoch 14/150 | Batch 90/153 | Loss=0.2264 | Dice_coeff=0.7736 | IoU=0.6307
# [TRAIN] Epoch 14/150 | Batch 100/153 | Loss=0.1590 | Dice_coeff=0.8410 | IoU=0.7256
# [TRAIN] Epoch 14/150 | Batch 110/153 | Loss=0.2833 | Dice_coeff=0.7167 | IoU=0.5585
# [TRAIN] Epoch 14/150 | Batch 120/153 | Loss=0.2255 | Dice_coeff=0.7745 | IoU=0.6320
# [TRAIN] Epoch 14/150 | Batch 130/153 | Loss=0.2367 | Dice_coeff=0.7633 | IoU=0.6172
# [TRAIN] Epoch 14/150 | Batch 140/153 | Loss=0.1771 | Dice_coeff=0.8229 | IoU=0.6990
# [TRAIN] Epoch 14/150 | Batch 150/153 | Loss=0.1621 | Dice_coeff=0.8379 | IoU=0.7211
#  Train Loss: 0.1802 | Avg_dice_coeff: 0.8198 | Avg_IoU: 0.6975
# Running Validation...
#  Valid Loss: 0.2069 | Dice_coeff: 0.7931 | IoU: 0.6678
# Validation loss improved from 0.2103 to 0.2069. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch13.pt
# ========== Epoch 15 / 150 ==========
# Training...
# [TRAIN] Epoch 15/150 | Batch 10/153 | Loss=0.0782 | Dice_coeff=0.9218 | IoU=0.8550
# [TRAIN] Epoch 15/150 | Batch 20/153 | Loss=0.1943 | Dice_coeff=0.8057 | IoU=0.6746
# [TRAIN] Epoch 15/150 | Batch 30/153 | Loss=0.3769 | Dice_coeff=0.6231 | IoU=0.4525
# [TRAIN] Epoch 15/150 | Batch 40/153 | Loss=0.1132 | Dice_coeff=0.8868 | IoU=0.7966
# [TRAIN] Epoch 15/150 | Batch 50/153 | Loss=0.2244 | Dice_coeff=0.7756 | IoU=0.6335
# [TRAIN] Epoch 15/150 | Batch 60/153 | Loss=0.1907 | Dice_coeff=0.8093 | IoU=0.6797
# [TRAIN] Epoch 15/150 | Batch 70/153 | Loss=0.2360 | Dice_coeff=0.7640 | IoU=0.6182
# [TRAIN] Epoch 15/150 | Batch 80/153 | Loss=0.2015 | Dice_coeff=0.7985 | IoU=0.6646
# [TRAIN] Epoch 15/150 | Batch 90/153 | Loss=0.1890 | Dice_coeff=0.8110 | IoU=0.6821
# [TRAIN] Epoch 15/150 | Batch 100/153 | Loss=0.1546 | Dice_coeff=0.8454 | IoU=0.7322
# [TRAIN] Epoch 15/150 | Batch 110/153 | Loss=0.1689 | Dice_coeff=0.8311 | IoU=0.7111
# [TRAIN] Epoch 15/150 | Batch 120/153 | Loss=0.1768 | Dice_coeff=0.8232 | IoU=0.6995
# [TRAIN] Epoch 15/150 | Batch 130/153 | Loss=0.2574 | Dice_coeff=0.7426 | IoU=0.5906
# [TRAIN] Epoch 15/150 | Batch 140/153 | Loss=0.2018 | Dice_coeff=0.7982 | IoU=0.6642
# [TRAIN] Epoch 15/150 | Batch 150/153 | Loss=0.1388 | Dice_coeff=0.8612 | IoU=0.7562
#  Train Loss: 0.1880 | Avg_dice_coeff: 0.8120 | Avg_IoU: 0.6873
# Running Validation...
#  Valid Loss: 0.2134 | Dice_coeff: 0.7866 | IoU: 0.6621
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch14.pt
# ========== Epoch 16 / 150 ==========
# Training...
# [TRAIN] Epoch 16/150 | Batch 10/153 | Loss=0.1194 | Dice_coeff=0.8806 | IoU=0.7866
# [TRAIN] Epoch 16/150 | Batch 20/153 | Loss=0.1548 | Dice_coeff=0.8452 | IoU=0.7320
# [TRAIN] Epoch 16/150 | Batch 30/153 | Loss=0.2949 | Dice_coeff=0.7051 | IoU=0.5446
# [TRAIN] Epoch 16/150 | Batch 40/153 | Loss=0.1852 | Dice_coeff=0.8148 | IoU=0.6874
# [TRAIN] Epoch 16/150 | Batch 50/153 | Loss=0.1200 | Dice_coeff=0.8800 | IoU=0.7857
# [TRAIN] Epoch 16/150 | Batch 60/153 | Loss=0.1177 | Dice_coeff=0.8823 | IoU=0.7893
# [TRAIN] Epoch 16/150 | Batch 70/153 | Loss=0.3332 | Dice_coeff=0.6668 | IoU=0.5002
# [TRAIN] Epoch 16/150 | Batch 80/153 | Loss=0.2621 | Dice_coeff=0.7379 | IoU=0.5846
# [TRAIN] Epoch 16/150 | Batch 90/153 | Loss=0.2059 | Dice_coeff=0.7941 | IoU=0.6585
# [TRAIN] Epoch 16/150 | Batch 100/153 | Loss=0.1139 | Dice_coeff=0.8861 | IoU=0.7955
# [TRAIN] Epoch 16/150 | Batch 110/153 | Loss=0.1307 | Dice_coeff=0.8693 | IoU=0.7689
# [TRAIN] Epoch 16/150 | Batch 120/153 | Loss=0.0951 | Dice_coeff=0.9049 | IoU=0.8263
# [TRAIN] Epoch 16/150 | Batch 130/153 | Loss=0.2628 | Dice_coeff=0.7372 | IoU=0.5838
# [TRAIN] Epoch 16/150 | Batch 140/153 | Loss=0.1138 | Dice_coeff=0.8862 | IoU=0.7956
# [TRAIN] Epoch 16/150 | Batch 150/153 | Loss=0.2283 | Dice_coeff=0.7717 | IoU=0.6283
#  Train Loss: 0.1705 | Avg_dice_coeff: 0.8295 | Avg_IoU: 0.7120
# Running Validation...
#  Valid Loss: 0.1919 | Dice_coeff: 0.8081 | IoU: 0.6884
# Validation loss improved from 0.2069 to 0.1919. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch15.pt
# ========== Epoch 17 / 150 ==========
# Training...
# [TRAIN] Epoch 17/150 | Batch 10/153 | Loss=0.1420 | Dice_coeff=0.8580 | IoU=0.7514
# [TRAIN] Epoch 17/150 | Batch 20/153 | Loss=0.1443 | Dice_coeff=0.8557 | IoU=0.7479
# [TRAIN] Epoch 17/150 | Batch 30/153 | Loss=0.1010 | Dice_coeff=0.8990 | IoU=0.8165
# [TRAIN] Epoch 17/150 | Batch 40/153 | Loss=0.1451 | Dice_coeff=0.8549 | IoU=0.7466
# [TRAIN] Epoch 17/150 | Batch 50/153 | Loss=0.1819 | Dice_coeff=0.8181 | IoU=0.6922
# [TRAIN] Epoch 17/150 | Batch 60/153 | Loss=0.1171 | Dice_coeff=0.8829 | IoU=0.7903
# [TRAIN] Epoch 17/150 | Batch 70/153 | Loss=0.2618 | Dice_coeff=0.7382 | IoU=0.5851
# [TRAIN] Epoch 17/150 | Batch 80/153 | Loss=0.1359 | Dice_coeff=0.8641 | IoU=0.7607
# [TRAIN] Epoch 17/150 | Batch 90/153 | Loss=0.0923 | Dice_coeff=0.9077 | IoU=0.8310
# [TRAIN] Epoch 17/150 | Batch 100/153 | Loss=0.1238 | Dice_coeff=0.8762 | IoU=0.7796
# [TRAIN] Epoch 17/150 | Batch 110/153 | Loss=0.1481 | Dice_coeff=0.8519 | IoU=0.7421
# [TRAIN] Epoch 17/150 | Batch 120/153 | Loss=0.1995 | Dice_coeff=0.8005 | IoU=0.6673
# [TRAIN] Epoch 17/150 | Batch 130/153 | Loss=0.1779 | Dice_coeff=0.8221 | IoU=0.6979
# [TRAIN] Epoch 17/150 | Batch 140/153 | Loss=0.1853 | Dice_coeff=0.8147 | IoU=0.6874
# [TRAIN] Epoch 17/150 | Batch 150/153 | Loss=0.1788 | Dice_coeff=0.8212 | IoU=0.6966
#  Train Loss: 0.1627 | Avg_dice_coeff: 0.8373 | Avg_IoU: 0.7227
# Running Validation...
#  Valid Loss: 0.1907 | Dice_coeff: 0.8093 | IoU: 0.6880
# Validation loss improved from 0.1919 to 0.1907. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch16.pt
# ========== Epoch 18 / 150 ==========
# Training...
# [TRAIN] Epoch 18/150 | Batch 10/153 | Loss=0.1786 | Dice_coeff=0.8214 | IoU=0.6969
# [TRAIN] Epoch 18/150 | Batch 20/153 | Loss=0.1300 | Dice_coeff=0.8700 | IoU=0.7698
# [TRAIN] Epoch 18/150 | Batch 30/153 | Loss=0.2005 | Dice_coeff=0.7995 | IoU=0.6660
# [TRAIN] Epoch 18/150 | Batch 40/153 | Loss=0.1712 | Dice_coeff=0.8288 | IoU=0.7076
# [TRAIN] Epoch 18/150 | Batch 50/153 | Loss=0.1790 | Dice_coeff=0.8210 | IoU=0.6963
# [TRAIN] Epoch 18/150 | Batch 60/153 | Loss=0.2212 | Dice_coeff=0.7788 | IoU=0.6377
# [TRAIN] Epoch 18/150 | Batch 70/153 | Loss=0.1738 | Dice_coeff=0.8262 | IoU=0.7039
# [TRAIN] Epoch 18/150 | Batch 80/153 | Loss=0.1301 | Dice_coeff=0.8699 | IoU=0.7697
# [TRAIN] Epoch 18/150 | Batch 90/153 | Loss=0.1516 | Dice_coeff=0.8484 | IoU=0.7367
# [TRAIN] Epoch 18/150 | Batch 100/153 | Loss=0.1776 | Dice_coeff=0.8224 | IoU=0.6984
# [TRAIN] Epoch 18/150 | Batch 110/153 | Loss=0.1411 | Dice_coeff=0.8589 | IoU=0.7527
# [TRAIN] Epoch 18/150 | Batch 120/153 | Loss=0.1466 | Dice_coeff=0.8534 | IoU=0.7443
# [TRAIN] Epoch 18/150 | Batch 130/153 | Loss=0.1288 | Dice_coeff=0.8712 | IoU=0.7718
# [TRAIN] Epoch 18/150 | Batch 140/153 | Loss=0.1876 | Dice_coeff=0.8124 | IoU=0.6841
# [TRAIN] Epoch 18/150 | Batch 150/153 | Loss=0.1159 | Dice_coeff=0.8841 | IoU=0.7923
#  Train Loss: 0.1671 | Avg_dice_coeff: 0.8329 | Avg_IoU: 0.7167
# Running Validation...
#  Valid Loss: 0.2160 | Dice_coeff: 0.7840 | IoU: 0.6561
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch17.pt
# ========== Epoch 19 / 150 ==========
# Training...
# [TRAIN] Epoch 19/150 | Batch 10/153 | Loss=0.1447 | Dice_coeff=0.8553 | IoU=0.7472
# [TRAIN] Epoch 19/150 | Batch 20/153 | Loss=0.1838 | Dice_coeff=0.8162 | IoU=0.6895
# [TRAIN] Epoch 19/150 | Batch 30/153 | Loss=0.1889 | Dice_coeff=0.8111 | IoU=0.6822
# [TRAIN] Epoch 19/150 | Batch 40/153 | Loss=0.1435 | Dice_coeff=0.8565 | IoU=0.7491
# [TRAIN] Epoch 19/150 | Batch 50/153 | Loss=0.1040 | Dice_coeff=0.8960 | IoU=0.8116
# [TRAIN] Epoch 19/150 | Batch 60/153 | Loss=0.1123 | Dice_coeff=0.8877 | IoU=0.7980
# [TRAIN] Epoch 19/150 | Batch 70/153 | Loss=0.1487 | Dice_coeff=0.8513 | IoU=0.7410
# [TRAIN] Epoch 19/150 | Batch 80/153 | Loss=0.1237 | Dice_coeff=0.8763 | IoU=0.7798
# [TRAIN] Epoch 19/150 | Batch 90/153 | Loss=0.1438 | Dice_coeff=0.8562 | IoU=0.7485
# [TRAIN] Epoch 19/150 | Batch 100/153 | Loss=0.2374 | Dice_coeff=0.7626 | IoU=0.6163
# [TRAIN] Epoch 19/150 | Batch 110/153 | Loss=0.1409 | Dice_coeff=0.8591 | IoU=0.7531
# [TRAIN] Epoch 19/150 | Batch 120/153 | Loss=0.1506 | Dice_coeff=0.8494 | IoU=0.7382
# [TRAIN] Epoch 19/150 | Batch 130/153 | Loss=0.1261 | Dice_coeff=0.8739 | IoU=0.7760
# [TRAIN] Epoch 19/150 | Batch 140/153 | Loss=0.1140 | Dice_coeff=0.8860 | IoU=0.7953
# [TRAIN] Epoch 19/150 | Batch 150/153 | Loss=0.1383 | Dice_coeff=0.8617 | IoU=0.7570
#  Train Loss: 0.1486 | Avg_dice_coeff: 0.8514 | Avg_IoU: 0.7434
# Running Validation...
#  Valid Loss: 0.1897 | Dice_coeff: 0.8103 | IoU: 0.6916
# Validation loss improved from 0.1907 to 0.1897. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch18.pt
# ========== Epoch 20 / 150 ==========
# Training...
# [TRAIN] Epoch 20/150 | Batch 10/153 | Loss=0.1353 | Dice_coeff=0.8647 | IoU=0.7617
# [TRAIN] Epoch 20/150 | Batch 20/153 | Loss=0.1369 | Dice_coeff=0.8631 | IoU=0.7592
# [TRAIN] Epoch 20/150 | Batch 30/153 | Loss=0.1410 | Dice_coeff=0.8590 | IoU=0.7529
# [TRAIN] Epoch 20/150 | Batch 40/153 | Loss=0.1658 | Dice_coeff=0.8342 | IoU=0.7156
# [TRAIN] Epoch 20/150 | Batch 50/153 | Loss=0.1302 | Dice_coeff=0.8698 | IoU=0.7696
# [TRAIN] Epoch 20/150 | Batch 60/153 | Loss=0.1109 | Dice_coeff=0.8891 | IoU=0.8004
# [TRAIN] Epoch 20/150 | Batch 70/153 | Loss=0.1730 | Dice_coeff=0.8270 | IoU=0.7051
# [TRAIN] Epoch 20/150 | Batch 80/153 | Loss=0.1470 | Dice_coeff=0.8530 | IoU=0.7437
# [TRAIN] Epoch 20/150 | Batch 90/153 | Loss=0.1416 | Dice_coeff=0.8584 | IoU=0.7519
# [TRAIN] Epoch 20/150 | Batch 100/153 | Loss=0.1370 | Dice_coeff=0.8630 | IoU=0.7590
# [TRAIN] Epoch 20/150 | Batch 110/153 | Loss=0.1795 | Dice_coeff=0.8205 | IoU=0.6957
# [TRAIN] Epoch 20/150 | Batch 120/153 | Loss=0.1850 | Dice_coeff=0.8150 | IoU=0.6878
# [TRAIN] Epoch 20/150 | Batch 130/153 | Loss=0.1777 | Dice_coeff=0.8223 | IoU=0.6983
# [TRAIN] Epoch 20/150 | Batch 140/153 | Loss=0.1763 | Dice_coeff=0.8237 | IoU=0.7002
# [TRAIN] Epoch 20/150 | Batch 150/153 | Loss=0.1294 | Dice_coeff=0.8706 | IoU=0.7708
#  Train Loss: 0.1523 | Avg_dice_coeff: 0.8477 | Avg_IoU: 0.7388
# Running Validation...
#  Valid Loss: 0.1998 | Dice_coeff: 0.8002 | IoU: 0.6776
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch19.pt
# ========== Epoch 21 / 150 ==========
# Training...
# [TRAIN] Epoch 21/150 | Batch 10/153 | Loss=0.0851 | Dice_coeff=0.9149 | IoU=0.8432
# [TRAIN] Epoch 21/150 | Batch 20/153 | Loss=0.1531 | Dice_coeff=0.8469 | IoU=0.7345
# [TRAIN] Epoch 21/150 | Batch 30/153 | Loss=0.2269 | Dice_coeff=0.7731 | IoU=0.6301
# [TRAIN] Epoch 21/150 | Batch 40/153 | Loss=0.1253 | Dice_coeff=0.8747 | IoU=0.7773
# [TRAIN] Epoch 21/150 | Batch 50/153 | Loss=0.0703 | Dice_coeff=0.9297 | IoU=0.8687
# [TRAIN] Epoch 21/150 | Batch 60/153 | Loss=0.1677 | Dice_coeff=0.8323 | IoU=0.7128
# [TRAIN] Epoch 21/150 | Batch 70/153 | Loss=0.1994 | Dice_coeff=0.8006 | IoU=0.6675
# [TRAIN] Epoch 21/150 | Batch 80/153 | Loss=0.2373 | Dice_coeff=0.7627 | IoU=0.6165
# [TRAIN] Epoch 21/150 | Batch 90/153 | Loss=0.1250 | Dice_coeff=0.8750 | IoU=0.7778
# [TRAIN] Epoch 21/150 | Batch 100/153 | Loss=0.1652 | Dice_coeff=0.8348 | IoU=0.7165
# [TRAIN] Epoch 21/150 | Batch 110/153 | Loss=0.1694 | Dice_coeff=0.8306 | IoU=0.7103
# [TRAIN] Epoch 21/150 | Batch 120/153 | Loss=0.1119 | Dice_coeff=0.8881 | IoU=0.7988
# [TRAIN] Epoch 21/150 | Batch 130/153 | Loss=0.1511 | Dice_coeff=0.8489 | IoU=0.7375
# [TRAIN] Epoch 21/150 | Batch 140/153 | Loss=0.2010 | Dice_coeff=0.7990 | IoU=0.6653
# [TRAIN] Epoch 21/150 | Batch 150/153 | Loss=0.0996 | Dice_coeff=0.9004 | IoU=0.8189
#  Train Loss: 0.1429 | Avg_dice_coeff: 0.8571 | Avg_IoU: 0.7521
# Running Validation...
#  Valid Loss: 0.1801 | Dice_coeff: 0.8199 | IoU: 0.7027
# Validation loss improved from 0.1897 to 0.1801. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch20.pt
# ========== Epoch 22 / 150 ==========
# Training...
# [TRAIN] Epoch 22/150 | Batch 10/153 | Loss=0.1110 | Dice_coeff=0.8890 | IoU=0.8001
# [TRAIN] Epoch 22/150 | Batch 20/153 | Loss=0.1781 | Dice_coeff=0.8219 | IoU=0.6976
# [TRAIN] Epoch 22/150 | Batch 30/153 | Loss=0.1724 | Dice_coeff=0.8276 | IoU=0.7059
# [TRAIN] Epoch 22/150 | Batch 40/153 | Loss=0.1183 | Dice_coeff=0.8817 | IoU=0.7884
# [TRAIN] Epoch 22/150 | Batch 50/153 | Loss=0.1466 | Dice_coeff=0.8534 | IoU=0.7443
# [TRAIN] Epoch 22/150 | Batch 60/153 | Loss=0.1573 | Dice_coeff=0.8427 | IoU=0.7282
# [TRAIN] Epoch 22/150 | Batch 70/153 | Loss=0.1169 | Dice_coeff=0.8831 | IoU=0.7907
# [TRAIN] Epoch 22/150 | Batch 80/153 | Loss=0.2181 | Dice_coeff=0.7819 | IoU=0.6419
# [TRAIN] Epoch 22/150 | Batch 90/153 | Loss=0.1285 | Dice_coeff=0.8715 | IoU=0.7722
# [TRAIN] Epoch 22/150 | Batch 100/153 | Loss=0.1816 | Dice_coeff=0.8184 | IoU=0.6926
# [TRAIN] Epoch 22/150 | Batch 110/153 | Loss=0.1390 | Dice_coeff=0.8610 | IoU=0.7560
# [TRAIN] Epoch 22/150 | Batch 120/153 | Loss=0.0905 | Dice_coeff=0.9095 | IoU=0.8340
# [TRAIN] Epoch 22/150 | Batch 130/153 | Loss=0.1110 | Dice_coeff=0.8890 | IoU=0.8002
# [TRAIN] Epoch 22/150 | Batch 140/153 | Loss=0.1394 | Dice_coeff=0.8606 | IoU=0.7553
# [TRAIN] Epoch 22/150 | Batch 150/153 | Loss=0.1633 | Dice_coeff=0.8367 | IoU=0.7193
#  Train Loss: 0.1454 | Avg_dice_coeff: 0.8546 | Avg_IoU: 0.7489
# Running Validation...
#  Valid Loss: 0.1910 | Dice_coeff: 0.8090 | IoU: 0.6895
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch21.pt
# ========== Epoch 23 / 150 ==========
# Training...
# [TRAIN] Epoch 23/150 | Batch 10/153 | Loss=0.1088 | Dice_coeff=0.8912 | IoU=0.8037
# [TRAIN] Epoch 23/150 | Batch 20/153 | Loss=0.1231 | Dice_coeff=0.8769 | IoU=0.7808
# [TRAIN] Epoch 23/150 | Batch 30/153 | Loss=0.1108 | Dice_coeff=0.8892 | IoU=0.8005
# [TRAIN] Epoch 23/150 | Batch 40/153 | Loss=0.1192 | Dice_coeff=0.8808 | IoU=0.7871
# [TRAIN] Epoch 23/150 | Batch 50/153 | Loss=0.1104 | Dice_coeff=0.8896 | IoU=0.8012
# [TRAIN] Epoch 23/150 | Batch 60/153 | Loss=0.1236 | Dice_coeff=0.8764 | IoU=0.7800
# [TRAIN] Epoch 23/150 | Batch 70/153 | Loss=0.1796 | Dice_coeff=0.8204 | IoU=0.6955
# [TRAIN] Epoch 23/150 | Batch 80/153 | Loss=0.2952 | Dice_coeff=0.7048 | IoU=0.5442
# [TRAIN] Epoch 23/150 | Batch 90/153 | Loss=0.1152 | Dice_coeff=0.8848 | IoU=0.7933
# [TRAIN] Epoch 23/150 | Batch 100/153 | Loss=0.1861 | Dice_coeff=0.8139 | IoU=0.6861
# [TRAIN] Epoch 23/150 | Batch 110/153 | Loss=0.1563 | Dice_coeff=0.8437 | IoU=0.7296
# [TRAIN] Epoch 23/150 | Batch 120/153 | Loss=0.1635 | Dice_coeff=0.8365 | IoU=0.7189
# [TRAIN] Epoch 23/150 | Batch 130/153 | Loss=0.1510 | Dice_coeff=0.8490 | IoU=0.7376
# [TRAIN] Epoch 23/150 | Batch 140/153 | Loss=0.0784 | Dice_coeff=0.9216 | IoU=0.8546
# [TRAIN] Epoch 23/150 | Batch 150/153 | Loss=0.1442 | Dice_coeff=0.8558 | IoU=0.7480
#  Train Loss: 0.1456 | Avg_dice_coeff: 0.8544 | Avg_IoU: 0.7486
# Running Validation...
#  Valid Loss: 0.2134 | Dice_coeff: 0.7866 | IoU: 0.6587
# No improvement in validation loss for 2 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch22.pt
# ========== Epoch 24 / 150 ==========
# Training...
# [TRAIN] Epoch 24/150 | Batch 10/153 | Loss=0.1885 | Dice_coeff=0.8115 | IoU=0.6828
# [TRAIN] Epoch 24/150 | Batch 20/153 | Loss=0.1080 | Dice_coeff=0.8920 | IoU=0.8050
# [TRAIN] Epoch 24/150 | Batch 30/153 | Loss=0.1191 | Dice_coeff=0.8809 | IoU=0.7871
# [TRAIN] Epoch 24/150 | Batch 40/153 | Loss=0.1754 | Dice_coeff=0.8246 | IoU=0.7015
# [TRAIN] Epoch 24/150 | Batch 50/153 | Loss=0.1353 | Dice_coeff=0.8647 | IoU=0.7616
# [TRAIN] Epoch 24/150 | Batch 60/153 | Loss=0.1718 | Dice_coeff=0.8282 | IoU=0.7068
# [TRAIN] Epoch 24/150 | Batch 70/153 | Loss=0.1754 | Dice_coeff=0.8246 | IoU=0.7015
# [TRAIN] Epoch 24/150 | Batch 80/153 | Loss=0.2422 | Dice_coeff=0.7578 | IoU=0.6100
# [TRAIN] Epoch 24/150 | Batch 90/153 | Loss=0.1253 | Dice_coeff=0.8747 | IoU=0.7773
# [TRAIN] Epoch 24/150 | Batch 100/153 | Loss=0.1354 | Dice_coeff=0.8646 | IoU=0.7614
# [TRAIN] Epoch 24/150 | Batch 110/153 | Loss=0.1264 | Dice_coeff=0.8736 | IoU=0.7756
# [TRAIN] Epoch 24/150 | Batch 120/153 | Loss=0.1310 | Dice_coeff=0.8690 | IoU=0.7683
# [TRAIN] Epoch 24/150 | Batch 130/153 | Loss=0.1340 | Dice_coeff=0.8660 | IoU=0.7637
# [TRAIN] Epoch 24/150 | Batch 140/153 | Loss=0.1433 | Dice_coeff=0.8567 | IoU=0.7493
# [TRAIN] Epoch 24/150 | Batch 150/153 | Loss=0.1358 | Dice_coeff=0.8642 | IoU=0.7609
#  Train Loss: 0.1364 | Avg_dice_coeff: 0.8636 | Avg_IoU: 0.7621
# Running Validation...
#  Valid Loss: 0.1798 | Dice_coeff: 0.8202 | IoU: 0.7029
# Validation loss improved from 0.1801 to 0.1798. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch23.pt
# ========== Epoch 25 / 150 ==========
# Training...
# [TRAIN] Epoch 25/150 | Batch 10/153 | Loss=0.1762 | Dice_coeff=0.8238 | IoU=0.7004
# [TRAIN] Epoch 25/150 | Batch 20/153 | Loss=0.1228 | Dice_coeff=0.8772 | IoU=0.7812
# [TRAIN] Epoch 25/150 | Batch 30/153 | Loss=0.1563 | Dice_coeff=0.8437 | IoU=0.7297
# [TRAIN] Epoch 25/150 | Batch 40/153 | Loss=0.1319 | Dice_coeff=0.8681 | IoU=0.7669
# [TRAIN] Epoch 25/150 | Batch 50/153 | Loss=0.0959 | Dice_coeff=0.9041 | IoU=0.8250
# [TRAIN] Epoch 25/150 | Batch 60/153 | Loss=0.1237 | Dice_coeff=0.8763 | IoU=0.7798
# [TRAIN] Epoch 25/150 | Batch 70/153 | Loss=0.1237 | Dice_coeff=0.8763 | IoU=0.7798
# [TRAIN] Epoch 25/150 | Batch 80/153 | Loss=0.1241 | Dice_coeff=0.8759 | IoU=0.7792
# [TRAIN] Epoch 25/150 | Batch 90/153 | Loss=0.0781 | Dice_coeff=0.9219 | IoU=0.8552
# [TRAIN] Epoch 25/150 | Batch 100/153 | Loss=0.1457 | Dice_coeff=0.8543 | IoU=0.7456
# [TRAIN] Epoch 25/150 | Batch 110/153 | Loss=0.1880 | Dice_coeff=0.8120 | IoU=0.6835
# [TRAIN] Epoch 25/150 | Batch 120/153 | Loss=0.1625 | Dice_coeff=0.8375 | IoU=0.7205
# [TRAIN] Epoch 25/150 | Batch 130/153 | Loss=0.1161 | Dice_coeff=0.8839 | IoU=0.7919
# [TRAIN] Epoch 25/150 | Batch 140/153 | Loss=0.1832 | Dice_coeff=0.8168 | IoU=0.6904
# [TRAIN] Epoch 25/150 | Batch 150/153 | Loss=0.1035 | Dice_coeff=0.8965 | IoU=0.8124
#  Train Loss: 0.1280 | Avg_dice_coeff: 0.8720 | Avg_IoU: 0.7748
# Running Validation...
#  Valid Loss: 0.1824 | Dice_coeff: 0.8176 | IoU: 0.6996
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch24.pt
# ========== Epoch 26 / 150 ==========
# Training...
# [TRAIN] Epoch 26/150 | Batch 10/153 | Loss=0.0944 | Dice_coeff=0.9056 | IoU=0.8275
# [TRAIN] Epoch 26/150 | Batch 20/153 | Loss=0.1435 | Dice_coeff=0.8565 | IoU=0.7490
# [TRAIN] Epoch 26/150 | Batch 30/153 | Loss=0.1050 | Dice_coeff=0.8950 | IoU=0.8100
# [TRAIN] Epoch 26/150 | Batch 40/153 | Loss=0.1051 | Dice_coeff=0.8949 | IoU=0.8098
# [TRAIN] Epoch 26/150 | Batch 50/153 | Loss=0.0973 | Dice_coeff=0.9027 | IoU=0.8227
# [TRAIN] Epoch 26/150 | Batch 60/153 | Loss=0.1039 | Dice_coeff=0.8961 | IoU=0.8117
# [TRAIN] Epoch 26/150 | Batch 70/153 | Loss=0.1144 | Dice_coeff=0.8856 | IoU=0.7947
# [TRAIN] Epoch 26/150 | Batch 80/153 | Loss=0.1182 | Dice_coeff=0.8818 | IoU=0.7886
# [TRAIN] Epoch 26/150 | Batch 90/153 | Loss=0.1657 | Dice_coeff=0.8343 | IoU=0.7157
# [TRAIN] Epoch 26/150 | Batch 100/153 | Loss=0.1271 | Dice_coeff=0.8729 | IoU=0.7744
# [TRAIN] Epoch 26/150 | Batch 110/153 | Loss=0.1254 | Dice_coeff=0.8746 | IoU=0.7771
# [TRAIN] Epoch 26/150 | Batch 120/153 | Loss=0.1093 | Dice_coeff=0.8907 | IoU=0.8029
# [TRAIN] Epoch 26/150 | Batch 130/153 | Loss=0.1429 | Dice_coeff=0.8571 | IoU=0.7499
# [TRAIN] Epoch 26/150 | Batch 140/153 | Loss=0.1339 | Dice_coeff=0.8661 | IoU=0.7639
# [TRAIN] Epoch 26/150 | Batch 150/153 | Loss=0.1969 | Dice_coeff=0.8031 | IoU=0.6710
#  Train Loss: 0.1249 | Avg_dice_coeff: 0.8751 | Avg_IoU: 0.7798
# Running Validation...
#  Valid Loss: 0.1779 | Dice_coeff: 0.8221 | IoU: 0.7050
# Validation loss improved from 0.1798 to 0.1779. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch25.pt
# ========== Epoch 27 / 150 ==========
# Training...
# [TRAIN] Epoch 27/150 | Batch 10/153 | Loss=0.1277 | Dice_coeff=0.8723 | IoU=0.7735
# [TRAIN] Epoch 27/150 | Batch 20/153 | Loss=0.0828 | Dice_coeff=0.9172 | IoU=0.8470
# [TRAIN] Epoch 27/150 | Batch 30/153 | Loss=0.1415 | Dice_coeff=0.8585 | IoU=0.7520
# [TRAIN] Epoch 27/150 | Batch 40/153 | Loss=0.0713 | Dice_coeff=0.9287 | IoU=0.8669
# [TRAIN] Epoch 27/150 | Batch 50/153 | Loss=0.1233 | Dice_coeff=0.8767 | IoU=0.7804
# [TRAIN] Epoch 27/150 | Batch 60/153 | Loss=0.1007 | Dice_coeff=0.8993 | IoU=0.8170
# [TRAIN] Epoch 27/150 | Batch 70/153 | Loss=0.1456 | Dice_coeff=0.8544 | IoU=0.7459
# [TRAIN] Epoch 27/150 | Batch 80/153 | Loss=0.0993 | Dice_coeff=0.9007 | IoU=0.8194
# [TRAIN] Epoch 27/150 | Batch 90/153 | Loss=0.0576 | Dice_coeff=0.9424 | IoU=0.8911
# [TRAIN] Epoch 27/150 | Batch 100/153 | Loss=0.1568 | Dice_coeff=0.8432 | IoU=0.7290
# [TRAIN] Epoch 27/150 | Batch 110/153 | Loss=0.1530 | Dice_coeff=0.8470 | IoU=0.7346
# [TRAIN] Epoch 27/150 | Batch 120/153 | Loss=0.0979 | Dice_coeff=0.9021 | IoU=0.8216
# [TRAIN] Epoch 27/150 | Batch 130/153 | Loss=0.2195 | Dice_coeff=0.7805 | IoU=0.6400
# [TRAIN] Epoch 27/150 | Batch 140/153 | Loss=0.0953 | Dice_coeff=0.9047 | IoU=0.8261
# [TRAIN] Epoch 27/150 | Batch 150/153 | Loss=0.0969 | Dice_coeff=0.9031 | IoU=0.8233
#  Train Loss: 0.1156 | Avg_dice_coeff: 0.8844 | Avg_IoU: 0.7940
# Running Validation...
#  Valid Loss: 0.1869 | Dice_coeff: 0.8131 | IoU: 0.6951
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch26.pt
# ========== Epoch 28 / 150 ==========
# Training...
# [TRAIN] Epoch 28/150 | Batch 10/153 | Loss=0.0792 | Dice_coeff=0.9208 | IoU=0.8532
# [TRAIN] Epoch 28/150 | Batch 20/153 | Loss=0.0994 | Dice_coeff=0.9006 | IoU=0.8192
# [TRAIN] Epoch 28/150 | Batch 30/153 | Loss=0.0725 | Dice_coeff=0.9275 | IoU=0.8649
# [TRAIN] Epoch 28/150 | Batch 40/153 | Loss=0.0974 | Dice_coeff=0.9026 | IoU=0.8225
# [TRAIN] Epoch 28/150 | Batch 50/153 | Loss=0.1089 | Dice_coeff=0.8911 | IoU=0.8036
# [TRAIN] Epoch 28/150 | Batch 60/153 | Loss=0.1136 | Dice_coeff=0.8864 | IoU=0.7960
# [TRAIN] Epoch 28/150 | Batch 70/153 | Loss=0.1198 | Dice_coeff=0.8802 | IoU=0.7860
# [TRAIN] Epoch 28/150 | Batch 80/153 | Loss=0.1243 | Dice_coeff=0.8757 | IoU=0.7789
# [TRAIN] Epoch 28/150 | Batch 90/153 | Loss=0.1236 | Dice_coeff=0.8764 | IoU=0.7800
# [TRAIN] Epoch 28/150 | Batch 100/153 | Loss=0.1168 | Dice_coeff=0.8832 | IoU=0.7909
# [TRAIN] Epoch 28/150 | Batch 110/153 | Loss=0.0841 | Dice_coeff=0.9159 | IoU=0.8448
# [TRAIN] Epoch 28/150 | Batch 120/153 | Loss=0.0886 | Dice_coeff=0.9114 | IoU=0.8372
# [TRAIN] Epoch 28/150 | Batch 130/153 | Loss=0.0953 | Dice_coeff=0.9047 | IoU=0.8259
# [TRAIN] Epoch 28/150 | Batch 140/153 | Loss=0.1182 | Dice_coeff=0.8818 | IoU=0.7886
# [TRAIN] Epoch 28/150 | Batch 150/153 | Loss=0.0984 | Dice_coeff=0.9016 | IoU=0.8209
#  Train Loss: 0.1200 | Avg_dice_coeff: 0.8800 | Avg_IoU: 0.7875
# Running Validation...
#  Valid Loss: 0.2127 | Dice_coeff: 0.7873 | IoU: 0.6653
# No improvement in validation loss for 2 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch27.pt
# ========== Epoch 29 / 150 ==========
# Training...
# [TRAIN] Epoch 29/150 | Batch 10/153 | Loss=0.1067 | Dice_coeff=0.8933 | IoU=0.8072
# [TRAIN] Epoch 29/150 | Batch 20/153 | Loss=0.1334 | Dice_coeff=0.8666 | IoU=0.7646
# [TRAIN] Epoch 29/150 | Batch 30/153 | Loss=0.0839 | Dice_coeff=0.9161 | IoU=0.8452
# [TRAIN] Epoch 29/150 | Batch 40/153 | Loss=0.1545 | Dice_coeff=0.8455 | IoU=0.7324
# [TRAIN] Epoch 29/150 | Batch 50/153 | Loss=0.2417 | Dice_coeff=0.7583 | IoU=0.6106
# [TRAIN] Epoch 29/150 | Batch 60/153 | Loss=0.0733 | Dice_coeff=0.9267 | IoU=0.8635
# [TRAIN] Epoch 29/150 | Batch 70/153 | Loss=0.0794 | Dice_coeff=0.9206 | IoU=0.8529
# [TRAIN] Epoch 29/150 | Batch 80/153 | Loss=0.0896 | Dice_coeff=0.9104 | IoU=0.8356
# [TRAIN] Epoch 29/150 | Batch 90/153 | Loss=0.0996 | Dice_coeff=0.9004 | IoU=0.8188
# [TRAIN] Epoch 29/150 | Batch 100/153 | Loss=0.0868 | Dice_coeff=0.9132 | IoU=0.8402
# [TRAIN] Epoch 29/150 | Batch 110/153 | Loss=0.1137 | Dice_coeff=0.8863 | IoU=0.7958
# [TRAIN] Epoch 29/150 | Batch 120/153 | Loss=0.1317 | Dice_coeff=0.8683 | IoU=0.7673
# [TRAIN] Epoch 29/150 | Batch 130/153 | Loss=0.0687 | Dice_coeff=0.9313 | IoU=0.8715
# [TRAIN] Epoch 29/150 | Batch 140/153 | Loss=0.1113 | Dice_coeff=0.8887 | IoU=0.7997
# [TRAIN] Epoch 29/150 | Batch 150/153 | Loss=0.1061 | Dice_coeff=0.8939 | IoU=0.8081
#  Train Loss: 0.1138 | Avg_dice_coeff: 0.8862 | Avg_IoU: 0.7971
# Running Validation...
#  Valid Loss: 0.1772 | Dice_coeff: 0.8228 | IoU: 0.7079
# Validation loss improved from 0.1779 to 0.1772. Saving model...
# Model saved to ==> 18-06-2025_04-10-51/model_best_valloss.pt
# Model saved to ==> 18-06-2025_04-10-51/model_epoch28.pt
# ========== Epoch 30 / 150 ==========
# Training...
# [TRAIN] Epoch 30/150 | Batch 10/153 | Loss=0.0724 | Dice_coeff=0.9276 | IoU=0.8650
# [TRAIN] Epoch 30/150 | Batch 20/153 | Loss=0.0958 | Dice_coeff=0.9042 | IoU=0.8252
# [TRAIN] Epoch 30/150 | Batch 30/153 | Loss=0.1142 | Dice_coeff=0.8858 | IoU=0.7951
# [TRAIN] Epoch 30/150 | Batch 40/153 | Loss=0.0905 | Dice_coeff=0.9095 | IoU=0.8339
# [TRAIN] Epoch 30/150 | Batch 50/153 | Loss=0.0636 | Dice_coeff=0.9364 | IoU=0.8804
# [TRAIN] Epoch 30/150 | Batch 60/153 | Loss=0.0941 | Dice_coeff=0.9059 | IoU=0.8279
# [TRAIN] Epoch 30/150 | Batch 70/153 | Loss=0.1061 | Dice_coeff=0.8939 | IoU=0.8082
# [TRAIN] Epoch 30/150 | Batch 80/153 | Loss=0.1173 | Dice_coeff=0.8827 | IoU=0.7900
# [TRAIN] Epoch 30/150 | Batch 90/153 | Loss=0.1187 | Dice_coeff=0.8813 | IoU=0.7877
# [TRAIN] Epoch 30/150 | Batch 100/153 | Loss=0.0997 | Dice_coeff=0.9003 | IoU=0.8188
# [TRAIN] Epoch 30/150 | Batch 110/153 | Loss=0.0719 | Dice_coeff=0.9281 | IoU=0.8659
# [TRAIN] Epoch 30/150 | Batch 120/153 | Loss=0.1124 | Dice_coeff=0.8876 | IoU=0.7979
# [TRAIN] Epoch 30/150 | Batch 130/153 | Loss=0.0941 | Dice_coeff=0.9059 | IoU=0.8280
# [TRAIN] Epoch 30/150 | Batch 140/153 | Loss=0.1189 | Dice_coeff=0.8811 | IoU=0.7875
# [TRAIN] Epoch 30/150 | Batch 150/153 | Loss=0.1774 | Dice_coeff=0.8226 | IoU=0.6986
#  Train Loss: 0.1110 | Avg_dice_coeff: 0.8890 | Avg_IoU: 0.8016
# Running Validation...
#  Valid Loss: 0.1817 | Dice_coeff: 0.8183 | IoU: 0.7031
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch29.pt
# ========== Epoch 31 / 150 ==========
# Training...
# [TRAIN] Epoch 31/150 | Batch 10/153 | Loss=0.1634 | Dice_coeff=0.8366 | IoU=0.7191
# [TRAIN] Epoch 31/150 | Batch 20/153 | Loss=0.0879 | Dice_coeff=0.9121 | IoU=0.8384
# [TRAIN] Epoch 31/150 | Batch 30/153 | Loss=0.1136 | Dice_coeff=0.8864 | IoU=0.7960
# [TRAIN] Epoch 31/150 | Batch 40/153 | Loss=0.1566 | Dice_coeff=0.8434 | IoU=0.7292
# ...
# [TRAIN] Epoch 140/150 | Batch 150/153 | Loss=0.0175 | Dice_coeff=0.9825 | IoU=0.9657
#  Train Loss: 0.0215 | Avg_dice_coeff: 0.9785 | Avg_IoU: 0.9583
# Running Validation...
#  Valid Loss: 0.1496 | Dice_coeff: 0.8504 | IoU: 0.7462
# No improvement in validation loss for 44 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch139.pt
# ========== Epoch 141 / 150 ==========
# Training...
# [TRAIN] Epoch 141/150 | Batch 10/153 | Loss=0.0157 | Dice_coeff=0.9843 | IoU=0.9691
# [TRAIN] Epoch 141/150 | Batch 20/153 | Loss=0.0184 | Dice_coeff=0.9816 | IoU=0.9638
# [TRAIN] Epoch 141/150 | Batch 30/153 | Loss=0.0406 | Dice_coeff=0.9594 | IoU=0.9219
# [TRAIN] Epoch 141/150 | Batch 40/153 | Loss=0.0126 | Dice_coeff=0.9874 | IoU=0.9750
# [TRAIN] Epoch 141/150 | Batch 50/153 | Loss=0.0344 | Dice_coeff=0.9656 | IoU=0.9334
# [TRAIN] Epoch 141/150 | Batch 60/153 | Loss=0.0143 | Dice_coeff=0.9857 | IoU=0.9718
# [TRAIN] Epoch 141/150 | Batch 70/153 | Loss=0.0162 | Dice_coeff=0.9838 | IoU=0.9682
# [TRAIN] Epoch 141/150 | Batch 80/153 | Loss=0.0147 | Dice_coeff=0.9853 | IoU=0.9709
# [TRAIN] Epoch 141/150 | Batch 90/153 | Loss=0.0167 | Dice_coeff=0.9833 | IoU=0.9671
# [TRAIN] Epoch 141/150 | Batch 100/153 | Loss=0.0214 | Dice_coeff=0.9786 | IoU=0.9582
# [TRAIN] Epoch 141/150 | Batch 110/153 | Loss=0.0129 | Dice_coeff=0.9871 | IoU=0.9744
# [TRAIN] Epoch 141/150 | Batch 120/153 | Loss=0.0112 | Dice_coeff=0.9888 | IoU=0.9778
# [TRAIN] Epoch 141/150 | Batch 130/153 | Loss=0.0537 | Dice_coeff=0.9463 | IoU=0.8980
# [TRAIN] Epoch 141/150 | Batch 140/153 | Loss=0.0205 | Dice_coeff=0.9795 | IoU=0.9599
# [TRAIN] Epoch 141/150 | Batch 150/153 | Loss=0.0185 | Dice_coeff=0.9815 | IoU=0.9637
#  Train Loss: 0.0213 | Avg_dice_coeff: 0.9787 | Avg_IoU: 0.9586
# Running Validation...
#  Valid Loss: 0.1493 | Dice_coeff: 0.8507 | IoU: 0.7465
# No improvement in validation loss for 45 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch140.pt
# ========== Epoch 142 / 150 ==========
# Training...
# [TRAIN] Epoch 142/150 | Batch 10/153 | Loss=0.0148 | Dice_coeff=0.9852 | IoU=0.9709
# [TRAIN] Epoch 142/150 | Batch 20/153 | Loss=0.0154 | Dice_coeff=0.9846 | IoU=0.9696
# [TRAIN] Epoch 142/150 | Batch 30/153 | Loss=0.1235 | Dice_coeff=0.8765 | IoU=0.7802
# [TRAIN] Epoch 142/150 | Batch 40/153 | Loss=0.0119 | Dice_coeff=0.9881 | IoU=0.9765
# [TRAIN] Epoch 142/150 | Batch 50/153 | Loss=0.0129 | Dice_coeff=0.9871 | IoU=0.9746
# [TRAIN] Epoch 142/150 | Batch 60/153 | Loss=0.0331 | Dice_coeff=0.9669 | IoU=0.9359
# [TRAIN] Epoch 142/150 | Batch 70/153 | Loss=0.0293 | Dice_coeff=0.9707 | IoU=0.9431
# [TRAIN] Epoch 142/150 | Batch 80/153 | Loss=0.0165 | Dice_coeff=0.9835 | IoU=0.9675
# [TRAIN] Epoch 142/150 | Batch 90/153 | Loss=0.0137 | Dice_coeff=0.9863 | IoU=0.9729
# [TRAIN] Epoch 142/150 | Batch 100/153 | Loss=0.0192 | Dice_coeff=0.9808 | IoU=0.9623
# [TRAIN] Epoch 142/150 | Batch 110/153 | Loss=0.0186 | Dice_coeff=0.9814 | IoU=0.9635
# [TRAIN] Epoch 142/150 | Batch 120/153 | Loss=0.0295 | Dice_coeff=0.9705 | IoU=0.9427
# [TRAIN] Epoch 142/150 | Batch 130/153 | Loss=0.0151 | Dice_coeff=0.9849 | IoU=0.9702
# [TRAIN] Epoch 142/150 | Batch 140/153 | Loss=0.0138 | Dice_coeff=0.9862 | IoU=0.9727
# [TRAIN] Epoch 142/150 | Batch 150/153 | Loss=0.0142 | Dice_coeff=0.9858 | IoU=0.9720
#  Train Loss: 0.0215 | Avg_dice_coeff: 0.9785 | Avg_IoU: 0.9584
# Running Validation...
#  Valid Loss: 0.1500 | Dice_coeff: 0.8500 | IoU: 0.7457
# No improvement in validation loss for 46 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch141.pt
# ========== Epoch 143 / 150 ==========
# Training...
# [TRAIN] Epoch 143/150 | Batch 10/153 | Loss=0.0141 | Dice_coeff=0.9859 | IoU=0.9721
# [TRAIN] Epoch 143/150 | Batch 20/153 | Loss=0.0270 | Dice_coeff=0.9730 | IoU=0.9475
# [TRAIN] Epoch 143/150 | Batch 30/153 | Loss=0.0112 | Dice_coeff=0.9888 | IoU=0.9778
# [TRAIN] Epoch 143/150 | Batch 40/153 | Loss=0.0180 | Dice_coeff=0.9820 | IoU=0.9647
# [TRAIN] Epoch 143/150 | Batch 50/153 | Loss=0.0224 | Dice_coeff=0.9776 | IoU=0.9562
# [TRAIN] Epoch 143/150 | Batch 60/153 | Loss=0.0139 | Dice_coeff=0.9861 | IoU=0.9726
# [TRAIN] Epoch 143/150 | Batch 70/153 | Loss=0.0173 | Dice_coeff=0.9827 | IoU=0.9660
# [TRAIN] Epoch 143/150 | Batch 80/153 | Loss=0.0322 | Dice_coeff=0.9678 | IoU=0.9375
# [TRAIN] Epoch 143/150 | Batch 90/153 | Loss=0.0154 | Dice_coeff=0.9846 | IoU=0.9697
# [TRAIN] Epoch 143/150 | Batch 100/153 | Loss=0.0147 | Dice_coeff=0.9853 | IoU=0.9710
# [TRAIN] Epoch 143/150 | Batch 110/153 | Loss=0.0149 | Dice_coeff=0.9851 | IoU=0.9707
# [TRAIN] Epoch 143/150 | Batch 120/153 | Loss=0.0313 | Dice_coeff=0.9687 | IoU=0.9393
# [TRAIN] Epoch 143/150 | Batch 130/153 | Loss=0.0135 | Dice_coeff=0.9865 | IoU=0.9733
# [TRAIN] Epoch 143/150 | Batch 140/153 | Loss=0.0187 | Dice_coeff=0.9813 | IoU=0.9633
# [TRAIN] Epoch 143/150 | Batch 150/153 | Loss=0.0901 | Dice_coeff=0.9099 | IoU=0.8347
#  Train Loss: 0.0215 | Avg_dice_coeff: 0.9785 | Avg_IoU: 0.9583
# Running Validation...
#  Valid Loss: 0.1494 | Dice_coeff: 0.8506 | IoU: 0.7466
# No improvement in validation loss for 47 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch142.pt
# ========== Epoch 144 / 150 ==========
# Training...
# [TRAIN] Epoch 144/150 | Batch 10/153 | Loss=0.0129 | Dice_coeff=0.9871 | IoU=0.9746
# [TRAIN] Epoch 144/150 | Batch 20/153 | Loss=0.0156 | Dice_coeff=0.9844 | IoU=0.9693
# [TRAIN] Epoch 144/150 | Batch 30/153 | Loss=0.0140 | Dice_coeff=0.9860 | IoU=0.9725
# [TRAIN] Epoch 144/150 | Batch 40/153 | Loss=0.0169 | Dice_coeff=0.9831 | IoU=0.9667
# [TRAIN] Epoch 144/150 | Batch 50/153 | Loss=0.0123 | Dice_coeff=0.9877 | IoU=0.9756
# [TRAIN] Epoch 144/150 | Batch 60/153 | Loss=0.0168 | Dice_coeff=0.9832 | IoU=0.9670
# [TRAIN] Epoch 144/150 | Batch 70/153 | Loss=0.0220 | Dice_coeff=0.9780 | IoU=0.9569
# [TRAIN] Epoch 144/150 | Batch 80/153 | Loss=0.0914 | Dice_coeff=0.9086 | IoU=0.8325
# [TRAIN] Epoch 144/150 | Batch 90/153 | Loss=0.0132 | Dice_coeff=0.9868 | IoU=0.9740
# [TRAIN] Epoch 144/150 | Batch 100/153 | Loss=0.0114 | Dice_coeff=0.9886 | IoU=0.9776
# [TRAIN] Epoch 144/150 | Batch 110/153 | Loss=0.0175 | Dice_coeff=0.9825 | IoU=0.9656
# [TRAIN] Epoch 144/150 | Batch 120/153 | Loss=0.0160 | Dice_coeff=0.9840 | IoU=0.9686
# [TRAIN] Epoch 144/150 | Batch 130/153 | Loss=0.0140 | Dice_coeff=0.9860 | IoU=0.9723
# [TRAIN] Epoch 144/150 | Batch 140/153 | Loss=0.0165 | Dice_coeff=0.9835 | IoU=0.9674
# [TRAIN] Epoch 144/150 | Batch 150/153 | Loss=0.0167 | Dice_coeff=0.9833 | IoU=0.9671
#  Train Loss: 0.0211 | Avg_dice_coeff: 0.9789 | Avg_IoU: 0.9590
# Running Validation...
#  Valid Loss: 0.1485 | Dice_coeff: 0.8515 | IoU: 0.7478
# No improvement in validation loss for 48 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch143.pt
# ========== Epoch 145 / 150 ==========
# Training...
# [TRAIN] Epoch 145/150 | Batch 10/153 | Loss=0.0183 | Dice_coeff=0.9817 | IoU=0.9641
# [TRAIN] Epoch 145/150 | Batch 20/153 | Loss=0.0555 | Dice_coeff=0.9445 | IoU=0.8949
# [TRAIN] Epoch 145/150 | Batch 30/153 | Loss=0.0288 | Dice_coeff=0.9712 | IoU=0.9441
# [TRAIN] Epoch 145/150 | Batch 40/153 | Loss=0.0208 | Dice_coeff=0.9792 | IoU=0.9592
# [TRAIN] Epoch 145/150 | Batch 50/153 | Loss=0.0222 | Dice_coeff=0.9778 | IoU=0.9566
# [TRAIN] Epoch 145/150 | Batch 60/153 | Loss=0.0229 | Dice_coeff=0.9771 | IoU=0.9553
# [TRAIN] Epoch 145/150 | Batch 70/153 | Loss=0.0128 | Dice_coeff=0.9872 | IoU=0.9747
# [TRAIN] Epoch 145/150 | Batch 80/153 | Loss=0.0118 | Dice_coeff=0.9882 | IoU=0.9767
# [TRAIN] Epoch 145/150 | Batch 90/153 | Loss=0.0217 | Dice_coeff=0.9783 | IoU=0.9575
# [TRAIN] Epoch 145/150 | Batch 100/153 | Loss=0.0137 | Dice_coeff=0.9863 | IoU=0.9729
# [TRAIN] Epoch 145/150 | Batch 110/153 | Loss=0.0124 | Dice_coeff=0.9876 | IoU=0.9755
# [TRAIN] Epoch 145/150 | Batch 120/153 | Loss=0.0223 | Dice_coeff=0.9777 | IoU=0.9564
# [TRAIN] Epoch 145/150 | Batch 130/153 | Loss=0.0136 | Dice_coeff=0.9864 | IoU=0.9731
# [TRAIN] Epoch 145/150 | Batch 140/153 | Loss=0.0179 | Dice_coeff=0.9821 | IoU=0.9648
# [TRAIN] Epoch 145/150 | Batch 150/153 | Loss=0.0242 | Dice_coeff=0.9758 | IoU=0.9527
#  Train Loss: 0.0208 | Avg_dice_coeff: 0.9792 | Avg_IoU: 0.9595
# Running Validation...
#  Valid Loss: 0.1493 | Dice_coeff: 0.8507 | IoU: 0.7465
# No improvement in validation loss for 49 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch144.pt
# ========== Epoch 146 / 150 ==========
# Training...
# [TRAIN] Epoch 146/150 | Batch 10/153 | Loss=0.0175 | Dice_coeff=0.9825 | IoU=0.9656
# [TRAIN] Epoch 146/150 | Batch 20/153 | Loss=0.0138 | Dice_coeff=0.9862 | IoU=0.9728
# [TRAIN] Epoch 146/150 | Batch 30/153 | Loss=0.0331 | Dice_coeff=0.9669 | IoU=0.9359
# [TRAIN] Epoch 146/150 | Batch 40/153 | Loss=0.0114 | Dice_coeff=0.9886 | IoU=0.9775
# [TRAIN] Epoch 146/150 | Batch 50/153 | Loss=0.0137 | Dice_coeff=0.9863 | IoU=0.9730
# [TRAIN] Epoch 146/150 | Batch 60/153 | Loss=0.0262 | Dice_coeff=0.9738 | IoU=0.9489
# [TRAIN] Epoch 146/150 | Batch 70/153 | Loss=0.0156 | Dice_coeff=0.9844 | IoU=0.9694
# [TRAIN] Epoch 146/150 | Batch 80/153 | Loss=0.0177 | Dice_coeff=0.9823 | IoU=0.9651
# [TRAIN] Epoch 146/150 | Batch 90/153 | Loss=0.0320 | Dice_coeff=0.9680 | IoU=0.9380
# [TRAIN] Epoch 146/150 | Batch 100/153 | Loss=0.0163 | Dice_coeff=0.9837 | IoU=0.9680
# [TRAIN] Epoch 146/150 | Batch 110/153 | Loss=0.0341 | Dice_coeff=0.9659 | IoU=0.9341
# [TRAIN] Epoch 146/150 | Batch 120/153 | Loss=0.0118 | Dice_coeff=0.9882 | IoU=0.9767
# [TRAIN] Epoch 146/150 | Batch 130/153 | Loss=0.0678 | Dice_coeff=0.9322 | IoU=0.8730
# [TRAIN] Epoch 146/150 | Batch 140/153 | Loss=0.0359 | Dice_coeff=0.9641 | IoU=0.9307
# [TRAIN] Epoch 146/150 | Batch 150/153 | Loss=0.0508 | Dice_coeff=0.9492 | IoU=0.9034
#  Train Loss: 0.0210 | Avg_dice_coeff: 0.9790 | Avg_IoU: 0.9592
# Running Validation...
#  Valid Loss: 0.1488 | Dice_coeff: 0.8512 | IoU: 0.7474
# No improvement in validation loss for 50 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch145.pt
# ========== Epoch 147 / 150 ==========
# Training...
# [TRAIN] Epoch 147/150 | Batch 10/153 | Loss=0.0151 | Dice_coeff=0.9849 | IoU=0.9703
# [TRAIN] Epoch 147/150 | Batch 20/153 | Loss=0.0156 | Dice_coeff=0.9844 | IoU=0.9694
# [TRAIN] Epoch 147/150 | Batch 30/153 | Loss=0.0240 | Dice_coeff=0.9760 | IoU=0.9532
# [TRAIN] Epoch 147/150 | Batch 40/153 | Loss=0.0211 | Dice_coeff=0.9789 | IoU=0.9587
# [TRAIN] Epoch 147/150 | Batch 50/153 | Loss=0.0122 | Dice_coeff=0.9878 | IoU=0.9759
# [TRAIN] Epoch 147/150 | Batch 60/153 | Loss=0.0135 | Dice_coeff=0.9865 | IoU=0.9733
# [TRAIN] Epoch 147/150 | Batch 70/153 | Loss=0.0177 | Dice_coeff=0.9823 | IoU=0.9652
# [TRAIN] Epoch 147/150 | Batch 80/153 | Loss=0.0133 | Dice_coeff=0.9867 | IoU=0.9737
# [TRAIN] Epoch 147/150 | Batch 90/153 | Loss=0.0139 | Dice_coeff=0.9861 | IoU=0.9725
# [TRAIN] Epoch 147/150 | Batch 100/153 | Loss=0.0150 | Dice_coeff=0.9850 | IoU=0.9705
# [TRAIN] Epoch 147/150 | Batch 110/153 | Loss=0.0345 | Dice_coeff=0.9655 | IoU=0.9333
# [TRAIN] Epoch 147/150 | Batch 120/153 | Loss=0.0141 | Dice_coeff=0.9859 | IoU=0.9722
# [TRAIN] Epoch 147/150 | Batch 130/153 | Loss=0.0162 | Dice_coeff=0.9838 | IoU=0.9680
# [TRAIN] Epoch 147/150 | Batch 140/153 | Loss=0.0542 | Dice_coeff=0.9458 | IoU=0.8971
# [TRAIN] Epoch 147/150 | Batch 150/153 | Loss=0.0134 | Dice_coeff=0.9866 | IoU=0.9736
#  Train Loss: 0.0212 | Avg_dice_coeff: 0.9788 | Avg_IoU: 0.9588
# Running Validation...
#  Valid Loss: 0.1499 | Dice_coeff: 0.8501 | IoU: 0.7458
# No improvement in validation loss for 51 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch146.pt
# ========== Epoch 148 / 150 ==========
# Training...
# [TRAIN] Epoch 148/150 | Batch 10/153 | Loss=0.0199 | Dice_coeff=0.9801 | IoU=0.9609
# [TRAIN] Epoch 148/150 | Batch 20/153 | Loss=0.0170 | Dice_coeff=0.9830 | IoU=0.9666
# [TRAIN] Epoch 148/150 | Batch 30/153 | Loss=0.0267 | Dice_coeff=0.9733 | IoU=0.9479
# [TRAIN] Epoch 148/150 | Batch 40/153 | Loss=0.0160 | Dice_coeff=0.9840 | IoU=0.9685
# [TRAIN] Epoch 148/150 | Batch 50/153 | Loss=0.0170 | Dice_coeff=0.9830 | IoU=0.9665
# [TRAIN] Epoch 148/150 | Batch 60/153 | Loss=0.0132 | Dice_coeff=0.9868 | IoU=0.9739
# [TRAIN] Epoch 148/150 | Batch 70/153 | Loss=0.0264 | Dice_coeff=0.9736 | IoU=0.9486
# [TRAIN] Epoch 148/150 | Batch 80/153 | Loss=0.0116 | Dice_coeff=0.9884 | IoU=0.9770
# [TRAIN] Epoch 148/150 | Batch 90/153 | Loss=0.0127 | Dice_coeff=0.9873 | IoU=0.9750
# [TRAIN] Epoch 148/150 | Batch 100/153 | Loss=0.0129 | Dice_coeff=0.9871 | IoU=0.9746
# [TRAIN] Epoch 148/150 | Batch 110/153 | Loss=0.0173 | Dice_coeff=0.9827 | IoU=0.9660
# [TRAIN] Epoch 148/150 | Batch 120/153 | Loss=0.0152 | Dice_coeff=0.9848 | IoU=0.9701
# [TRAIN] Epoch 148/150 | Batch 130/153 | Loss=0.0133 | Dice_coeff=0.9867 | IoU=0.9738
# [TRAIN] Epoch 148/150 | Batch 140/153 | Loss=0.0145 | Dice_coeff=0.9855 | IoU=0.9715
# [TRAIN] Epoch 148/150 | Batch 150/153 | Loss=0.0262 | Dice_coeff=0.9738 | IoU=0.9489
#  Train Loss: 0.0208 | Avg_dice_coeff: 0.9792 | Avg_IoU: 0.9597
# Running Validation...
#  Valid Loss: 0.1494 | Dice_coeff: 0.8506 | IoU: 0.7466
# No improvement in validation loss for 52 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch147.pt
# ========== Epoch 149 / 150 ==========
# Training...
# [TRAIN] Epoch 149/150 | Batch 10/153 | Loss=0.0239 | Dice_coeff=0.9761 | IoU=0.9534
# [TRAIN] Epoch 149/150 | Batch 20/153 | Loss=0.0163 | Dice_coeff=0.9837 | IoU=0.9680
# [TRAIN] Epoch 149/150 | Batch 30/153 | Loss=0.0168 | Dice_coeff=0.9832 | IoU=0.9670
# [TRAIN] Epoch 149/150 | Batch 40/153 | Loss=0.0153 | Dice_coeff=0.9847 | IoU=0.9698
# [TRAIN] Epoch 149/150 | Batch 50/153 | Loss=0.0266 | Dice_coeff=0.9734 | IoU=0.9481
# [TRAIN] Epoch 149/150 | Batch 60/153 | Loss=0.0182 | Dice_coeff=0.9818 | IoU=0.9643
# [TRAIN] Epoch 149/150 | Batch 70/153 | Loss=0.0121 | Dice_coeff=0.9879 | IoU=0.9760
# [TRAIN] Epoch 149/150 | Batch 80/153 | Loss=0.0387 | Dice_coeff=0.9613 | IoU=0.9254
# [TRAIN] Epoch 149/150 | Batch 90/153 | Loss=0.0180 | Dice_coeff=0.9820 | IoU=0.9646
# [TRAIN] Epoch 149/150 | Batch 100/153 | Loss=0.0212 | Dice_coeff=0.9788 | IoU=0.9585
# [TRAIN] Epoch 149/150 | Batch 110/153 | Loss=0.0183 | Dice_coeff=0.9817 | IoU=0.9641
# [TRAIN] Epoch 149/150 | Batch 120/153 | Loss=0.0151 | Dice_coeff=0.9849 | IoU=0.9702
# [TRAIN] Epoch 149/150 | Batch 130/153 | Loss=0.0159 | Dice_coeff=0.9841 | IoU=0.9687
# [TRAIN] Epoch 149/150 | Batch 140/153 | Loss=0.0127 | Dice_coeff=0.9873 | IoU=0.9748
# [TRAIN] Epoch 149/150 | Batch 150/153 | Loss=0.0148 | Dice_coeff=0.9852 | IoU=0.9709
#  Train Loss: 0.0212 | Avg_dice_coeff: 0.9788 | Avg_IoU: 0.9588
# Running Validation...
#  Valid Loss: 0.1488 | Dice_coeff: 0.8512 | IoU: 0.7472
# No improvement in validation loss for 53 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch148.pt
# ========== Epoch 150 / 150 ==========
# Training...
# [TRAIN] Epoch 150/150 | Batch 10/153 | Loss=0.0173 | Dice_coeff=0.9827 | IoU=0.9660
# [TRAIN] Epoch 150/150 | Batch 20/153 | Loss=0.0331 | Dice_coeff=0.9669 | IoU=0.9359
# [TRAIN] Epoch 150/150 | Batch 30/153 | Loss=0.0332 | Dice_coeff=0.9668 | IoU=0.9357
# [TRAIN] Epoch 150/150 | Batch 40/153 | Loss=0.0147 | Dice_coeff=0.9853 | IoU=0.9711
# [TRAIN] Epoch 150/150 | Batch 50/153 | Loss=0.0210 | Dice_coeff=0.9790 | IoU=0.9589
# [TRAIN] Epoch 150/150 | Batch 60/153 | Loss=0.0181 | Dice_coeff=0.9819 | IoU=0.9645
# [TRAIN] Epoch 150/150 | Batch 70/153 | Loss=0.0145 | Dice_coeff=0.9855 | IoU=0.9713
# [TRAIN] Epoch 150/150 | Batch 80/153 | Loss=0.0193 | Dice_coeff=0.9807 | IoU=0.9622
# [TRAIN] Epoch 150/150 | Batch 90/153 | Loss=0.0139 | Dice_coeff=0.9861 | IoU=0.9726
# [TRAIN] Epoch 150/150 | Batch 100/153 | Loss=0.0151 | Dice_coeff=0.9849 | IoU=0.9703
# [TRAIN] Epoch 150/150 | Batch 110/153 | Loss=0.0503 | Dice_coeff=0.9497 | IoU=0.9041
# [TRAIN] Epoch 150/150 | Batch 120/153 | Loss=0.0165 | Dice_coeff=0.9835 | IoU=0.9675
# [TRAIN] Epoch 150/150 | Batch 130/153 | Loss=0.0672 | Dice_coeff=0.9328 | IoU=0.8740
# [TRAIN] Epoch 150/150 | Batch 140/153 | Loss=0.0359 | Dice_coeff=0.9641 | IoU=0.9307
# [TRAIN] Epoch 150/150 | Batch 150/153 | Loss=0.0137 | Dice_coeff=0.9863 | IoU=0.9730
#  Train Loss: 0.0209 | Avg_dice_coeff: 0.9791 | Avg_IoU: 0.9594
# Running Validation...
#  Valid Loss: 0.1492 | Dice_coeff: 0.8508 | IoU: 0.7469
# No improvement in validation loss for 54 epochs.
# Model saved to ==> 18-06-2025_04-10-51/model_epoch149.pt
# Training complete!

# %%
trainer.visualize_scores()

# %%
test_loader = DataLoader(dataset=valid_dataset, batch_size=1, shuffle=False)

trainer.eval(test_loader)
# Out:
# [Test] Batch 100/611 | Test Loss=0.0323
# [Test] Batch 200/611 | Test Loss=0.1945
# [Test] Batch 300/611 | Test Loss=0.3484
# [Test] Batch 400/611 | Test Loss=0.4140
# [Test] Batch 500/611 | Test Loss=0.4711
# [Test] Batch 600/611 | Test Loss=0.0522
#  Test Loss: 0.1953 | Dice_coeff: 0.8047 | IoU: 0.7235

# %%
width = 4
columns = 3
n_examples = 12

fig, axs = plt.subplots(columns, width, figsize=(3*width , 3*columns), constrained_layout=True)
i = 0
with torch.no_grad():
    for data in test_loader:
        image, mask = data
        mask = mask[0][0]
        if not mask.byte().any():
            continue
        image = image.to(config.DEVICE)
        prediction = trainer.model(image).to('cpu')[0][0]
        prediction = torch.where(prediction > 0.5, 1, 0)
        
        axs[i//width][i%width].imshow(image[0].to('cpu').permute(1, 2, 0))
        axs[i//width][i%width].imshow(mask, alpha=0.5)
        axs[i//width][i%width].imshow(prediction, alpha=0.5)
        if n_examples == i + 1:
            break
        i += 1
