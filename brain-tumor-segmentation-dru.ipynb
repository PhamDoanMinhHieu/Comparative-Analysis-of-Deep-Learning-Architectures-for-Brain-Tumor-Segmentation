# %% [markdown]
# ## **1. Importing required libraries**

# %%
import os
import cv2
import time
import numpy as np
import pandas as pd
from glob import glob
from tqdm import tqdm
import numpy as np 
import cv2 as cv
import zipfile
import io
import requests
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW, lr_scheduler
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
from sklearn.impute import SimpleImputer
# import albumentations
from sklearn.model_selection import train_test_split
from scipy.ndimage.morphology import binary_dilation
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, models, transforms
import torchvision.transforms.functional as TF
from torchvision.utils import make_grid
from datetime import datetime
from enum import Enum
import math
# import hdf5storage
import h5py
from typing import Dict, List, Tuple, Optional, Union

from PIL import Image

# You can use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass

warnings.warn = warn
warnings.filterwarnings('ignore')
# Out:
# /tmp/ipykernel_19/368343941.py:23: DeprecationWarning: Please import `binary_dilation` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.morphology import binary_dilation

# %%
class Config:
    def __init__(self):
        # Dataset and DataLoader Parameters
        self.IMG_SIZE = (256, 256)
        self.BATCH_SIZE = 16
        self.TRAIN_RATIO = 0.8
        self.TEST_RATIO = 0.2

        # Training Parameters
        self.EPOCHS = 150
        self.LEARNING_RATE = 1e-3
        self.WEIGHT_DECAY = 1e-4
        self.LEARNING_RATE_MIN = 1e-6
        self.ACCUMALATION_STEPS = 1
        self.DICE_LOSS = True
        self.PATIENCE = 150

        # Model Parameters
        self.IN_CHANNELS = 1
        self.OUT_CLASSES = 1

        # Other Parameters
        self.DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.SEED = 42
        self.ROOT = "/kaggle/input/brain-tumor-dataset/data/"
        self.SAVE_DIR = '/kaggle/working/checkpoint'

config = Config()

# %%
def set_all_seeds(seed):
    # NumPy
    np.random.seed(seed)
    # PyTorch
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # For multi-GPU setups
    # Ensures that the CUDA convolutions are deterministic, but might slow down training
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False # Set to False for reproducibility

set_all_seeds(config.SEED)

# %%
class ClassesLabels(Enum):
    """Brain tumor classification labels"""
    Meningioma = 1  # U màng não
    Glioma = 2      # U thần kinh đệm  
    Pituitary = 3   # Tuyến uyên
    
    def __len__(self):
        return 3


class BrainTumorDataset(Dataset):
    """
    Brain tumor dataset with balanced class distribution
    
    Args:
        root: Root directory containing class folders
        train: If True, creates training set; if False, creates test set 
        classes: Tuple of classes to include
        test_freq: Fraction of data to use for testing
        random_seed: Random seed for reproducible splits
        normalize_image: Whether to normalize images to 0-255 range
        verbose: Whether to print dataset statistics
    """
    
    CLASS_FOLDERS = {
        ClassesLabels.Meningioma: 'meningioma',
        ClassesLabels.Glioma: 'glioma',
        ClassesLabels.Pituitary: 'pituitary'
    }
    
    def __init__(
        self,
        root: str,
        train: bool = True,
        classes: Tuple[ClassesLabels, ...] = (ClassesLabels.Meningioma, ClassesLabels.Glioma, ClassesLabels.Pituitary),
        test_freq: float = 0.15,
        random_seed: int = 42,
        normalize_image: bool = True,
        verbose: bool = True
    ):
        super().__init__()
        self.root = self._validate_path(root)
        self.train = train
        self.classes = classes
        self.test_freq = test_freq
        self.normalize_image = normalize_image
        
        # Set random seed for reproducible splits
        np.random.seed(random_seed)
        
        # Load and split data
        self.items, self.class_info = self._load_and_split_data()
        
        if verbose:
            self._print_stats()
    
    def _validate_path(self, path: str) -> str:
        """Validate and normalize root path"""
        if not os.path.exists(path):
            raise ValueError(f"Root path does not exist: {path}")
        return os.path.normpath(path)
    
    def _load_and_split_data(self) -> Tuple[List[str], Dict]:
        """Load files and split into train/test per class"""
        items = []
        class_info = {}
        
        for class_label in self.classes:
            folder_name = self.CLASS_FOLDERS[class_label]
            folder_path = os.path.join(self.root, folder_name)
            
            if not os.path.exists(folder_path):
                print(f"Warning: Folder {folder_path} does not exist!")
                continue
            
            # Get all valid files for this class
            all_files = self._get_valid_files(folder_path)
            if not all_files:
                print(f"Warning: No valid files found in {folder_path}")
                continue
            
            # Split files for this class
            train_files, test_files = self._split_files(all_files)
            selected_files = train_files if self.train else test_files
            
            # Add to items with folder prefix
            items.extend([f'{folder_name}/{f}' for f in selected_files])
            
            # Store class statistics
            class_info[class_label.name] = {
                'total': len(all_files),
                'train': len(train_files),
                'test': len(test_files),
                'selected': len(selected_files)
            }
        
        return items, class_info
    
    def _get_valid_files(self, folder_path: str) -> List[str]:
        """Get all valid data files from folder"""
        valid_extensions = ('.mat', '.h5', '.hdf5')
        files = [f for f in os.listdir(folder_path) 
                if f.lower().endswith(valid_extensions)]
        return sorted(files)  # Sort for consistent ordering
    
    def _split_files(self, files: List[str]) -> Tuple[List[str], List[str]]:
        """Split files into train and test sets"""
        files_shuffled = files.copy()
        np.random.shuffle(files_shuffled)
        
        split_point = math.floor((1 - self.test_freq) * len(files_shuffled))
        train_files = files_shuffled[:split_point]
        test_files = files_shuffled[split_point:]
        
        return train_files, test_files
    
    def _normalize_image(self, image: np.ndarray) -> np.ndarray:
        """Normalize image to 0-255 range using MATLAB formula"""
        im1 = image.astype(np.float64)
        min_val, max_val = np.min(im1), np.max(im1)
        
        if max_val == min_val:
            return np.zeros_like(im1, dtype=np.uint8)
        
        im_normalized = 255.0 * (im1 - min_val) / (max_val - min_val)
        return im_normalized.astype(np.uint8)
    
    def _print_stats(self):
        """Print dataset statistics"""
        mode = "Training" if self.train else "Testing"
        print(f"\n=== {mode} Dataset Statistics ===")
        print(f"Total samples: {len(self.items)}")
        print(f"Test frequency: {self.test_freq}")
        
        if self.class_info:
            print("\nClass breakdown:")
            total_selected = sum(info['selected'] for info in self.class_info.values())
            
            for class_name, info in self.class_info.items():
                percentage = (info['selected'] / total_selected * 100) if total_selected > 0 else 0
                print(f"  {class_name}: {info['selected']} ({percentage:.1f}%) "
                      f"[Total: {info['total']}, Train: {info['train']}, Test: {info['test']}]")
        print("=" * 50)
    
    def get_class_distribution(self) -> Dict[str, int]:
        """Get class distribution in current dataset"""
        return {name: info['selected'] for name, info in self.class_info.items()}
    
    def __len__(self) -> int:
        return len(self.items)
    
    def __getitem__(self, idx: int) -> Dict:
        if not (0 <= idx < len(self.items)):
            raise IndexError(f"Index {idx} out of range [0, {len(self.items)})")
        
        file_path = os.path.join(self.root, self.items[idx])
        
        try:
            with h5py.File(file_path, 'r') as f:
                data = f['cjdata']
                
                raw_image = data['image'][:]
                mask = data['tumorMask'][:]
                label = int(data['label'][0][0])
                
                # Apply normalization if requested
                image = self._normalize_image(raw_image) if self.normalize_image else raw_image
                
                return {
                    "label": label,
                    "image": image,
                    "mask": mask,
                    "file_path": self.items[idx]
                }
        
        except Exception as e:
            raise RuntimeError(f"Error loading {file_path}: {str(e)}")


class BrainTumorDatasetMask(BrainTumorDataset):
    """Dataset that returns (image, mask) tuples for backward compatibility"""
    
    def __init__(self, root: str, train: bool = True, transform=None, **kwargs):
        super().__init__(root=root, train=train, **kwargs)
        self.transform = transform
    
    def __getitem__(self, idx: int) -> Union[Tuple[np.ndarray, np.ndarray], any]:
        metadata = super().__getitem__(idx)
        sample = (metadata["image"], metadata["mask"])
        
        return self.transform(*sample) if self.transform else sample

# %%
def inspect_sample(dataset: BrainTumorDataset, idx: int = 0):
    """Inspect a dataset sample"""
    if len(dataset) == 0:
        print("Dataset is empty!")
        return
    
    sample = dataset[idx]
    print(f"\n=== Sample {idx} Inspection ===")
    
    if isinstance(sample, dict):
        print(f"Label: {sample['label']}")
        print(f"Image shape: {sample['image'].shape}, dtype: {sample['image'].dtype}")
        print(f"Image range: [{sample['image'].min()}, {sample['image'].max()}]")
        print(f"Mask shape: {sample['mask'].shape}, dtype: {sample['mask'].dtype}")
        print(f"File: {sample['file_path']}")
    else:
        print(f"Sample type: {type(sample)}")
        if isinstance(sample, tuple) and len(sample) == 2:
            image, mask = sample
            print(f"Image shape: {image.shape}, dtype: {image.dtype}")
            print(f"Mask shape: {mask.shape}, dtype: {mask.dtype}")
    
    print("=" * 35)

# %%
dataset_mask = BrainTumorDatasetMask(root=config.ROOT, train=True, test_freq=0.2)
sample_mask = dataset_mask[0]  # Trả về (image, mask)
print(f"Mask dataset sample type: {type(sample_mask)}")

inspect_sample(dataset_mask, 0)
# Out:
# === Training Dataset Statistics ===
# Total samples: 2438
# Test frequency: 0.2
#
# Class breakdown:
#   Meningioma: 566 (23.2%) [Total: 708, Train: 566, Test: 142]
#   Glioma: 1140 (46.8%) [Total: 1426, Train: 1140, Test: 286]
#   Pituitary: 732 (30.0%) [Total: 915, Train: 732, Test: 183]
# ==================================================
# Mask dataset sample type: <class 'tuple'>
#
# === Sample 0 Inspection ===
# Sample type: <class 'tuple'>
# Image shape: (512, 512), dtype: uint8
# Mask shape: (512, 512), dtype: uint8
# ===================================

# %%
# Visualize function
def visualize(images, masks, original_images=None, original_masks=None):
    fontsize=18
    
    # Xử lý trường hợp input là single sample
    if not isinstance(images, (list, tuple)):
        images = [images]
        masks = [masks]
        if original_images is not None:
            original_images = [original_images]
        if original_masks is not None:
            original_masks = [original_masks]
    
    num_samples = len(images)
    
    if original_images is None and original_masks is None:
        # Hiển thị 2 hàng: hàng 1 là images, hàng 2 là masks
        f, ax = plt.subplots(2, num_samples, figsize=(4*num_samples, 8))
        
        # Nếu chỉ có 1 sample, ax sẽ là 1D array
        if num_samples == 1:
            ax = ax.reshape(2, 1)
        
        for i in range(num_samples):
            ax[0, i].imshow(images[i], cmap='gray')
            ax[0, i].set_title(f'Image {i+1}', fontsize=fontsize)
            ax[0, i].axis('off')
            
            ax[1, i].imshow(masks[i], cmap='gray')
            ax[1, i].set_title(f'Mask {i+1}', fontsize=fontsize)
            ax[1, i].axis('off')
    else:
        # Hiển thị 4 hàng: original images, original masks, transformed images, transformed masks
        f, ax = plt.subplots(4, num_samples, figsize=(4*num_samples, 16))
        
        # Nếu chỉ có 1 sample, ax sẽ là 1D array
        if num_samples == 1:
            ax = ax.reshape(4, 1)
        
        for i in range(num_samples):
            ax[0, i].imshow(original_images[i], cmap='gray')
            ax[0, i].set_title(f'Original Image {i+1}', fontsize=fontsize)
            ax[0, i].axis('off')
            
            ax[1, i].imshow(original_masks[i], cmap='gray')
            ax[1, i].set_title(f'Original Mask {i+1}', fontsize=fontsize)
            ax[1, i].axis('off')
            
            ax[2, i].imshow(images[i], cmap='gray')
            ax[2, i].set_title(f'Transformed Image {i+1}', fontsize=fontsize)
            ax[2, i].axis('off')
            
            ax[3, i].imshow(masks[i], cmap='gray')
            ax[3, i].set_title(f'Transformed Mask {i+1}', fontsize=fontsize)
            ax[3, i].axis('off')
    
    plt.tight_layout()
    plt.show()

# Ví dụ sử dụng với multiple samples
def visualize_multiple_samples(dataset, indices, with_preprocessing=True):
    """
    Hiển thị nhiều samples từ dataset
    
    Args:
        dataset: Dataset object
        indices: List các index muốn hiển thị
        with_preprocessing: Có hiển thị ảnh trước và sau preprocessing không
    """
    images = []
    masks = []
    original_images = []
    original_masks = []
    
    for idx in indices:
        if with_preprocessing and hasattr(dataset, 'transform') and dataset.transform is not None:
            # Lấy dữ liệu gốc (không preprocessing)
            dataset_temp = dataset.__class__(dataset.root, dataset.train, transform=None, classes=dataset.classes)
            orig_img, orig_mask = dataset_temp[idx]
            original_images.append(orig_img)
            original_masks.append(orig_mask)
            
            # Lấy dữ liệu đã preprocessing
            proc_img, proc_mask = dataset[idx]
            images.append(proc_img.squeeze() if hasattr(proc_img, 'squeeze') else proc_img)
            masks.append(proc_mask.squeeze() if hasattr(proc_mask, 'squeeze') else proc_mask)
        else:
            # Chỉ lấy dữ liệu hiện tại
            img, mask = dataset[idx]
            images.append(img.squeeze() if hasattr(img, 'squeeze') else img)
            masks.append(mask.squeeze() if hasattr(mask, 'squeeze') else mask)
    
    if with_preprocessing and original_images:
        visualize(images, masks, original_images, original_masks)
    else:
        visualize(images, masks)

# Hàm tiền xử lí dữ liệu
def preprocessing(image, mask):
    image_transformer = transforms.Compose([
        transforms.ToTensor(),
        transforms.Resize(config.IMG_SIZE, interpolation=0),
        # transforms.Normalize(mean=(0.5,), std=(0.5,))  # Normalize image
        ])
    mask_transformer = transforms.Compose([
        transforms.Lambda(lambda x: transforms.ToPILImage()(transforms.ToTensor()(x).float().squeeze())),
        transforms.ToTensor(),
        transforms.Resize(config.IMG_SIZE, interpolation=0),
    ])
    # image = np.transpose(np.array(image)) / 65535.0
    # image = image * 2 - 1
    image = np.transpose(np.array(image))
    mask = np.transpose(np.array(mask))
    mask = mask_transformer(mask)
    mask = mask / mask.max()
    mask = torch.where(mask > 0.5, 1, 0).float()
    return image_transformer(image).float(), mask

# %%
# Khởi tạo dataset
dataset = BrainTumorDatasetMask(root=config.ROOT, train=True, transform=preprocessing)
original_image, original_mask = dataset[3]
print(f'#=>Original image: {type(original_image)}')
print(f'#=>Original mask: {type(original_mask)}')
# Out:
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
# #=>Original image: <class 'torch.Tensor'>
# #=>Original mask: <class 'torch.Tensor'>

# %%
visualize(original_image.squeeze(), original_mask.squeeze())

# %%
visualize_multiple_samples(dataset, [0, 1, 2, 3])
# Out:
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
#
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
#
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================
#
# === Training Dataset Statistics ===
# Total samples: 2590
# Test frequency: 0.15
#
# Class breakdown:
#   Meningioma: 601 (23.2%) [Total: 708, Train: 601, Test: 107]
#   Glioma: 1212 (46.8%) [Total: 1426, Train: 1212, Test: 214]
#   Pituitary: 777 (30.0%) [Total: 915, Train: 777, Test: 138]
# ==================================================

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DoubleConv, self).__init__()
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.GroupNorm(min(8, out_channels), out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.GroupNorm(min(8, out_channels), out_channels),
            nn.ReLU(inplace=True),
        )
    
    def forward(self, x):
        return self.double_conv(x)
    
class DownBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DownBlock, self).__init__()
        self.double_conv = DoubleConv(in_channels, out_channels)
        self.down_sample = nn.MaxPool2d(2)
        
    def forward(self, x):
        skip_out = self.double_conv(x)
        down_out = self.down_sample(skip_out)
        return down_out, skip_out
    
class UpBlock(nn.Module):
    def __init__(self, in_channels, out_channels, up_sample_mode):
        super(UpBlock, self).__init__()
        if up_sample_mode == 'conv_transpose':
            self.up_sample = nn.ConvTranspose2d(in_channels-out_channels, in_channels-out_channels, kernel_size=2, stride=2)        
        elif up_sample_mode == 'bilinear':
            self.up_sample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        else:
            raise ValueError("Unsupported `up_sample_mode` (can take one of `conv_transpose` or `bilinear`)")
        self.double_conv = DoubleConv(in_channels, out_channels)

    def forward(self, down_input, skip_input):
        x = self.up_sample(down_input)
        x = torch.cat([x, skip_input], dim=1)
        return self.double_conv(x)

class ConvDRU(nn.Module):
    def __init__(self,
                 input_size,
                 hidden_size,
                 ):
        super(ConvDRU, self).__init__()

        self.reset_gate = DoubleConv(input_size, input_size)
        self.update_gate = DoubleConv(input_size, hidden_size)
        self.out_gate = DoubleConv(input_size, hidden_size)

    def forward(self, input_, h=None):
        update = torch.sigmoid(self.update_gate(input_))
        reset = torch.sigmoid(self.reset_gate(input_))

        out_inputs = torch.tanh(self.out_gate(input_ * reset))
        # h_new = h * (1 - update) + out_inputs * update
        h_new = h * update + (1 - update) * out_inputs

        return h_new

# Dual-gated Reccurent Unit
class DRU(nn.Module):
    def __init__(self, in_channels=3, out_classes=2, steps=3, up_sample_mode='conv_transpose'):
        super(DRU, self).__init__()
        self.up_sample_mode = up_sample_mode
        self.steps = steps
        filters = [32, 64, 128, 256, 512]
        # filters = [64, 128, 256, 512, 1024]
        # Downsampling Path
        self.down_conv1 = DownBlock(in_channels + out_classes, filters[0])
        self.down_conv2 = DownBlock(filters[0], filters[1])
        self.down_conv3 = DownBlock(filters[1], filters[2])
        self.down_conv4 = DownBlock(filters[2], filters[3])
        # Bottleneck
        self.gru = ConvDRU(filters[3], filters[4])
        # upsampling Path
        self.up_conv4 = UpBlock(filters[3] + filters[4], filters[3], self.up_sample_mode)
        self.up_conv3 = UpBlock(filters[2] + filters[3], filters[2], self.up_sample_mode)
        self.up_conv2 = UpBlock(filters[1] + filters[2], filters[1], self.up_sample_mode)
        self.up_conv1 = UpBlock(filters[1] + filters[0], filters[0], self.up_sample_mode)
        # Final Convolution
        self.conv_last = nn.Conv2d(filters[0], out_classes, kernel_size=1)
        self.softmax = nn.Softmax2d()
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x, h, s):
        list_st = []
        for i in range(self.steps):
            s = self.softmax(s)
            stacked_inputs = torch.cat([x, s], dim=1)
            x, skip1_out = self.down_conv1(stacked_inputs)
            x, skip2_out = self.down_conv2(x)
            x, skip3_out = self.down_conv3(x)
            x, skip4_out = self.down_conv4(x)
            h = self.gru(x, h)
            x = self.up_conv4(h, skip4_out)
            x = self.up_conv3(x, skip3_out)
            x = self.up_conv2(x, skip2_out)
            x = self.up_conv1(x, skip1_out)
            x = self.conv_last(x)
            x = self.sigmoid(x)

            list_st += [x]
        return list_st

# %%
class Trainer():
    def __init__(self,
                 model,
                 train_dataloader,
                 valid_dataloader,
                 epochs=10,
                 save_dir=None,
                 device='cpu',
                 accumalation_steps=4,
                 patience=5):  # Add patience for early stopping
        self.device = device
        self.accumalation_steps = accumalation_steps

        self.model = model.to(self.device)

        self.train_losses = []
        self.train_dice_coeff_values = []
        self.train_iou_values = []
        self.val_losses = []
        self.val_dice_coeff_values = []
        self.val_iou_values = []
        
        self.patience = patience  # Early stopping patience
        self.early_stop = False  # Flag for early stopping
        self.best_valid_loss = float('inf')  # Initialize best loss

        if save_dir != None and os.path.exists(save_dir):
            print("Load weight from file:{}".format(save_dir))
            self.save_dir = save_dir
            epcho_checkpoint_path = glob.glob("{}/model_epoch*".format(self.save_dir))
            if len(epcho_checkpoint_path) == 0:
                print("No checkpoint found in: {}\nCheck save_dir...".format(self.save_dir))
            else:
                self.load_checkpoint(epcho_checkpoint_path[0])
                print("Restore weight successful from: {}".format(epcho_checkpoint_path))
        else:
            self.save_dir = datetime.now().strftime("%d-%m-%Y_%H-%M-%S")
            os.makedirs(self.save_dir)
            print("Training new model, save to: {}".format(self.save_dir))

        self.train_dataloader = train_dataloader
        self.valid_dataloader = valid_dataloader
        self.epochs = epochs

    def save_checkpoint(self, save_path):
        state_dict = {'model_state_dict': self.model.state_dict(),
                      'train_losses': self.train_losses,
                      'train_dice_coeff_values': self.train_dice_coeff_values,
                      'train_iou_values': self.train_iou_values,
                      'val_losses': self.val_losses,
                      'val_dice_coeff_values': self.val_dice_coeff_values,
                      'val_iou_values': self.val_iou_values
                     }
        torch.save(state_dict, save_path)
        print(f"Model saved to ==> {save_path}")

    def load_checkpoint(self, load_path):
        state_dict = torch.load(load_path, map_location=self.device)
        print(f"Model restored from <== {load_path}")
        self.model.load_state_dict(state_dict["model_state_dict"])
        self.train_losses = state_dict["train_losses"]
        self.train_dice_coeff_values = state_dict["train_dice_coeff_values"]
        self.train_iou_values = state_dict['train_iou_values']
        self.val_losses = state_dict["val_losses"]
        self.val_dice_coeff_values = state_dict["val_dice_coeff_values"]
        self.val_iou_values = state_dict['val_iou_values']

    @staticmethod
    def iou(pred_mask, true_mask):
        # Làm phẳng các tensor
        pred_mask = pred_mask.view(-1)
        true_mask = true_mask.view(-1)
    
        # Tính toán phần giao nhau và hợp nhất
        intersection = torch.sum(pred_mask * true_mask)
        union = torch.sum(pred_mask) + torch.sum(true_mask) - intersection
    
        # Tính IoU
        iou = intersection / union
    
        return iou

    @staticmethod
    def dice_loss(pred, target, smooth=1e-6):
        pred = pred.view(-1)
        target = target.view(-1)
        
        # Flatten the tensors to calculate the intersection and union of predicted and true masks
        intersection = torch.sum(pred * target)
        union = torch.sum(pred) + torch.sum(target)
        
        # Compute Dice coefficient
        dice = (2. * intersection + smooth) / (union + smooth)
        
        return 1 - dice

    @staticmethod
    def dice_coeff(pred, target, smooth=1e-6, threshold=0.5):
        pred = pred.view(-1)
        target = target.view(-1)
        # pred = (pred > threshold).float()
        
        intersection = torch.sum(pred * target)
        union = torch.sum(pred) + torch.sum(target)
        return (2. * intersection + smooth) / (union + smooth)
    
    def train(self):
        if config.DICE_LOSS:
            criterions= [self.dice_loss for _ in range(3)]
        else:
            criterions= [nn.BCELoss() for _ in range(3)]
            
        # print(len(criterions))
        # criterion = self.dice_loss
        optimizer = torch.optim.AdamW(self.model.parameters(), lr=config.LEARNING_RATE, weight_decay=config.WEIGHT_DECAY)

        scheduler = lr_scheduler.CosineAnnealingLR(optimizer, T_max=config.EPOCHS, eta_min=config.LEARNING_RATE_MIN)
        
        patience_counter = 0  # Track epochs without improvement

        for epoch_i in range(0, self.epochs):
            if self.early_stop:  # Check if early stopping is triggered
                print("Early stopping triggered. Training stopped.")
                break

            print('========== Epoch {:} / {:} =========='.format(epoch_i + 1, self.epochs))
            print('Training...')

            total_loss = 0
            total_com_losses = [0]*3
            self.model.train()
            nb_train_steps = 0
            train_iou = 0
            train_dice_coeff = 0

            for step, batch in enumerate(self.train_dataloader):
                img, mask = batch
                img, mask = img.to(self.device), mask.to(self.device)
                
                s = torch.zeros_like(mask).to(self.device)
                h = torch.zeros(mask.size(0), 512, 16, 16).to(self.device)
                outputs = self.model(img, h, s)

               # compute loss
                alpha = 0.4 # 0.4 # 1
                steps = 3
                loss = 0
                losses = []
                # for i in range(steps-1, -1, -1):
                for i in range(steps):
                    _loss = criterions[i](outputs[i], mask)
                    # print(_loss)
                    # print(_loss.requires_grad)     # Phải trả về True
                    loss = loss + _loss*(alpha**(steps-i-1))
                    losses.append(_loss)
                    # losses = [_loss] + losses

                
                dice = self.dice_coeff(outputs[-1].detach(), mask).item()
                train_dice_coeff += dice
                iou = self.iou(outputs[-1].detach(), mask).item()
                train_iou += iou
                # print(loss)
                loss = loss / self.accumalation_steps
                total_loss += loss.item() * self.accumalation_steps
                for i in range(steps):
                    total_com_losses[i] += losses[i].item()
                
                nb_train_steps += 1

                loss.backward()
                if (step + 1) % self.accumalation_steps == 0:
                    optimizer.step()
                    # scheduler.step()
                    optimizer.zero_grad()

                if (step + 1) % 10 == 0:
                    print("[TRAIN] Epoch {}/{} | Batch {}/{} | Loss_1={:.4f} | Loss_2={:.4f} | Loss_3={:.4f} | Totol_Loss={:.4f} | Dice_coeff={:.4f} | IoU={:.4f}".format(epoch_i + 1, self.epochs, step + 1, len(self.train_dataloader), losses[0].item(), losses[1].item(), losses[2].item(), loss.item(), dice, iou))
                            
            scheduler.step()
            avg_train_loss = total_loss / len(self.train_dataloader)
            avg_train_dice_coeff = train_dice_coeff / nb_train_steps
            avg_train_iou = train_iou / nb_train_steps
            print(" Train Loss_1: {:.4f} | Loss_2: {:.4f} | Loss_3: {:.4f} | Total_Loss: {:.4f} | Avg_dice_coeff: {:.4f} | Avg_IoU: {:.4f}".format(total_com_losses[0]/nb_train_steps, total_com_losses[1]/nb_train_steps, total_com_losses[2]/nb_train_steps, avg_train_loss, avg_train_dice_coeff, avg_train_iou))

            self.train_losses.append(avg_train_loss)
            self.train_dice_coeff_values.append(avg_train_dice_coeff)
            self.train_iou_values.append(avg_train_iou)

            print("Running Validation...")
            self.model.eval()
            eval_loss = 0
            eval_com_losses = [0]*3
            eval_iou = 0
            eval_dice_coeff = 0
            nb_eval_steps = 0

            for batch in self.valid_dataloader:
                img, mask = batch
                img, mask = img.to(self.device), mask.to(self.device)

                with torch.no_grad():
                    s = torch.zeros_like(mask).to(self.device)
                    h = torch.zeros(mask.size(0), 512, 16, 16).to(self.device)
                    outputs = self.model(img, h, s)
            
                    # compute loss
                    alpha = 0.4 # 0.4 # 1
                    steps = 3
                    loss = 0
                    losses = []
                    # for i in range(steps-1, -1, -1):
                    for i in range(steps):
                        _loss = criterions[i](outputs[i], mask)
                        loss = loss + _loss*(alpha**(steps-i-1))
                        losses.append(_loss)

                    for i in range(steps):
                        eval_com_losses[i] += losses[i].item()
                        
                    eval_dice_coeff += self.dice_coeff(outputs[-1].detach(), mask).item()
                    eval_iou += self.iou(outputs[-1].detach(), mask).item()
                    eval_loss += loss.item()
                    nb_eval_steps += 1

            avg_val_loss = eval_loss / nb_eval_steps
            avg_val_dice_coeff = eval_dice_coeff / nb_eval_steps
            avg_val_iou = eval_iou / nb_eval_steps
            
            print(f" Valid Loss_1: {eval_com_losses[0]/nb_eval_steps:.4f} | Loss_2: {eval_com_losses[1]/nb_eval_steps:.4f} | Loss_3: {eval_com_losses[2]/nb_eval_steps:.4f} \n Total_Loss: {avg_val_loss:.4f} | Dice_coeff: {avg_val_dice_coeff:.4f} | IoU: {avg_val_iou:.4f}")

            self.val_losses.append(avg_val_loss)
            self.val_dice_coeff_values.append(avg_val_dice_coeff)
            self.val_iou_values.append(avg_val_iou)

            # Early stopping logic
            if (eval_com_losses[2]/nb_eval_steps) < self.best_valid_loss:
                print(f"Validation loss improved from {self.best_valid_loss:.4f} to {eval_com_losses[2]/nb_eval_steps:.4f}. Saving model...")
                self.best_valid_loss = eval_com_losses[2]/nb_eval_steps
                patience_counter = 0  # Reset patience counter
                best_valid_loss_path = "{}/model_best_valloss.pt".format(self.save_dir)
                self.save_checkpoint(best_valid_loss_path)
            else:
                patience_counter += 1
                print(f"No improvement in validation loss for {patience_counter} epochs.")
                if patience_counter >= self.patience:
                    print(f"Stopping early after {patience_counter} epochs without improvement.")
                    self.early_stop = True

            # Save checkpoint for current epoch
            epoch_i_path = "{}/model_epoch{}.pt".format(self.save_dir, epoch_i)
            self.save_checkpoint(epoch_i_path)

            # Remove the previous epoch's checkpoint
            if os.path.exists("{}/model_epoch{}.pt".format(self.save_dir, epoch_i-1)):
                os.remove("{}/model_epoch{}.pt".format(self.save_dir, epoch_i-1))

        print("Training complete!")
        

    def eval(self, dataloader):
        self.model.eval()
        if config.DICE_LOSS:
            criterions= [self.dice_loss for _ in range(3)]
        else:
            criterions= [nn.BCELoss() for _ in range(3)]
        nb_eval_steps = 0
        eval_loss = 0
        eval_com_losses = [0]*3
        eval_iou = 0
        eval_dice_coeff = 0
        for step, batch in enumerate(dataloader):
            img, mask = batch
            img, mask = img.to(self.device), mask.to(self.device)

            with torch.no_grad():
                s = torch.zeros_like(mask).to(self.device)
                h = torch.zeros(mask.size(0), 512, 16, 16).to(self.device)
                outputs = self.model(img.to(self.device), h, s)

                # compute loss
                alpha = 0.4 # 0.4 # 1
                steps = 3
                loss = 0
                losses = []
                # for i in range(steps-1, -1, -1):
                for i in range(steps):
                    _loss = criterions[i](outputs[i], mask)
                    # print(_loss)
                    # print(_loss.requires_grad)     # Phải trả về True
                    loss = loss + _loss*(alpha**(steps-i-1))
                    losses.append(_loss)
                    # losses = [_loss] + losses

                for i in range(steps):
                    eval_com_losses[i] += losses[i].item()
                    
                eval_dice_coeff += self.dice_coeff(outputs[-1], mask).item()
                eval_iou += self.iou(outputs[-1], mask).item()
                eval_loss += loss.item()
                nb_eval_steps += 1
                
            if (step + 1) % 100 == 0:
                    print("[Test] Batch {}/{} | Test Loss_1={:.4f} | Loss_2={:.4f} | Loss_3={:.4f} | Total_Loss={:.4f}".format(step + 1, len(dataloader), losses[0], losses[1], losses[2], loss))
        avg_val_loss = eval_loss / nb_eval_steps
        avg_dice_coeff = eval_dice_coeff / nb_eval_steps
        avg_iou = eval_iou / nb_eval_steps
        
        print(f" Test Loss_1: {eval_com_losses[0]/nb_eval_steps:.4f} | Loss_2: {eval_com_losses[1]/nb_eval_steps:.4f} | Loss_2: {eval_com_losses[2]/nb_eval_steps:.4f} \n Total_Loss: {avg_val_loss:.4f} | Dice_coeff: {avg_dice_coeff:.4f} | IoU: {avg_iou:.4f}")
        return

    def visualize_scores(self):
        num_epoches = range(1, len(self.train_losses) + 1)
        # Vẽ Loss
        plt.figure(figsize=(12, 6))
        plt.plot(num_epoches, self.train_losses, label='Train Loss', marker='o', color='blue')
        plt.plot(num_epoches, self.val_losses, label='Test Loss', marker='o', color='orange')
        plt.title('Training and Testing Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        plt.grid(True)
        plt.show()
        
        # Vẽ Dice Coeff
        plt.figure(figsize=(12, 6))
        plt.plot(num_epoches, self.train_dice_coeff_values, label='Train Dice Coeff', marker='o', color='green')
        plt.plot(num_epoches, self.val_dice_coeff_values, label='Test Dice Coeff', marker='o', color='red')
        plt.title('Training and Testing Dice Coeff')
        plt.xlabel('Epochs')
        plt.ylabel('Dice Coeff')
        plt.legend()
        plt.grid(True)
        plt.show()

        # Vẽ IoU
        plt.figure(figsize=(12, 6))
        plt.plot(num_epoches, self.train_iou_values, label='Train IoU', marker='o', color='green')
        plt.plot(num_epoches, self.val_iou_values, label='Test IoU', marker='o', color='red')
        plt.title('Training and Testing IoU')
        plt.xlabel('Epochs')
        plt.ylabel('IoU')
        plt.legend()
        plt.grid(True)
        plt.show()

# %%
train_dataset = BrainTumorDatasetMask(root=config.ROOT, train=True, 
                                      test_freq=config.TEST_RATIO, transform=preprocessing)
valid_dataset = BrainTumorDatasetMask(root=config.ROOT, train=False, 
                                      test_freq=config.TEST_RATIO, transform=preprocessing)
print(f'Length of train dataset: {len(train_dataset)}')
print(f'Length of test dataset: {len(valid_dataset)}')

train_loader = DataLoader(dataset=train_dataset, batch_size=config.BATCH_SIZE, shuffle=True)
valid_loader = DataLoader(dataset=valid_dataset, batch_size=config.BATCH_SIZE, shuffle=False)
print(f'Length of train loader: {len(train_loader)}')
print(f'Length of test loader: {len(valid_loader)}')
# Out:
# === Training Dataset Statistics ===
# Total samples: 2438
# Test frequency: 0.2
#
# Class breakdown:
#   Meningioma: 566 (23.2%) [Total: 708, Train: 566, Test: 142]
#   Glioma: 1140 (46.8%) [Total: 1426, Train: 1140, Test: 286]
#   Pituitary: 732 (30.0%) [Total: 915, Train: 732, Test: 183]
# ==================================================
#
# === Testing Dataset Statistics ===
# Total samples: 611
# Test frequency: 0.2
#
# Class breakdown:
#   Meningioma: 142 (23.2%) [Total: 708, Train: 566, Test: 142]
#   Glioma: 286 (46.8%) [Total: 1426, Train: 1140, Test: 286]
#   Pituitary: 183 (30.0%) [Total: 915, Train: 732, Test: 183]
# ==================================================
# Length of train dataset: 2438
# Length of test dataset: 611
# Length of train loader: 153
# Length of test loader: 39

# %%
model = DRU(in_channels=config.IN_CHANNELS, out_classes=config.OUT_CLASSES).to(config.DEVICE)

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
    
print("Number parameters:", count_parameters(model))
# Out:
# Number parameters: 13969057

# %%
trainer = Trainer(
    model=model,
    train_dataloader=train_loader,
    valid_dataloader=valid_loader,
    epochs=config.EPOCHS,
    save_dir=config.SAVE_DIR,
    device=config.DEVICE,
    accumalation_steps=config.ACCUMALATION_STEPS,
    patience = config.PATIENCE
)
# Out:
# Training new model, save to: 20-06-2025_08-37-31

# %%
# trainer.load_checkpoint('/kaggle/input/sru_brain_tumor/pytorch/default/3/model_sru_brain_tumor_v3.pt')

# %%
trainer.train()
# Out:
# ========== Epoch 1 / 150 ==========
# Training...
# [TRAIN] Epoch 1/150 | Batch 10/153 | Loss_1=0.9469 | Loss_2=0.9458 | Loss_3=0.9452 | Totol_Loss=1.4751 | Dice_coeff=0.0548 | IoU=0.0281
# [TRAIN] Epoch 1/150 | Batch 20/153 | Loss_1=0.9120 | Loss_2=0.9097 | Loss_3=0.9078 | Totol_Loss=1.4176 | Dice_coeff=0.0922 | IoU=0.0483
# [TRAIN] Epoch 1/150 | Batch 30/153 | Loss_1=0.9390 | Loss_2=0.9361 | Loss_3=0.9346 | Totol_Loss=1.4593 | Dice_coeff=0.0654 | IoU=0.0338
# [TRAIN] Epoch 1/150 | Batch 40/153 | Loss_1=0.8999 | Loss_2=0.8886 | Loss_3=0.8872 | Totol_Loss=1.3866 | Dice_coeff=0.1128 | IoU=0.0598
# [TRAIN] Epoch 1/150 | Batch 50/153 | Loss_1=0.8880 | Loss_2=0.8807 | Loss_3=0.8796 | Totol_Loss=1.3740 | Dice_coeff=0.1204 | IoU=0.0641
# [TRAIN] Epoch 1/150 | Batch 60/153 | Loss_1=0.8753 | Loss_2=0.8571 | Loss_3=0.8548 | Totol_Loss=1.3377 | Dice_coeff=0.1452 | IoU=0.0783
# [TRAIN] Epoch 1/150 | Batch 70/153 | Loss_1=0.8955 | Loss_2=0.8967 | Loss_3=0.9035 | Totol_Loss=1.4054 | Dice_coeff=0.0965 | IoU=0.0507
# [TRAIN] Epoch 1/150 | Batch 80/153 | Loss_1=0.8570 | Loss_2=0.8535 | Loss_3=0.8589 | Totol_Loss=1.3374 | Dice_coeff=0.1411 | IoU=0.0759
# [TRAIN] Epoch 1/150 | Batch 90/153 | Loss_1=0.8684 | Loss_2=0.8605 | Loss_3=0.8646 | Totol_Loss=1.3478 | Dice_coeff=0.1354 | IoU=0.0726
# [TRAIN] Epoch 1/150 | Batch 100/153 | Loss_1=0.8319 | Loss_2=0.7577 | Loss_3=0.7492 | Totol_Loss=1.1854 | Dice_coeff=0.2508 | IoU=0.1434
# [TRAIN] Epoch 1/150 | Batch 110/153 | Loss_1=0.8866 | Loss_2=0.8491 | Loss_3=0.8444 | Totol_Loss=1.3259 | Dice_coeff=0.1556 | IoU=0.0844
# [TRAIN] Epoch 1/150 | Batch 120/153 | Loss_1=0.8887 | Loss_2=0.8152 | Loss_3=0.8103 | Totol_Loss=1.2786 | Dice_coeff=0.1897 | IoU=0.1048
# [TRAIN] Epoch 1/150 | Batch 130/153 | Loss_1=0.8473 | Loss_2=0.8153 | Loss_3=0.8169 | Totol_Loss=1.2786 | Dice_coeff=0.1831 | IoU=0.1008
# [TRAIN] Epoch 1/150 | Batch 140/153 | Loss_1=0.7631 | Loss_2=0.6887 | Loss_3=0.6759 | Totol_Loss=1.0735 | Dice_coeff=0.3241 | IoU=0.1934
# [TRAIN] Epoch 1/150 | Batch 150/153 | Loss_1=0.6996 | Loss_2=0.6390 | Loss_3=0.6380 | Totol_Loss=1.0056 | Dice_coeff=0.3620 | IoU=0.2210
#  Train Loss_1: 0.8595 | Loss_2: 0.8356 | Loss_3: 0.8337 | Total_Loss: 1.3054 | Avg_dice_coeff: 0.1663 | Avg_IoU: 0.0935
# Running Validation...
#  Valid Loss_1: 0.7307 | Loss_2: 0.6822 | Loss_3: 0.6844
#  Total_Loss: 1.0742 | Dice_coeff: 0.3156 | IoU: 0.1944
# Validation loss improved from inf to 0.6844. Saving model...
# Model saved to ==> 20-06-2025_08-37-31/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-37-31/model_epoch0.pt
# ========== Epoch 2 / 150 ==========
# Training...
# [TRAIN] Epoch 2/150 | Batch 10/153 | Loss_1=0.6516 | Loss_2=0.5274 | Loss_3=0.5180 | Totol_Loss=0.8332 | Dice_coeff=0.4820 | IoU=0.3175
# [TRAIN] Epoch 2/150 | Batch 20/153 | Loss_1=0.6330 | Loss_2=0.6233 | Loss_3=0.6277 | Totol_Loss=0.9783 | Dice_coeff=0.3723 | IoU=0.2287
# [TRAIN] Epoch 2/150 | Batch 30/153 | Loss_1=0.8282 | Loss_2=0.8165 | Loss_3=0.8174 | Totol_Loss=1.2765 | Dice_coeff=0.1826 | IoU=0.1005
# [TRAIN] Epoch 2/150 | Batch 40/153 | Loss_1=0.7461 | Loss_2=0.6988 | Loss_3=0.6907 | Totol_Loss=1.0896 | Dice_coeff=0.3093 | IoU=0.1830
# [TRAIN] Epoch 2/150 | Batch 50/153 | Loss_1=0.7288 | Loss_2=0.6749 | Loss_3=0.6622 | Totol_Loss=1.0488 | Dice_coeff=0.3378 | IoU=0.2032
# [TRAIN] Epoch 2/150 | Batch 60/153 | Loss_1=0.7480 | Loss_2=0.6827 | Loss_3=0.6761 | Totol_Loss=1.0689 | Dice_coeff=0.3239 | IoU=0.1932
# [TRAIN] Epoch 2/150 | Batch 70/153 | Loss_1=0.6034 | Loss_2=0.5138 | Loss_3=0.5079 | Totol_Loss=0.8099 | Dice_coeff=0.4921 | IoU=0.3264
# [TRAIN] Epoch 2/150 | Batch 80/153 | Loss_1=0.5658 | Loss_2=0.5004 | Loss_3=0.5063 | Totol_Loss=0.7970 | Dice_coeff=0.4937 | IoU=0.3277
# [TRAIN] Epoch 2/150 | Batch 90/153 | Loss_1=0.6154 | Loss_2=0.5639 | Loss_3=0.5763 | Totol_Loss=0.9003 | Dice_coeff=0.4237 | IoU=0.2688
# [TRAIN] Epoch 2/150 | Batch 100/153 | Loss_1=0.5034 | Loss_2=0.4380 | Loss_3=0.4457 | Totol_Loss=0.7015 | Dice_coeff=0.5543 | IoU=0.3834
# [TRAIN] Epoch 2/150 | Batch 110/153 | Loss_1=0.6796 | Loss_2=0.6483 | Loss_3=0.6556 | Totol_Loss=1.0237 | Dice_coeff=0.3444 | IoU=0.2080
# [TRAIN] Epoch 2/150 | Batch 120/153 | Loss_1=0.7269 | Loss_2=0.6912 | Loss_3=0.6791 | Totol_Loss=1.0719 | Dice_coeff=0.3209 | IoU=0.1911
# [TRAIN] Epoch 2/150 | Batch 130/153 | Loss_1=0.6090 | Loss_2=0.5276 | Loss_3=0.5083 | Totol_Loss=0.8168 | Dice_coeff=0.4917 | IoU=0.3260
# [TRAIN] Epoch 2/150 | Batch 140/153 | Loss_1=0.6318 | Loss_2=0.5806 | Loss_3=0.5702 | Totol_Loss=0.9036 | Dice_coeff=0.4298 | IoU=0.2737
# [TRAIN] Epoch 2/150 | Batch 150/153 | Loss_1=0.6363 | Loss_2=0.5996 | Loss_3=0.6017 | Totol_Loss=0.9434 | Dice_coeff=0.3983 | IoU=0.2487
#  Train Loss_1: 0.6914 | Loss_2: 0.6368 | Loss_3: 0.6304 | Total_Loss: 0.9957 | Avg_dice_coeff: 0.3696 | Avg_IoU: 0.2300
# Running Validation...
#  Valid Loss_1: 0.6539 | Loss_2: 0.5965 | Loss_3: 0.5954
#  Total_Loss: 0.9386 | Dice_coeff: 0.4046 | IoU: 0.2678
# Validation loss improved from 0.6844 to 0.5954. Saving model...
# Model saved to ==> 20-06-2025_08-37-31/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-37-31/model_epoch1.pt
# ========== Epoch 3 / 150 ==========
# Training...
# [TRAIN] Epoch 3/150 | Batch 10/153 | Loss_1=0.6458 | Loss_2=0.6227 | Loss_3=0.6348 | Totol_Loss=0.9872 | Dice_coeff=0.3652 | IoU=0.2234
# [TRAIN] Epoch 3/150 | Batch 20/153 | Loss_1=0.7263 | Loss_2=0.6638 | Loss_3=0.6504 | Totol_Loss=1.0321 | Dice_coeff=0.3496 | IoU=0.2118
# [TRAIN] Epoch 3/150 | Batch 30/153 | Loss_1=0.8081 | Loss_2=0.7556 | Loss_3=0.7416 | Totol_Loss=1.1731 | Dice_coeff=0.2584 | IoU=0.1484
# [TRAIN] Epoch 3/150 | Batch 40/153 | Loss_1=0.5923 | Loss_2=0.5186 | Loss_3=0.5152 | Totol_Loss=0.8174 | Dice_coeff=0.4848 | IoU=0.3199
# [TRAIN] Epoch 3/150 | Batch 50/153 | Loss_1=0.6261 | Loss_2=0.5824 | Loss_3=0.5860 | Totol_Loss=0.9191 | Dice_coeff=0.4140 | IoU=0.2611
# [TRAIN] Epoch 3/150 | Batch 60/153 | Loss_1=0.6310 | Loss_2=0.5562 | Loss_3=0.5487 | Totol_Loss=0.8722 | Dice_coeff=0.4513 | IoU=0.2914
# [TRAIN] Epoch 3/150 | Batch 70/153 | Loss_1=0.6459 | Loss_2=0.5907 | Loss_3=0.5807 | Totol_Loss=0.9203 | Dice_coeff=0.4193 | IoU=0.2653
# [TRAIN] Epoch 3/150 | Batch 80/153 | Loss_1=0.7235 | Loss_2=0.7055 | Loss_3=0.7031 | Totol_Loss=1.1010 | Dice_coeff=0.2969 | IoU=0.1743
# [TRAIN] Epoch 3/150 | Batch 90/153 | Loss_1=0.7632 | Loss_2=0.7478 | Loss_3=0.7425 | Totol_Loss=1.1638 | Dice_coeff=0.2575 | IoU=0.1477
# [TRAIN] Epoch 3/150 | Batch 100/153 | Loss_1=0.6141 | Loss_2=0.5664 | Loss_3=0.5802 | Totol_Loss=0.9050 | Dice_coeff=0.4198 | IoU=0.2657
# [TRAIN] Epoch 3/150 | Batch 110/153 | Loss_1=0.6209 | Loss_2=0.5301 | Loss_3=0.5044 | Totol_Loss=0.8157 | Dice_coeff=0.4956 | IoU=0.3295
# [TRAIN] Epoch 3/150 | Batch 120/153 | Loss_1=0.6452 | Loss_2=0.6390 | Loss_3=0.6553 | Totol_Loss=1.0142 | Dice_coeff=0.3447 | IoU=0.2082
# [TRAIN] Epoch 3/150 | Batch 130/153 | Loss_1=0.8034 | Loss_2=0.7697 | Loss_3=0.7632 | Totol_Loss=1.1996 | Dice_coeff=0.2368 | IoU=0.1343
# [TRAIN] Epoch 3/150 | Batch 140/153 | Loss_1=0.6577 | Loss_2=0.6134 | Loss_3=0.6158 | Totol_Loss=0.9664 | Dice_coeff=0.3842 | IoU=0.2378
# [TRAIN] Epoch 3/150 | Batch 150/153 | Loss_1=0.8552 | Loss_2=0.8321 | Loss_3=0.8262 | Totol_Loss=1.2958 | Dice_coeff=0.1738 | IoU=0.0952
#  Train Loss_1: 0.6614 | Loss_2: 0.6093 | Loss_3: 0.6027 | Total_Loss: 0.9522 | Avg_dice_coeff: 0.3973 | Avg_IoU: 0.2527
# Running Validation...
#  Valid Loss_1: 0.6487 | Loss_2: 0.5947 | Loss_3: 0.5949
#  Total_Loss: 0.9365 | Dice_coeff: 0.4051 | IoU: 0.2669
# Validation loss improved from 0.5954 to 0.5949. Saving model...
# Model saved to ==> 20-06-2025_08-37-31/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-37-31/model_epoch2.pt
# ========== Epoch 4 / 150 ==========
# Training...
# [TRAIN] Epoch 4/150 | Batch 10/153 | Loss_1=0.6661 | Loss_2=0.6026 | Loss_3=0.5840 | Totol_Loss=0.9316 | Dice_coeff=0.4160 | IoU=0.2627
# [TRAIN] Epoch 4/150 | Batch 20/153 | Loss_1=0.7377 | Loss_2=0.7077 | Loss_3=0.7032 | Totol_Loss=1.1043 | Dice_coeff=0.2968 | IoU=0.1743
# [TRAIN] Epoch 4/150 | Batch 30/153 | Loss_1=0.6422 | Loss_2=0.5810 | Loss_3=0.5646 | Totol_Loss=0.8997 | Dice_coeff=0.4354 | IoU=0.2783
# [TRAIN] Epoch 4/150 | Batch 40/153 | Loss_1=0.6941 | Loss_2=0.6332 | Loss_3=0.6228 | Totol_Loss=0.9871 | Dice_coeff=0.3772 | IoU=0.2325
# [TRAIN] Epoch 4/150 | Batch 50/153 | Loss_1=0.6205 | Loss_2=0.5786 | Loss_3=0.5942 | Totol_Loss=0.9249 | Dice_coeff=0.4058 | IoU=0.2546
# [TRAIN] Epoch 4/150 | Batch 60/153 | Loss_1=0.6464 | Loss_2=0.6097 | Loss_3=0.6113 | Totol_Loss=0.9587 | Dice_coeff=0.3887 | IoU=0.2412
# [TRAIN] Epoch 4/150 | Batch 70/153 | Loss_1=0.6850 | Loss_2=0.6577 | Loss_3=0.6546 | Totol_Loss=1.0273 | Dice_coeff=0.3454 | IoU=0.2088
# [TRAIN] Epoch 4/150 | Batch 80/153 | Loss_1=0.6510 | Loss_2=0.6159 | Loss_3=0.6227 | Totol_Loss=0.9732 | Dice_coeff=0.3773 | IoU=0.2325
# [TRAIN] Epoch 4/150 | Batch 90/153 | Loss_1=0.6181 | Loss_2=0.5968 | Loss_3=0.6042 | Totol_Loss=0.9418 | Dice_coeff=0.3958 | IoU=0.2467
# [TRAIN] Epoch 4/150 | Batch 100/153 | Loss_1=0.7201 | Loss_2=0.6808 | Loss_3=0.6357 | Totol_Loss=1.0232 | Dice_coeff=0.3643 | IoU=0.2227
# [TRAIN] Epoch 4/150 | Batch 110/153 | Loss_1=0.6861 | Loss_2=0.6720 | Loss_3=0.6796 | Totol_Loss=1.0582 | Dice_coeff=0.3204 | IoU=0.1907
# [TRAIN] Epoch 4/150 | Batch 120/153 | Loss_1=0.6226 | Loss_2=0.5940 | Loss_3=0.5932 | Totol_Loss=0.9304 | Dice_coeff=0.4068 | IoU=0.2553
# [TRAIN] Epoch 4/150 | Batch 130/153 | Loss_1=0.5365 | Loss_2=0.4602 | Loss_3=0.4428 | Totol_Loss=0.7127 | Dice_coeff=0.5572 | IoU=0.3862
# [TRAIN] Epoch 4/150 | Batch 140/153 | Loss_1=0.7937 | Loss_2=0.7978 | Loss_3=0.8000 | Totol_Loss=1.2461 | Dice_coeff=0.2000 | IoU=0.1111
# [TRAIN] Epoch 4/150 | Batch 150/153 | Loss_1=0.6818 | Loss_2=0.6411 | Loss_3=0.6335 | Totol_Loss=0.9990 | Dice_coeff=0.3665 | IoU=0.2244
#  Train Loss_1: 0.6472 | Loss_2: 0.6013 | Loss_3: 0.5947 | Total_Loss: 0.9387 | Avg_dice_coeff: 0.4053 | Avg_IoU: 0.2586
# Running Validation...
#  Valid Loss_1: 0.6487 | Loss_2: 0.5981 | Loss_3: 0.5984
#  Total_Loss: 0.9415 | Dice_coeff: 0.4016 | IoU: 0.2644
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 20-06-2025_08-37-31/model_epoch3.pt
# ========== Epoch 5 / 150 ==========
# Training...
# [TRAIN] Epoch 5/150 | Batch 10/153 | Loss_1=0.6286 | Loss_2=0.5956 | Loss_3=0.6075 | Totol_Loss=0.9463 | Dice_coeff=0.3925 | IoU=0.2441
# [TRAIN] Epoch 5/150 | Batch 20/153 | Loss_1=0.7905 | Loss_2=0.7385 | Loss_3=0.7070 | Totol_Loss=1.1289 | Dice_coeff=0.2930 | IoU=0.1717
# [TRAIN] Epoch 5/150 | Batch 30/153 | Loss_1=0.8032 | Loss_2=0.7786 | Loss_3=0.7700 | Totol_Loss=1.2100 | Dice_coeff=0.2300 | IoU=0.1299
# [TRAIN] Epoch 5/150 | Batch 40/153 | Loss_1=0.5852 | Loss_2=0.5212 | Loss_3=0.5291 | Totol_Loss=0.8312 | Dice_coeff=0.4709 | IoU=0.3080
# [TRAIN] Epoch 5/150 | Batch 50/153 | Loss_1=0.8437 | Loss_2=0.8078 | Loss_3=0.7951 | Totol_Loss=1.2532 | Dice_coeff=0.2049 | IoU=0.1142
# [TRAIN] Epoch 5/150 | Batch 60/153 | Loss_1=0.6084 | Loss_2=0.5577 | Loss_3=0.5688 | Totol_Loss=0.8892 | Dice_coeff=0.4312 | IoU=0.2748
# [TRAIN] Epoch 5/150 | Batch 70/153 | Loss_1=0.7305 | Loss_2=0.6878 | Loss_3=0.6722 | Totol_Loss=1.0642 | Dice_coeff=0.3278 | IoU=0.1960
# [TRAIN] Epoch 5/150 | Batch 80/153 | Loss_1=0.5395 | Loss_2=0.4907 | Loss_3=0.4871 | Totol_Loss=0.7697 | Dice_coeff=0.5129 | IoU=0.3449
# [TRAIN] Epoch 5/150 | Batch 90/153 | Loss_1=0.5405 | Loss_2=0.5132 | Loss_3=0.5376 | Totol_Loss=0.8294 | Dice_coeff=0.4624 | IoU=0.3007
# [TRAIN] Epoch 5/150 | Batch 100/153 | Loss_1=0.3978 | Loss_2=0.3362 | Loss_3=0.3410 | Totol_Loss=0.5391 | Dice_coeff=0.6590 | IoU=0.4914
# [TRAIN] Epoch 5/150 | Batch 110/153 | Loss_1=0.5652 | Loss_2=0.4705 | Loss_3=0.4729 | Totol_Loss=0.7515 | Dice_coeff=0.5271 | IoU=0.3579
# [TRAIN] Epoch 5/150 | Batch 120/153 | Loss_1=0.5938 | Loss_2=0.5201 | Loss_3=0.5238 | Totol_Loss=0.8268 | Dice_coeff=0.4762 | IoU=0.3125
# [TRAIN] Epoch 5/150 | Batch 130/153 | Loss_1=0.6673 | Loss_2=0.6132 | Loss_3=0.6037 | Totol_Loss=0.9557 | Dice_coeff=0.3963 | IoU=0.2471
# [TRAIN] Epoch 5/150 | Batch 140/153 | Loss_1=0.7539 | Loss_2=0.7149 | Loss_3=0.6938 | Totol_Loss=1.1004 | Dice_coeff=0.3062 | IoU=0.1808
# [TRAIN] Epoch 5/150 | Batch 150/153 | Loss_1=0.6340 | Loss_2=0.6210 | Loss_3=0.6221 | Totol_Loss=0.9719 | Dice_coeff=0.3779 | IoU=0.2330
#  Train Loss_1: 0.6409 | Loss_2: 0.5924 | Loss_3: 0.5848 | Total_Loss: 0.9243 | Avg_dice_coeff: 0.4152 | Avg_IoU: 0.2664
# Running Validation...
#  Valid Loss_1: 0.6236 | Loss_2: 0.5821 | Loss_3: 0.5773
#  Total_Loss: 0.9099 | Dice_coeff: 0.4227 | IoU: 0.2822
# Validation loss improved from 0.5949 to 0.5773. Saving model...
# Model saved to ==> 20-06-2025_08-37-31/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-37-31/model_epoch4.pt
# ========== Epoch 6 / 150 ==========
# Training...
# [TRAIN] Epoch 6/150 | Batch 10/153 | Loss_1=0.6397 | Loss_2=0.6567 | Loss_3=0.6594 | Totol_Loss=1.0244 | Dice_coeff=0.3406 | IoU=0.2053
# [TRAIN] Epoch 6/150 | Batch 20/153 | Loss_1=0.5985 | Loss_2=0.5460 | Loss_3=0.5383 | Totol_Loss=0.8525 | Dice_coeff=0.4617 | IoU=0.3001
# [TRAIN] Epoch 6/150 | Batch 30/153 | Loss_1=0.8038 | Loss_2=0.7921 | Loss_3=0.7781 | Totol_Loss=1.2236 | Dice_coeff=0.2219 | IoU=0.1248
# [TRAIN] Epoch 6/150 | Batch 40/153 | Loss_1=0.7373 | Loss_2=0.6779 | Loss_3=0.6529 | Totol_Loss=1.0421 | Dice_coeff=0.3471 | IoU=0.2100
# [TRAIN] Epoch 6/150 | Batch 50/153 | Loss_1=0.6504 | Loss_2=0.6031 | Loss_3=0.5935 | Totol_Loss=0.9388 | Dice_coeff=0.4065 | IoU=0.2551
# [TRAIN] Epoch 6/150 | Batch 60/153 | Loss_1=0.5864 | Loss_2=0.5025 | Loss_3=0.4790 | Totol_Loss=0.7739 | Dice_coeff=0.5210 | IoU=0.3522
# [TRAIN] Epoch 6/150 | Batch 70/153 | Loss_1=0.6547 | Loss_2=0.6004 | Loss_3=0.5821 | Totol_Loss=0.9271 | Dice_coeff=0.4179 | IoU=0.2641
# [TRAIN] Epoch 6/150 | Batch 80/153 | Loss_1=0.5235 | Loss_2=0.4667 | Loss_3=0.4564 | Totol_Loss=0.7269 | Dice_coeff=0.5436 | IoU=0.3732
# [TRAIN] Epoch 6/150 | Batch 90/153 | Loss_1=0.6645 | Loss_2=0.6331 | Loss_3=0.5848 | Totol_Loss=0.9444 | Dice_coeff=0.4152 | IoU=0.2620
# [TRAIN] Epoch 6/150 | Batch 100/153 | Loss_1=0.5426 | Loss_2=0.4705 | Loss_3=0.4327 | Totol_Loss=0.7077 | Dice_coeff=0.5673 | IoU=0.3960
# [TRAIN] Epoch 6/150 | Batch 110/153 | Loss_1=0.7958 | Loss_2=0.7851 | Loss_3=0.7762 | Totol_Loss=1.2176 | Dice_coeff=0.2238 | IoU=0.1260
# [TRAIN] Epoch 6/150 | Batch 120/153 | Loss_1=0.6550 | Loss_2=0.6208 | Loss_3=0.6243 | Totol_Loss=0.9774 | Dice_coeff=0.3757 | IoU=0.2313
# [TRAIN] Epoch 6/150 | Batch 130/153 | Loss_1=0.7766 | Loss_2=0.7288 | Loss_3=0.6798 | Totol_Loss=1.0956 | Dice_coeff=0.3202 | IoU=0.1906
# [TRAIN] Epoch 6/150 | Batch 140/153 | Loss_1=0.6829 | Loss_2=0.6258 | Loss_3=0.6080 | Totol_Loss=0.9676 | Dice_coeff=0.3920 | IoU=0.2438
# [TRAIN] Epoch 6/150 | Batch 150/153 | Loss_1=0.5371 | Loss_2=0.4783 | Loss_3=0.4655 | Totol_Loss=0.7428 | Dice_coeff=0.5345 | IoU=0.3647
#  Train Loss_1: 0.6328 | Loss_2: 0.5851 | Loss_3: 0.5770 | Total_Loss: 0.9123 | Avg_dice_coeff: 0.4230 | Avg_IoU: 0.2732
# Running Validation...
#  Valid Loss_1: 0.6236 | Loss_2: 0.5707 | Loss_3: 0.5618
#  Total_Loss: 0.8898 | Dice_coeff: 0.4382 | IoU: 0.2980
# Validation loss improved from 0.5773 to 0.5618. Saving model...
# Model saved to ==> 20-06-2025_08-37-31/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-37-31/model_epoch5.pt
# ========== Epoch 7 / 150 ==========
# Training...
# [TRAIN] Epoch 7/150 | Batch 10/153 | Loss_1=0.5631 | Loss_2=0.5369 | Loss_3=0.5630 | Totol_Loss=0.8678 | Dice_coeff=0.4370 | IoU=0.2796
# [TRAIN] Epoch 7/150 | Batch 20/153 | Loss_1=0.8079 | Loss_2=0.7561 | Loss_3=0.7226 | Totol_Loss=1.1543 | Dice_coeff=0.2774 | IoU=0.1610
# [TRAIN] Epoch 7/150 | Batch 30/153 | Loss_1=0.6872 | Loss_2=0.5843 | Loss_3=0.5548 | Totol_Loss=0.8985 | Dice_coeff=0.4452 | IoU=0.2863
# [TRAIN] Epoch 7/150 | Batch 40/153 | Loss_1=0.6776 | Loss_2=0.6203 | Loss_3=0.6067 | Totol_Loss=0.9632 | Dice_coeff=0.3933 | IoU=0.2448
# [TRAIN] Epoch 7/150 | Batch 50/153 | Loss_1=0.6353 | Loss_2=0.5907 | Loss_3=0.5908 | Totol_Loss=0.9287 | Dice_coeff=0.4092 | IoU=0.2572
# [TRAIN] Epoch 7/150 | Batch 60/153 | Loss_1=0.8610 | Loss_2=0.8271 | Loss_3=0.8037 | Totol_Loss=1.2723 | Dice_coeff=0.1963 | IoU=0.1089
# [TRAIN] Epoch 7/150 | Batch 70/153 | Loss_1=0.7171 | Loss_2=0.6566 | Loss_3=0.6523 | Totol_Loss=1.0297 | Dice_coeff=0.3477 | IoU=0.2104
# [TRAIN] Epoch 7/150 | Batch 80/153 | Loss_1=0.8620 | Loss_2=0.8437 | Loss_3=0.8184 | Totol_Loss=1.2937 | Dice_coeff=0.1816 | IoU=0.0999
# [TRAIN] Epoch 7/150 | Batch 90/153 | Loss_1=0.4928 | Loss_2=0.4854 | Loss_3=0.5130 | Totol_Loss=0.7860 | Dice_coeff=0.4870 | IoU=0.3219
# [TRAIN] Epoch 7/150 | Batch 100/153 | Loss_1=0.7315 | Loss_2=0.6699 | Loss_3=0.6309 | Totol_Loss=1.0158 | Dice_coeff=0.3691 | IoU=0.2263
# [TRAIN] Epoch 7/150 | Batch 110/153 | Loss_1=0.7344 | Loss_2=0.6751 | Loss_3=0.6514 | Totol_Loss=1.0389 | Dice_coeff=0.3486 | IoU=0.2111
# [TRAIN] Epoch 7/150 | Batch 120/153 | Loss_1=0.6997 | Loss_2=0.6657 | Loss_3=0.6610 | Totol_Loss=1.0393 | Dice_coeff=0.3390 | IoU=0.2041
# [TRAIN] Epoch 7/150 | Batch 130/153 | Loss_1=0.6198 | Loss_2=0.5577 | Loss_3=0.5408 | Totol_Loss=0.8630 | Dice_coeff=0.4592 | IoU=0.2980
# [TRAIN] Epoch 7/150 | Batch 140/153 | Loss_1=0.5468 | Loss_2=0.5334 | Loss_3=0.5532 | Totol_Loss=0.8541 | Dice_coeff=0.4468 | IoU=0.2876
# [TRAIN] Epoch 7/150 | Batch 150/153 | Loss_1=0.4361 | Loss_2=0.3857 | Loss_3=0.3979 | Totol_Loss=0.6220 | Dice_coeff=0.6021 | IoU=0.4307
#  Train Loss_1: 0.6367 | Loss_2: 0.5849 | Loss_3: 0.5774 | Total_Loss: 0.9132 | Avg_dice_coeff: 0.4226 | Avg_IoU: 0.2725
# Running Validation...
#  Valid Loss_1: 0.6036 | Loss_2: 0.5481 | Loss_3: 0.5474
#  Total_Loss: 0.8632 | Dice_coeff: 0.4526 | IoU: 0.3109
# Validation loss improved from 0.5618 to 0.5474. Saving model...
# Model saved to ==> 20-06-2025_08-37-31/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-37-31/model_epoch6.pt
# ========== Epoch 8 / 150 ==========
# Training...
# [TRAIN] Epoch 8/150 | Batch 10/153 | Loss_1=0.6449 | Loss_2=0.5695 | Loss_3=0.5407 | Totol_Loss=0.8717 | Dice_coeff=0.4593 | IoU=0.2981
# [TRAIN] Epoch 8/150 | Batch 20/153 | Loss_1=0.6181 | Loss_2=0.5679 | Loss_3=0.5414 | Totol_Loss=0.8674 | Dice_coeff=0.4586 | IoU=0.2975
# [TRAIN] Epoch 8/150 | Batch 30/153 | Loss_1=0.4276 | Loss_2=0.3942 | Loss_3=0.4219 | Totol_Loss=0.6480 | Dice_coeff=0.5781 | IoU=0.4066
# [TRAIN] Epoch 8/150 | Batch 40/153 | Loss_1=0.7404 | Loss_2=0.6948 | Loss_3=0.6797 | Totol_Loss=1.0761 | Dice_coeff=0.3203 | IoU=0.1907
# [TRAIN] Epoch 8/150 | Batch 50/153 | Loss_1=0.6925 | Loss_2=0.6341 | Loss_3=0.6083 | Totol_Loss=0.9727 | Dice_coeff=0.3917 | IoU=0.2436
# [TRAIN] Epoch 8/150 | Batch 60/153 | Loss_1=0.6172 | Loss_2=0.5689 | Loss_3=0.5608 | Totol_Loss=0.8872 | Dice_coeff=0.4392 | IoU=0.2814
# [TRAIN] Epoch 8/150 | Batch 70/153 | Loss_1=0.7761 | Loss_2=0.7406 | Loss_3=0.7250 | Totol_Loss=1.1454 | Dice_coeff=0.2750 | IoU=0.1594
# [TRAIN] Epoch 8/150 | Batch 80/153 | Loss_1=0.7048 | Loss_2=0.6710 | Loss_3=0.6445 | Totol_Loss=1.0257 | Dice_coeff=0.3555 | IoU=0.2162
# [TRAIN] Epoch 8/150 | Batch 90/153 | Loss_1=0.6031 | Loss_2=0.5327 | Loss_3=0.5150 | Totol_Loss=0.8245 | Dice_coeff=0.4850 | IoU=0.3202
# [TRAIN] Epoch 8/150 | Batch 100/153 | Loss_1=0.5234 | Loss_2=0.4809 | Loss_3=0.4772 | Totol_Loss=0.7533 | Dice_coeff=0.5228 | IoU=0.3539
# [TRAIN] Epoch 8/150 | Batch 110/153 | Loss_1=0.5129 | Loss_2=0.4396 | Loss_3=0.4277 | Totol_Loss=0.6857 | Dice_coeff=0.5723 | IoU=0.4008
# [TRAIN] Epoch 8/150 | Batch 120/153 | Loss_1=0.5772 | Loss_2=0.5172 | Loss_3=0.5088 | Totol_Loss=0.8080 | Dice_coeff=0.4912 | IoU=0.3256
# [TRAIN] Epoch 8/150 | Batch 130/153 | Loss_1=0.6626 | Loss_2=0.6401 | Loss_3=0.6426 | Totol_Loss=1.0047 | Dice_coeff=0.3574 | IoU=0.2176
# [TRAIN] Epoch 8/150 | Batch 140/153 | Loss_1=0.6614 | Loss_2=0.6166 | Loss_3=0.6001 | Totol_Loss=0.9526 | Dice_coeff=0.3999 | IoU=0.2499
# [TRAIN] Epoch 8/150 | Batch 150/153 | Loss_1=0.6828 | Loss_2=0.6326 | Loss_3=0.6150 | Totol_Loss=0.9773 | Dice_coeff=0.3850 | IoU=0.2384
#  Train Loss_1: 0.6234 | Loss_2: 0.5750 | Loss_3: 0.5700 | Total_Loss: 0.8998 | Avg_dice_coeff: 0.4300 | Avg_IoU: 0.2783
# Running Validation...
#  Valid Loss_1: 0.6194 | Loss_2: 0.5594 | Loss_3: 0.5513
#  Total_Loss: 0.8741 | Dice_coeff: 0.4487 | IoU: 0.3065
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 20-06-2025_08-37-31/model_epoch7.pt
# ========== Epoch 9 / 150 ==========
# Training...
# [TRAIN] Epoch 9/150 | Batch 10/153 | Loss_1=0.6478 | Loss_2=0.5968 | Loss_3=0.5874 | Totol_Loss=0.9298 | Dice_coeff=0.4126 | IoU=0.2599
# [TRAIN] Epoch 9/150 | Batch 20/153 | Loss_1=0.6979 | Loss_2=0.6549 | Loss_3=0.6449 | Totol_Loss=1.0186 | Dice_coeff=0.3551 | IoU=0.2159
# [TRAIN] Epoch 9/150 | Batch 30/153 | Loss_1=0.6691 | Loss_2=0.6347 | Loss_3=0.6113 | Totol_Loss=0.9722 | Dice_coeff=0.3887 | IoU=0.2412
# [TRAIN] Epoch 9/150 | Batch 40/153 | Loss_1=0.7165 | Loss_2=0.6897 | Loss_3=0.6896 | Totol_Loss=1.0801 | Dice_coeff=0.3104 | IoU=0.1837
# [TRAIN] Epoch 9/150 | Batch 50/153 | Loss_1=0.7218 | Loss_2=0.6773 | Loss_3=0.6541 | Totol_Loss=1.0405 | Dice_coeff=0.3459 | IoU=0.2091
# [TRAIN] Epoch 9/150 | Batch 60/153 | Loss_1=0.5599 | Loss_2=0.5145 | Loss_3=0.5145 | Totol_Loss=0.8099 | Dice_coeff=0.4855 | IoU=0.3206
# [TRAIN] Epoch 9/150 | Batch 70/153 | Loss_1=0.6459 | Loss_2=0.6135 | Loss_3=0.6064 | Totol_Loss=0.9551 | Dice_coeff=0.3936 | IoU=0.2450
# [TRAIN] Epoch 9/150 | Batch 80/153 | Loss_1=0.7419 | Loss_2=0.6968 | Loss_3=0.6935 | Totol_Loss=1.0910 | Dice_coeff=0.3065 | IoU=0.1810
# [TRAIN] Epoch 9/150 | Batch 90/153 | Loss_1=0.6800 | Loss_2=0.6433 | Loss_3=0.6402 | Totol_Loss=1.0064 | Dice_coeff=0.3598 | IoU=0.2193
# [TRAIN] Epoch 9/150 | Batch 100/153 | Loss_1=0.4877 | Loss_2=0.4282 | Loss_3=0.4305 | Totol_Loss=0.6798 | Dice_coeff=0.5695 | IoU=0.3981
# [TRAIN] Epoch 9/150 | Batch 110/153 | Loss_1=0.6285 | Loss_2=0.5781 | Loss_3=0.5650 | Totol_Loss=0.8968 | Dice_coeff=0.4350 | IoU=0.2779
# [TRAIN] Epoch 9/150 | Batch 120/153 | Loss_1=0.7297 | Loss_2=0.6864 | Loss_3=0.6722 | Totol_Loss=1.0636 | Dice_coeff=0.3278 | IoU=0.1960
# [TRAIN] Epoch 9/150 | Batch 130/153 | Loss_1=0.8902 | Loss_2=0.8574 | Loss_3=0.8389 | Totol_Loss=1.3243 | Dice_coeff=0.1611 | IoU=0.0876
# [TRAIN] Epoch 9/150 | Batch 140/153 | Loss_1=0.6834 | Loss_2=0.6088 | Loss_3=0.5726 | Totol_Loss=0.9254 | Dice_coeff=0.4274 | IoU=0.2718
# [TRAIN] Epoch 9/150 | Batch 150/153 | Loss_1=0.7025 | Loss_2=0.6574 | Loss_3=0.6480 | Totol_Loss=1.0233 | Dice_coeff=0.3520 | IoU=0.2136
#  Train Loss_1: 0.6211 | Loss_2: 0.5730 | Loss_3: 0.5669 | Total_Loss: 0.8955 | Avg_dice_coeff: 0.4331 | Avg_IoU: 0.2812
# Running Validation...
#  Valid Loss_1: 0.6898 | Loss_2: 0.6705 | Loss_3: 0.6731
#  Total_Loss: 1.0517 | Dice_coeff: 0.3269 | IoU: 0.2216
# No improvement in validation loss for 2 epochs.
# Model saved to ==> 20-06-2025_08-37-31/model_epoch8.pt
# ========== Epoch 10 / 150 ==========
# Training...
# [TRAIN] Epoch 10/150 | Batch 10/153 | Loss_1=0.6071 | Loss_2=0.5615 | Loss_3=0.5587 | Totol_Loss=0.8805 | Dice_coeff=0.4413 | IoU=0.2831
# [TRAIN] Epoch 10/150 | Batch 20/153 | Loss_1=0.7692 | Loss_2=0.7252 | Loss_3=0.7101 | Totol_Loss=1.1233 | Dice_coeff=0.2899 | IoU=0.1695
# [TRAIN] Epoch 10/150 | Batch 30/153 | Loss_1=0.7090 | Loss_2=0.6623 | Loss_3=0.6370 | Totol_Loss=1.0153 | Dice_coeff=0.3630 | IoU=0.2218
# [TRAIN] Epoch 10/150 | Batch 40/153 | Loss_1=0.6076 | Loss_2=0.5613 | Loss_3=0.5362 | Totol_Loss=0.8579 | Dice_coeff=0.4638 | IoU=0.3019
# [TRAIN] Epoch 10/150 | Batch 50/153 | Loss_1=0.5198 | Loss_2=0.4894 | Loss_3=0.5094 | Totol_Loss=0.7884 | Dice_coeff=0.4906 | IoU=0.3250
# [TRAIN] Epoch 10/150 | Batch 60/153 | Loss_1=0.6964 | Loss_2=0.6277 | Loss_3=0.6015 | Totol_Loss=0.9640 | Dice_coeff=0.3985 | IoU=0.2488
# [TRAIN] Epoch 10/150 | Batch 70/153 | Loss_1=0.5664 | Loss_2=0.5197 | Loss_3=0.5245 | Totol_Loss=0.8230 | Dice_coeff=0.4755 | IoU=0.3119
# [TRAIN] Epoch 10/150 | Batch 80/153 | Loss_1=0.5313 | Loss_2=0.4879 | Loss_3=0.4826 | Totol_Loss=0.7628 | Dice_coeff=0.5174 | IoU=0.3489
# [TRAIN] Epoch 10/150 | Batch 90/153 | Loss_1=0.6242 | Loss_2=0.5968 | Loss_3=0.6066 | Totol_Loss=0.9452 | Dice_coeff=0.3934 | IoU=0.2449
# [TRAIN] Epoch 10/150 | Batch 100/153 | Loss_1=0.6753 | Loss_2=0.6586 | Loss_3=0.6412 | Totol_Loss=1.0127 | Dice_coeff=0.3588 | IoU=0.2186
# [TRAIN] Epoch 10/150 | Batch 110/153 | Loss_1=0.6407 | Loss_2=0.5707 | Loss_3=0.5517 | Totol_Loss=0.8826 | Dice_coeff=0.4483 | IoU=0.2889
# [TRAIN] Epoch 10/150 | Batch 120/153 | Loss_1=0.6586 | Loss_2=0.6118 | Loss_3=0.6112 | Totol_Loss=0.9613 | Dice_coeff=0.3888 | IoU=0.2413
# [TRAIN] Epoch 10/150 | Batch 130/153 | Loss_1=0.6790 | Loss_2=0.6471 | Loss_3=0.6556 | Totol_Loss=1.0230 | Dice_coeff=0.3444 | IoU=0.2080
# [TRAIN] Epoch 10/150 | Batch 140/153 | Loss_1=0.5452 | Loss_2=0.4848 | Loss_3=0.4770 | Totol_Loss=0.7582 | Dice_coeff=0.5230 | IoU=0.3541
# [TRAIN] Epoch 10/150 | Batch 150/153 | Loss_1=0.5427 | Loss_2=0.5050 | Loss_3=0.5136 | Totol_Loss=0.8025 | Dice_coeff=0.4864 | IoU=0.3213
#  Train Loss_1: 0.6178 | Loss_2: 0.5672 | Loss_3: 0.5606 | Total_Loss: 0.8863 | Avg_dice_coeff: 0.4394 | Avg_IoU: 0.2861
# Running Validation...
#  Valid Loss_1: 0.5914 | Loss_2: 0.5446 | Loss_3: 0.5423
#  Total_Loss: 0.8548 | Dice_coeff: 0.4577 | IoU: 0.3198
# Validation loss improved from 0.5474 to 0.5423. Saving model...
# Model saved to ==> 20-06-2025_08-37-31/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-37-31/model_epoch9.pt
# ========== Epoch 11 / 150 ==========
# Training...
# [TRAIN] Epoch 11/150 | Batch 10/153 | Loss_1=0.7062 | Loss_2=0.6162 | Loss_3=0.5884 | Totol_Loss=0.9479 | Dice_coeff=0.4116 | IoU=0.2591
# [TRAIN] Epoch 11/150 | Batch 20/153 | Loss_1=0.6890 | Loss_2=0.6398 | Loss_3=0.6199 | Totol_Loss=0.9861 | Dice_coeff=0.3801 | IoU=0.2347
# [TRAIN] Epoch 11/150 | Batch 30/153 | Loss_1=0.5351 | Loss_2=0.4625 | Loss_3=0.4470 | Totol_Loss=0.7176 | Dice_coeff=0.5530 | IoU=0.3822
# [TRAIN] Epoch 11/150 | Batch 40/153 | Loss_1=0.7192 | Loss_2=0.6485 | Loss_3=0.6378 | Totol_Loss=1.0123 | Dice_coeff=0.3622 | IoU=0.2211
# [TRAIN] Epoch 11/150 | Batch 50/153 | Loss_1=0.5287 | Loss_2=0.4589 | Loss_3=0.4412 | Totol_Loss=0.7093 | Dice_coeff=0.5588 | IoU=0.3877
# [TRAIN] Epoch 11/150 | Batch 60/153 | Loss_1=0.7479 | Loss_2=0.6962 | Loss_3=0.6949 | Totol_Loss=1.0931 | Dice_coeff=0.3051 | IoU=0.1800
# [TRAIN] Epoch 11/150 | Batch 70/153 | Loss_1=0.4395 | Loss_2=0.3630 | Loss_3=0.3844 | Totol_Loss=0.5999 | Dice_coeff=0.6156 | IoU=0.4447
# [TRAIN] Epoch 11/150 | Batch 80/153 | Loss_1=0.6471 | Loss_2=0.5964 | Loss_3=0.5882 | Totol_Loss=0.9303 | Dice_coeff=0.4118 | IoU=0.2593
# [TRAIN] Epoch 11/150 | Batch 90/153 | Loss_1=0.6259 | Loss_2=0.5530 | Loss_3=0.5476 | Totol_Loss=0.8689 | Dice_coeff=0.4524 | IoU=0.2924
# [TRAIN] Epoch 11/150 | Batch 100/153 | Loss_1=0.6731 | Loss_2=0.5789 | Loss_3=0.5368 | Totol_Loss=0.8760 | Dice_coeff=0.4632 | IoU=0.3014
# [TRAIN] Epoch 11/150 | Batch 110/153 | Loss_1=0.4189 | Loss_2=0.3670 | Loss_3=0.3719 | Totol_Loss=0.5858 | Dice_coeff=0.6281 | IoU=0.4578
# [TRAIN] Epoch 11/150 | Batch 120/153 | Loss_1=0.4273 | Loss_2=0.3640 | Loss_3=0.3666 | Totol_Loss=0.5806 | Dice_coeff=0.6334 | IoU=0.4635
# [TRAIN] Epoch 11/150 | Batch 130/153 | Loss_1=0.6005 | Loss_2=0.5273 | Loss_3=0.5105 | Totol_Loss=0.8175 | Dice_coeff=0.4895 | IoU=0.3240
# [TRAIN] Epoch 11/150 | Batch 140/153 | Loss_1=0.5314 | Loss_2=0.4905 | Loss_3=0.5072 | Totol_Loss=0.7884 | Dice_coeff=0.4928 | IoU=0.3270
# [TRAIN] Epoch 11/150 | Batch 150/153 | Loss_1=0.6662 | Loss_2=0.6061 | Loss_3=0.5938 | Totol_Loss=0.9429 | Dice_coeff=0.4062 | IoU=0.2548
#  Train Loss_1: 0.6060 | Loss_2: 0.5488 | Loss_3: 0.5417 | Total_Loss: 0.8582 | Avg_dice_coeff: 0.4583 | Avg_IoU: 0.3025
# Running Validation...
#  Valid Loss_1: 0.5866 | Loss_2: 0.5357 | Loss_3: 0.5393
#  Total_Loss: 0.8474 | Dice_coeff: 0.4607 | IoU: 0.3191
# Validation loss improved from 0.5423 to 0.5393. Saving model...
# Model saved to ==> 20-06-2025_08-37-31/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-37-31/model_epoch10.pt
# ========== Epoch 12 / 150 ==========
# Training...
# [TRAIN] Epoch 12/150 | Batch 10/153 | Loss_1=0.5162 | Loss_2=0.4316 | Loss_3=0.4313 | Totol_Loss=0.6865 | Dice_coeff=0.5687 | IoU=0.3974
# [TRAIN] Epoch 12/150 | Batch 20/153 | Loss_1=0.6676 | Loss_2=0.6226 | Loss_3=0.6300 | Totol_Loss=0.9859 | Dice_coeff=0.3700 | IoU=0.2270
# [TRAIN] Epoch 12/150 | Batch 30/153 | Loss_1=0.7089 | Loss_2=0.6668 | Loss_3=0.6712 | Totol_Loss=1.0513 | Dice_coeff=0.3288 | IoU=0.1968
# [TRAIN] Epoch 12/150 | Batch 40/153 | Loss_1=0.6827 | Loss_2=0.6088 | Loss_3=0.5848 | Totol_Loss=0.9376 | Dice_coeff=0.4152 | IoU=0.2620
# [TRAIN] Epoch 12/150 | Batch 50/153 | Loss_1=0.6741 | Loss_2=0.6191 | Loss_3=0.6095 | Totol_Loss=0.9650 | Dice_coeff=0.3905 | IoU=0.2426
# [TRAIN] Epoch 12/150 | Batch 60/153 | Loss_1=0.5616 | Loss_2=0.5287 | Loss_3=0.5386 | Totol_Loss=0.8399 | Dice_coeff=0.4614 | IoU=0.2999
# [TRAIN] Epoch 12/150 | Batch 70/153 | Loss_1=0.5569 | Loss_2=0.5339 | Loss_3=0.5423 | Totol_Loss=0.8450 | Dice_coeff=0.4577 | IoU=0.2968
# [TRAIN] Epoch 12/150 | Batch 80/153 | Loss_1=0.5919 | Loss_2=0.5181 | Loss_3=0.4889 | Totol_Loss=0.7909 | Dice_coeff=0.5111 | IoU=0.3433
# [TRAIN] Epoch 12/150 | Batch 90/153 | Loss_1=0.6629 | Loss_2=0.6229 | Loss_3=0.6041 | Totol_Loss=0.9593 | Dice_coeff=0.3959 | IoU=0.2468
# [TRAIN] Epoch 12/150 | Batch 100/153 | Loss_1=0.6202 | Loss_2=0.5537 | Loss_3=0.5425 | Totol_Loss=0.8632 | Dice_coeff=0.4575 | IoU=0.2966
# [TRAIN] Epoch 12/150 | Batch 110/153 | Loss_1=0.5851 | Loss_2=0.5263 | Loss_3=0.5267 | Totol_Loss=0.8308 | Dice_coeff=0.4733 | IoU=0.3100
# [TRAIN] Epoch 12/150 | Batch 120/153 | Loss_1=0.5762 | Loss_2=0.5088 | Loss_3=0.4747 | Totol_Loss=0.7704 | Dice_coeff=0.5253 | IoU=0.3562
# [TRAIN] Epoch 12/150 | Batch 130/153 | Loss_1=0.5591 | Loss_2=0.5002 | Loss_3=0.4874 | Totol_Loss=0.7769 | Dice_coeff=0.5126 | IoU=0.3447
# [TRAIN] Epoch 12/150 | Batch 140/153 | Loss_1=0.5285 | Loss_2=0.4713 | Loss_3=0.4759 | Totol_Loss=0.7489 | Dice_coeff=0.5241 | IoU=0.3551
# [TRAIN] Epoch 12/150 | Batch 150/153 | Loss_1=0.5643 | Loss_2=0.4934 | Loss_3=0.4764 | Totol_Loss=0.7640 | Dice_coeff=0.5236 | IoU=0.3547
#  Train Loss_1: 0.6060 | Loss_2: 0.5517 | Loss_3: 0.5453 | Total_Loss: 0.8629 | Avg_dice_coeff: 0.4547 | Avg_IoU: 0.2987
# Running Validation...
#  Valid Loss_1: 0.5827 | Loss_2: 0.5286 | Loss_3: 0.5344
#  Total_Loss: 0.8391 | Dice_coeff: 0.4656 | IoU: 0.3229
# Validation loss improved from 0.5393 to 0.5344. Saving model...
# Model saved to ==> 20-06-2025_08-37-31/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-37-31/model_epoch11.pt
# ========== Epoch 13 / 150 ==========
# Training...
# [TRAIN] Epoch 13/150 | Batch 10/153 | Loss_1=0.6080 | Loss_2=0.5653 | Loss_3=0.5460 | Totol_Loss=0.8694 | Dice_coeff=0.4540 | IoU=0.2937
# [TRAIN] Epoch 13/150 | Batch 20/153 | Loss_1=0.4370 | Loss_2=0.4156 | Loss_3=0.4117 | Totol_Loss=0.6478 | Dice_coeff=0.5883 | IoU=0.4168
# [TRAIN] Epoch 13/150 | Batch 30/153 | Loss_1=0.7206 | Loss_2=0.6765 | Loss_3=0.6793 | Totol_Loss=1.0652 | Dice_coeff=0.3207 | IoU=0.1910
# [TRAIN] Epoch 13/150 | Batch 40/153 | Loss_1=0.6925 | Loss_2=0.6194 | Loss_3=0.5982 | Totol_Loss=0.9568 | Dice_coeff=0.4018 | IoU=0.2514
# [TRAIN] Epoch 13/150 | Batch 50/153 | Loss_1=0.5832 | Loss_2=0.5375 | Loss_3=0.5408 | Totol_Loss=0.8491 | Dice_coeff=0.4592 | IoU=0.2980
# [TRAIN] Epoch 13/150 | Batch 60/153 | Loss_1=0.7011 | Loss_2=0.6341 | Loss_3=0.6125 | Totol_Loss=0.9783 | Dice_coeff=0.3875 | IoU=0.2403
# [TRAIN] Epoch 13/150 | Batch 70/153 | Loss_1=0.5629 | Loss_2=0.4917 | Loss_3=0.4958 | Totol_Loss=0.7825 | Dice_coeff=0.5042 | IoU=0.3371
# [TRAIN] Epoch 13/150 | Batch 80/153 | Loss_1=0.5869 | Loss_2=0.5006 | Loss_3=0.4927 | Totol_Loss=0.7869 | Dice_coeff=0.5073 | IoU=0.3398
# [TRAIN] Epoch 13/150 | Batch 90/153 | Loss_1=0.6182 | Loss_2=0.5448 | Loss_3=0.5316 | Totol_Loss=0.8484 | Dice_coeff=0.4684 | IoU=0.3058
# [TRAIN] Epoch 13/150 | Batch 100/153 | Loss_1=0.5122 | Loss_2=0.4678 | Loss_3=0.4554 | Totol_Loss=0.7245 | Dice_coeff=0.5446 | IoU=0.3742
# [TRAIN] Epoch 13/150 | Batch 110/153 | Loss_1=0.8420 | Loss_2=0.8378 | Loss_3=0.8306 | Totol_Loss=1.3004 | Dice_coeff=0.1694 | IoU=0.0925
# [TRAIN] Epoch 13/150 | Batch 120/153 | Loss_1=0.8101 | Loss_2=0.7579 | Loss_3=0.7316 | Totol_Loss=1.1644 | Dice_coeff=0.2684 | IoU=0.1550
# [TRAIN] Epoch 13/150 | Batch 130/153 | Loss_1=0.7012 | Loss_2=0.6229 | Loss_3=0.6051 | Totol_Loss=0.9665 | Dice_coeff=0.3949 | IoU=0.2460
# [TRAIN] Epoch 13/150 | Batch 140/153 | Loss_1=0.5541 | Loss_2=0.4904 | Loss_3=0.4898 | Totol_Loss=0.7746 | Dice_coeff=0.5102 | IoU=0.3425
# [TRAIN] Epoch 13/150 | Batch 150/153 | Loss_1=0.6025 | Loss_2=0.5641 | Loss_3=0.5742 | Totol_Loss=0.8963 | Dice_coeff=0.4258 | IoU=0.2705
#  Train Loss_1: 0.5925 | Loss_2: 0.5304 | Loss_3: 0.5238 | Total_Loss: 0.8308 | Avg_dice_coeff: 0.4762 | Avg_IoU: 0.3166
# Running Validation...
#  Valid Loss_1: 0.5756 | Loss_2: 0.5109 | Loss_3: 0.5136
#  Total_Loss: 0.8101 | Dice_coeff: 0.4864 | IoU: 0.3465
# Validation loss improved from 0.5344 to 0.5136. Saving model...
# Model saved to ==> 20-06-2025_08-37-31/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-37-31/model_epoch12.pt
# ========== Epoch 14 / 150 ==========
# Training...
# [TRAIN] Epoch 14/150 | Batch 10/153 | Loss_1=0.5854 | Loss_2=0.5180 | Loss_3=0.4953 | Totol_Loss=0.7962 | Dice_coeff=0.5047 | IoU=0.3375
# [TRAIN] Epoch 14/150 | Batch 20/153 | Loss_1=0.6136 | Loss_2=0.5439 | Loss_3=0.5294 | Totol_Loss=0.8451 | Dice_coeff=0.4706 | IoU=0.3077
# [TRAIN] Epoch 14/150 | Batch 30/153 | Loss_1=0.5617 | Loss_2=0.5360 | Loss_3=0.5335 | Totol_Loss=0.8377 | Dice_coeff=0.4665 | IoU=0.3042
# [TRAIN] Epoch 14/150 | Batch 40/153 | Loss_1=0.6125 | Loss_2=0.5402 | Loss_3=0.5229 | Totol_Loss=0.8370 | Dice_coeff=0.4771 | IoU=0.3133
# [TRAIN] Epoch 14/150 | Batch 50/153 | Loss_1=0.6797 | Loss_2=0.5612 | Loss_3=0.5391 | Totol_Loss=0.8724 | Dice_coeff=0.4609 | IoU=0.2994
# [TRAIN] Epoch 14/150 | Batch 60/153 | Loss_1=0.4586 | Loss_2=0.4707 | Loss_3=0.5448 | Totol_Loss=0.8064 | Dice_coeff=0.4552 | IoU=0.2947
# [TRAIN] Epoch 14/150 | Batch 70/153 | Loss_1=0.6790 | Loss_2=0.5892 | Loss_3=0.5652 | Totol_Loss=0.9095 | Dice_coeff=0.4348 | IoU=0.2778
# [TRAIN] Epoch 14/150 | Batch 80/153 | Loss_1=0.6019 | Loss_2=0.5520 | Loss_3=0.5571 | Totol_Loss=0.8742 | Dice_coeff=0.4429 | IoU=0.2844
# [TRAIN] Epoch 14/150 | Batch 90/153 | Loss_1=0.5618 | Loss_2=0.5011 | Loss_3=0.4967 | Totol_Loss=0.7870 | Dice_coeff=0.5033 | IoU=0.3363
# [TRAIN] Epoch 14/150 | Batch 100/153 | Loss_1=0.6341 | Loss_2=0.5554 | Loss_3=0.5410 | Totol_Loss=0.8646 | Dice_coeff=0.4590 | IoU=0.2979
# [TRAIN] Epoch 14/150 | Batch 110/153 | Loss_1=0.5877 | Loss_2=0.5911 | Loss_3=0.6282 | Totol_Loss=0.9587 | Dice_coeff=0.3718 | IoU=0.2284
# [TRAIN] Epoch 14/150 | Batch 120/153 | Loss_1=0.5549 | Loss_2=0.4874 | Loss_3=0.4616 | Totol_Loss=0.7453 | Dice_coeff=0.5384 | IoU=0.3684
# [TRAIN] Epoch 14/150 | Batch 130/153 | Loss_1=0.6728 | Loss_2=0.6389 | Loss_3=0.6446 | Totol_Loss=1.0079 | Dice_coeff=0.3554 | IoU=0.2161
# [TRAIN] Epoch 14/150 | Batch 140/153 | Loss_1=0.6258 | Loss_2=0.5302 | Loss_3=0.4861 | Totol_Loss=0.7983 | Dice_coeff=0.5139 | IoU=0.3458
# [TRAIN] Epoch 14/150 | Batch 150/153 | Loss_1=0.5479 | Loss_2=0.4676 | Loss_3=0.4544 | Totol_Loss=0.7291 | Dice_coeff=0.5456 | IoU=0.3751
#  Train Loss_1: 0.5996 | Loss_2: 0.5332 | Loss_3: 0.5256 | Total_Loss: 0.8348 | Avg_dice_coeff: 0.4744 | Avg_IoU: 0.3159
# Running Validation...
#  Valid Loss_1: 0.5764 | Loss_2: 0.5151 | Loss_3: 0.5137
#  Total_Loss: 0.8120 | Dice_coeff: 0.4863 | IoU: 0.3470
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 20-06-2025_08-37-31/model_epoch13.pt
# ========== Epoch 15 / 150 ==========
# Training...
# [TRAIN] Epoch 15/150 | Batch 10/153 | Loss_1=0.6083 | Loss_2=0.5330 | Loss_3=0.5073 | Totol_Loss=0.8178 | Dice_coeff=0.4927 | IoU=0.3269
# [TRAIN] Epoch 15/150 | Batch 20/153 | Loss_1=0.5242 | Loss_2=0.4601 | Loss_3=0.4448 | Totol_Loss=0.7127 | Dice_coeff=0.5552 | IoU=0.3843
# [TRAIN] Epoch 15/150 | Batch 30/153 | Loss_1=0.4561 | Loss_2=0.3895 | Loss_3=0.4179 | Totol_Loss=0.6467 | Dice_coeff=0.5821 | IoU=0.4106
# [TRAIN] Epoch 15/150 | Batch 40/153 | Loss_1=0.5413 | Loss_2=0.4886 | Loss_3=0.4990 | Totol_Loss=0.7811 | Dice_coeff=0.5010 | IoU=0.3342
# [TRAIN] Epoch 15/150 | Batch 50/153 | Loss_1=0.6037 | Loss_2=0.5789 | Loss_3=0.5899 | Totol_Loss=0.9181 | Dice_coeff=0.4101 | IoU=0.2579
# [TRAIN] Epoch 15/150 | Batch 60/153 | Loss_1=0.5359 | Loss_2=0.4523 | Loss_3=0.4366 | Totol_Loss=0.7033 | Dice_coeff=0.5634 | IoU=0.3922
# [TRAIN] Epoch 15/150 | Batch 70/153 | Loss_1=0.4702 | Loss_2=0.4161 | Loss_3=0.4235 | Totol_Loss=0.6651 | Dice_coeff=0.5765 | IoU=0.4050
# [TRAIN] Epoch 15/150 | Batch 80/153 | Loss_1=0.4824 | Loss_2=0.4256 | Loss_3=0.4287 | Totol_Loss=0.6761 | Dice_coeff=0.5713 | IoU=0.3999
# [TRAIN] Epoch 15/150 | Batch 90/153 | Loss_1=0.7065 | Loss_2=0.6263 | Loss_3=0.5792 | Totol_Loss=0.9427 | Dice_coeff=0.4208 | IoU=0.2665
# [TRAIN] Epoch 15/150 | Batch 100/153 | Loss_1=0.5809 | Loss_2=0.5325 | Loss_3=0.5327 | Totol_Loss=0.8387 | Dice_coeff=0.4673 | IoU=0.3049
# [TRAIN] Epoch 15/150 | Batch 110/153 | Loss_1=0.4946 | Loss_2=0.4404 | Loss_3=0.4482 | Totol_Loss=0.7035 | Dice_coeff=0.5518 | IoU=0.3811
# [TRAIN] Epoch 15/150 | Batch 120/153 | Loss_1=0.4402 | Loss_2=0.3569 | Loss_3=0.3674 | Totol_Loss=0.5806 | Dice_coeff=0.6326 | IoU=0.4626
# [TRAIN] Epoch 15/150 | Batch 130/153 | Loss_1=0.6234 | Loss_2=0.5929 | Loss_3=0.5801 | Totol_Loss=0.9170 | Dice_coeff=0.4199 | IoU=0.2658
# [TRAIN] Epoch 15/150 | Batch 140/153 | Loss_1=0.5420 | Loss_2=0.4590 | Loss_3=0.4605 | Totol_Loss=0.7308 | Dice_coeff=0.5395 | IoU=0.3694
# [TRAIN] Epoch 15/150 | Batch 150/153 | Loss_1=0.5169 | Loss_2=0.4643 | Loss_3=0.4656 | Totol_Loss=0.7340 | Dice_coeff=0.5344 | IoU=0.3646
#  Train Loss_1: 0.5836 | Loss_2: 0.5241 | Loss_3: 0.5178 | Total_Loss: 0.8208 | Avg_dice_coeff: 0.4822 | Avg_IoU: 0.3227
# Running Validation...
#  Valid Loss_1: 0.6061 | Loss_2: 0.5269 | Loss_3: 0.5094
#  Total_Loss: 0.8171 | Dice_coeff: 0.4906 | IoU: 0.3525
# Validation loss improved from 0.5136 to 0.5094. Saving model...
# Model saved to ==> 20-06-2025_08-37-31/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-37-31/model_epoch14.pt
# ========== Epoch 16 / 150 ==========
# Training...
# [TRAIN] Epoch 16/150 | Batch 10/153 | Loss_1=0.5679 | Loss_2=0.5088 | Loss_3=0.4979 | Totol_Loss=0.7922 | Dice_coeff=0.5021 | IoU=0.3352
# [TRAIN] Epoch 16/150 | Batch 20/153 | Loss_1=0.5454 | Loss_2=0.4679 | Loss_3=0.4669 | Totol_Loss=0.7413 | Dice_coeff=0.5331 | IoU=0.3635
# [TRAIN] Epoch 16/150 | Batch 30/153 | Loss_1=0.6260 | Loss_2=0.5622 | Loss_3=0.5581 | Totol_Loss=0.8831 | Dice_coeff=0.4419 | IoU=0.2836
# [TRAIN] Epoch 16/150 | Batch 40/153 | Loss_1=0.5318 | Loss_2=0.4916 | Loss_3=0.5080 | Totol_Loss=0.7897 | Dice_coeff=0.4920 | IoU=0.3263
# [TRAIN] Epoch 16/150 | Batch 50/153 | Loss_1=0.5810 | Loss_2=0.5441 | Loss_3=0.5787 | Totol_Loss=0.8893 | Dice_coeff=0.4213 | IoU=0.2668
# [TRAIN] Epoch 16/150 | Batch 60/153 | Loss_1=0.7285 | Loss_2=0.6435 | Loss_3=0.6164 | Totol_Loss=0.9903 | Dice_coeff=0.3836 | IoU=0.2373
# [TRAIN] Epoch 16/150 | Batch 70/153 | Loss_1=0.5914 | Loss_2=0.5167 | Loss_3=0.5023 | Totol_Loss=0.8036 | Dice_coeff=0.4977 | IoU=0.3313
# [TRAIN] Epoch 16/150 | Batch 80/153 | Loss_1=0.5459 | Loss_2=0.5021 | Loss_3=0.5032 | Totol_Loss=0.7914 | Dice_coeff=0.4968 | IoU=0.3305
# [TRAIN] Epoch 16/150 | Batch 90/153 | Loss_1=0.7292 | Loss_2=0.6320 | Loss_3=0.6025 | Totol_Loss=0.9720 | Dice_coeff=0.3975 | IoU=0.2481
# [TRAIN] Epoch 16/150 | Batch 100/153 | Loss_1=0.5690 | Loss_2=0.4697 | Loss_3=0.4561 | Totol_Loss=0.7351 | Dice_coeff=0.5439 | IoU=0.3735
# [TRAIN] Epoch 16/150 | Batch 110/153 | Loss_1=0.6475 | Loss_2=0.5813 | Loss_3=0.5634 | Totol_Loss=0.8995 | Dice_coeff=0.4366 | IoU=0.2793
# [TRAIN] Epoch 16/150 | Batch 120/153 | Loss_1=0.5215 | Loss_2=0.4521 | Loss_3=0.4502 | Totol_Loss=0.7145 | Dice_coeff=0.5498 | IoU=0.3791
# [TRAIN] Epoch 16/150 | Batch 130/153 | Loss_1=0.6865 | Loss_2=0.6123 | Loss_3=0.6048 | Totol_Loss=0.9595 | Dice_coeff=0.3952 | IoU=0.2463
# [TRAIN] Epoch 16/150 | Batch 140/153 | Loss_1=0.5573 | Loss_2=0.5042 | Loss_3=0.5077 | Totol_Loss=0.7986 | Dice_coeff=0.4923 | IoU=0.3265
# [TRAIN] Epoch 16/150 | Batch 150/153 | Loss_1=0.5112 | Loss_2=0.4393 | Loss_3=0.4486 | Totol_Loss=0.7061 | Dice_coeff=0.5514 | IoU=0.3806
#  Train Loss_1: 0.5909 | Loss_2: 0.5269 | Loss_3: 0.5213 | Total_Loss: 0.8265 | Avg_dice_coeff: 0.4787 | Avg_IoU: 0.3201
# Running Validation...
#  Valid Loss_1: 0.5745 | Loss_2: 0.5072 | Loss_3: 0.4996
#  Total_Loss: 0.7944 | Dice_coeff: 0.5004 | IoU: 0.3621
# Validation loss improved from 0.5094 to 0.4996. Saving model...
# Model saved to ==> 20-06-2025_08-37-31/model_best_valloss.pt
# Model saved to ==> 20-06-2025_08-37-31/model_epoch15.pt
# ========== Epoch 17 / 150 ==========
# Training...
# [TRAIN] Epoch 17/150 | Batch 10/153 | Loss_1=0.3890 | Loss_2=0.3165 | Loss_3=0.3544 | Totol_Loss=0.5432 | Dice_coeff=0.6456 | IoU=0.4767
# [TRAIN] Epoch 17/150 | Batch 20/153 | Loss_1=0.4495 | Loss_2=0.3696 | Loss_3=0.3734 | Totol_Loss=0.5931 | Dice_coeff=0.6266 | IoU=0.4563
# [TRAIN] Epoch 17/150 | Batch 30/153 | Loss_1=0.6681 | Loss_2=0.6203 | Loss_3=0.6220 | Totol_Loss=0.9771 | Dice_coeff=0.3780 | IoU=0.2330
# [TRAIN] Epoch 17/150 | Batch 40/153 | Loss_1=0.5598 | Loss_2=0.4876 | Loss_3=0.4651 | Totol_Loss=0.7497 | Dice_coeff=0.5349 | IoU=0.3651
# [TRAIN] Epoch 17/150 | Batch 50/153 | Loss_1=0.6706 | Loss_2=0.5791 | Loss_3=0.5443 | Totol_Loss=0.8832 | Dice_coeff=0.4557 | IoU=0.2951
# [TRAIN] Epoch 17/150 | Batch 60/153 | Loss_1=0.7125 | Loss_2=0.6211 | Loss_3=0.5821 | Totol_Loss=0.9445 | Dice_coeff=0.4179 | IoU=0.2642
# [TRAIN] Epoch 17/150 | Batch 70/153 | Loss_1=0.7493 | Loss_2=0.7068 | Loss_3=0.6889 | Totol_Loss=1.0915 | Dice_coeff=0.3111 | IoU=0.1842
# [TRAIN] Epoch 17/150 | Batch 80/153 | Loss_1=0.5846 | Loss_2=0.5167 | Loss_3=0.4924 | Totol_Loss=0.7926 | Dice_coeff=0.5076 | IoU=0.3402
# [TRAIN] Epoch 17/150 | Batch 90/153 | Loss_1=0.7016 | Loss_2=0.6624 | Loss_3=0.6325 | Totol_Loss=1.0097 | Dice_coeff=0.3675 | IoU=0.2251
# [TRAIN] Epoch 17/150 | Batch 100/153 | Loss_1=0.5467 | Loss_2=0.4694 | Loss_3=0.4618 | Totol_Loss=0.7370 | Dice_coeff=0.5382 | IoU=0.3682
# [TRAIN] Epoch 17/150 | Batch 110/153 | Loss_1=0.6452 | Loss_2=0.5723 | Loss_3=0.5415 | Totol_Loss=0.8736 | Dice_coeff=0.4585 | IoU=0.2975
# [TRAIN] Epoch 17/150 | Batch 120/153 | Loss_1=0.6336 | Loss_2=0.5722 | Loss_3=0.5582 | Totol_Loss=0.8885 | Dice_coeff=0.4418 | IoU=0.2835
# [TRAIN] Epoch 17/150 | Batch 130/153 | Loss_1=0.5881 | Loss_2=0.5376 | Loss_3=0.5285 | Totol_Loss=0.8376 | Dice_coeff=0.4715 | IoU=0.3085
# [TRAIN] Epoch 17/150 | Batch 140/153 | Loss_1=0.6747 | Loss_2=0.6525 | Loss_3=0.6741 | Totol_Loss=1.0430 | Dice_coeff=0.3259 | IoU=0.1947
# [TRAIN] Epoch 17/150 | Batch 150/153 | Loss_1=0.5807 | Loss_2=0.5055 | Loss_3=0.4884 | Totol_Loss=0.7835 | Dice_coeff=0.5116 | IoU=0.3438
#  Train Loss_1: 0.5947 | Loss_2: 0.5293 | Loss_3: 0.5232 | Total_Loss: 0.8301 | Avg_dice_coeff: 0.4768 | Avg_IoU: 0.3195
# Running Validation...
#  Valid Loss_1: 0.5943 | Loss_2: 0.5317 | Loss_3: 0.5146
#  Total_Loss: 0.8223 | Dice_coeff: 0.4854 | IoU: 0.3485
# No improvement in validation loss for 1 epochs.
# Model saved to ==> 20-06-2025_08-37-31/model_epoch16.pt
# ========== Epoch 18 / 150 ==========
# Training...
# [TRAIN] Epoch 18/150 | Batch 10/153 | Loss_1=0.6566 | Loss_2=0.5858 | Loss_3=0.5558 | Totol_Loss=0.8952 | Dice_coeff=0.4442 | IoU=0.2855
# [TRAIN] Epoch 18/150 | Batch 20/153 | Loss_1=0.7038 | Loss_2=0.6509 | Loss_3=0.6521 | Totol_Loss=1.0251 | Dice_coeff=0.3479 | IoU=0.2106
# [TRAIN] Epoch 18/150 | Batch 30/153 | Loss_1=0.5860 | Loss_2=0.4592 | Loss_3=0.4376 | Totol_Loss=0.7151 | Dice_coeff=0.5624 | IoU=0.3912
# [TRAIN] Epoch 18/150 | Batch 40/153 | Loss_1=0.8118 | Loss_2=0.7657 | Loss_3=0.7635 | Totol_Loss=1.1997 | Dice_coeff=0.2365 | IoU=0.1341
# [TRAIN] Epoch 18/150 | Batch 50/153 | Loss_1=0.6158 | Loss_2=0.5408 | Loss_3=0.5383 | Totol_Loss=0.8532 | Dice_coeff=0.4617 | IoU=0.3001
# [TRAIN] Epoch 18/150 | Batch 60/153 | Loss_1=0.5314 | Loss_2=0.4556 | Loss_3=0.4785 | Totol_Loss=0.7458 | Dice_coeff=0.5215 | IoU=0.3527
# [TRAIN] Epoch 18/150 | Batch 70/153 | Loss_1=0.6068 | Loss_2=0.5542 | Loss_3=0.5680 | Totol_Loss=0.8868 | Dice_coeff=0.4320 | IoU=0.2755
# [TRAIN] Epoch 18/150 | Batch 80/153 | Loss_1=0.6965 | Loss_2=0.6366 | Loss_3=0.6189 | Totol_Loss=0.9850 | Dice_coeff=0.3811 | IoU=0.2354
# [TRAIN] Epoch 18/150 | Batch 90/153 | Loss_1=0.6746 | Loss_2=0.6111 | Loss_3=0.6089 | Totol_Loss=0.9613 | Dice_coeff=0.3911 | IoU=0.2431
# [TRAIN] Epoch 18/150 | Batch 100/153 | Loss_1=0.5941 | Loss_2=0.5523 | Loss_3=0.5417 | Totol_Loss=0.8577 | Dice_coeff=0.4583 | IoU=0.2972
# [TRAIN] Epoch 18/150 | Batch 110/153 | Loss_1=0.7821 | Loss_2=0.7172 | Loss_3=0.6666 | Totol_Loss=1.0786 | Dice_coeff=0.3334 | IoU=0.2001
# [TRAIN] Epoch 18/150 | Batch 120/153 | Loss_1=0.7411 | Loss_2=0.6892 | Loss_3=0.6627 | Totol_Loss=1.0569 | Dice_coeff=0.3373 | IoU=0.2029
# [TRAIN] Epoch 18/150 | Batch 130/153 | Loss_1=0.6646 | Loss_2=0.6201 | Loss_3=0.6172 | Totol_Loss=0.9715 | Dice_coeff=0.3828 | IoU=0.2367
# [TRAIN] Epoch 18/150 | Batch 140/153 | Loss_1=0.4138 | Loss_2=0.3911 | Loss_3=0.4058 | Totol_Loss=0.6284 | Dice_coeff=0.5942 | IoU=0.4227
# [TRAIN] Epoch 18/150 | Batch 150/153 | Loss_1=0.5787 | Loss_2=0.5365 | Loss_3=0.5221 | Totol_Loss=0.8293 | Dice_coeff=0.4779 | IoU=0.3140
#  Train Loss_1: 0.5926 | Loss_2: 0.5249 | Loss_3: 0.5173 | Total_Loss: 0.8221 | Avg_dice_coeff: 0.4827 | Avg_IoU: 0.3234
# Running Validation...
#  Valid Loss_1: 0.5864 | Loss_2: 0.5231 | Loss_3: 0.5152
#  Total_Loss: 0.8182 | Dice_coeff: 0.4848 | IoU: 0.3424
# No improvement in validation loss for 2 epochs.
# Model saved to ==> 20-06-2025_08-37-31/model_epoch17.pt
# ========== Epoch 19 / 150 ==========
# Training...
# [TRAIN] Epoch 19/150 | Batch 10/153 | Loss_1=0.6757 | Loss_2=0.6102 | Loss_3=0.5784 | Totol_Loss=0.9306 | Dice_coeff=0.4216 | IoU=0.2671
# [TRAIN] Epoch 19/150 | Batch 20/153 | Loss_1=0.5512 | Loss_2=0.4860 | Loss_3=0.4744 | Totol_Loss=0.7570 | Dice_coeff=0.5256 | IoU=0.3565
# [TRAIN] Epoch 19/150 | Batch 30/153 | Loss_1=0.7133 | Loss_2=0.6545 | Loss_3=0.6171 | Totol_Loss=0.9930 | Dice_coeff=0.3829 | IoU=0.2368
# [TRAIN] Epoch 19/150 | Batch 40/153 | Loss_1=0.5042 | Loss_2=0.4249 | Loss_3=0.4131 | Totol_Loss=0.6638 | Dice_coeff=0.5869 | IoU=0.4153
# [TRAIN] Epoch 19/150 | Batch 50/153 | Loss_1=0.3892 | Loss_2=0.3322 | Loss_3=0.3449 | Totol_Loss=0.5400 | Dice_coeff=0.6551 | IoU=0.4871
# [TRAIN] Epoch 19/150 | Batch 60/153 | Loss_1=0.6156 | Loss_2=0.5308 | Loss_3=0.5227 | Totol_Loss=0.8335 | Dice_coeff=0.4773 | IoU=0.3135
# [TRAIN] Epoch 19/150 | Batch 70/153 | Loss_1=0.5450 | Loss_2=0.4663 | Loss_3=0.4791 | Totol_Loss=0.7528 | Dice_coeff=0.5209 | IoU=0.3522
# [TRAIN] Epoch 19/150 | Batch 80/153 | Loss_1=0.6315 | Loss_2=0.5678 | Loss_3=0.5735 | Totol_Loss=0.9017 | Dice_coeff=0.4265 | IoU=0.2710
# [TRAIN] Epoch 19/150 | Batch 90/153 | Loss_1=0.4578 | Loss_2=0.4264 | Loss_3=0.4455 | Totol_Loss=0.6894 | Dice_coeff=0.5545 | IoU=0.3836
# [TRAIN] Epoch 19/150 | Batch 100/153 | Loss_1=0.5881 | Loss_2=0.4928 | Loss_3=0.5000 | Totol_Loss=0.7912 | Dice_coeff=0.5000 | IoU=0.3333
# [TRAIN] Epoch 19/150 | Batch 110/153 | Loss_1=0.5838 | Loss_2=0.5414 | Loss_3=0.5389 | Totol_Loss=0.8489 | Dice_coeff=0.4611 | IoU=0.2996
# [TRAIN] Epoch 19/150 | Batch 120/153 | Loss_1=0.3578 | Loss_2=0.2797 | Loss_3=0.2763 | Totol_Loss=0.4454 | Dice_coeff=0.7237 | IoU=0.5671
# [TRAIN] Epoch 19/150 | Batch 130/153 | Loss_1=0.5614 | Loss_2=0.4723 | Loss_3=0.4198 | Totol_Loss=0.6985 | Dice_coeff=0.5802 | IoU=0.4087
# [TRAIN] Epoch 19/150 | Batch 140/153 | Loss_1=0.4422 | Loss_2=0.3573 | Loss_3=0.3558 | Totol_Loss=0.5695 | Dice_coeff=0.6442 | IoU=0.4752
# [TRAIN] Epoch 19/150 | Batch 150/153 | Loss_1=0.6290 | Loss_2=0.6110 | Loss_3=0.6145 | Totol_Loss=0.9596 | Dice_coeff=0.3855 | IoU=0.2387
#  Train Loss_1: 0.5600 | Loss_2: 0.4971 | Loss_3: 0.4923 | Total_Loss: 0.7808 | Avg_dice_coeff: 0.5077 | Avg_IoU: 0.3446
# Running Validation...
#  Valid Loss_1: 0.5246 | Loss_2: 0.4944 | Loss_3: 0.5114
#  Total_Loss: 0.7932 | Dice_coeff: 0.4886 | IoU: 0.3394
# No improvement in validation loss for 3 epochs.
# Model saved to ==> 20-06-2025_08-37-31/model_epoch18.pt
# ========== Epoch 20 / 150 ==========
# Training...
# [TRAIN] Epoch 20/150 | Batch 10/153 | Loss_1=0.7356 | Loss_2=0.6865 | Loss_3=0.6761 | Totol_Loss=1.0684 | Dice_coeff=0.3239 | IoU=0.1933
# [TRAIN] Epoch 20/150 | Batch 20/153 | Loss_1=0.5647 | Loss_2=0.5127 | Loss_3=0.5059 | Totol_Loss=0.8014 | Dice_coeff=0.4941 | IoU=0.3281
# ...
# [TRAIN] Epoch 144/150 | Batch 110/153 | Loss_1=0.1578 | Loss_2=0.1346 | Loss_3=0.1336 | Totol_Loss=0.2127 | Dice_coeff=0.8664 | IoU=0.7642
# [TRAIN] Epoch 144/150 | Batch 120/153 | Loss_1=0.1615 | Loss_2=0.1011 | Loss_3=0.1001 | Totol_Loss=0.1664 | Dice_coeff=0.8999 | IoU=0.8180
# [TRAIN] Epoch 144/150 | Batch 130/153 | Loss_1=0.1836 | Loss_2=0.1334 | Loss_3=0.1315 | Totol_Loss=0.2143 | Dice_coeff=0.8685 | IoU=0.7675
# [TRAIN] Epoch 144/150 | Batch 140/153 | Loss_1=0.1508 | Loss_2=0.1224 | Loss_3=0.1210 | Totol_Loss=0.1941 | Dice_coeff=0.8790 | IoU=0.7841
# [TRAIN] Epoch 144/150 | Batch 150/153 | Loss_1=0.1071 | Loss_2=0.0755 | Loss_3=0.0737 | Totol_Loss=0.1210 | Dice_coeff=0.9263 | IoU=0.8627
#  Train Loss_1: 0.1303 | Loss_2: 0.0955 | Loss_3: 0.0940 | Total_Loss: 0.1531 | Avg_dice_coeff: 0.9060 | Avg_IoU: 0.8292
# Running Validation...
#  Valid Loss_1: 0.2434 | Loss_2: 0.2063 | Loss_3: 0.2051
#  Total_Loss: 0.3266 | Dice_coeff: 0.7949 | IoU: 0.6692
# No improvement in validation loss for 20 epochs.
# Model saved to ==> 20-06-2025_08-37-31/model_epoch143.pt
# ========== Epoch 145 / 150 ==========
# Training...
# [TRAIN] Epoch 145/150 | Batch 10/153 | Loss_1=0.0911 | Loss_2=0.0672 | Loss_3=0.0657 | Totol_Loss=0.1071 | Dice_coeff=0.9343 | IoU=0.8768
# [TRAIN] Epoch 145/150 | Batch 20/153 | Loss_1=0.0915 | Loss_2=0.0714 | Loss_3=0.0720 | Totol_Loss=0.1151 | Dice_coeff=0.9280 | IoU=0.8657
# [TRAIN] Epoch 145/150 | Batch 30/153 | Loss_1=0.0831 | Loss_2=0.0595 | Loss_3=0.0602 | Totol_Loss=0.0973 | Dice_coeff=0.9398 | IoU=0.8864
# [TRAIN] Epoch 145/150 | Batch 40/153 | Loss_1=0.1319 | Loss_2=0.1072 | Loss_3=0.1070 | Totol_Loss=0.1710 | Dice_coeff=0.8930 | IoU=0.8067
# [TRAIN] Epoch 145/150 | Batch 50/153 | Loss_1=0.1364 | Loss_2=0.0877 | Loss_3=0.0866 | Totol_Loss=0.1435 | Dice_coeff=0.9134 | IoU=0.8407
# [TRAIN] Epoch 145/150 | Batch 60/153 | Loss_1=0.1075 | Loss_2=0.0705 | Loss_3=0.0700 | Totol_Loss=0.1154 | Dice_coeff=0.9300 | IoU=0.8691
# [TRAIN] Epoch 145/150 | Batch 70/153 | Loss_1=0.1469 | Loss_2=0.1040 | Loss_3=0.1021 | Totol_Loss=0.1672 | Dice_coeff=0.8979 | IoU=0.8147
# [TRAIN] Epoch 145/150 | Batch 80/153 | Loss_1=0.1236 | Loss_2=0.0878 | Loss_3=0.0873 | Totol_Loss=0.1422 | Dice_coeff=0.9127 | IoU=0.8394
# [TRAIN] Epoch 145/150 | Batch 90/153 | Loss_1=0.0890 | Loss_2=0.0625 | Loss_3=0.0604 | Totol_Loss=0.0996 | Dice_coeff=0.9396 | IoU=0.8861
# [TRAIN] Epoch 145/150 | Batch 100/153 | Loss_1=0.0827 | Loss_2=0.0592 | Loss_3=0.0591 | Totol_Loss=0.0960 | Dice_coeff=0.9409 | IoU=0.8884
# [TRAIN] Epoch 145/150 | Batch 110/153 | Loss_1=0.0969 | Loss_2=0.0605 | Loss_3=0.0584 | Totol_Loss=0.0981 | Dice_coeff=0.9416 | IoU=0.8897
# [TRAIN] Epoch 145/150 | Batch 120/153 | Loss_1=0.1210 | Loss_2=0.0768 | Loss_3=0.0751 | Totol_Loss=0.1252 | Dice_coeff=0.9249 | IoU=0.8602
# [TRAIN] Epoch 145/150 | Batch 130/153 | Loss_1=0.1305 | Loss_2=0.0969 | Loss_3=0.0939 | Totol_Loss=0.1535 | Dice_coeff=0.9061 | IoU=0.8284
# [TRAIN] Epoch 145/150 | Batch 140/153 | Loss_1=0.1190 | Loss_2=0.0892 | Loss_3=0.0882 | Totol_Loss=0.1429 | Dice_coeff=0.9118 | IoU=0.8379
# [TRAIN] Epoch 145/150 | Batch 150/153 | Loss_1=0.1123 | Loss_2=0.0888 | Loss_3=0.0886 | Totol_Loss=0.1421 | Dice_coeff=0.9114 | IoU=0.8372
#  Train Loss_1: 0.1302 | Loss_2: 0.0956 | Loss_3: 0.0942 | Total_Loss: 0.1533 | Avg_dice_coeff: 0.9058 | Avg_IoU: 0.8290
# Running Validation...
#  Valid Loss_1: 0.2434 | Loss_2: 0.2061 | Loss_3: 0.2048
#  Total_Loss: 0.3262 | Dice_coeff: 0.7952 | IoU: 0.6696
# No improvement in validation loss for 21 epochs.
# Model saved to ==> 20-06-2025_08-37-31/model_epoch144.pt
# ========== Epoch 146 / 150 ==========
# Training...
# [TRAIN] Epoch 146/150 | Batch 10/153 | Loss_1=0.1723 | Loss_2=0.1389 | Loss_3=0.1369 | Totol_Loss=0.2200 | Dice_coeff=0.8631 | IoU=0.7592
# [TRAIN] Epoch 146/150 | Batch 20/153 | Loss_1=0.1552 | Loss_2=0.1213 | Loss_3=0.1196 | Totol_Loss=0.1930 | Dice_coeff=0.8804 | IoU=0.7863
# [TRAIN] Epoch 146/150 | Batch 30/153 | Loss_1=0.1433 | Loss_2=0.1194 | Loss_3=0.1204 | Totol_Loss=0.1911 | Dice_coeff=0.8796 | IoU=0.7851
# [TRAIN] Epoch 146/150 | Batch 40/153 | Loss_1=0.1180 | Loss_2=0.0927 | Loss_3=0.0903 | Totol_Loss=0.1463 | Dice_coeff=0.9097 | IoU=0.8343
# [TRAIN] Epoch 146/150 | Batch 50/153 | Loss_1=0.1156 | Loss_2=0.0853 | Loss_3=0.0836 | Totol_Loss=0.1362 | Dice_coeff=0.9164 | IoU=0.8457
# [TRAIN] Epoch 146/150 | Batch 60/153 | Loss_1=0.1362 | Loss_2=0.1156 | Loss_3=0.1158 | Totol_Loss=0.1838 | Dice_coeff=0.8842 | IoU=0.7925
# [TRAIN] Epoch 146/150 | Batch 70/153 | Loss_1=0.0905 | Loss_2=0.0622 | Loss_3=0.0614 | Totol_Loss=0.1007 | Dice_coeff=0.9386 | IoU=0.8844
# [TRAIN] Epoch 146/150 | Batch 80/153 | Loss_1=0.1594 | Loss_2=0.1059 | Loss_3=0.1028 | Totol_Loss=0.1706 | Dice_coeff=0.8972 | IoU=0.8136
# [TRAIN] Epoch 146/150 | Batch 90/153 | Loss_1=0.1312 | Loss_2=0.0886 | Loss_3=0.0896 | Totol_Loss=0.1460 | Dice_coeff=0.9104 | IoU=0.8356
# [TRAIN] Epoch 146/150 | Batch 100/153 | Loss_1=0.1147 | Loss_2=0.0857 | Loss_3=0.0845 | Totol_Loss=0.1371 | Dice_coeff=0.9155 | IoU=0.8442
# [TRAIN] Epoch 146/150 | Batch 110/153 | Loss_1=0.1324 | Loss_2=0.0978 | Loss_3=0.0966 | Totol_Loss=0.1569 | Dice_coeff=0.9034 | IoU=0.8238
# [TRAIN] Epoch 146/150 | Batch 120/153 | Loss_1=0.1502 | Loss_2=0.1137 | Loss_3=0.1101 | Totol_Loss=0.1796 | Dice_coeff=0.8899 | IoU=0.8016
# [TRAIN] Epoch 146/150 | Batch 130/153 | Loss_1=0.2143 | Loss_2=0.1765 | Loss_3=0.1735 | Totol_Loss=0.2784 | Dice_coeff=0.8265 | IoU=0.7043
# [TRAIN] Epoch 146/150 | Batch 140/153 | Loss_1=0.1375 | Loss_2=0.1054 | Loss_3=0.1035 | Totol_Loss=0.1677 | Dice_coeff=0.8965 | IoU=0.8124
# [TRAIN] Epoch 146/150 | Batch 150/153 | Loss_1=0.1303 | Loss_2=0.0962 | Loss_3=0.0961 | Totol_Loss=0.1554 | Dice_coeff=0.9039 | IoU=0.8247
#  Train Loss_1: 0.1300 | Loss_2: 0.0952 | Loss_3: 0.0937 | Total_Loss: 0.1526 | Avg_dice_coeff: 0.9063 | Avg_IoU: 0.8297
# Running Validation...
#  Valid Loss_1: 0.2433 | Loss_2: 0.2063 | Loss_3: 0.2051
#  Total_Loss: 0.3265 | Dice_coeff: 0.7949 | IoU: 0.6693
# No improvement in validation loss for 22 epochs.
# Model saved to ==> 20-06-2025_08-37-31/model_epoch145.pt
# ========== Epoch 147 / 150 ==========
# Training...
# [TRAIN] Epoch 147/150 | Batch 10/153 | Loss_1=0.1110 | Loss_2=0.0902 | Loss_3=0.0900 | Totol_Loss=0.1439 | Dice_coeff=0.9100 | IoU=0.8348
# [TRAIN] Epoch 147/150 | Batch 20/153 | Loss_1=0.1211 | Loss_2=0.0995 | Loss_3=0.0995 | Totol_Loss=0.1586 | Dice_coeff=0.9005 | IoU=0.8191
# [TRAIN] Epoch 147/150 | Batch 30/153 | Loss_1=0.1098 | Loss_2=0.0770 | Loss_3=0.0755 | Totol_Loss=0.1239 | Dice_coeff=0.9245 | IoU=0.8596
# [TRAIN] Epoch 147/150 | Batch 40/153 | Loss_1=0.1377 | Loss_2=0.0985 | Loss_3=0.0973 | Totol_Loss=0.1587 | Dice_coeff=0.9027 | IoU=0.8227
# [TRAIN] Epoch 147/150 | Batch 50/153 | Loss_1=0.1324 | Loss_2=0.1007 | Loss_3=0.0999 | Totol_Loss=0.1613 | Dice_coeff=0.9001 | IoU=0.8184
# [TRAIN] Epoch 147/150 | Batch 60/153 | Loss_1=0.1458 | Loss_2=0.1157 | Loss_3=0.1146 | Totol_Loss=0.1842 | Dice_coeff=0.8854 | IoU=0.7944
# [TRAIN] Epoch 147/150 | Batch 70/153 | Loss_1=0.1222 | Loss_2=0.0831 | Loss_3=0.0823 | Totol_Loss=0.1351 | Dice_coeff=0.9177 | IoU=0.8479
# [TRAIN] Epoch 147/150 | Batch 80/153 | Loss_1=0.1128 | Loss_2=0.0900 | Loss_3=0.0879 | Totol_Loss=0.1420 | Dice_coeff=0.9121 | IoU=0.8384
# [TRAIN] Epoch 147/150 | Batch 90/153 | Loss_1=0.1442 | Loss_2=0.1049 | Loss_3=0.1044 | Totol_Loss=0.1694 | Dice_coeff=0.8956 | IoU=0.8109
# [TRAIN] Epoch 147/150 | Batch 100/153 | Loss_1=0.1372 | Loss_2=0.0893 | Loss_3=0.0873 | Totol_Loss=0.1450 | Dice_coeff=0.9127 | IoU=0.8394
# [TRAIN] Epoch 147/150 | Batch 110/153 | Loss_1=0.1826 | Loss_2=0.1176 | Loss_3=0.1158 | Totol_Loss=0.1921 | Dice_coeff=0.8842 | IoU=0.7924
# [TRAIN] Epoch 147/150 | Batch 120/153 | Loss_1=0.1053 | Loss_2=0.0693 | Loss_3=0.0652 | Totol_Loss=0.1098 | Dice_coeff=0.9348 | IoU=0.8776
# [TRAIN] Epoch 147/150 | Batch 130/153 | Loss_1=0.1002 | Loss_2=0.0730 | Loss_3=0.0711 | Totol_Loss=0.1164 | Dice_coeff=0.9289 | IoU=0.8672
# [TRAIN] Epoch 147/150 | Batch 140/153 | Loss_1=0.1312 | Loss_2=0.0988 | Loss_3=0.0981 | Totol_Loss=0.1586 | Dice_coeff=0.9019 | IoU=0.8213
# [TRAIN] Epoch 147/150 | Batch 150/153 | Loss_1=0.1648 | Loss_2=0.1272 | Loss_3=0.1265 | Totol_Loss=0.2038 | Dice_coeff=0.8735 | IoU=0.7754
#  Train Loss_1: 0.1300 | Loss_2: 0.0953 | Loss_3: 0.0938 | Total_Loss: 0.1527 | Avg_dice_coeff: 0.9062 | Avg_IoU: 0.8296
# Running Validation...
#  Valid Loss_1: 0.2430 | Loss_2: 0.2057 | Loss_3: 0.2043
#  Total_Loss: 0.3255 | Dice_coeff: 0.7957 | IoU: 0.6703
# No improvement in validation loss for 23 epochs.
# Model saved to ==> 20-06-2025_08-37-31/model_epoch146.pt
# ========== Epoch 148 / 150 ==========
# Training...
# [TRAIN] Epoch 148/150 | Batch 10/153 | Loss_1=0.0802 | Loss_2=0.0547 | Loss_3=0.0552 | Totol_Loss=0.0900 | Dice_coeff=0.9448 | IoU=0.8953
# [TRAIN] Epoch 148/150 | Batch 20/153 | Loss_1=0.1074 | Loss_2=0.0862 | Loss_3=0.0862 | Totol_Loss=0.1379 | Dice_coeff=0.9138 | IoU=0.8412
# [TRAIN] Epoch 148/150 | Batch 30/153 | Loss_1=0.0916 | Loss_2=0.0697 | Loss_3=0.0685 | Totol_Loss=0.1110 | Dice_coeff=0.9315 | IoU=0.8719
# [TRAIN] Epoch 148/150 | Batch 40/153 | Loss_1=0.1263 | Loss_2=0.1005 | Loss_3=0.1000 | Totol_Loss=0.1604 | Dice_coeff=0.9000 | IoU=0.8182
# [TRAIN] Epoch 148/150 | Batch 50/153 | Loss_1=0.1155 | Loss_2=0.0882 | Loss_3=0.0861 | Totol_Loss=0.1399 | Dice_coeff=0.9139 | IoU=0.8414
# [TRAIN] Epoch 148/150 | Batch 60/153 | Loss_1=0.1408 | Loss_2=0.1138 | Loss_3=0.1139 | Totol_Loss=0.1819 | Dice_coeff=0.8861 | IoU=0.7955
# [TRAIN] Epoch 148/150 | Batch 70/153 | Loss_1=0.2197 | Loss_2=0.1694 | Loss_3=0.1686 | Totol_Loss=0.2715 | Dice_coeff=0.8314 | IoU=0.7115
# [TRAIN] Epoch 148/150 | Batch 80/153 | Loss_1=0.0877 | Loss_2=0.0705 | Loss_3=0.0705 | Totol_Loss=0.1127 | Dice_coeff=0.9295 | IoU=0.8683
# [TRAIN] Epoch 148/150 | Batch 90/153 | Loss_1=0.1229 | Loss_2=0.0855 | Loss_3=0.0828 | Totol_Loss=0.1366 | Dice_coeff=0.9172 | IoU=0.8471
# [TRAIN] Epoch 148/150 | Batch 100/153 | Loss_1=0.1480 | Loss_2=0.1156 | Loss_3=0.1130 | Totol_Loss=0.1829 | Dice_coeff=0.8870 | IoU=0.7970
# [TRAIN] Epoch 148/150 | Batch 110/153 | Loss_1=0.1316 | Loss_2=0.1014 | Loss_3=0.0965 | Totol_Loss=0.1581 | Dice_coeff=0.9035 | IoU=0.8240
# [TRAIN] Epoch 148/150 | Batch 120/153 | Loss_1=0.1397 | Loss_2=0.0830 | Loss_3=0.0807 | Totol_Loss=0.1363 | Dice_coeff=0.9193 | IoU=0.8506
# [TRAIN] Epoch 148/150 | Batch 130/153 | Loss_1=0.2524 | Loss_2=0.1648 | Loss_3=0.1623 | Totol_Loss=0.2686 | Dice_coeff=0.8377 | IoU=0.7207
# [TRAIN] Epoch 148/150 | Batch 140/153 | Loss_1=0.1681 | Loss_2=0.1294 | Loss_3=0.1285 | Totol_Loss=0.2071 | Dice_coeff=0.8715 | IoU=0.7723
# [TRAIN] Epoch 148/150 | Batch 150/153 | Loss_1=0.1209 | Loss_2=0.0792 | Loss_3=0.0788 | Totol_Loss=0.1298 | Dice_coeff=0.9212 | IoU=0.8539
#  Train Loss_1: 0.1297 | Loss_2: 0.0949 | Loss_3: 0.0933 | Total_Loss: 0.1520 | Avg_dice_coeff: 0.9067 | Avg_IoU: 0.8305
# Running Validation...
#  Valid Loss_1: 0.2433 | Loss_2: 0.2063 | Loss_3: 0.2051
#  Total_Loss: 0.3266 | Dice_coeff: 0.7949 | IoU: 0.6693
# No improvement in validation loss for 24 epochs.
# Model saved to ==> 20-06-2025_08-37-31/model_epoch147.pt
# ========== Epoch 149 / 150 ==========
# Training...
# [TRAIN] Epoch 149/150 | Batch 10/153 | Loss_1=0.1310 | Loss_2=0.0980 | Loss_3=0.0953 | Totol_Loss=0.1555 | Dice_coeff=0.9047 | IoU=0.8259
# [TRAIN] Epoch 149/150 | Batch 20/153 | Loss_1=0.1197 | Loss_2=0.0836 | Loss_3=0.0810 | Totol_Loss=0.1336 | Dice_coeff=0.9190 | IoU=0.8502
# [TRAIN] Epoch 149/150 | Batch 30/153 | Loss_1=0.1358 | Loss_2=0.0990 | Loss_3=0.0957 | Totol_Loss=0.1570 | Dice_coeff=0.9043 | IoU=0.8254
# [TRAIN] Epoch 149/150 | Batch 40/153 | Loss_1=0.1582 | Loss_2=0.1139 | Loss_3=0.1130 | Totol_Loss=0.1839 | Dice_coeff=0.8870 | IoU=0.7969
# [TRAIN] Epoch 149/150 | Batch 50/153 | Loss_1=0.1277 | Loss_2=0.1015 | Loss_3=0.1006 | Totol_Loss=0.1616 | Dice_coeff=0.8994 | IoU=0.8172
# [TRAIN] Epoch 149/150 | Batch 60/153 | Loss_1=0.1351 | Loss_2=0.1025 | Loss_3=0.0993 | Totol_Loss=0.1620 | Dice_coeff=0.9007 | IoU=0.8193
# [TRAIN] Epoch 149/150 | Batch 70/153 | Loss_1=0.1134 | Loss_2=0.0822 | Loss_3=0.0807 | Totol_Loss=0.1317 | Dice_coeff=0.9193 | IoU=0.8507
# [TRAIN] Epoch 149/150 | Batch 80/153 | Loss_1=0.1320 | Loss_2=0.1052 | Loss_3=0.1045 | Totol_Loss=0.1677 | Dice_coeff=0.8955 | IoU=0.8108
# [TRAIN] Epoch 149/150 | Batch 90/153 | Loss_1=0.1203 | Loss_2=0.0718 | Loss_3=0.0694 | Totol_Loss=0.1173 | Dice_coeff=0.9306 | IoU=0.8703
# [TRAIN] Epoch 149/150 | Batch 100/153 | Loss_1=0.1105 | Loss_2=0.0785 | Loss_3=0.0773 | Totol_Loss=0.1264 | Dice_coeff=0.9227 | IoU=0.8565
# [TRAIN] Epoch 149/150 | Batch 110/153 | Loss_1=0.1251 | Loss_2=0.0822 | Loss_3=0.0794 | Totol_Loss=0.1323 | Dice_coeff=0.9206 | IoU=0.8528
# [TRAIN] Epoch 149/150 | Batch 120/153 | Loss_1=0.2194 | Loss_2=0.1474 | Loss_3=0.1428 | Totol_Loss=0.2369 | Dice_coeff=0.8572 | IoU=0.7501
# [TRAIN] Epoch 149/150 | Batch 130/153 | Loss_1=0.1739 | Loss_2=0.1302 | Loss_3=0.1267 | Totol_Loss=0.2065 | Dice_coeff=0.8733 | IoU=0.7752
# [TRAIN] Epoch 149/150 | Batch 140/153 | Loss_1=0.1117 | Loss_2=0.0817 | Loss_3=0.0785 | Totol_Loss=0.1290 | Dice_coeff=0.9215 | IoU=0.8545
# [TRAIN] Epoch 149/150 | Batch 150/153 | Loss_1=0.1383 | Loss_2=0.1118 | Loss_3=0.1106 | Totol_Loss=0.1774 | Dice_coeff=0.8894 | IoU=0.8009
#  Train Loss_1: 0.1290 | Loss_2: 0.0944 | Loss_3: 0.0929 | Total_Loss: 0.1513 | Avg_dice_coeff: 0.9071 | Avg_IoU: 0.8313
# Running Validation...
#  Valid Loss_1: 0.2432 | Loss_2: 0.2060 | Loss_3: 0.2047
#  Total_Loss: 0.3261 | Dice_coeff: 0.7953 | IoU: 0.6698
# No improvement in validation loss for 25 epochs.
# Model saved to ==> 20-06-2025_08-37-31/model_epoch148.pt
# ========== Epoch 150 / 150 ==========
# Training...
# [TRAIN] Epoch 150/150 | Batch 10/153 | Loss_1=0.1296 | Loss_2=0.0951 | Loss_3=0.0951 | Totol_Loss=0.1539 | Dice_coeff=0.9049 | IoU=0.8263
# [TRAIN] Epoch 150/150 | Batch 20/153 | Loss_1=0.1259 | Loss_2=0.1056 | Loss_3=0.1050 | Totol_Loss=0.1674 | Dice_coeff=0.8950 | IoU=0.8100
# [TRAIN] Epoch 150/150 | Batch 30/153 | Loss_1=0.1109 | Loss_2=0.0722 | Loss_3=0.0709 | Totol_Loss=0.1176 | Dice_coeff=0.9291 | IoU=0.8675
# [TRAIN] Epoch 150/150 | Batch 40/153 | Loss_1=0.1091 | Loss_2=0.0759 | Loss_3=0.0732 | Totol_Loss=0.1210 | Dice_coeff=0.9268 | IoU=0.8636
# [TRAIN] Epoch 150/150 | Batch 50/153 | Loss_1=0.1586 | Loss_2=0.1178 | Loss_3=0.1172 | Totol_Loss=0.1897 | Dice_coeff=0.8828 | IoU=0.7902
# [TRAIN] Epoch 150/150 | Batch 60/153 | Loss_1=0.1405 | Loss_2=0.1142 | Loss_3=0.1132 | Totol_Loss=0.1814 | Dice_coeff=0.8868 | IoU=0.7966
# [TRAIN] Epoch 150/150 | Batch 70/153 | Loss_1=0.1302 | Loss_2=0.0898 | Loss_3=0.0898 | Totol_Loss=0.1466 | Dice_coeff=0.9102 | IoU=0.8352
# [TRAIN] Epoch 150/150 | Batch 80/153 | Loss_1=0.1134 | Loss_2=0.0929 | Loss_3=0.0933 | Totol_Loss=0.1486 | Dice_coeff=0.9067 | IoU=0.8294
# [TRAIN] Epoch 150/150 | Batch 90/153 | Loss_1=0.1710 | Loss_2=0.1269 | Loss_3=0.1227 | Totol_Loss=0.2009 | Dice_coeff=0.8773 | IoU=0.7814
# [TRAIN] Epoch 150/150 | Batch 100/153 | Loss_1=0.1240 | Loss_2=0.0988 | Loss_3=0.0973 | Totol_Loss=0.1566 | Dice_coeff=0.9027 | IoU=0.8227
# [TRAIN] Epoch 150/150 | Batch 110/153 | Loss_1=0.1199 | Loss_2=0.0866 | Loss_3=0.0847 | Totol_Loss=0.1385 | Dice_coeff=0.9153 | IoU=0.8439
# [TRAIN] Epoch 150/150 | Batch 120/153 | Loss_1=0.1437 | Loss_2=0.1118 | Loss_3=0.1120 | Totol_Loss=0.1797 | Dice_coeff=0.8880 | IoU=0.7985
# [TRAIN] Epoch 150/150 | Batch 130/153 | Loss_1=0.1375 | Loss_2=0.0922 | Loss_3=0.0869 | Totol_Loss=0.1457 | Dice_coeff=0.9131 | IoU=0.8402
# [TRAIN] Epoch 150/150 | Batch 140/153 | Loss_1=0.1771 | Loss_2=0.1225 | Loss_3=0.1205 | Totol_Loss=0.1979 | Dice_coeff=0.8795 | IoU=0.7849
# [TRAIN] Epoch 150/150 | Batch 150/153 | Loss_1=0.0850 | Loss_2=0.0560 | Loss_3=0.0568 | Totol_Loss=0.0928 | Dice_coeff=0.9432 | IoU=0.8925
#  Train Loss_1: 0.1302 | Loss_2: 0.0951 | Loss_3: 0.0935 | Total_Loss: 0.1524 | Avg_dice_coeff: 0.9065 | Avg_IoU: 0.8301
# Running Validation...
#  Valid Loss_1: 0.2432 | Loss_2: 0.2060 | Loss_3: 0.2046
#  Total_Loss: 0.3259 | Dice_coeff: 0.7954 | IoU: 0.6699
# No improvement in validation loss for 26 epochs.
# Model saved to ==> 20-06-2025_08-37-31/model_epoch149.pt
# Training complete!

# %%
trainer.visualize_scores()

# %%
test_loader = DataLoader(dataset=valid_dataset, batch_size=1, shuffle=False)

trainer.eval(test_loader)
# Out:
# [Test] Batch 100/611 | Test Loss_1=0.0697 | Loss_2=0.0757 | Loss_3=0.0758 | Total_Loss=0.1172
# [Test] Batch 200/611 | Test Loss_1=0.2580 | Loss_2=0.4590 | Loss_3=0.4646 | Total_Loss=0.6895
# [Test] Batch 300/611 | Test Loss_1=0.6500 | Loss_2=0.6164 | Loss_3=0.6100 | Total_Loss=0.9606
# [Test] Batch 400/611 | Test Loss_1=0.3067 | Loss_2=0.3355 | Loss_3=0.3425 | Total_Loss=0.5258
# [Test] Batch 500/611 | Test Loss_1=0.1398 | Loss_2=0.0825 | Loss_3=0.0780 | Total_Loss=0.1333
# [Test] Batch 600/611 | Test Loss_1=0.4309 | Loss_2=0.3743 | Loss_3=0.3634 | Total_Loss=0.5820
#  Test Loss_1: 0.3089 | Loss_2: 0.2695 | Loss_2: 0.2675
#  Total_Loss: 0.4247 | Dice_coeff: 0.7325 | IoU: 0.6388

# %%
width = 4
columns = 3
n_examples = 12

fig, axs = plt.subplots(columns, width, figsize=(3*width , 3*columns), constrained_layout=True)
red_patch = mpatches.Patch(color='red', label='The red data')
fig.legend(loc='upper right',handles=[
    mpatches.Patch(color='red', label='Ground truth'),
    mpatches.Patch(color='green', label='Predicted abnormality')])
i = 0
with torch.no_grad():
    for data in test_loader:
        image, mask = data
        image, mask = image.to(config.DEVICE), mask.to(config.DEVICE)
        
        if not mask.byte().any():
            continue
        image = image.to(config.DEVICE)
        s = torch.zeros_like(mask).to(config.DEVICE)
        h = torch.zeros(mask.size(0), 512, 16, 16).to(config.DEVICE)
        prediction = trainer.model(image, h, s)[-1][0][0]
        prediction = torch.where(prediction > 0.5, 1, 0)
        # prediction_edges = prediction - binary_dilation(prediction)
        # ground_truth = mask - binary_dilation(mask)
        # image[0, 0, ground_truth.bool()[0]] = 255
        # image[0, 1, prediction_edges.bool()] = 255
        
        axs[i//width][i%width].imshow(image[0].to('cpu').permute(1, 2, 0))
        axs[i//width][i%width].imshow(mask.cpu()[0][0], alpha=0.5)
        axs[i//width][i%width].imshow(prediction.cpu(), alpha=0.5)
        # axs[i//width][i%width].imshow(prediction.unsqueeze(0).to('cpu').permute(1, 2, 0), alpha=0.2)
        if n_examples == i + 1:
            break
        i += 1
